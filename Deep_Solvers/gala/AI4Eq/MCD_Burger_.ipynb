# %%
import os
import re

os.chdir("../..")

import torch
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset

from collections import OrderedDict

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from pyDOE import lhs
from scipy.stats import uniform,norm
from scipy.interpolate import griddata

from gala.Galab import llaplace
from NN import DNN

np.random.seed(1234)

# CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")

# %% [markdown]
# ## Burgers Equation
#
# $$\frac{\partial u}{\partial t} + u\frac{\partial u}{\partial x} - \frac{0.01}{\pi}\frac{\partial^{2} u}{\partial x^{2}}=0$$
# $$u(x,0) = -sin( \pi x),  u(-1,t)=u(1,t)=0$$

# %% [markdown]
# ## Feed Forward Neural Network

# %%
# Deep neural network
class DNN(torch.nn.Module):
    def __init__(self, layers):
        super(DNN, self).__init__()

        # Number of layers
        self.depth = len(layers) - 1
        
        # Activation Function
        self.activation = torch.nn.Tanh
        
        # The following loop organized the layers of the NN         
        layer_list = list()
        for i in range(self.depth - 1): 
            layer_list.append(
                ('layer_%d' % i, torch.nn.Linear(layers[i], layers[i+1])))
            layer_list.append(('activation_%d' % i, self.activation()))
        layer_list.append(
            ('layer_%d' % (self.depth - 1), torch.nn.Linear(layers[-2], layers[-1]))
        )
        layerDict = OrderedDict(layer_list)
        
        # Deploy layers
        self.layers = torch.nn.Sequential(layerDict)

    def forward(self, x):
        out = self.layers(x)
        return out

# %%
# Deep neural network
class Dropout_DNN(torch.nn.Module):
    def __init__(self, layers):
        super(Dropout_DNN, self).__init__()

        # Number of layers
        self.depth = len(layers) - 1
        
        # Activation Function
        self.activation = torch.nn.Tanh
        
        # The following loop organized the layers of the NN         
        layer_list = list()
        for i in range(self.depth - 1): 
            layer_list.append(('layer_%d' % i, torch.nn.Linear(layers[i], layers[i+1])))
            layer_list.append(('activation_%d' % i, self.activation()))
            layer_list.append(('dropout_%d' % i, torch.nn.Dropout(p = 0.5)))

        layer_list.append(
            ('layer_%d' % (self.depth - 1), torch.nn.Linear(layers[-2], layers[-1]))
        )
        layerDict = OrderedDict(layer_list)
        
        # Deploy layers
        self.layers = torch.nn.Sequential(layerDict)

    def forward(self, x):
        out = self.layers(x)
        return out

# %% [markdown]
# ## Parametric PINN for Inverse Problems

# %%
def de(self,data_domain):
    """ The pytorch autograd version of calculating residual """
    u = self(data_domain)
    
    du = torch.autograd.grad(
        u, data_domain, 
        grad_outputs=torch.ones_like(u),
        retain_graph=True,
        create_graph=True
    )[0]

    ddu_x = torch.autograd.grad(
        du[:,0],data_domain, 
        grad_outputs=torch.ones_like(du[:,0]),
        retain_graph=True,
        create_graph=True
        )[0]
    
    f = du[:,1].reshape(-1,1) + u.reshape(-1,1)*du[:,0].reshape(-1,1) - data_domain[:,2].reshape(-1,1)*ddu_x[:,0].reshape(-1,1)

    return f

def ini_c(self,data_inic):
    u = self(data_inic)
    return u

def left_bc(self,data_lbc):
    u = self(data_lbc)
    return u

def right_bc(self,data_rbc):
    u = self(data_rbc)
    return u

# %%
DNN.de = de
DNN.ini_c = ini_c
DNN.left_bc = left_bc
DNN.right_bc = right_bc

Dropout_DNN.de = de
Dropout_DNN.ini_c = ini_c
Dropout_DNN.left_bc = left_bc
Dropout_DNN.right_bc = right_bc

# %%
def samples_space(size,maxl=1):
    t_f_train = lhs(2, size)*maxl
    t_f_train[:,0] = t_f_train[:,0]*(2)-1
    t_f_train[:,1] = t_f_train[:,1]*(0.5)
    return t_f_train

def samples_param(min,max,size = 100):
    return np.random.uniform(min,max,size = size)

# %%
def data_pde(size,minp,maxp):

    xy, param = samples_space(size),samples_param(minp,maxp,(size,1)).reshape(-1,1)
    pde_domain = torch.tensor(np.hstack((xy,param.reshape(-1,1)))).float()
    
    x,y, param  = torch.tensor(xy[:,0]).reshape(-1,1),torch.tensor(xy[:,1]).reshape(-1,1),torch.tensor(param).reshape(-1,1)
    
    ini = torch.sin(torch.pi*x).reshape(-1,1) + torch.normal(mean = torch.tensor(0.0),std = torch.tensor(0.005)).reshape(-1,1)
    
    ini_c = torch.cat([ini,torch.zeros_like(x).float(),param],axis = 1).float()

    left_bc = torch.cat([torch.ones_like(x).float()*(-1),y, param],axis = 1).float()

    right_bc = torch.cat([torch.ones_like(x).float(),y, param],axis = 1).float()

    return pde_domain,ini_c,left_bc,right_bc

# %%
def data_pde2(size,minp,maxp):

    xy, param = samples_space(size),samples_param(minp,maxp,(size,1)).reshape(-1,1)
    pde_domain = torch.tensor(np.hstack((xy,param.reshape(-1,1)))).float()
    
    x,y, param  = torch.tensor(xy[:,0]).reshape(-1,1),torch.tensor(xy[:,1]).reshape(-1,1),torch.tensor(param).reshape(-1,1)
    
    ini = torch.sin(torch.pi*x).reshape(-1,1) 
    ini_c = torch.cat([ini,torch.zeros_like(x).float(),param],axis = 1).float()

    left_bc = torch.cat([torch.ones_like(x).float()*(-1),y, param],axis = 1).float()

    right_bc = torch.cat([torch.ones_like(x).float(),y, param],axis = 1).float()

    return pde_domain,ini_c,left_bc,right_bc

# %%
pde_domain,ini_c,left_bc,right_bc = data_pde(5,0.0001, 0.05)
pde_domain,ini_c2,left_bc,right_bc = data_pde2(5,0.0001, 0.05)
print(ini_c)
print(ini_c2)
plt.plot(ini_c2[:,0])
plt.plot(ini_c[:,0])
# Out:
# tensor([[ 0.1772,  0.0000,  0.0142],
#         [-0.9922,  0.0000,  0.0271],
#         [-0.5705,  0.0000,  0.0202],
#         [ 0.8289,  0.0000,  0.0153],
#         [-0.7031,  0.0000,  0.0441]])
# tensor([[ 0.9992,  0.0000,  0.0467],
#         [-0.5150,  0.0000,  0.0232],
#         [-0.9891,  0.0000,  0.0287],
#         [ 0.4327,  0.0000,  0.0174],
#         [-0.0313,  0.0000,  0.0281]])

# %%
def data_pde2(size,minp,maxp):

    xy, param = samples_space(size),samples_param(minp,maxp,(size,1)).reshape(-1,1)
    pde_domain = torch.tensor(np.hstack((xy,param.reshape(-1,1)))).float()
    
    x,y, param  = torch.tensor(xy[:,0]).reshape(-1,1),torch.tensor(xy[:,1]).reshape(-1,1),torch.tensor(param).reshape(-1,1)
    
    ini = torch.sin(torch.pi*x).reshape(-1,1) 
    ini_c = torch.cat([ini,torch.zeros_like(x).float(),param],axis = 1).float()

    left_bc = torch.cat([torch.ones_like(x).float()*(-1),y, param],axis = 1).float()

    right_bc = torch.cat([torch.ones_like(x).float(),y, param],axis = 1).float()

    return pde_domain,ini_c,left_bc,right_bc

# %%
def train_adam(pinn,loss,optimizer,epochs, sample_size = 100,minval_param = 0.2,maxval_param = 2,repetitions=1):
      print("Starting Adam Training")
      train_loss=[]
      for i in range(epochs):
        pde_domain,ini_c,left_bc,right_bc = data_pde(sample_size,minval_param,maxval_param)
        
        pde_domain,ini_c = Variable(pde_domain,requires_grad=True),Variable(ini_c,requires_grad=True)
        left_bc,right_bc = Variable(left_bc,requires_grad=True),Variable(right_bc,requires_grad=True)
        
        for _ in range(repetitions):
                optimizer.zero_grad()

                pde_pred,ini_c_pred = pinn.de(pde_domain), pinn.ini_c(ini_c)
                left_bc_pred,right_bc_pred = pinn.left_bc(left_bc),pinn.right_bc(right_bc)

                loss_pde,loss_ini = loss(pde_pred,torch.zeros_like(pde_pred)),loss(ini_c_pred,torch.zeros_like(pde_pred))
                loss_lbc,loss_rbc = loss(left_bc_pred,torch.zeros_like(pde_pred)),loss(right_bc_pred,torch.zeros_like(pde_pred))

                Loss =  loss_pde + loss_ini + loss_lbc + loss_rbc
                train_loss.append(Loss.item())
                if i % 10 == 0:
                        print('Iter %d, Loss: %.5e, Loss_PDE: %.5e, Loss_ini: %.5e, Loss_lbc: %.5e,Loss_rbc: %.5e' % (i, 
                                                                         Loss.item(),loss_pde.item(),loss_ini.item(), loss_lbc.item(), loss_rbc.item()))
                                
                Loss.backward() 

                optimizer.step() 

                #sheduler.step()
      return train_loss

# %%
def train_LBFGS(pinn,loss,optimizer, sample_size = 100, minval_param = 0.2,maxval_param = 2):
    print("Starting Training: LBFGS optimizer")
    train_loss=[]

    pde_domain,ini_c,left_bc,right_bc = data_pde(sample_size,minval_param,maxval_param)
    
    pde_domain,ini_c = Variable(pde_domain,requires_grad=True),Variable(ini_c,requires_grad=True)
    left_bc,right_bc = Variable(left_bc,requires_grad=True),Variable(right_bc,requires_grad=True)
    

    def loss_func_train():
        optimizer.zero_grad()
        
        pde_pred,ini_c_pred = pinn.de(pde_domain), pinn.ini_c(ini_c)
        left_bc_pred,right_bc_pred = pinn.left_bc(left_bc),pinn.right_bc(right_bc)

        loss_pde,loss_ini = loss(pde_pred,torch.zeros_like(pde_pred)),loss(ini_c_pred,torch.zeros_like(pde_pred))
        loss_lbc,loss_rbc = loss(left_bc_pred,torch.zeros_like(pde_pred)),loss(right_bc_pred,torch.zeros_like(pde_pred))

        Loss =  loss_pde + loss_ini + loss_lbc + loss_rbc
        train_loss.append(Loss.item())

        print('Loss: %.5e, Loss_PDE: %.5e, Loss_ini: %.5e, Loss_lbc: %.5e,Loss_rbc: %.5e' % ( 
                                                            Loss.item(),loss_pde.item(),loss_ini.item(), loss_lbc.item(), loss_rbc.item()))

        Loss.backward() 

        return Loss

    optimizer.step(loss_func_train) 
    return train_loss

# %%
# Number of observations
epochs = 1200
nobs = 3000
#nobs = 500
lr = 0.01

min_param , max_param = 0.0001, 0.05

layers = [3] + 3*[40] + [1]

model = DNN(layers)

# model.load_state_dict(torch.load(f"../Projects-1/Physics _Informed_NN/GaLA/Gala_models/BurgEq_4_30.pt"))
# model.eval()

# %%
loss = torch.nn.MSELoss(reduction ='mean')

optimizer = torch.optim.Adam(model.parameters(), lr = lr)

loss_history = train_adam(model,loss,optimizer,epochs, nobs,min_param,max_param)

optimizer = torch.optim.LBFGS(
    model.parameters(), lr=lr, max_iter=50000, max_eval=None, tolerance_grad=1e-5, tolerance_change=1.0 * np.finfo(float).eps,line_search_fn="strong_wolfe" 
    )

loss_history_b = train_LBFGS(model,loss,optimizer, nobs*2,min_param,max_param)
# Out:
# Starting Adam Training
# Iter 0, Loss: 7.61662e-02, Loss_PDE: 2.91117e-03, Loss_ini: 2.20141e-02, Loss_lbc: 1.17608e-04,Loss_rbc: 5.11233e-02
# Iter 10, Loss: 1.14964e-02, Loss_PDE: 4.98784e-05, Loss_ini: 2.29077e-03, Loss_lbc: 3.40960e-03,Loss_rbc: 5.74616e-03
# Iter 20, Loss: 3.38170e-03, Loss_PDE: 1.15502e-04, Loss_ini: 8.23686e-04, Loss_lbc: 2.49500e-04,Loss_rbc: 2.19301e-03
# Iter 30, Loss: 2.27265e-04, Loss_PDE: 4.61470e-05, Loss_ini: 5.00710e-05, Loss_lbc: 2.77653e-05,Loss_rbc: 1.03282e-04
# Iter 40, Loss: 1.28455e-04, Loss_PDE: 6.30387e-06, Loss_ini: 3.12153e-05, Loss_lbc: 1.14842e-06,Loss_rbc: 8.97874e-05
# Iter 50, Loss: 8.65063e-05, Loss_PDE: 7.76838e-07, Loss_ini: 2.00967e-05, Loss_lbc: 5.24350e-05,Loss_rbc: 1.31978e-05
# Iter 60, Loss: 2.29078e-05, Loss_PDE: 6.15331e-06, Loss_ini: 3.67779e-06, Loss_lbc: 1.19273e-05,Loss_rbc: 1.14936e-06
# Iter 70, Loss: 9.96200e-06, Loss_PDE: 1.21424e-06, Loss_ini: 3.67254e-06, Loss_lbc: 6.17316e-08,Loss_rbc: 5.01349e-06
# Iter 80, Loss: 3.23114e-06, Loss_PDE: 5.86079e-07, Loss_ini: 1.30245e-06, Loss_lbc: 3.51695e-08,Loss_rbc: 1.30744e-06
# Iter 90, Loss: 2.19587e-06, Loss_PDE: 7.69595e-07, Loss_ini: 5.03752e-07, Loss_lbc: 6.52257e-07,Loss_rbc: 2.70264e-07
# Iter 100, Loss: 1.11331e-06, Loss_PDE: 5.07303e-07, Loss_ini: 3.76918e-07, Loss_lbc: 1.39614e-07,Loss_rbc: 8.94753e-08
# Iter 110, Loss: 9.80409e-07, Loss_PDE: 4.96326e-07, Loss_ini: 3.43729e-07, Loss_lbc: 6.90051e-08,Loss_rbc: 7.13493e-08
# Iter 120, Loss: 7.74733e-07, Loss_PDE: 4.71288e-07, Loss_ini: 2.15755e-07, Loss_lbc: 4.54065e-08,Loss_rbc: 4.22829e-08
# Iter 130, Loss: 7.72930e-07, Loss_PDE: 4.41799e-07, Loss_ini: 1.84789e-07, Loss_lbc: 3.27291e-08,Loss_rbc: 1.13612e-07
# Iter 140, Loss: 7.08932e-07, Loss_PDE: 4.15411e-07, Loss_ini: 1.93777e-07, Loss_lbc: 5.01244e-08,Loss_rbc: 4.96196e-08
# Iter 150, Loss: 6.88482e-07, Loss_PDE: 3.99333e-07, Loss_ini: 2.10791e-07, Loss_lbc: 3.98994e-08,Loss_rbc: 3.84584e-08
# Iter 160, Loss: 6.66329e-07, Loss_PDE: 3.88906e-07, Loss_ini: 1.93177e-07, Loss_lbc: 3.26228e-08,Loss_rbc: 5.16221e-08
# Iter 170, Loss: 6.40110e-07, Loss_PDE: 3.71313e-07, Loss_ini: 1.83855e-07, Loss_lbc: 3.56112e-08,Loss_rbc: 4.93308e-08
# Iter 180, Loss: 6.13040e-07, Loss_PDE: 3.48799e-07, Loss_ini: 1.84013e-07, Loss_lbc: 3.70221e-08,Loss_rbc: 4.32058e-08
# Iter 190, Loss: 5.87416e-07, Loss_PDE: 3.36396e-07, Loss_ini: 1.79940e-07, Loss_lbc: 3.02003e-08,Loss_rbc: 4.08795e-08
# Iter 200, Loss: 5.69218e-07, Loss_PDE: 3.23407e-07, Loss_ini: 1.68108e-07, Loss_lbc: 3.41335e-08,Loss_rbc: 4.35687e-08
# Iter 210, Loss: 5.47858e-07, Loss_PDE: 3.04962e-07, Loss_ini: 1.71422e-07, Loss_lbc: 3.24502e-08,Loss_rbc: 3.90243e-08
# Iter 220, Loss: 5.21798e-07, Loss_PDE: 2.89737e-07, Loss_ini: 1.67151e-07, Loss_lbc: 2.82648e-08,Loss_rbc: 3.66452e-08
# Iter 230, Loss: 4.98858e-07, Loss_PDE: 2.73204e-07, Loss_ini: 1.56266e-07, Loss_lbc: 3.12460e-08,Loss_rbc: 3.81425e-08
# Iter 240, Loss: 4.92308e-07, Loss_PDE: 2.70962e-07, Loss_ini: 1.55675e-07, Loss_lbc: 2.96748e-08,Loss_rbc: 3.59959e-08
# Iter 250, Loss: 4.67899e-07, Loss_PDE: 2.55194e-07, Loss_ini: 1.50010e-07, Loss_lbc: 2.75984e-08,Loss_rbc: 3.50967e-08
# Iter 260, Loss: 4.44642e-07, Loss_PDE: 2.40390e-07, Loss_ini: 1.43020e-07, Loss_lbc: 2.80785e-08,Loss_rbc: 3.31535e-08
# Iter 270, Loss: 4.25387e-07, Loss_PDE: 2.29338e-07, Loss_ini: 1.39021e-07, Loss_lbc: 2.57609e-08,Loss_rbc: 3.12669e-08
# Iter 280, Loss: 4.13037e-07, Loss_PDE: 2.17736e-07, Loss_ini: 1.38221e-07, Loss_lbc: 2.61244e-08,Loss_rbc: 3.09560e-08
# Iter 290, Loss: 3.92441e-07, Loss_PDE: 2.07161e-07, Loss_ini: 1.28884e-07, Loss_lbc: 2.63318e-08,Loss_rbc: 3.00641e-08
# Iter 300, Loss: 3.76229e-07, Loss_PDE: 1.94887e-07, Loss_ini: 1.32288e-07, Loss_lbc: 2.23459e-08,Loss_rbc: 2.67080e-08
# Iter 310, Loss: 3.53767e-07, Loss_PDE: 1.80364e-07, Loss_ini: 1.18693e-07, Loss_lbc: 2.61021e-08,Loss_rbc: 2.86079e-08
# Iter 320, Loss: 3.43777e-07, Loss_PDE: 1.75872e-07, Loss_ini: 1.23343e-07, Loss_lbc: 2.04100e-08,Loss_rbc: 2.41524e-08
# Iter 330, Loss: 3.28968e-07, Loss_PDE: 1.67764e-07, Loss_ini: 1.13431e-07, Loss_lbc: 2.20544e-08,Loss_rbc: 2.57190e-08
# Iter 340, Loss: 3.17128e-07, Loss_PDE: 1.59755e-07, Loss_ini: 1.13341e-07, Loss_lbc: 2.05280e-08,Loss_rbc: 2.35029e-08
# Iter 350, Loss: 2.97934e-07, Loss_PDE: 1.50176e-07, Loss_ini: 1.05777e-07, Loss_lbc: 1.99222e-08,Loss_rbc: 2.20597e-08
# Iter 360, Loss: 2.84019e-07, Loss_PDE: 1.42388e-07, Loss_ini: 9.97293e-08, Loss_lbc: 1.98997e-08,Loss_rbc: 2.20021e-08
# Iter 370, Loss: 2.73216e-07, Loss_PDE: 1.34570e-07, Loss_ini: 1.00590e-07, Loss_lbc: 1.77981e-08,Loss_rbc: 2.02575e-08
# Iter 380, Loss: 2.58160e-07, Loss_PDE: 1.26621e-07, Loss_ini: 9.28514e-08, Loss_lbc: 1.87864e-08,Loss_rbc: 1.99014e-08
# Iter 390, Loss: 2.48043e-07, Loss_PDE: 1.20116e-07, Loss_ini: 8.84869e-08, Loss_lbc: 1.88455e-08,Loss_rbc: 2.05946e-08
# Iter 400, Loss: 2.34470e-07, Loss_PDE: 1.10675e-07, Loss_ini: 9.11612e-08, Loss_lbc: 1.54255e-08,Loss_rbc: 1.72078e-08
# Iter 410, Loss: 2.25129e-07, Loss_PDE: 1.08244e-07, Loss_ini: 8.29182e-08, Loss_lbc: 1.63437e-08,Loss_rbc: 1.76224e-08
# Iter 420, Loss: 2.13158e-07, Loss_PDE: 9.94428e-08, Loss_ini: 8.08866e-08, Loss_lbc: 1.57885e-08,Loss_rbc: 1.70401e-08
# Iter 430, Loss: 2.02368e-07, Loss_PDE: 9.59566e-08, Loss_ini: 7.88361e-08, Loss_lbc: 1.30701e-08,Loss_rbc: 1.45056e-08
# Iter 440, Loss: 1.94490e-07, Loss_PDE: 9.04631e-08, Loss_ini: 7.59204e-08, Loss_lbc: 1.33295e-08,Loss_rbc: 1.47766e-08
# Iter 450, Loss: 1.82310e-07, Loss_PDE: 8.40741e-08, Loss_ini: 6.86617e-08, Loss_lbc: 1.43514e-08,Loss_rbc: 1.52228e-08
# Iter 460, Loss: 1.73415e-07, Loss_PDE: 7.85336e-08, Loss_ini: 6.79060e-08, Loss_lbc: 1.32342e-08,Loss_rbc: 1.37413e-08
# Iter 470, Loss: 1.63934e-07, Loss_PDE: 7.36882e-08, Loss_ini: 6.49293e-08, Loss_lbc: 1.24244e-08,Loss_rbc: 1.28917e-08
# Iter 480, Loss: 1.58651e-07, Loss_PDE: 7.11412e-08, Loss_ini: 6.02994e-08, Loss_lbc: 1.35902e-08,Loss_rbc: 1.36207e-08
# Iter 490, Loss: 1.47516e-07, Loss_PDE: 6.51545e-08, Loss_ini: 5.85902e-08, Loss_lbc: 1.18886e-08,Loss_rbc: 1.18828e-08
# Iter 500, Loss: 1.41385e-07, Loss_PDE: 6.18925e-08, Loss_ini: 5.79945e-08, Loss_lbc: 1.04489e-08,Loss_rbc: 1.10490e-08
# Iter 510, Loss: 1.32454e-07, Loss_PDE: 5.77816e-08, Loss_ini: 5.37817e-08, Loss_lbc: 1.05479e-08,Loss_rbc: 1.03429e-08
# Iter 520, Loss: 1.25094e-07, Loss_PDE: 5.39209e-08, Loss_ini: 5.07902e-08, Loss_lbc: 1.03685e-08,Loss_rbc: 1.00141e-08
# Iter 530, Loss: 1.17734e-07, Loss_PDE: 5.02099e-08, Loss_ini: 4.90792e-08, Loss_lbc: 9.23526e-09,Loss_rbc: 9.20941e-09
# Iter 540, Loss: 1.11481e-07, Loss_PDE: 4.70602e-08, Loss_ini: 4.69481e-08, Loss_lbc: 8.71004e-09,Loss_rbc: 8.76286e-09
# Iter 550, Loss: 1.06504e-07, Loss_PDE: 4.44763e-08, Loss_ini: 4.48046e-08, Loss_lbc: 8.64964e-09,Loss_rbc: 8.57340e-09
# Iter 560, Loss: 1.01958e-07, Loss_PDE: 4.28063e-08, Loss_ini: 4.29367e-08, Loss_lbc: 8.20520e-09,Loss_rbc: 8.00996e-09
# Iter 570, Loss: 9.51381e-08, Loss_PDE: 3.90584e-08, Loss_ini: 4.10684e-08, Loss_lbc: 7.64228e-09,Loss_rbc: 7.36899e-09
# Iter 580, Loss: 9.09304e-08, Loss_PDE: 3.78310e-08, Loss_ini: 3.86811e-08, Loss_lbc: 7.38637e-09,Loss_rbc: 7.03197e-09
# Iter 590, Loss: 8.62367e-08, Loss_PDE: 3.55874e-08, Loss_ini: 3.64652e-08, Loss_lbc: 7.39632e-09,Loss_rbc: 6.78781e-09
# Iter 600, Loss: 8.14527e-08, Loss_PDE: 3.28254e-08, Loss_ini: 3.55956e-08, Loss_lbc: 6.73804e-09,Loss_rbc: 6.29365e-09
# Iter 610, Loss: 7.73792e-08, Loss_PDE: 3.13720e-08, Loss_ini: 3.30534e-08, Loss_lbc: 6.75822e-09,Loss_rbc: 6.19555e-09
# Iter 620, Loss: 7.19040e-08, Loss_PDE: 2.89166e-08, Loss_ini: 3.15346e-08, Loss_lbc: 5.83947e-09,Loss_rbc: 5.61332e-09
# Iter 630, Loss: 6.93483e-08, Loss_PDE: 2.83878e-08, Loss_ini: 2.91623e-08, Loss_lbc: 6.24516e-09,Loss_rbc: 5.55310e-09
# Iter 640, Loss: 6.44923e-08, Loss_PDE: 2.57284e-08, Loss_ini: 2.73482e-08, Loss_lbc: 6.09403e-09,Loss_rbc: 5.32166e-09
# Iter 650, Loss: 6.25866e-08, Loss_PDE: 2.55193e-08, Loss_ini: 2.68427e-08, Loss_lbc: 5.50328e-09,Loss_rbc: 4.72136e-09
# Iter 660, Loss: 5.81383e-08, Loss_PDE: 2.32591e-08, Loss_ini: 2.60767e-08, Loss_lbc: 4.58615e-09,Loss_rbc: 4.21633e-09
# Iter 670, Loss: 5.48541e-08, Loss_PDE: 2.17801e-08, Loss_ini: 2.33890e-08, Loss_lbc: 5.22470e-09,Loss_rbc: 4.46034e-09
# Iter 680, Loss: 5.25247e-08, Loss_PDE: 2.07379e-08, Loss_ini: 2.23839e-08, Loss_lbc: 5.08031e-09,Loss_rbc: 4.32262e-09
# Iter 690, Loss: 4.96635e-08, Loss_PDE: 2.02143e-08, Loss_ini: 2.11256e-08, Loss_lbc: 4.48500e-09,Loss_rbc: 3.83856e-09
# Iter 700, Loss: 4.70917e-08, Loss_PDE: 1.92509e-08, Loss_ini: 1.98037e-08, Loss_lbc: 4.41927e-09,Loss_rbc: 3.61791e-09
# Iter 710, Loss: 4.59072e-08, Loss_PDE: 1.91517e-08, Loss_ini: 1.96333e-08, Loss_lbc: 3.87605e-09,Loss_rbc: 3.24618e-09
# Iter 720, Loss: 4.18668e-08, Loss_PDE: 1.67236e-08, Loss_ini: 1.71051e-08, Loss_lbc: 4.53819e-09,Loss_rbc: 3.49997e-09
# Iter 730, Loss: 3.98432e-08, Loss_PDE: 1.62685e-08, Loss_ini: 1.68065e-08, Loss_lbc: 3.78099e-09,Loss_rbc: 2.98716e-09
# Iter 740, Loss: 3.76354e-08, Loss_PDE: 1.59374e-08, Loss_ini: 1.57568e-08, Loss_lbc: 3.27112e-09,Loss_rbc: 2.67014e-09
# Iter 750, Loss: 3.61769e-08, Loss_PDE: 1.52205e-08, Loss_ini: 1.50702e-08, Loss_lbc: 3.33528e-09,Loss_rbc: 2.55094e-09
# Iter 760, Loss: 3.37151e-08, Loss_PDE: 1.38634e-08, Loss_ini: 1.46096e-08, Loss_lbc: 2.93886e-09,Loss_rbc: 2.30319e-09
# Iter 770, Loss: 3.25975e-08, Loss_PDE: 1.38611e-08, Loss_ini: 1.33308e-08, Loss_lbc: 3.09284e-09,Loss_rbc: 2.31278e-09
# Iter 780, Loss: 3.06682e-08, Loss_PDE: 1.29895e-08, Loss_ini: 1.28485e-08, Loss_lbc: 2.77247e-09,Loss_rbc: 2.05783e-09
# Iter 790, Loss: 2.95370e-08, Loss_PDE: 1.31364e-08, Loss_ini: 1.19082e-08, Loss_lbc: 2.59525e-09,Loss_rbc: 1.89707e-09
# Iter 800, Loss: 2.76555e-08, Loss_PDE: 1.19721e-08, Loss_ini: 1.13964e-08, Loss_lbc: 2.44365e-09,Loss_rbc: 1.84338e-09
# Iter 810, Loss: 2.64824e-08, Loss_PDE: 1.16458e-08, Loss_ini: 1.08110e-08, Loss_lbc: 2.31991e-09,Loss_rbc: 1.70570e-09
# Iter 820, Loss: 2.56527e-08, Loss_PDE: 1.15245e-08, Loss_ini: 1.01291e-08, Loss_lbc: 2.27924e-09,Loss_rbc: 1.71987e-09
# Iter 830, Loss: 2.48634e-08, Loss_PDE: 1.17816e-08, Loss_ini: 9.32511e-09, Loss_lbc: 2.20097e-09,Loss_rbc: 1.55564e-09
# Iter 840, Loss: 2.38993e-08, Loss_PDE: 1.16537e-08, Loss_ini: 8.75176e-09, Loss_lbc: 2.05608e-09,Loss_rbc: 1.43780e-09
# Iter 850, Loss: 2.24232e-08, Loss_PDE: 1.08944e-08, Loss_ini: 8.07122e-09, Loss_lbc: 2.06118e-09,Loss_rbc: 1.39645e-09
# Iter 860, Loss: 2.19454e-08, Loss_PDE: 1.08478e-08, Loss_ini: 7.66404e-09, Loss_lbc: 2.03129e-09,Loss_rbc: 1.40228e-09
# Iter 870, Loss: 2.02149e-08, Loss_PDE: 1.00615e-08, Loss_ini: 7.21196e-09, Loss_lbc: 1.72118e-09,Loss_rbc: 1.22031e-09
# Iter 880, Loss: 1.98125e-08, Loss_PDE: 1.02161e-08, Loss_ini: 7.10768e-09, Loss_lbc: 1.48437e-09,Loss_rbc: 1.00436e-09
# Iter 890, Loss: 1.90374e-08, Loss_PDE: 1.00558e-08, Loss_ini: 6.52332e-09, Loss_lbc: 1.46425e-09,Loss_rbc: 9.93997e-10
# Iter 900, Loss: 1.75280e-08, Loss_PDE: 8.96188e-09, Loss_ini: 5.84819e-09, Loss_lbc: 1.65861e-09,Loss_rbc: 1.05935e-09
# Iter 910, Loss: 1.68350e-08, Loss_PDE: 8.77731e-09, Loss_ini: 5.43239e-09, Loss_lbc: 1.63325e-09,Loss_rbc: 9.92006e-10
# Iter 920, Loss: 1.61522e-08, Loss_PDE: 8.71203e-09, Loss_ini: 5.24073e-09, Loss_lbc: 1.34762e-09,Loss_rbc: 8.51777e-10
# Iter 930, Loss: 1.55812e-08, Loss_PDE: 8.55819e-09, Loss_ini: 4.70527e-09, Loss_lbc: 1.43350e-09,Loss_rbc: 8.84201e-10
# Iter 940, Loss: 1.53950e-08, Loss_PDE: 8.68460e-09, Loss_ini: 4.70576e-09, Loss_lbc: 1.24734e-09,Loss_rbc: 7.57314e-10
# Iter 950, Loss: 1.45886e-08, Loss_PDE: 8.32223e-09, Loss_ini: 4.39288e-09, Loss_lbc: 1.15613e-09,Loss_rbc: 7.17367e-10
# Iter 960, Loss: 1.40603e-08, Loss_PDE: 8.04975e-09, Loss_ini: 3.98409e-09, Loss_lbc: 1.29736e-09,Loss_rbc: 7.29132e-10
# Iter 970, Loss: 1.39375e-08, Loss_PDE: 8.43208e-09, Loss_ini: 3.67379e-09, Loss_lbc: 1.15149e-09,Loss_rbc: 6.80099e-10
# Iter 980, Loss: 1.33878e-08, Loss_PDE: 8.15184e-09, Loss_ini: 3.78782e-09, Loss_lbc: 8.79675e-10,Loss_rbc: 5.68495e-10
# Iter 990, Loss: 1.26665e-08, Loss_PDE: 7.83543e-09, Loss_ini: 3.26515e-09, Loss_lbc: 9.72697e-10,Loss_rbc: 5.93185e-10
# Iter 1000, Loss: 1.20797e-08, Loss_PDE: 7.45335e-09, Loss_ini: 3.17398e-09, Loss_lbc: 9.02024e-10,Loss_rbc: 5.50359e-10
# Iter 1010, Loss: 1.18365e-08, Loss_PDE: 7.54092e-09, Loss_ini: 2.84755e-09, Loss_lbc: 9.09440e-10,Loss_rbc: 5.38612e-10
# Iter 1020, Loss: 1.14866e-08, Loss_PDE: 7.42652e-09, Loss_ini: 2.78154e-09, Loss_lbc: 7.99879e-10,Loss_rbc: 4.78677e-10
# Iter 1030, Loss: 1.12327e-08, Loss_PDE: 7.39331e-09, Loss_ini: 2.45544e-09, Loss_lbc: 8.88645e-10,Loss_rbc: 4.95346e-10
# Iter 1040, Loss: 1.13090e-08, Loss_PDE: 7.69084e-09, Loss_ini: 2.38450e-09, Loss_lbc: 7.72689e-10,Loss_rbc: 4.60937e-10
# Iter 1050, Loss: 1.04329e-08, Loss_PDE: 6.97834e-09, Loss_ini: 2.34552e-09, Loss_lbc: 6.90036e-10,Loss_rbc: 4.19025e-10
# Iter 1060, Loss: 9.86980e-09, Loss_PDE: 6.64922e-09, Loss_ini: 1.97375e-09, Loss_lbc: 8.10780e-10,Loss_rbc: 4.36056e-10
# Iter 1070, Loss: 1.00186e-08, Loss_PDE: 6.96961e-09, Loss_ini: 2.05598e-09, Loss_lbc: 6.08184e-10,Loss_rbc: 3.84849e-10
# Iter 1080, Loss: 9.66421e-09, Loss_PDE: 6.81572e-09, Loss_ini: 1.81794e-09, Loss_lbc: 6.48521e-10,Loss_rbc: 3.82023e-10
# Iter 1090, Loss: 9.49550e-09, Loss_PDE: 6.77274e-09, Loss_ini: 1.72578e-09, Loss_lbc: 6.29810e-10,Loss_rbc: 3.67176e-10
# Iter 1100, Loss: 9.46527e-09, Loss_PDE: 6.90341e-09, Loss_ini: 1.56164e-09, Loss_lbc: 6.42631e-10,Loss_rbc: 3.57592e-10
# Iter 1110, Loss: 9.08685e-09, Loss_PDE: 6.65739e-09, Loss_ini: 1.55725e-09, Loss_lbc: 5.48331e-10,Loss_rbc: 3.23879e-10
# Iter 1120, Loss: 8.85530e-09, Loss_PDE: 6.57324e-09, Loss_ini: 1.36226e-09, Loss_lbc: 5.81285e-10,Loss_rbc: 3.38522e-10
# Iter 1130, Loss: 8.61582e-09, Loss_PDE: 6.49433e-09, Loss_ini: 1.29606e-09, Loss_lbc: 5.11574e-10,Loss_rbc: 3.13862e-10
# Iter 1140, Loss: 8.26595e-09, Loss_PDE: 6.22993e-09, Loss_ini: 1.21998e-09, Loss_lbc: 5.13411e-10,Loss_rbc: 3.02634e-10
# Iter 1150, Loss: 8.01997e-09, Loss_PDE: 6.09807e-09, Loss_ini: 1.11437e-09, Loss_lbc: 5.03697e-10,Loss_rbc: 3.03828e-10
# Iter 1160, Loss: 7.60638e-09, Loss_PDE: 5.78816e-09, Loss_ini: 1.05196e-09, Loss_lbc: 4.85137e-10,Loss_rbc: 2.81126e-10
# Iter 1170, Loss: 7.83163e-09, Loss_PDE: 6.09497e-09, Loss_ini: 9.79754e-10, Loss_lbc: 4.82149e-10,Loss_rbc: 2.74766e-10
# Iter 1180, Loss: 7.81349e-09, Loss_PDE: 6.16060e-09, Loss_ini: 9.52788e-10, Loss_lbc: 4.34606e-10,Loss_rbc: 2.65498e-10
# Iter 1190, Loss: 7.34774e-09, Loss_PDE: 5.80112e-09, Loss_ini: 8.40353e-10, Loss_lbc: 4.44343e-10,Loss_rbc: 2.61929e-10
# Starting Training: LBFGS optimizer
# Loss: 7.41626e-09, Loss_PDE: 5.91269e-09, Loss_ini: 8.28527e-10, Loss_lbc: 4.16388e-10,Loss_rbc: 2.58664e-10

# %%
#path = f"./gala/AI4eq/Models/burgers_{nobs}.pt"
# path = f"./gala/AI4eq/Models/burgers_mcd.pt"
# torch.save(model.state_dict(),path)

# %%
def MCD (dropout_model,X_star, samples = 1000):
    dropout_model.train()

    predictions = []

    for _ in range(samples):
        pred = dropout_model(X_star)  # Perform a forward pass with dropout
        predictions.append(pred.cpu().detach().numpy())  # Store the result

    predictions_mcd = np.array(predictions)
    return np.mean(predictions_mcd, axis=0),np.std(predictions_mcd, axis=0)

# %%
x = np.linspace(-1,1,100)
y = np.linspace(0,1,100)

xx, yy = np.meshgrid(x, y)
xx, yy = torch.tensor(xx).reshape(-1,1).float(),torch.tensor(yy).reshape(-1,1).float()


X_star = torch.cat([xx,yy,torch.ones_like(xx)*(0.005)],axis = 1)
mean, std = MCD (model,X_star, samples = 1000)

fig, axs = plt.subplots(2,1, figsize=(10, 5))

xx,yy = np.meshgrid(x, y)

U_pred = griddata(np.hstack([xx.reshape(-1,1),yy.reshape(-1,1)]), mean[:,0], (xx,yy), method='cubic')
U_sigma = griddata(np.hstack([xx.reshape(-1,1),yy.reshape(-1,1)]), std[:,0], (xx,yy), method='cubic')

axs[0].contourf(y.flatten(), x.flatten(), U_pred.T,cmap='rainbow')

axs[1].plot(x,U_pred[75,:])
axs[1].fill_between(x.reshape(-1), U_pred[75,:]+U_sigma[75,:],U_pred[75,:]-U_sigma[75,:],alpha=0.4, color = "red",label = r"NN Uncertainty ($\sigma^{2})$")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 9
#       5 xx, yy = torch.tensor(xx).reshape(-1,1).float(),torch.tensor(yy).reshape(-1,1).float()
#       8 X_star = torch.cat([xx,yy,torch.ones_like(xx)*(0.005)],axis = 1)
# ----> 9 mean, std = MCD (model,X_star, samples = 1000)
#      11 fig, axs = plt.subplots(2,1, figsize=(10, 5))
#      13 xx,yy = np.meshgrid(x, y)
#
# NameError: name 'MCD' is not defined

# %%
x = np.linspace(-1,1,100)
y = np.linspace(0,1,100)

xx, yy = np.meshgrid(x, y)
xx, yy = torch.tensor(xx).reshape(-1,1).float(),torch.tensor(yy).reshape(-1,1).float()


X_star = torch.cat([xx,yy,torch.ones_like(xx)*(0.01/np.pi)],axis = 1)

mean= model(X_star)

fig, axs = plt.subplots(1,1, figsize=(10, 5))

xx,yy = np.meshgrid(x, y)

U_pred = griddata(np.hstack([xx.reshape(-1,1),yy.reshape(-1,1)]), mean.detach().numpy().flatten(), (xx,yy), method='cubic')

axs.contourf(y.flatten(), x.flatten(), U_pred,cmap='rainbow')
