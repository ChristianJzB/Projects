# %%
import os
import re

os.chdir("../..")

import torch
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset

from collections import OrderedDict

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from pyDOE import lhs
from scipy.stats import uniform,norm
from scipy.interpolate import griddata

from gala.Galab import llaplace

np.random.seed(1234)

# CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")

# %% [markdown]
# ## Burgers Equation
#
# $$\frac{\partial u}{\partial t} + u\frac{\partial u}{\partial x} - \frac{0.01}{\pi}\frac{\partial^{2} u}{\partial x^{2}}=0$$
# $$u(x,0) = -sin( \pi x),  u(-1,t)=u(1,t)=0$$

# %% [markdown]
# ## Feed Forward Neural Network

# %%
# Deep neural network
class DNN(torch.nn.Module):
    def __init__(self, layers):
        super(DNN, self).__init__()

        # Number of layers
        self.depth = len(layers) - 1
        
        # Activation Function
        self.activation = torch.nn.Tanh
        
        # The following loop organized the layers of the NN         
        layer_list = list()
        for i in range(self.depth - 1): 
            layer_list.append(
                ('layer_%d' % i, torch.nn.Linear(layers[i], layers[i+1])))
            layer_list.append(('activation_%d' % i, self.activation()))
        layer_list.append(
            ('layer_%d' % (self.depth - 1), torch.nn.Linear(layers[-2], layers[-1]))
        )
        layerDict = OrderedDict(layer_list)
        
        # Deploy layers
        self.layers = torch.nn.Sequential(layerDict)

    def forward(self, x):
        out = self.layers(x)
        return out

# %%
# Deep neural network
class Dropout_DNN(torch.nn.Module):
    def __init__(self, layers):
        super(Dropout_DNN, self).__init__()

        # Number of layers
        self.depth = len(layers) - 1
        
        # Activation Function
        self.activation = torch.nn.Tanh
        
        # The following loop organized the layers of the NN         
        layer_list = list()
        for i in range(self.depth - 1): 
            layer_list.append(('layer_%d' % i, torch.nn.Linear(layers[i], layers[i+1])))
            layer_list.append(('activation_%d' % i, self.activation()))
            layer_list.append(('dropout_%d' % i, torch.nn.Dropout(p = 0.5)))

        layer_list.append(
            ('layer_%d' % (self.depth - 1), torch.nn.Linear(layers[-2], layers[-1]))
        )
        layerDict = OrderedDict(layer_list)
        
        # Deploy layers
        self.layers = torch.nn.Sequential(layerDict)

    def forward(self, x):
        out = self.layers(x)
        return out

# %% [markdown]
# ## Parametric PINN for Inverse Problems

# %%
def de(self,data_domain):
    """ The pytorch autograd version of calculating residual """
    u = self(data_domain)
    
    du = torch.autograd.grad(
        u, data_domain, 
        grad_outputs=torch.ones_like(u),
        retain_graph=True,
        create_graph=True
    )[0]

    ddu_x = torch.autograd.grad(
        du[:,0],data_domain, 
        grad_outputs=torch.ones_like(du[:,0]),
        retain_graph=True,
        create_graph=True
        )[0]
    
    f = du[:,1].reshape(-1,1) + u.reshape(-1,1)*du[:,0].reshape(-1,1) - data_domain[:,2].reshape(-1,1)*ddu_x[:,0].reshape(-1,1)

    return f

def ini_c(self,data_inic):
    u = self(data_inic)
    return u + torch.sin(torch.pi*data_inic[:,0].reshape(-1,1))

def left_bc(self,data_lbc):
    u = self(data_lbc)
    return u

def right_bc(self,data_rbc):
    u = self(data_rbc)
    return u

# %%
DNN.de = de
DNN.ini_c = ini_c
DNN.left_bc = left_bc
DNN.right_bc = right_bc

Dropout_DNN.de = de
Dropout_DNN.ini_c = ini_c
Dropout_DNN.left_bc = left_bc
Dropout_DNN.right_bc = right_bc

# %%
def samples_space(size,maxl = 1):
    t_f_train = lhs(2, size)*maxl
    t_f_train[:,0] = t_f_train[:,0]*(2)-1
    return t_f_train

def samples_param(min,max,size = 100):
    return np.random.uniform(min,max,size = size)

# %%
def data_pde(size,minp,maxp):

    xy, param = samples_space(size),samples_param(minp,maxp,(size,1)).reshape(-1,1)
    pde_domain = torch.tensor(np.hstack((xy,param.reshape(-1,1)))).float()
    
    x,y, param  = torch.tensor(xy[:,0]).reshape(-1,1),torch.tensor(xy[:,1]).reshape(-1,1),torch.tensor(param).reshape(-1,1)

    ini_c = torch.cat([x,torch.zeros_like(x).float(),param],axis = 1).float()

    left_bc = torch.cat([torch.ones_like(x).float()*(-1),y, param],axis = 1).float()

    right_bc = torch.cat([torch.ones_like(x).float(),y, param],axis = 1).float()

    return pde_domain,ini_c,left_bc,right_bc

# %%
def train_adam(pinn,loss,optimizer,epochs, sample_size = 100,minval_param = 0.2,maxval_param = 2,repetitions=1):
      print("Starting Adam Training")
      train_loss=[]
      for i in range(epochs):
        pde_domain,ini_c,left_bc,right_bc = data_pde(sample_size,minval_param,maxval_param)
        
        pde_domain,ini_c = Variable(pde_domain,requires_grad=True),Variable(ini_c,requires_grad=True)
        left_bc,right_bc = Variable(left_bc,requires_grad=True),Variable(right_bc,requires_grad=True)
        
        for _ in range(repetitions):
                optimizer.zero_grad()

                pde_pred,ini_c_pred = pinn.de(pde_domain), pinn.ini_c(ini_c)
                left_bc_pred,right_bc_pred = pinn.left_bc(left_bc),pinn.right_bc(right_bc)

                loss_pde,loss_ini = loss(pde_pred,torch.zeros_like(pde_pred)),loss(ini_c_pred,torch.zeros_like(pde_pred))
                loss_lbc,loss_rbc = loss(left_bc_pred,torch.zeros_like(pde_pred)),loss(right_bc_pred,torch.zeros_like(pde_pred))

                Loss =  loss_pde + loss_ini + loss_lbc + loss_rbc
                train_loss.append(Loss.item())
                if i % 10 == 0:
                        print('Iter %d, Loss: %.5e, Loss_PDE: %.5e, Loss_ini: %.5e, Loss_lbc: %.5e,Loss_rbc: %.5e' % (i, 
                                                                         Loss.item(),loss_pde.item(),loss_ini.item(), loss_lbc.item(), loss_rbc.item()))
                                
                Loss.backward() 

                optimizer.step() 

                #sheduler.step()
      return train_loss

# %%
def train_LBFGS(pinn,loss,optimizer, sample_size = 100, minval_param = 0.2,maxval_param = 2):
    print("Starting Training: LBFGS optimizer")
    train_loss=[]

    pde_domain,ini_c,left_bc,right_bc = data_pde(sample_size,minval_param,maxval_param)
    
    pde_domain,ini_c = Variable(pde_domain,requires_grad=True),Variable(ini_c,requires_grad=True)
    left_bc,right_bc = Variable(left_bc,requires_grad=True),Variable(right_bc,requires_grad=True)
    

    def loss_func_train():
        optimizer.zero_grad()
        
        pde_pred,ini_c_pred = pinn.de(pde_domain), pinn.ini_c(ini_c)
        left_bc_pred,right_bc_pred = pinn.left_bc(left_bc),pinn.right_bc(right_bc)

        loss_pde,loss_ini = loss(pde_pred,torch.zeros_like(pde_pred)),loss(ini_c_pred,torch.zeros_like(pde_pred))
        loss_lbc,loss_rbc = loss(left_bc_pred,torch.zeros_like(pde_pred)),loss(right_bc_pred,torch.zeros_like(pde_pred))

        Loss =  loss_pde + loss_ini + loss_lbc + loss_rbc
        train_loss.append(Loss.item())

        print('Loss: %.5e, Loss_PDE: %.5e, Loss_ini: %.5e, Loss_lbc: %.5e,Loss_rbc: %.5e' % ( 
                                                            Loss.item(),loss_pde.item(),loss_ini.item(), loss_lbc.item(), loss_rbc.item()))

        Loss.backward() 

        return Loss

    optimizer.step(loss_func_train) 
    return train_loss

# %%
# Number of observations
epochs = 1200
nobs = 3000
lr = 0.01

min_param , max_param = 0.0001, 0.05

layers = [3] + 3*[40] + [1]

model = Dropout_DNN(layers)

# model.load_state_dict(torch.load(f"../Projects-1/Physics _Informed_NN/GaLA/Gala_models/BurgEq_4_30.pt"))
# model.eval()

# %%
loss = torch.nn.MSELoss(reduction ='mean')

optimizer = torch.optim.Adam(model.parameters(), lr = lr)

loss_history = train_adam(model,loss,optimizer,epochs, nobs,min_param,max_param)

optimizer = torch.optim.LBFGS(
    model.parameters(), lr=lr, max_iter=50000, max_eval=None, tolerance_grad=1e-5, tolerance_change=1.0 * np.finfo(float).eps,line_search_fn="strong_wolfe" 
    )

loss_history_b = train_LBFGS(model,loss,optimizer, nobs*2,min_param,max_param)
# Out:
# Starting Adam Training
# Iter 0, Loss: 5.55753e-01, Loss_PDE: 1.24465e-02, Loss_ini: 5.00110e-01, Loss_lbc: 2.05872e-02,Loss_rbc: 2.26098e-02
# Iter 10, Loss: 4.59069e-01, Loss_PDE: 1.49987e-03, Loss_ini: 4.28436e-01, Loss_lbc: 1.61309e-02,Loss_rbc: 1.30015e-02
# Iter 20, Loss: 4.43332e-01, Loss_PDE: 2.23938e-03, Loss_ini: 3.86653e-01, Loss_lbc: 2.94003e-02,Loss_rbc: 2.50391e-02
# Iter 30, Loss: 4.10915e-01, Loss_PDE: 4.26947e-03, Loss_ini: 3.44013e-01, Loss_lbc: 3.16402e-02,Loss_rbc: 3.09928e-02
# Iter 40, Loss: 3.80951e-01, Loss_PDE: 1.02275e-02, Loss_ini: 2.88424e-01, Loss_lbc: 4.09307e-02,Loss_rbc: 4.13694e-02
# Iter 50, Loss: 3.61237e-01, Loss_PDE: 1.02835e-02, Loss_ini: 2.71366e-01, Loss_lbc: 3.82631e-02,Loss_rbc: 4.13245e-02
# Iter 60, Loss: 3.51721e-01, Loss_PDE: 1.13401e-02, Loss_ini: 2.71810e-01, Loss_lbc: 3.20894e-02,Loss_rbc: 3.64815e-02
# Iter 70, Loss: 3.38159e-01, Loss_PDE: 1.43155e-02, Loss_ini: 2.58231e-01, Loss_lbc: 3.19021e-02,Loss_rbc: 3.37105e-02
# Iter 80, Loss: 3.26690e-01, Loss_PDE: 1.44083e-02, Loss_ini: 2.39169e-01, Loss_lbc: 3.91310e-02,Loss_rbc: 3.39814e-02
# Iter 90, Loss: 3.16097e-01, Loss_PDE: 1.67415e-02, Loss_ini: 2.17463e-01, Loss_lbc: 4.11322e-02,Loss_rbc: 4.07603e-02
# Iter 100, Loss: 3.03620e-01, Loss_PDE: 2.19676e-02, Loss_ini: 2.07897e-01, Loss_lbc: 3.90455e-02,Loss_rbc: 3.47102e-02
# Iter 110, Loss: 2.93504e-01, Loss_PDE: 2.71181e-02, Loss_ini: 2.11429e-01, Loss_lbc: 2.84606e-02,Loss_rbc: 2.64962e-02
# Iter 120, Loss: 2.77005e-01, Loss_PDE: 2.35442e-02, Loss_ini: 1.90199e-01, Loss_lbc: 3.24002e-02,Loss_rbc: 3.08619e-02
# Iter 130, Loss: 2.64399e-01, Loss_PDE: 2.89059e-02, Loss_ini: 1.80735e-01, Loss_lbc: 2.76705e-02,Loss_rbc: 2.70882e-02
# Iter 140, Loss: 2.52299e-01, Loss_PDE: 3.14503e-02, Loss_ini: 1.72214e-01, Loss_lbc: 2.62431e-02,Loss_rbc: 2.23924e-02
# Iter 150, Loss: 2.54110e-01, Loss_PDE: 3.15299e-02, Loss_ini: 1.82868e-01, Loss_lbc: 2.23743e-02,Loss_rbc: 1.73376e-02
# Iter 160, Loss: 2.54028e-01, Loss_PDE: 3.06722e-02, Loss_ini: 1.74860e-01, Loss_lbc: 2.51020e-02,Loss_rbc: 2.33945e-02
# Iter 170, Loss: 2.47929e-01, Loss_PDE: 3.22825e-02, Loss_ini: 1.64744e-01, Loss_lbc: 2.59649e-02,Loss_rbc: 2.49375e-02
# Iter 180, Loss: 2.39969e-01, Loss_PDE: 3.95602e-02, Loss_ini: 1.55751e-01, Loss_lbc: 2.22401e-02,Loss_rbc: 2.24181e-02
# Iter 190, Loss: 2.42489e-01, Loss_PDE: 4.47531e-02, Loss_ini: 1.56768e-01, Loss_lbc: 1.90640e-02,Loss_rbc: 2.19033e-02
# Iter 200, Loss: 2.42515e-01, Loss_PDE: 4.81160e-02, Loss_ini: 1.54143e-01, Loss_lbc: 1.92272e-02,Loss_rbc: 2.10292e-02
# Iter 210, Loss: 2.33769e-01, Loss_PDE: 4.21318e-02, Loss_ini: 1.43297e-01, Loss_lbc: 2.58017e-02,Loss_rbc: 2.25382e-02
# Iter 220, Loss: 2.30614e-01, Loss_PDE: 4.24142e-02, Loss_ini: 1.40257e-01, Loss_lbc: 2.46044e-02,Loss_rbc: 2.33375e-02
# Iter 230, Loss: 2.33019e-01, Loss_PDE: 4.82521e-02, Loss_ini: 1.39328e-01, Loss_lbc: 2.13847e-02,Loss_rbc: 2.40536e-02
# Iter 240, Loss: 2.25215e-01, Loss_PDE: 4.12024e-02, Loss_ini: 1.47146e-01, Loss_lbc: 1.70450e-02,Loss_rbc: 1.98215e-02
# Iter 250, Loss: 2.21874e-01, Loss_PDE: 3.58533e-02, Loss_ini: 1.49539e-01, Loss_lbc: 1.73518e-02,Loss_rbc: 1.91294e-02
# Iter 260, Loss: 2.26920e-01, Loss_PDE: 3.83526e-02, Loss_ini: 1.50683e-01, Loss_lbc: 1.85572e-02,Loss_rbc: 1.93268e-02
# Iter 270, Loss: 2.25565e-01, Loss_PDE: 3.83895e-02, Loss_ini: 1.53978e-01, Loss_lbc: 1.73001e-02,Loss_rbc: 1.58975e-02
# Iter 280, Loss: 2.22513e-01, Loss_PDE: 4.11941e-02, Loss_ini: 1.38505e-01, Loss_lbc: 2.03393e-02,Loss_rbc: 2.24747e-02
# Iter 290, Loss: 2.27195e-01, Loss_PDE: 4.65658e-02, Loss_ini: 1.37063e-01, Loss_lbc: 2.07339e-02,Loss_rbc: 2.28326e-02
# Iter 300, Loss: 2.19068e-01, Loss_PDE: 3.70587e-02, Loss_ini: 1.40022e-01, Loss_lbc: 2.10845e-02,Loss_rbc: 2.09032e-02
# Iter 310, Loss: 2.23153e-01, Loss_PDE: 4.14280e-02, Loss_ini: 1.40794e-01, Loss_lbc: 2.02885e-02,Loss_rbc: 2.06426e-02
# Iter 320, Loss: 2.22163e-01, Loss_PDE: 4.18060e-02, Loss_ini: 1.40386e-01, Loss_lbc: 1.96158e-02,Loss_rbc: 2.03553e-02
# Iter 330, Loss: 2.25317e-01, Loss_PDE: 4.15313e-02, Loss_ini: 1.46766e-01, Loss_lbc: 1.83216e-02,Loss_rbc: 1.86980e-02
# Iter 340, Loss: 2.22119e-01, Loss_PDE: 3.99711e-02, Loss_ini: 1.49170e-01, Loss_lbc: 1.66292e-02,Loss_rbc: 1.63481e-02
# Iter 350, Loss: 2.26802e-01, Loss_PDE: 4.30512e-02, Loss_ini: 1.47816e-01, Loss_lbc: 1.84557e-02,Loss_rbc: 1.74800e-02
# Iter 360, Loss: 2.24156e-01, Loss_PDE: 3.85989e-02, Loss_ini: 1.53292e-01, Loss_lbc: 1.56332e-02,Loss_rbc: 1.66316e-02
# Iter 370, Loss: 2.17625e-01, Loss_PDE: 3.37063e-02, Loss_ini: 1.47036e-01, Loss_lbc: 1.87443e-02,Loss_rbc: 1.81378e-02
# Iter 380, Loss: 2.24972e-01, Loss_PDE: 4.22239e-02, Loss_ini: 1.33312e-01, Loss_lbc: 2.24172e-02,Loss_rbc: 2.70188e-02
# Iter 390, Loss: 2.26974e-01, Loss_PDE: 5.10542e-02, Loss_ini: 1.24058e-01, Loss_lbc: 2.43501e-02,Loss_rbc: 2.75116e-02
# Iter 400, Loss: 2.17151e-01, Loss_PDE: 5.25760e-02, Loss_ini: 1.21143e-01, Loss_lbc: 1.97929e-02,Loss_rbc: 2.36382e-02
# Iter 410, Loss: 2.14364e-01, Loss_PDE: 3.91186e-02, Loss_ini: 1.33872e-01, Loss_lbc: 1.99130e-02,Loss_rbc: 2.14603e-02
# Iter 420, Loss: 2.20145e-01, Loss_PDE: 3.35347e-02, Loss_ini: 1.49868e-01, Loss_lbc: 1.68380e-02,Loss_rbc: 1.99044e-02
# Iter 430, Loss: 2.20214e-01, Loss_PDE: 4.51893e-02, Loss_ini: 1.41484e-01, Loss_lbc: 1.57285e-02,Loss_rbc: 1.78120e-02
# Iter 440, Loss: 2.18985e-01, Loss_PDE: 4.50156e-02, Loss_ini: 1.32581e-01, Loss_lbc: 2.14901e-02,Loss_rbc: 1.98984e-02
# Iter 450, Loss: 2.20454e-01, Loss_PDE: 3.96523e-02, Loss_ini: 1.34633e-01, Loss_lbc: 2.02500e-02,Loss_rbc: 2.59192e-02
# Iter 460, Loss: 2.15831e-01, Loss_PDE: 3.93420e-02, Loss_ini: 1.36837e-01, Loss_lbc: 1.86997e-02,Loss_rbc: 2.09528e-02
# Iter 470, Loss: 2.21630e-01, Loss_PDE: 4.18882e-02, Loss_ini: 1.41088e-01, Loss_lbc: 1.90766e-02,Loss_rbc: 1.95778e-02
# Iter 480, Loss: 2.16555e-01, Loss_PDE: 3.91707e-02, Loss_ini: 1.42614e-01, Loss_lbc: 1.78574e-02,Loss_rbc: 1.69134e-02
# Iter 490, Loss: 2.15535e-01, Loss_PDE: 4.69898e-02, Loss_ini: 1.31588e-01, Loss_lbc: 1.72975e-02,Loss_rbc: 1.96604e-02
# Iter 500, Loss: 2.14809e-01, Loss_PDE: 3.97398e-02, Loss_ini: 1.32917e-01, Loss_lbc: 1.90196e-02,Loss_rbc: 2.31332e-02
# Iter 510, Loss: 2.23459e-01, Loss_PDE: 3.46209e-02, Loss_ini: 1.52181e-01, Loss_lbc: 1.80856e-02,Loss_rbc: 1.85721e-02
# Iter 520, Loss: 2.19316e-01, Loss_PDE: 4.33247e-02, Loss_ini: 1.40021e-01, Loss_lbc: 1.88405e-02,Loss_rbc: 1.71298e-02
# Iter 530, Loss: 2.21540e-01, Loss_PDE: 4.60787e-02, Loss_ini: 1.39591e-01, Loss_lbc: 1.77871e-02,Loss_rbc: 1.80830e-02
# Iter 540, Loss: 2.17625e-01, Loss_PDE: 4.32249e-02, Loss_ini: 1.37923e-01, Loss_lbc: 1.74081e-02,Loss_rbc: 1.90685e-02
# Iter 550, Loss: 2.19017e-01, Loss_PDE: 4.08168e-02, Loss_ini: 1.38588e-01, Loss_lbc: 1.80021e-02,Loss_rbc: 2.16108e-02
# Iter 560, Loss: 2.20557e-01, Loss_PDE: 4.47016e-02, Loss_ini: 1.36617e-01, Loss_lbc: 1.75827e-02,Loss_rbc: 2.16554e-02
# Iter 570, Loss: 2.12785e-01, Loss_PDE: 4.02666e-02, Loss_ini: 1.32417e-01, Loss_lbc: 2.16958e-02,Loss_rbc: 1.84060e-02
# Iter 580, Loss: 2.23278e-01, Loss_PDE: 4.80697e-02, Loss_ini: 1.27821e-01, Loss_lbc: 2.46496e-02,Loss_rbc: 2.27371e-02
# Iter 590, Loss: 2.17652e-01, Loss_PDE: 4.71411e-02, Loss_ini: 1.26572e-01, Loss_lbc: 2.12167e-02,Loss_rbc: 2.27226e-02
# Iter 600, Loss: 2.14401e-01, Loss_PDE: 3.84210e-02, Loss_ini: 1.39563e-01, Loss_lbc: 1.72822e-02,Loss_rbc: 1.91347e-02
# Iter 610, Loss: 2.17212e-01, Loss_PDE: 4.77873e-02, Loss_ini: 1.28029e-01, Loss_lbc: 2.05860e-02,Loss_rbc: 2.08099e-02
# Iter 620, Loss: 2.19933e-01, Loss_PDE: 6.02703e-02, Loss_ini: 1.15718e-01, Loss_lbc: 2.06765e-02,Loss_rbc: 2.32678e-02
# Iter 630, Loss: 2.19633e-01, Loss_PDE: 4.36538e-02, Loss_ini: 1.26179e-01, Loss_lbc: 2.37760e-02,Loss_rbc: 2.60242e-02
# Iter 640, Loss: 2.16920e-01, Loss_PDE: 3.52284e-02, Loss_ini: 1.46973e-01, Loss_lbc: 1.65148e-02,Loss_rbc: 1.82039e-02
# Iter 650, Loss: 2.22949e-01, Loss_PDE: 3.31504e-02, Loss_ini: 1.57591e-01, Loss_lbc: 1.44485e-02,Loss_rbc: 1.77588e-02
# Iter 660, Loss: 2.17573e-01, Loss_PDE: 4.64334e-02, Loss_ini: 1.35429e-01, Loss_lbc: 1.66776e-02,Loss_rbc: 1.90327e-02
# Iter 670, Loss: 2.15689e-01, Loss_PDE: 5.10989e-02, Loss_ini: 1.29806e-01, Loss_lbc: 1.70287e-02,Loss_rbc: 1.77555e-02
# Iter 680, Loss: 2.24254e-01, Loss_PDE: 5.30199e-02, Loss_ini: 1.36316e-01, Loss_lbc: 1.99171e-02,Loss_rbc: 1.50011e-02
# Iter 690, Loss: 2.18745e-01, Loss_PDE: 4.76482e-02, Loss_ini: 1.37303e-01, Loss_lbc: 1.73007e-02,Loss_rbc: 1.64931e-02
# Iter 700, Loss: 2.13332e-01, Loss_PDE: 5.07166e-02, Loss_ini: 1.22211e-01, Loss_lbc: 2.10951e-02,Loss_rbc: 1.93090e-02
# Iter 710, Loss: 2.23887e-01, Loss_PDE: 4.83454e-02, Loss_ini: 1.37338e-01, Loss_lbc: 2.07520e-02,Loss_rbc: 1.74515e-02
# Iter 720, Loss: 2.22425e-01, Loss_PDE: 5.27354e-02, Loss_ini: 1.23297e-01, Loss_lbc: 2.27427e-02,Loss_rbc: 2.36497e-02
# Iter 730, Loss: 2.19217e-01, Loss_PDE: 4.94978e-02, Loss_ini: 1.26264e-01, Loss_lbc: 2.04584e-02,Loss_rbc: 2.29963e-02
# Iter 740, Loss: 2.13651e-01, Loss_PDE: 4.60267e-02, Loss_ini: 1.26196e-01, Loss_lbc: 1.97565e-02,Loss_rbc: 2.16713e-02
# Iter 750, Loss: 2.17094e-01, Loss_PDE: 3.26708e-02, Loss_ini: 1.39443e-01, Loss_lbc: 2.31415e-02,Loss_rbc: 2.18388e-02
# Iter 760, Loss: 2.12383e-01, Loss_PDE: 4.48400e-02, Loss_ini: 1.22583e-01, Loss_lbc: 2.31602e-02,Loss_rbc: 2.18002e-02
# Iter 770, Loss: 2.15507e-01, Loss_PDE: 5.05687e-02, Loss_ini: 1.26875e-01, Loss_lbc: 1.89025e-02,Loss_rbc: 1.91603e-02
# Iter 780, Loss: 2.14131e-01, Loss_PDE: 4.62457e-02, Loss_ini: 1.28262e-01, Loss_lbc: 1.87864e-02,Loss_rbc: 2.08363e-02
# Iter 790, Loss: 2.17239e-01, Loss_PDE: 5.11651e-02, Loss_ini: 1.23830e-01, Loss_lbc: 2.26290e-02,Loss_rbc: 1.96151e-02
# Iter 800, Loss: 2.11878e-01, Loss_PDE: 4.25373e-02, Loss_ini: 1.31469e-01, Loss_lbc: 1.72672e-02,Loss_rbc: 2.06048e-02
# Iter 810, Loss: 2.07641e-01, Loss_PDE: 3.61757e-02, Loss_ini: 1.36259e-01, Loss_lbc: 1.62254e-02,Loss_rbc: 1.89805e-02
# Iter 820, Loss: 2.15220e-01, Loss_PDE: 4.05841e-02, Loss_ini: 1.43896e-01, Loss_lbc: 1.46060e-02,Loss_rbc: 1.61336e-02
# Iter 830, Loss: 2.13084e-01, Loss_PDE: 4.20615e-02, Loss_ini: 1.38746e-01, Loss_lbc: 1.49796e-02,Loss_rbc: 1.72967e-02
# Iter 840, Loss: 2.11347e-01, Loss_PDE: 3.86121e-02, Loss_ini: 1.37067e-01, Loss_lbc: 1.67887e-02,Loss_rbc: 1.88792e-02
# Iter 850, Loss: 2.18659e-01, Loss_PDE: 4.37229e-02, Loss_ini: 1.39289e-01, Loss_lbc: 1.82727e-02,Loss_rbc: 1.73748e-02
# Iter 860, Loss: 2.12310e-01, Loss_PDE: 4.36550e-02, Loss_ini: 1.24807e-01, Loss_lbc: 2.22635e-02,Loss_rbc: 2.15843e-02
# Iter 870, Loss: 2.09849e-01, Loss_PDE: 3.71640e-02, Loss_ini: 1.28968e-01, Loss_lbc: 2.45510e-02,Loss_rbc: 1.91656e-02
# Iter 880, Loss: 2.11310e-01, Loss_PDE: 3.92586e-02, Loss_ini: 1.34611e-01, Loss_lbc: 1.81056e-02,Loss_rbc: 1.93354e-02
# Iter 890, Loss: 2.12318e-01, Loss_PDE: 4.50117e-02, Loss_ini: 1.26717e-01, Loss_lbc: 2.04229e-02,Loss_rbc: 2.01672e-02
# Iter 900, Loss: 2.13091e-01, Loss_PDE: 4.22763e-02, Loss_ini: 1.26155e-01, Loss_lbc: 2.19660e-02,Loss_rbc: 2.26938e-02
# Iter 910, Loss: 2.14208e-01, Loss_PDE: 4.15873e-02, Loss_ini: 1.36423e-01, Loss_lbc: 1.77056e-02,Loss_rbc: 1.84919e-02
# Iter 920, Loss: 2.11581e-01, Loss_PDE: 4.93488e-02, Loss_ini: 1.31278e-01, Loss_lbc: 1.61408e-02,Loss_rbc: 1.48142e-02
# Iter 930, Loss: 2.15741e-01, Loss_PDE: 4.40656e-02, Loss_ini: 1.32905e-01, Loss_lbc: 1.89477e-02,Loss_rbc: 1.98224e-02
# Iter 940, Loss: 2.11553e-01, Loss_PDE: 3.68033e-02, Loss_ini: 1.34891e-01, Loss_lbc: 1.86767e-02,Loss_rbc: 2.11815e-02
# Iter 950, Loss: 2.11857e-01, Loss_PDE: 4.34538e-02, Loss_ini: 1.35125e-01, Loss_lbc: 1.50967e-02,Loss_rbc: 1.81814e-02
# Iter 960, Loss: 2.12280e-01, Loss_PDE: 4.21241e-02, Loss_ini: 1.32900e-01, Loss_lbc: 1.75750e-02,Loss_rbc: 1.96806e-02
# Iter 970, Loss: 2.13095e-01, Loss_PDE: 4.85679e-02, Loss_ini: 1.27312e-01, Loss_lbc: 1.86332e-02,Loss_rbc: 1.85818e-02
# Iter 980, Loss: 2.11207e-01, Loss_PDE: 4.29447e-02, Loss_ini: 1.35579e-01, Loss_lbc: 1.56944e-02,Loss_rbc: 1.69887e-02
# Iter 990, Loss: 2.12101e-01, Loss_PDE: 3.78148e-02, Loss_ini: 1.37237e-01, Loss_lbc: 1.75584e-02,Loss_rbc: 1.94911e-02
# Iter 1000, Loss: 2.06836e-01, Loss_PDE: 4.53282e-02, Loss_ini: 1.20994e-01, Loss_lbc: 1.92450e-02,Loss_rbc: 2.12688e-02
# Iter 1010, Loss: 2.08533e-01, Loss_PDE: 3.56545e-02, Loss_ini: 1.36608e-01, Loss_lbc: 1.71094e-02,Loss_rbc: 1.91608e-02
# Iter 1020, Loss: 2.12173e-01, Loss_PDE: 3.23126e-02, Loss_ini: 1.46919e-01, Loss_lbc: 1.64235e-02,Loss_rbc: 1.65181e-02
# Iter 1030, Loss: 2.12754e-01, Loss_PDE: 4.57793e-02, Loss_ini: 1.30406e-01, Loss_lbc: 1.89159e-02,Loss_rbc: 1.76535e-02
# Iter 1040, Loss: 2.15919e-01, Loss_PDE: 4.26558e-02, Loss_ini: 1.30715e-01, Loss_lbc: 1.86350e-02,Loss_rbc: 2.39132e-02
# Iter 1050, Loss: 2.05999e-01, Loss_PDE: 4.42105e-02, Loss_ini: 1.24181e-01, Loss_lbc: 1.78754e-02,Loss_rbc: 1.97323e-02
# Iter 1060, Loss: 2.08010e-01, Loss_PDE: 3.97812e-02, Loss_ini: 1.33105e-01, Loss_lbc: 1.63696e-02,Loss_rbc: 1.87540e-02
# Iter 1070, Loss: 2.10389e-01, Loss_PDE: 3.71424e-02, Loss_ini: 1.35126e-01, Loss_lbc: 1.90450e-02,Loss_rbc: 1.90755e-02
# Iter 1080, Loss: 2.06238e-01, Loss_PDE: 3.81971e-02, Loss_ini: 1.29121e-01, Loss_lbc: 2.02695e-02,Loss_rbc: 1.86505e-02
# Iter 1090, Loss: 2.13089e-01, Loss_PDE: 4.67953e-02, Loss_ini: 1.28792e-01, Loss_lbc: 1.96203e-02,Loss_rbc: 1.78810e-02
# Iter 1100, Loss: 2.03463e-01, Loss_PDE: 4.11535e-02, Loss_ini: 1.28457e-01, Loss_lbc: 1.71617e-02,Loss_rbc: 1.66916e-02
# Iter 1110, Loss: 2.12426e-01, Loss_PDE: 4.60723e-02, Loss_ini: 1.23848e-01, Loss_lbc: 1.93896e-02,Loss_rbc: 2.31158e-02
# Iter 1120, Loss: 2.09899e-01, Loss_PDE: 4.44885e-02, Loss_ini: 1.23889e-01, Loss_lbc: 1.96289e-02,Loss_rbc: 2.18928e-02
# Iter 1130, Loss: 2.11670e-01, Loss_PDE: 4.49913e-02, Loss_ini: 1.29474e-01, Loss_lbc: 1.56747e-02,Loss_rbc: 2.15303e-02
# Iter 1140, Loss: 2.14212e-01, Loss_PDE: 5.19972e-02, Loss_ini: 1.27166e-01, Loss_lbc: 1.78426e-02,Loss_rbc: 1.72057e-02
# Iter 1150, Loss: 2.08900e-01, Loss_PDE: 4.99529e-02, Loss_ini: 1.23530e-01, Loss_lbc: 1.77326e-02,Loss_rbc: 1.76845e-02
# Iter 1160, Loss: 2.10453e-01, Loss_PDE: 4.35233e-02, Loss_ini: 1.34183e-01, Loss_lbc: 1.63189e-02,Loss_rbc: 1.64276e-02
# Iter 1170, Loss: 2.12940e-01, Loss_PDE: 3.95256e-02, Loss_ini: 1.23980e-01, Loss_lbc: 2.45323e-02,Loss_rbc: 2.49021e-02
# Iter 1180, Loss: 2.12422e-01, Loss_PDE: 4.33577e-02, Loss_ini: 1.33901e-01, Loss_lbc: 2.01090e-02,Loss_rbc: 1.50540e-02
# Iter 1190, Loss: 2.10217e-01, Loss_PDE: 5.07496e-02, Loss_ini: 1.20573e-01, Loss_lbc: 1.95253e-02,Loss_rbc: 1.93694e-02
# Starting Training: LBFGS optimizer
# Loss: 2.03767e-01, Loss_PDE: 4.22895e-02, Loss_ini: 1.28636e-01, Loss_lbc: 1.61055e-02,Loss_rbc: 1.67357e-02
# Loss: 2.06313e-01, Loss_PDE: 4.23218e-02, Loss_ini: 1.28946e-01, Loss_lbc: 1.70580e-02,Loss_rbc: 1.79874e-02
# Loss: 2.08786e-01, Loss_PDE: 4.43122e-02, Loss_ini: 1.30442e-01, Loss_lbc: 1.68905e-02,Loss_rbc: 1.71420e-02
# Loss: 2.10443e-01, Loss_PDE: 4.72550e-02, Loss_ini: 1.30466e-01, Loss_lbc: 1.60074e-02,Loss_rbc: 1.67142e-02
# Loss: 2.10447e-01, Loss_PDE: 4.48124e-02, Loss_ini: 1.32111e-01, Loss_lbc: 1.65013e-02,Loss_rbc: 1.70217e-02

# %%
def MCD (dropout_model,X_star, samples = 1000):
    dropout_model.train()

    predictions = []

    for _ in range(samples):
        pred = dropout_model(X_star)  # Perform a forward pass with dropout
        predictions.append(pred.cpu().detach().numpy())  # Store the result

    predictions_mcd = np.array(predictions)
    return np.mean(predictions_mcd, axis=0),np.std(predictions_mcd, axis=0)

# %%
x = np.linspace(-1,1,100)
y = np.linspace(0,1,100)

xx, yy = np.meshgrid(x, y)
xx, yy = torch.tensor(xx).reshape(-1,1).float(),torch.tensor(yy).reshape(-1,1).float()


X_star = torch.cat([xx,yy,torch.ones_like(xx)*(0.005)],axis = 1)
mean, std = MCD (model,X_star, samples = 1000)

fig, axs = plt.subplots(2,1, figsize=(10, 5))

xx,yy = np.meshgrid(x, y)

U_pred = griddata(np.hstack([xx.reshape(-1,1),yy.reshape(-1,1)]), mean[:,0], (xx,yy), method='cubic')
U_sigma = griddata(np.hstack([xx.reshape(-1,1),yy.reshape(-1,1)]), std[:,0], (xx,yy), method='cubic')

axs[0].contourf(y.flatten(), x.flatten(), U_pred.T,cmap='rainbow')

axs[1].plot(x,U_pred[75,:])
axs[1].fill_between(x.reshape(-1), U_pred[75,:]+U_sigma[75,:],U_pred[75,:]-U_sigma[75,:],alpha=0.4, color = "red",label = r"NN Uncertainty ($\sigma^{2})$")
# Out:
# (100, 100)
