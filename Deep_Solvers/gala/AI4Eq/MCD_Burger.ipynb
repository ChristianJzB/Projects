# %%
import os
import re

os.chdir("../..")

import torch
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset

from collections import OrderedDict

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from pyDOE import lhs
from scipy.stats import uniform,norm
from scipy.interpolate import griddata

from gala.Galab import llaplace
from NN import DNN_Ensemble

np.random.seed(1234)

# CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")

# %% [markdown]
# ## Burgers Equation
#
# $$\frac{\partial u}{\partial t} + u\frac{\partial u}{\partial x} - \frac{0.01}{\pi}\frac{\partial^{2} u}{\partial x^{2}}=0$$
# $$u(x,0) = -sin( \pi x),  u(-1,t)=u(1,t)=0$$

# %% [markdown]
# ## Feed Forward Neural Network

# %%
# Deep neural network
class DNN(torch.nn.Module):
    def __init__(self, layers):
        super(DNN, self).__init__()

        # Number of layers
        self.depth = len(layers) - 1
        
        # Activation Function
        self.activation = torch.nn.Tanh
        
        # The following loop organized the layers of the NN         
        layer_list = list()
        for i in range(self.depth - 1): 
            layer_list.append(
                ('layer_%d' % i, torch.nn.Linear(layers[i], layers[i+1])))
            layer_list.append(('activation_%d' % i, self.activation()))
        layer_list.append(
            ('layer_%d' % (self.depth - 1), torch.nn.Linear(layers[-2], layers[-1]))
        )
        layerDict = OrderedDict(layer_list)
        
        # Deploy layers
        self.layers = torch.nn.Sequential(layerDict)

    def forward(self, x):
        out = self.layers(x)
        return out

# %%
# Deep neural network
class Dropout_DNN(torch.nn.Module):
    def __init__(self, layers):
        super(Dropout_DNN, self).__init__()

        # Number of layers
        self.depth = len(layers) - 1
        
        # Activation Function
        self.activation = torch.nn.Tanh
        
        # The following loop organized the layers of the NN         
        layer_list = list()
        for i in range(self.depth - 1): 
            layer_list.append(('layer_%d' % i, torch.nn.Linear(layers[i], layers[i+1])))
            layer_list.append(('activation_%d' % i, self.activation()))
            layer_list.append(('dropout_%d' % i, torch.nn.Dropout(p = 0.5)))

        layer_list.append(
            ('layer_%d' % (self.depth - 1), torch.nn.Linear(layers[-2], layers[-1]))
        )
        layerDict = OrderedDict(layer_list)
        
        # Deploy layers
        self.layers = torch.nn.Sequential(layerDict)

    def forward(self, x):
        out = self.layers(x)
        return out

# %% [markdown]
# ## Parametric PINN for Inverse Problems

# %%
def de(self,data_domain):
    """ The pytorch autograd version of calculating residual """
    u = self(data_domain)
    
    du = torch.autograd.grad(
        u, data_domain, 
        grad_outputs=torch.ones_like(u),
        retain_graph=True,
        create_graph=True
    )[0]

    ddu_x = torch.autograd.grad(
        du[:,0],data_domain, 
        grad_outputs=torch.ones_like(du[:,0]),
        retain_graph=True,
        create_graph=True
        )[0]
    
    f = du[:,1].reshape(-1,1) + u.reshape(-1,1)*du[:,0].reshape(-1,1) - data_domain[:,2].reshape(-1,1)*ddu_x[:,0].reshape(-1,1)

    return f

def ini_c(self,data_inic):
    u = self(data_inic)
    return u + torch.sin(torch.pi*data_inic[:,0].reshape(-1,1))

def left_bc(self,data_lbc):
    u = self(data_lbc)
    return u

def right_bc(self,data_rbc):
    u = self(data_rbc)
    return u

# %%
DNN.de = de
DNN.ini_c = ini_c
DNN.left_bc = left_bc
DNN.right_bc = right_bc

Dropout_DNN.de = de
Dropout_DNN.ini_c = ini_c
Dropout_DNN.left_bc = left_bc
Dropout_DNN.right_bc = right_bc

# %%
def samples_space(size,maxl=1):
    t_f_train = lhs(2, size)*maxl
    t_f_train[:,0] = t_f_train[:,0]*(2)-1
    t_f_train[:,1] = t_f_train[:,1]*(0.5)
    return t_f_train

def samples_param(min,max,size = 100):
    return np.random.uniform(min,max,size = size)

# %%
def data_pde(size,minp,maxp):

    xy, param = samples_space(size),samples_param(minp,maxp,(size,1)).reshape(-1,1)
    pde_domain = torch.tensor(np.hstack((xy,param.reshape(-1,1)))).float()
    
    x,y, param  = torch.tensor(xy[:,0]).reshape(-1,1),torch.tensor(xy[:,1]).reshape(-1,1),torch.tensor(param).reshape(-1,1)

    ini_c = torch.cat([x,torch.zeros_like(x).float(),param],axis = 1).float()

    left_bc = torch.cat([torch.ones_like(x).float()*(-1),y, param],axis = 1).float()

    right_bc = torch.cat([torch.ones_like(x).float(),y, param],axis = 1).float()

    return pde_domain,ini_c,left_bc,right_bc

# %%
def train_adam(pinn,loss,optimizer,epochs, sample_size = 100,minval_param = 0.2,maxval_param = 2,repetitions=1):
      print("Starting Adam Training")
      train_loss=[]
      for i in range(epochs):
        pde_domain,ini_c,left_bc,right_bc = data_pde(sample_size,minval_param,maxval_param)
        
        pde_domain,ini_c = Variable(pde_domain,requires_grad=True),Variable(ini_c,requires_grad=True)
        left_bc,right_bc = Variable(left_bc,requires_grad=True),Variable(right_bc,requires_grad=True)
        
        for _ in range(repetitions):
                optimizer.zero_grad()

                pde_pred,ini_c_pred = pinn.de(pde_domain), pinn.ini_c(ini_c)
                left_bc_pred,right_bc_pred = pinn.left_bc(left_bc),pinn.right_bc(right_bc)

                loss_pde,loss_ini = loss(pde_pred,torch.zeros_like(pde_pred)),loss(ini_c_pred,torch.zeros_like(pde_pred))
                loss_lbc,loss_rbc = loss(left_bc_pred,torch.zeros_like(pde_pred)),loss(right_bc_pred,torch.zeros_like(pde_pred))

                Loss =  loss_pde + loss_ini + loss_lbc + loss_rbc
                train_loss.append(Loss.item())
                if i % 10 == 0:
                        print('Iter %d, Loss: %.5e, Loss_PDE: %.5e, Loss_ini: %.5e, Loss_lbc: %.5e,Loss_rbc: %.5e' % (i, 
                                                                         Loss.item(),loss_pde.item(),loss_ini.item(), loss_lbc.item(), loss_rbc.item()))
                                
                Loss.backward() 

                optimizer.step() 

                #sheduler.step()
      return train_loss

# %%
def train_LBFGS(pinn,loss,optimizer, sample_size = 100, minval_param = 0.2,maxval_param = 2):
    print("Starting Training: LBFGS optimizer")
    train_loss=[]

    pde_domain,ini_c,left_bc,right_bc = data_pde(sample_size,minval_param,maxval_param)
    
    pde_domain,ini_c = Variable(pde_domain,requires_grad=True),Variable(ini_c,requires_grad=True)
    left_bc,right_bc = Variable(left_bc,requires_grad=True),Variable(right_bc,requires_grad=True)
    

    def loss_func_train():
        optimizer.zero_grad()
        
        pde_pred,ini_c_pred = pinn.de(pde_domain), pinn.ini_c(ini_c)
        left_bc_pred,right_bc_pred = pinn.left_bc(left_bc),pinn.right_bc(right_bc)

        loss_pde,loss_ini = loss(pde_pred,torch.zeros_like(pde_pred)),loss(ini_c_pred,torch.zeros_like(pde_pred))
        loss_lbc,loss_rbc = loss(left_bc_pred,torch.zeros_like(pde_pred)),loss(right_bc_pred,torch.zeros_like(pde_pred))

        Loss =  loss_pde + loss_ini + loss_lbc + loss_rbc
        train_loss.append(Loss.item())

        print('Loss: %.5e, Loss_PDE: %.5e, Loss_ini: %.5e, Loss_lbc: %.5e,Loss_rbc: %.5e' % ( 
                                                            Loss.item(),loss_pde.item(),loss_ini.item(), loss_lbc.item(), loss_rbc.item()))

        Loss.backward() 

        return Loss

    optimizer.step(loss_func_train) 
    return train_loss

# %%
# Number of observations
epochs = 1200
nobs = 3000
#nobs = 500
lr = 0.01

min_param , max_param = 0.0001, 0.05

layers = [3] + 3*[40] + [1]

model = Dropout_DNN(layers)

# model.load_state_dict(torch.load(f"../Projects-1/Physics _Informed_NN/GaLA/Gala_models/BurgEq_4_30.pt"))
# model.eval()

# %%
loss = torch.nn.MSELoss(reduction ='mean')

optimizer = torch.optim.Adam(model.parameters(), lr = lr)

loss_history = train_adam(model,loss,optimizer,epochs, nobs,min_param,max_param)

optimizer = torch.optim.LBFGS(
    model.parameters(), lr=lr, max_iter=50000, max_eval=None, tolerance_grad=1e-5, tolerance_change=1.0 * np.finfo(float).eps,line_search_fn="strong_wolfe" 
    )

loss_history_b = train_LBFGS(model,loss,optimizer, nobs*2,min_param,max_param)
# Out:
# Starting Adam Training
# Iter 0, Loss: 6.00354e-01, Loss_PDE: 1.34742e-02, Loss_ini: 5.29342e-01, Loss_lbc: 3.10396e-02,Loss_rbc: 2.64981e-02
# Iter 10, Loss: 4.68376e-01, Loss_PDE: 1.51674e-03, Loss_ini: 4.26902e-01, Loss_lbc: 1.81488e-02,Loss_rbc: 2.18080e-02
# Iter 20, Loss: 4.56843e-01, Loss_PDE: 7.19180e-04, Loss_ini: 4.22184e-01, Loss_lbc: 1.43717e-02,Loss_rbc: 1.95681e-02
# Iter 30, Loss: 4.35764e-01, Loss_PDE: 8.39109e-04, Loss_ini: 3.79835e-01, Loss_lbc: 2.58683e-02,Loss_rbc: 2.92213e-02
# Iter 40, Loss: 3.92043e-01, Loss_PDE: 3.29815e-03, Loss_ini: 3.19790e-01, Loss_lbc: 3.69527e-02,Loss_rbc: 3.20022e-02
# Iter 50, Loss: 3.71506e-01, Loss_PDE: 7.24092e-03, Loss_ini: 2.88049e-01, Loss_lbc: 3.72542e-02,Loss_rbc: 3.89623e-02
# Iter 60, Loss: 3.56426e-01, Loss_PDE: 1.00427e-02, Loss_ini: 2.69408e-01, Loss_lbc: 3.83675e-02,Loss_rbc: 3.86073e-02
# Iter 70, Loss: 3.48918e-01, Loss_PDE: 1.34110e-02, Loss_ini: 2.51662e-01, Loss_lbc: 4.25035e-02,Loss_rbc: 4.13412e-02
# Iter 80, Loss: 3.45205e-01, Loss_PDE: 1.38716e-02, Loss_ini: 2.62670e-01, Loss_lbc: 3.38267e-02,Loss_rbc: 3.48372e-02
# Iter 90, Loss: 3.39850e-01, Loss_PDE: 1.34440e-02, Loss_ini: 2.50009e-01, Loss_lbc: 3.83964e-02,Loss_rbc: 3.80007e-02
# Iter 100, Loss: 3.37819e-01, Loss_PDE: 1.33789e-02, Loss_ini: 2.58116e-01, Loss_lbc: 3.41404e-02,Loss_rbc: 3.21845e-02
# Iter 110, Loss: 3.28167e-01, Loss_PDE: 1.58398e-02, Loss_ini: 2.45030e-01, Loss_lbc: 3.35007e-02,Loss_rbc: 3.37958e-02
# Iter 120, Loss: 3.21119e-01, Loss_PDE: 1.53586e-02, Loss_ini: 2.35218e-01, Loss_lbc: 3.41691e-02,Loss_rbc: 3.63733e-02
# Iter 130, Loss: 3.15884e-01, Loss_PDE: 1.74478e-02, Loss_ini: 2.31125e-01, Loss_lbc: 3.35845e-02,Loss_rbc: 3.37259e-02
# Iter 140, Loss: 3.07233e-01, Loss_PDE: 1.68987e-02, Loss_ini: 2.21110e-01, Loss_lbc: 3.43671e-02,Loss_rbc: 3.48570e-02
# Iter 150, Loss: 2.93833e-01, Loss_PDE: 2.29825e-02, Loss_ini: 1.99666e-01, Loss_lbc: 3.71464e-02,Loss_rbc: 3.40384e-02
# Iter 160, Loss: 2.86919e-01, Loss_PDE: 3.13928e-02, Loss_ini: 1.98318e-01, Loss_lbc: 2.85754e-02,Loss_rbc: 2.86327e-02
# Iter 170, Loss: 2.77698e-01, Loss_PDE: 2.95923e-02, Loss_ini: 1.91371e-01, Loss_lbc: 2.89435e-02,Loss_rbc: 2.77911e-02
# Iter 180, Loss: 2.74848e-01, Loss_PDE: 4.00315e-02, Loss_ini: 1.82750e-01, Loss_lbc: 2.42608e-02,Loss_rbc: 2.78060e-02
# Iter 190, Loss: 2.69085e-01, Loss_PDE: 2.99227e-02, Loss_ini: 1.86782e-01, Loss_lbc: 2.43010e-02,Loss_rbc: 2.80797e-02
# Iter 200, Loss: 2.65011e-01, Loss_PDE: 2.98873e-02, Loss_ini: 1.89314e-01, Loss_lbc: 2.03679e-02,Loss_rbc: 2.54414e-02
# Iter 210, Loss: 2.58445e-01, Loss_PDE: 3.61054e-02, Loss_ini: 1.72115e-01, Loss_lbc: 2.44973e-02,Loss_rbc: 2.57266e-02
# Iter 220, Loss: 2.61469e-01, Loss_PDE: 4.19175e-02, Loss_ini: 1.59123e-01, Loss_lbc: 2.98998e-02,Loss_rbc: 3.05295e-02
# Iter 230, Loss: 2.57712e-01, Loss_PDE: 4.28321e-02, Loss_ini: 1.65154e-01, Loss_lbc: 2.56843e-02,Loss_rbc: 2.40423e-02
# Iter 240, Loss: 2.53787e-01, Loss_PDE: 3.32152e-02, Loss_ini: 1.70540e-01, Loss_lbc: 2.69797e-02,Loss_rbc: 2.30518e-02
# Iter 250, Loss: 2.52907e-01, Loss_PDE: 3.22000e-02, Loss_ini: 1.70233e-01, Loss_lbc: 2.85440e-02,Loss_rbc: 2.19302e-02
# Iter 260, Loss: 2.51190e-01, Loss_PDE: 2.90185e-02, Loss_ini: 1.65772e-01, Loss_lbc: 3.02344e-02,Loss_rbc: 2.61651e-02
# Iter 270, Loss: 2.47834e-01, Loss_PDE: 3.16548e-02, Loss_ini: 1.56945e-01, Loss_lbc: 2.96031e-02,Loss_rbc: 2.96310e-02
# Iter 280, Loss: 2.47644e-01, Loss_PDE: 2.66187e-02, Loss_ini: 1.77621e-01, Loss_lbc: 2.28979e-02,Loss_rbc: 2.05065e-02
# Iter 290, Loss: 2.48147e-01, Loss_PDE: 3.92444e-02, Loss_ini: 1.68695e-01, Loss_lbc: 1.90414e-02,Loss_rbc: 2.11658e-02
# Iter 300, Loss: 2.44134e-01, Loss_PDE: 4.28921e-02, Loss_ini: 1.56722e-01, Loss_lbc: 2.26239e-02,Loss_rbc: 2.18961e-02
# Iter 310, Loss: 2.44259e-01, Loss_PDE: 4.62745e-02, Loss_ini: 1.50933e-01, Loss_lbc: 2.51791e-02,Loss_rbc: 2.18720e-02
# Iter 320, Loss: 2.35901e-01, Loss_PDE: 3.99286e-02, Loss_ini: 1.50293e-01, Loss_lbc: 2.19952e-02,Loss_rbc: 2.36839e-02
# Iter 330, Loss: 2.41022e-01, Loss_PDE: 4.39590e-02, Loss_ini: 1.51663e-01, Loss_lbc: 2.32623e-02,Loss_rbc: 2.21384e-02
# Iter 340, Loss: 2.40725e-01, Loss_PDE: 3.54005e-02, Loss_ini: 1.61900e-01, Loss_lbc: 2.36036e-02,Loss_rbc: 1.98212e-02
# Iter 350, Loss: 2.38732e-01, Loss_PDE: 3.90937e-02, Loss_ini: 1.56917e-01, Loss_lbc: 2.19391e-02,Loss_rbc: 2.07823e-02
# Iter 360, Loss: 2.41279e-01, Loss_PDE: 3.67638e-02, Loss_ini: 1.56585e-01, Loss_lbc: 2.31858e-02,Loss_rbc: 2.47440e-02
# Iter 370, Loss: 2.34384e-01, Loss_PDE: 3.47187e-02, Loss_ini: 1.46286e-01, Loss_lbc: 2.92413e-02,Loss_rbc: 2.41376e-02
# Iter 380, Loss: 2.34481e-01, Loss_PDE: 3.73728e-02, Loss_ini: 1.46376e-01, Loss_lbc: 2.60003e-02,Loss_rbc: 2.47316e-02
# Iter 390, Loss: 2.38460e-01, Loss_PDE: 4.08919e-02, Loss_ini: 1.45301e-01, Loss_lbc: 2.44310e-02,Loss_rbc: 2.78362e-02
# Iter 400, Loss: 2.34585e-01, Loss_PDE: 4.60525e-02, Loss_ini: 1.37617e-01, Loss_lbc: 2.51495e-02,Loss_rbc: 2.57659e-02
# Iter 410, Loss: 2.32491e-01, Loss_PDE: 5.19737e-02, Loss_ini: 1.31701e-01, Loss_lbc: 2.47904e-02,Loss_rbc: 2.40255e-02
# Iter 420, Loss: 2.38837e-01, Loss_PDE: 4.49471e-02, Loss_ini: 1.48163e-01, Loss_lbc: 2.02470e-02,Loss_rbc: 2.54797e-02
# Iter 430, Loss: 2.35583e-01, Loss_PDE: 4.49218e-02, Loss_ini: 1.35256e-01, Loss_lbc: 2.76971e-02,Loss_rbc: 2.77077e-02
# Iter 440, Loss: 2.31438e-01, Loss_PDE: 5.09964e-02, Loss_ini: 1.39219e-01, Loss_lbc: 2.19814e-02,Loss_rbc: 1.92406e-02
# Iter 450, Loss: 2.30197e-01, Loss_PDE: 3.71218e-02, Loss_ini: 1.49399e-01, Loss_lbc: 2.34559e-02,Loss_rbc: 2.02204e-02
# Iter 460, Loss: 2.35243e-01, Loss_PDE: 5.13087e-02, Loss_ini: 1.41352e-01, Loss_lbc: 2.16857e-02,Loss_rbc: 2.08969e-02
# Iter 470, Loss: 2.30547e-01, Loss_PDE: 4.40230e-02, Loss_ini: 1.37749e-01, Loss_lbc: 2.69394e-02,Loss_rbc: 2.18355e-02
# Iter 480, Loss: 2.33094e-01, Loss_PDE: 4.09441e-02, Loss_ini: 1.51801e-01, Loss_lbc: 2.12665e-02,Loss_rbc: 1.90818e-02
# Iter 490, Loss: 2.30844e-01, Loss_PDE: 3.98088e-02, Loss_ini: 1.55770e-01, Loss_lbc: 1.86960e-02,Loss_rbc: 1.65692e-02
# Iter 500, Loss: 2.30344e-01, Loss_PDE: 3.93211e-02, Loss_ini: 1.50665e-01, Loss_lbc: 1.93196e-02,Loss_rbc: 2.10379e-02
# Iter 510, Loss: 2.30805e-01, Loss_PDE: 4.14752e-02, Loss_ini: 1.46420e-01, Loss_lbc: 2.09516e-02,Loss_rbc: 2.19577e-02
# Iter 520, Loss: 2.26606e-01, Loss_PDE: 3.77223e-02, Loss_ini: 1.41249e-01, Loss_lbc: 2.42009e-02,Loss_rbc: 2.34337e-02
# Iter 530, Loss: 2.32719e-01, Loss_PDE: 4.33835e-02, Loss_ini: 1.47730e-01, Loss_lbc: 2.10201e-02,Loss_rbc: 2.05860e-02
# Iter 540, Loss: 2.29729e-01, Loss_PDE: 3.26544e-02, Loss_ini: 1.51152e-01, Loss_lbc: 2.14997e-02,Loss_rbc: 2.44236e-02
# Iter 550, Loss: 2.28432e-01, Loss_PDE: 4.45268e-02, Loss_ini: 1.35902e-01, Loss_lbc: 2.34608e-02,Loss_rbc: 2.45423e-02
# Iter 560, Loss: 2.33499e-01, Loss_PDE: 5.22379e-02, Loss_ini: 1.35970e-01, Loss_lbc: 2.20569e-02,Loss_rbc: 2.32336e-02
# Iter 570, Loss: 2.32634e-01, Loss_PDE: 5.86329e-02, Loss_ini: 1.26504e-01, Loss_lbc: 2.20634e-02,Loss_rbc: 2.54331e-02
# Iter 580, Loss: 2.24954e-01, Loss_PDE: 4.03217e-02, Loss_ini: 1.36315e-01, Loss_lbc: 2.48058e-02,Loss_rbc: 2.35108e-02
# Iter 590, Loss: 2.25909e-01, Loss_PDE: 3.76182e-02, Loss_ini: 1.44086e-01, Loss_lbc: 2.12708e-02,Loss_rbc: 2.29335e-02
# Iter 600, Loss: 2.22112e-01, Loss_PDE: 4.02559e-02, Loss_ini: 1.40795e-01, Loss_lbc: 1.84779e-02,Loss_rbc: 2.25838e-02
# Iter 610, Loss: 2.32942e-01, Loss_PDE: 4.31288e-02, Loss_ini: 1.46322e-01, Loss_lbc: 2.15190e-02,Loss_rbc: 2.19723e-02
# Iter 620, Loss: 2.24946e-01, Loss_PDE: 3.39262e-02, Loss_ini: 1.55122e-01, Loss_lbc: 1.87737e-02,Loss_rbc: 1.71244e-02
# Iter 630, Loss: 2.30909e-01, Loss_PDE: 3.86293e-02, Loss_ini: 1.55446e-01, Loss_lbc: 1.78556e-02,Loss_rbc: 1.89780e-02
# Iter 640, Loss: 2.33072e-01, Loss_PDE: 5.47662e-02, Loss_ini: 1.42244e-01, Loss_lbc: 1.75499e-02,Loss_rbc: 1.85117e-02
# Iter 650, Loss: 2.24952e-01, Loss_PDE: 4.46962e-02, Loss_ini: 1.42260e-01, Loss_lbc: 1.86436e-02,Loss_rbc: 1.93523e-02
# Iter 660, Loss: 2.30177e-01, Loss_PDE: 5.02075e-02, Loss_ini: 1.39635e-01, Loss_lbc: 1.84105e-02,Loss_rbc: 2.19236e-02
# Iter 670, Loss: 2.27746e-01, Loss_PDE: 4.46505e-02, Loss_ini: 1.43877e-01, Loss_lbc: 2.06325e-02,Loss_rbc: 1.85857e-02
# Iter 680, Loss: 2.34305e-01, Loss_PDE: 4.85036e-02, Loss_ini: 1.42466e-01, Loss_lbc: 2.08327e-02,Loss_rbc: 2.25028e-02
# Iter 690, Loss: 2.28044e-01, Loss_PDE: 5.56855e-02, Loss_ini: 1.32550e-01, Loss_lbc: 1.97577e-02,Loss_rbc: 2.00510e-02
# Iter 700, Loss: 2.24380e-01, Loss_PDE: 3.98893e-02, Loss_ini: 1.49590e-01, Loss_lbc: 1.77143e-02,Loss_rbc: 1.71870e-02
# Iter 710, Loss: 2.24170e-01, Loss_PDE: 3.51794e-02, Loss_ini: 1.48054e-01, Loss_lbc: 1.97574e-02,Loss_rbc: 2.11792e-02
# Iter 720, Loss: 2.24567e-01, Loss_PDE: 3.66477e-02, Loss_ini: 1.44738e-01, Loss_lbc: 2.04486e-02,Loss_rbc: 2.27326e-02
# Iter 730, Loss: 2.23729e-01, Loss_PDE: 3.97850e-02, Loss_ini: 1.44477e-01, Loss_lbc: 1.93266e-02,Loss_rbc: 2.01402e-02
# Iter 740, Loss: 2.30472e-01, Loss_PDE: 4.60575e-02, Loss_ini: 1.47734e-01, Loss_lbc: 1.70565e-02,Loss_rbc: 1.96243e-02
# Iter 750, Loss: 2.28849e-01, Loss_PDE: 4.51163e-02, Loss_ini: 1.47204e-01, Loss_lbc: 1.78192e-02,Loss_rbc: 1.87099e-02
# Iter 760, Loss: 2.34312e-01, Loss_PDE: 4.58018e-02, Loss_ini: 1.48943e-01, Loss_lbc: 1.87578e-02,Loss_rbc: 2.08093e-02
# Iter 770, Loss: 2.31952e-01, Loss_PDE: 5.04180e-02, Loss_ini: 1.46084e-01, Loss_lbc: 1.78289e-02,Loss_rbc: 1.76206e-02
# Iter 780, Loss: 2.29982e-01, Loss_PDE: 5.23187e-02, Loss_ini: 1.41422e-01, Loss_lbc: 1.82825e-02,Loss_rbc: 1.79581e-02
# Iter 790, Loss: 2.24973e-01, Loss_PDE: 4.70391e-02, Loss_ini: 1.35478e-01, Loss_lbc: 2.28519e-02,Loss_rbc: 1.96035e-02
# Iter 800, Loss: 2.23562e-01, Loss_PDE: 3.60136e-02, Loss_ini: 1.43376e-01, Loss_lbc: 2.18689e-02,Loss_rbc: 2.23040e-02
# Iter 810, Loss: 2.25806e-01, Loss_PDE: 3.56585e-02, Loss_ini: 1.50810e-01, Loss_lbc: 2.05249e-02,Loss_rbc: 1.88130e-02
# Iter 820, Loss: 2.24902e-01, Loss_PDE: 3.97722e-02, Loss_ini: 1.36804e-01, Loss_lbc: 2.43142e-02,Loss_rbc: 2.40121e-02
# Iter 830, Loss: 2.25634e-01, Loss_PDE: 4.88236e-02, Loss_ini: 1.32664e-01, Loss_lbc: 2.27478e-02,Loss_rbc: 2.13994e-02
# Iter 840, Loss: 2.26421e-01, Loss_PDE: 4.06736e-02, Loss_ini: 1.36231e-01, Loss_lbc: 2.15980e-02,Loss_rbc: 2.79179e-02
# Iter 850, Loss: 2.25544e-01, Loss_PDE: 3.94770e-02, Loss_ini: 1.41986e-01, Loss_lbc: 2.07988e-02,Loss_rbc: 2.32827e-02
# Iter 860, Loss: 2.29373e-01, Loss_PDE: 4.52865e-02, Loss_ini: 1.42879e-01, Loss_lbc: 1.95182e-02,Loss_rbc: 2.16898e-02
# Iter 870, Loss: 2.22111e-01, Loss_PDE: 4.44613e-02, Loss_ini: 1.39486e-01, Loss_lbc: 1.80120e-02,Loss_rbc: 2.01520e-02
# Iter 880, Loss: 2.22803e-01, Loss_PDE: 3.64983e-02, Loss_ini: 1.44276e-01, Loss_lbc: 2.24919e-02,Loss_rbc: 1.95367e-02
# Iter 890, Loss: 2.25456e-01, Loss_PDE: 4.14399e-02, Loss_ini: 1.44321e-01, Loss_lbc: 2.13270e-02,Loss_rbc: 1.83689e-02
# Iter 900, Loss: 2.25115e-01, Loss_PDE: 3.82651e-02, Loss_ini: 1.42331e-01, Loss_lbc: 2.25633e-02,Loss_rbc: 2.19563e-02
# Iter 910, Loss: 2.31677e-01, Loss_PDE: 5.15529e-02, Loss_ini: 1.27828e-01, Loss_lbc: 2.89585e-02,Loss_rbc: 2.33384e-02
# Iter 920, Loss: 2.30639e-01, Loss_PDE: 5.67691e-02, Loss_ini: 1.15728e-01, Loss_lbc: 2.71391e-02,Loss_rbc: 3.10025e-02
# Iter 930, Loss: 2.20523e-01, Loss_PDE: 3.68990e-02, Loss_ini: 1.35536e-01, Loss_lbc: 2.30471e-02,Loss_rbc: 2.50405e-02
# Iter 940, Loss: 2.24953e-01, Loss_PDE: 3.64728e-02, Loss_ini: 1.51958e-01, Loss_lbc: 1.83020e-02,Loss_rbc: 1.82199e-02
# Iter 950, Loss: 2.23703e-01, Loss_PDE: 4.81414e-02, Loss_ini: 1.34152e-01, Loss_lbc: 2.13607e-02,Loss_rbc: 2.00490e-02
# Iter 960, Loss: 2.20160e-01, Loss_PDE: 4.07593e-02, Loss_ini: 1.41037e-01, Loss_lbc: 1.76605e-02,Loss_rbc: 2.07031e-02
# Iter 970, Loss: 2.23075e-01, Loss_PDE: 4.33599e-02, Loss_ini: 1.41935e-01, Loss_lbc: 1.78334e-02,Loss_rbc: 1.99471e-02
# Iter 980, Loss: 2.22395e-01, Loss_PDE: 3.85780e-02, Loss_ini: 1.42366e-01, Loss_lbc: 1.93424e-02,Loss_rbc: 2.21084e-02
# Iter 990, Loss: 2.20444e-01, Loss_PDE: 4.33753e-02, Loss_ini: 1.34068e-01, Loss_lbc: 2.06602e-02,Loss_rbc: 2.23410e-02
# Iter 1000, Loss: 2.22230e-01, Loss_PDE: 5.33742e-02, Loss_ini: 1.23808e-01, Loss_lbc: 2.13550e-02,Loss_rbc: 2.36930e-02
# Iter 1010, Loss: 2.24232e-01, Loss_PDE: 4.41432e-02, Loss_ini: 1.34013e-01, Loss_lbc: 2.25355e-02,Loss_rbc: 2.35403e-02
# Iter 1020, Loss: 2.19495e-01, Loss_PDE: 3.85897e-02, Loss_ini: 1.47436e-01, Loss_lbc: 1.55861e-02,Loss_rbc: 1.78829e-02
# Iter 1030, Loss: 2.23936e-01, Loss_PDE: 4.17299e-02, Loss_ini: 1.45226e-01, Loss_lbc: 1.99931e-02,Loss_rbc: 1.69872e-02
# Iter 1040, Loss: 2.17480e-01, Loss_PDE: 4.54507e-02, Loss_ini: 1.36735e-01, Loss_lbc: 1.74808e-02,Loss_rbc: 1.78136e-02
# Iter 1050, Loss: 2.26572e-01, Loss_PDE: 5.50896e-02, Loss_ini: 1.21004e-01, Loss_lbc: 2.43846e-02,Loss_rbc: 2.60940e-02
# Iter 1060, Loss: 2.19538e-01, Loss_PDE: 4.13543e-02, Loss_ini: 1.40231e-01, Loss_lbc: 2.05986e-02,Loss_rbc: 1.73544e-02
# Iter 1070, Loss: 2.21142e-01, Loss_PDE: 3.75546e-02, Loss_ini: 1.50707e-01, Loss_lbc: 1.54547e-02,Loss_rbc: 1.74252e-02
# Iter 1080, Loss: 2.20015e-01, Loss_PDE: 3.88327e-02, Loss_ini: 1.46865e-01, Loss_lbc: 1.96680e-02,Loss_rbc: 1.46495e-02
# Iter 1090, Loss: 2.19606e-01, Loss_PDE: 4.16053e-02, Loss_ini: 1.29614e-01, Loss_lbc: 2.23197e-02,Loss_rbc: 2.60667e-02
# Iter 1100, Loss: 2.20777e-01, Loss_PDE: 4.52055e-02, Loss_ini: 1.30205e-01, Loss_lbc: 2.23856e-02,Loss_rbc: 2.29812e-02
# Iter 1110, Loss: 2.22076e-01, Loss_PDE: 4.55225e-02, Loss_ini: 1.37739e-01, Loss_lbc: 1.83459e-02,Loss_rbc: 2.04683e-02
# Iter 1120, Loss: 2.20936e-01, Loss_PDE: 4.21344e-02, Loss_ini: 1.41497e-01, Loss_lbc: 1.92242e-02,Loss_rbc: 1.80806e-02
# Iter 1130, Loss: 2.27257e-01, Loss_PDE: 4.80897e-02, Loss_ini: 1.37884e-01, Loss_lbc: 1.97976e-02,Loss_rbc: 2.14865e-02
# Iter 1140, Loss: 2.26718e-01, Loss_PDE: 4.29889e-02, Loss_ini: 1.41437e-01, Loss_lbc: 2.17534e-02,Loss_rbc: 2.05379e-02
# Iter 1150, Loss: 2.20341e-01, Loss_PDE: 4.28461e-02, Loss_ini: 1.40623e-01, Loss_lbc: 1.73123e-02,Loss_rbc: 1.95602e-02
# Iter 1160, Loss: 2.22341e-01, Loss_PDE: 5.18824e-02, Loss_ini: 1.36402e-01, Loss_lbc: 1.59896e-02,Loss_rbc: 1.80671e-02
# Iter 1170, Loss: 2.23728e-01, Loss_PDE: 4.90314e-02, Loss_ini: 1.25065e-01, Loss_lbc: 2.49437e-02,Loss_rbc: 2.46883e-02
# Iter 1180, Loss: 2.17126e-01, Loss_PDE: 3.94431e-02, Loss_ini: 1.43000e-01, Loss_lbc: 1.74815e-02,Loss_rbc: 1.72010e-02
# Iter 1190, Loss: 2.23618e-01, Loss_PDE: 4.13360e-02, Loss_ini: 1.41647e-01, Loss_lbc: 1.98111e-02,Loss_rbc: 2.08237e-02
# Starting Training: LBFGS optimizer
# Loss: 2.19602e-01, Loss_PDE: 4.07724e-02, Loss_ini: 1.36117e-01, Loss_lbc: 2.07891e-02,Loss_rbc: 2.19237e-02
# Loss: 2.14775e-01, Loss_PDE: 3.69715e-02, Loss_ini: 1.36857e-01, Loss_lbc: 2.05922e-02,Loss_rbc: 2.03542e-02
# Loss: 2.20656e-01, Loss_PDE: 4.11863e-02, Loss_ini: 1.38574e-01, Loss_lbc: 1.99097e-02,Loss_rbc: 2.09855e-02
# Loss: 2.18273e-01, Loss_PDE: 4.03820e-02, Loss_ini: 1.36759e-01, Loss_lbc: 2.01954e-02,Loss_rbc: 2.09367e-02
# Loss: 2.18337e-01, Loss_PDE: 4.09304e-02, Loss_ini: 1.35918e-01, Loss_lbc: 1.97486e-02,Loss_rbc: 2.17399e-02

# %%
#path = f"./gala/AI4eq/Models/burgers_{nobs}.pt"
path = f"./gala/AI4eq/Models/burgers_mcd.pt"
torch.save(model.state_dict(),path)

# %%
def MCD (dropout_model,X_star, samples = 1000):
    dropout_model.train()

    predictions = []

    for _ in range(samples):
        pred = dropout_model(X_star)  # Perform a forward pass with dropout
        predictions.append(pred.cpu().detach().numpy())  # Store the result

    predictions_mcd = np.array(predictions)
    return np.mean(predictions_mcd, axis=0),np.std(predictions_mcd, axis=0)

# %%
x = np.linspace(-1,1,100)
y = np.linspace(0,1,100)

xx, yy = np.meshgrid(x, y)
xx, yy = torch.tensor(xx).reshape(-1,1).float(),torch.tensor(yy).reshape(-1,1).float()


X_star = torch.cat([xx,yy,torch.ones_like(xx)*(0.005)],axis = 1)
mean, std = MCD (model,X_star, samples = 1000)

fig, axs = plt.subplots(2,1, figsize=(10, 5))

xx,yy = np.meshgrid(x, y)

U_pred = griddata(np.hstack([xx.reshape(-1,1),yy.reshape(-1,1)]), mean[:,0], (xx,yy), method='cubic')
U_sigma = griddata(np.hstack([xx.reshape(-1,1),yy.reshape(-1,1)]), std[:,0], (xx,yy), method='cubic')

axs[0].contourf(y.flatten(), x.flatten(), U_pred.T,cmap='rainbow')

axs[1].plot(x,U_pred[75,:])
axs[1].fill_between(x.reshape(-1), U_pred[75,:]+U_sigma[75,:],U_pred[75,:]-U_sigma[75,:],alpha=0.4, color = "red",label = r"NN Uncertainty ($\sigma^{2})$")
