# %%
import torch
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset

from collections import OrderedDict

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from pyDOE import lhs
from scipy.stats import uniform,norm

import os
import re

os.chdir("/home/s2113174/Projects-1")

np.random.seed(1234)

# CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")

# %% [markdown]
# ## Making the data for an Inverse Problem following the parametric ODE
#
# $$-\frac{d}{dx}(e^{\theta}\frac{du(x)}{dx}) = 1, \quad x\in (0,1),\theta \in [-1,1]$$
# $$u(0) = 0, u(1)=1$$
#
# with solution
# $$ u(x) = \frac{x - x^{2}}{2 e^{\theta}}$$
#
# ## The Problem consist in infering $ \alpha $

# %%
ns = 1
t= np.linspace(0,ns,1000)
mean, std = 0,np.sqrt(1e-5)

Exact = (t - t**2) / 2*np.exp(0.314)

noise_sol = Exact + np.random.normal(mean,std, len(t))

plt.scatter(t,noise_sol)
plt.xlabel("T")
plt.ylabel("Observations")
# Out:
# Text(0, 0.5, 'Observations')

# %% [markdown]
# ## Feed Forward Neural Network

# %%
# Deep neural network
class DNN(torch.nn.Module):
    def __init__(self, layers):
        super(DNN, self).__init__()

        # Number of layers
        self.depth = len(layers) - 1
        
        # Activation Function
        self.activation = torch.nn.Tanh
        
        # The following loop organized the layers of the NN         
        layer_list = list()
        for i in range(self.depth - 1): 
            layer_list.append(
                ('layer_%d' % i, torch.nn.Linear(layers[i], layers[i+1])))
            layer_list.append(('activation_%d' % i, self.activation()))
        layer_list.append(
            ('layer_%d' % (self.depth - 1), torch.nn.Linear(layers[-2], layers[-1]))
        )
        layerDict = OrderedDict(layer_list)
        
        # Deploy layers
        self.layers = torch.nn.Sequential(layerDict)

    def forward(self, x):
        out = self.layers(x)
        return out

# %% [markdown]
# ## Parametric PINN for Inverse Problems

# %%
def DE(self,t,pr):
    """ The pytorch autograd version of calculating residual """
    u = self(torch.cat([t, pr], dim=1))
    
    u_t = torch.autograd.grad(
        u, t, 
        grad_outputs=torch.ones_like(u),
        retain_graph=True,
        create_graph=True
    )[0]

    u_tt = torch.autograd.grad(
        u_t, t, 
        grad_outputs=torch.ones_like(u_t),
        retain_graph=True,
        create_graph=True
    )[0]
    
    f = -torch.exp(pr)*u_tt - 1
    return f

# %%
DNN.DE = DE

# %%
def sample_ic(size):
    return np.zeros(size)

def sample_bc(size):
    return np.ones(size)

def samples_space(size,maxl):
    t_f_train = lhs(1, size)*maxl
    return t_f_train

def samples_param(min,max,size = 100):
    return min + np.random.rand(size)*(max - min)

# %%
def train(epochs, pinn,loss,optimizer,size,maxl,minp,maxp):
   
   print("Starting Training")

   #for epoch in range(epochs):
   itr_loss = 0.0   

   for i in range(epochs):

    ic,bc, t, param = sample_ic(size),sample_bc(size),samples_space(size,maxl),samples_param(minp,maxp,size)

    ic, bc, t, param = torch.tensor(ic).float().to(device),torch.tensor(bc).float().to(device), torch.tensor(t).float().to(device), torch.tensor(param).float().to(device)

    ic, bc ,t, param = Variable(ic,requires_grad=True).reshape(-1,1),Variable(bc,requires_grad=True).reshape(-1,1), Variable(t,requires_grad=True).reshape(-1,1), Variable(param,requires_grad=True).reshape(-1,1)

       
    def loss_func_train():
        
        optimizer.zero_grad()

        ic_pred,bc_pred,f_pred = pinn(torch.cat([ic, param], dim=1)), pinn(torch.cat([bc, param], dim=1)),pinn.DE(t,param)

        loss_u_ic,loss_u_bc,loss_f = loss(ic_pred,torch.zeros_like(t)),loss(bc_pred,torch.zeros_like(t)),loss(f_pred,torch.zeros_like(t))

        Loss =  loss_f + loss_u_ic + loss_u_bc

        if i % 10 == 0:
                print('Iter %d, Loss: %.5e, Loss_ic: %.5e, Loss_f: %.5e' % (i, Loss.item(), loss_u_ic.item(), loss_f.item()))
           
        Loss.backward() 
    
        return Loss

    optimizer.step(loss_func_train) 
    
    oupt = pinn(torch.cat([ic, param], dim=1))  

    loss_val = loss_func_train() 

    itr_loss += loss_val.item()

# %%
# Number of observations
epochs = 150
nobs = 2000
lr = 0.01

min_param , max_param = -1, 1

space = 1

layers = [2] + 4*[50] + [1]

# %%
model = DNN(layers)

# %%
loss = torch.nn.MSELoss(reduction ='mean')

optimizer = torch.optim.LBFGS(
    model.parameters(), lr=lr, max_iter=50000, max_eval=None, tolerance_grad=1e-5, tolerance_change=1.0 * np.finfo(float).eps,line_search_fn="strong_wolfe" 
    )

#optimizer = torch.optim.Adam(model.parameters(), lr = lr)

# %%
#train(epochs, model,loss,optimizer,nobs,space,min_param , max_param)

model.load_state_dict(torch.load("Param_model_2.pt"))
model.eval()
# Out:
# Starting Training
# Iter 0, Loss: 1.00610e+00, Loss_ic: 9.04161e-03, Loss_f: 9.91151e-01
# Iter 0, Loss: 1.00587e+00, Loss_ic: 8.99843e-03, Loss_f: 9.91010e-01
# Iter 0, Loss: 1.00380e+00, Loss_ic: 8.61441e-03, Loss_f: 9.89736e-01
# Iter 0, Loss: 9.84379e-01, Loss_ic: 5.23407e-03, Loss_f: 9.77017e-01
# Iter 0, Loss: 9.82325e-01, Loss_ic: 5.02152e-03, Loss_f: 9.75393e-01
# Iter 0, Loss: 9.64439e-01, Loss_ic: 3.30074e-03, Loss_f: 9.60650e-01
# Iter 0, Loss: 8.57561e-01, Loss_ic: 8.26680e-03, Loss_f: 8.01083e-01
# Iter 0, Loss: 8.56698e-01, Loss_ic: 8.30544e-03, Loss_f: 7.99737e-01
# Iter 0, Loss: 8.52817e-01, Loss_ic: 8.48146e-03, Loss_f: 7.93653e-01
# Iter 0, Loss: 8.11678e-01, Loss_ic: 1.06358e-02, Loss_f: 7.24514e-01
# Iter 0, Loss: 7.18299e-01, Loss_ic: 2.78561e-02, Loss_f: 3.85458e-01
# Iter 0, Loss: 7.15029e-01, Loss_ic: 2.72288e-02, Loss_f: 3.83731e-01
# Iter 0, Loss: 7.00468e-01, Loss_ic: 2.45069e-02, Loss_f: 3.76080e-01
# Iter 0, Loss: 5.63515e-01, Loss_ic: 7.43121e-03, Loss_f: 3.08521e-01
# Iter 0, Loss: 5.57742e-01, Loss_ic: 7.19667e-03, Loss_f: 3.08320e-01
# Iter 0, Loss: 5.09956e-01, Loss_ic: 7.10153e-03, Loss_f: 3.06731e-01
# Iter 0, Loss: 5.06292e-01, Loss_ic: 7.28460e-03, Loss_f: 3.05537e-01
# Iter 0, Loss: 4.75513e-01, Loss_ic: 1.01633e-02, Loss_f: 2.96098e-01
# Iter 0, Loss: 4.72482e-01, Loss_ic: 1.04378e-02, Loss_f: 2.95858e-01
# Iter 0, Loss: 4.46788e-01, Loss_ic: 1.36341e-02, Loss_f: 2.93933e-01
# Iter 0, Loss: 4.44424e-01, Loss_ic: 1.39906e-02, Loss_f: 2.93492e-01
# Iter 0, Loss: 4.24327e-01, Loss_ic: 1.77712e-02, Loss_f: 2.89966e-01
# Iter 0, Loss: 4.22419e-01, Loss_ic: 1.80984e-02, Loss_f: 2.89743e-01
# Iter 0, Loss: 4.06169e-01, Loss_ic: 2.14144e-02, Loss_f: 2.87960e-01
# Iter 0, Loss: 4.04617e-01, Loss_ic: 2.17220e-02, Loss_f: 2.87732e-01
# Iter 0, Loss: 3.97821e-01, Loss_ic: 2.31829e-02, Loss_f: 2.86762e-01
# Iter 0, Loss: 3.51708e-01, Loss_ic: 4.89619e-02, Loss_f: 2.81754e-01
# Iter 0, Loss: 3.51552e-01, Loss_ic: 4.89672e-02, Loss_f: 2.81729e-01
# Iter 0, Loss: 3.50855e-01, Loss_ic: 4.89922e-02, Loss_f: 2.81618e-01
# Iter 0, Loss: 3.44039e-01, Loss_ic: 4.94248e-02, Loss_f: 2.80525e-01
# Iter 0, Loss: 3.43479e-01, Loss_ic: 4.92797e-02, Loss_f: 2.80318e-01
# Iter 0, Loss: 3.38579e-01, Loss_ic: 4.80251e-02, Loss_f: 2.78472e-01
# Iter 0, Loss: 3.03856e-01, Loss_ic: 4.06899e-02, Loss_f: 2.61203e-01
# Iter 0, Loss: 3.03237e-01, Loss_ic: 4.04806e-02, Loss_f: 2.60776e-01
# Iter 0, Loss: 2.97797e-01, Loss_ic: 3.86899e-02, Loss_f: 2.56939e-01
# Iter 0, Loss: 2.58843e-01, Loss_ic: 3.04758e-02, Loss_f: 2.20116e-01
# Iter 0, Loss: 2.57882e-01, Loss_ic: 3.02497e-02, Loss_f: 2.19284e-01
# Iter 0, Loss: 2.49392e-01, Loss_ic: 2.83200e-02, Loss_f: 2.11831e-01
# Iter 0, Loss: 1.93273e-01, Loss_ic: 2.55592e-02, Loss_f: 1.46171e-01
# Iter 0, Loss: 1.92521e-01, Loss_ic: 2.54331e-02, Loss_f: 1.45547e-01
# Iter 0, Loss: 1.85978e-01, Loss_ic: 2.44356e-02, Loss_f: 1.40001e-01
# Iter 0, Loss: 1.51021e-01, Loss_ic: 3.26474e-02, Loss_f: 9.38169e-02
# Iter 0, Loss: 1.50221e-01, Loss_ic: 3.22965e-02, Loss_f: 9.35879e-02
# Iter 0, Loss: 1.43252e-01, Loss_ic: 2.92428e-02, Loss_f: 9.16105e-02
# Iter 0, Loss: 9.95103e-02, Loss_ic: 1.01364e-02, Loss_f: 8.15495e-02
# Iter 0, Loss: 9.92034e-02, Loss_ic: 1.00288e-02, Loss_f: 8.13840e-02
# Iter 0, Loss: 9.78542e-02, Loss_ic: 9.55713e-03, Loss_f: 8.06499e-02
# Iter 0, Loss: 8.68737e-02, Loss_ic: 5.91493e-03, Loss_f: 7.38101e-02
# Iter 0, Loss: 8.66706e-02, Loss_ic: 5.85006e-03, Loss_f: 7.36586e-02
# Iter 0, Loss: 8.57767e-02, Loss_ic: 5.56848e-03, Loss_f: 7.29852e-02
# Iter 0, Loss: 7.83515e-02, Loss_ic: 3.68629e-03, Loss_f: 6.66187e-02
# Iter 0, Loss: 7.82031e-02, Loss_ic: 3.69223e-03, Loss_f: 6.64616e-02
# Iter 0, Loss: 7.75500e-02, Loss_ic: 3.72130e-03, Loss_f: 6.57667e-02
# Iter 0, Loss: 7.21138e-02, Loss_ic: 4.29989e-03, Loss_f: 5.95877e-02
# Iter 0, Loss: 7.19189e-02, Loss_ic: 4.29980e-03, Loss_f: 5.94283e-02
# Iter 0, Loss: 7.02343e-02, Loss_ic: 4.31903e-03, Loss_f: 5.80318e-02
# Iter 0, Loss: 6.01950e-02, Loss_ic: 6.57464e-03, Loss_f: 4.77407e-02
# Iter 0, Loss: 5.99967e-02, Loss_ic: 6.53570e-03, Loss_f: 4.75698e-02
# Iter 0, Loss: 5.84527e-02, Loss_ic: 6.19017e-03, Loss_f: 4.62684e-02
# Iter 0, Loss: 5.83192e-02, Loss_ic: 6.14674e-03, Loss_f: 4.61837e-02
# Iter 0, Loss: 5.71642e-02, Loss_ic: 5.76511e-03, Loss_f: 4.54547e-02
# Iter 0, Loss: 5.00435e-02, Loss_ic: 2.93029e-03, Loss_f: 4.11347e-02
# Iter 0, Loss: 4.99841e-02, Loss_ic: 2.92041e-03, Loss_f: 4.11020e-02
# Iter 0, Loss: 4.97193e-02, Loss_ic: 2.87645e-03, Loss_f: 4.09569e-02
# Iter 0, Loss: 4.71305e-02, Loss_ic: 2.45087e-03, Loss_f: 3.96106e-02
# Iter 0, Loss: 4.69193e-02, Loss_ic: 2.44159e-03, Loss_f: 3.94692e-02
# Iter 0, Loss: 4.50891e-02, Loss_ic: 2.37264e-03, Loss_f: 3.82425e-02
# Iter 0, Loss: 3.74288e-02, Loss_ic: 2.77498e-03, Loss_f: 3.39713e-02
# Iter 0, Loss: 3.73330e-02, Loss_ic: 2.76342e-03, Loss_f: 3.38846e-02
# Iter 0, Loss: 3.65212e-02, Loss_ic: 2.66257e-03, Loss_f: 3.31510e-02
# Iter 0, Loss: 3.64026e-02, Loss_ic: 2.66513e-03, Loss_f: 3.30278e-02
# Iter 0, Loss: 3.53778e-02, Loss_ic: 2.69102e-03, Loss_f: 3.19587e-02
# Iter 0, Loss: 2.96838e-02, Loss_ic: 3.27886e-03, Loss_f: 2.54580e-02
# Iter 0, Loss: 2.96509e-02, Loss_ic: 3.27650e-03, Loss_f: 2.54253e-02
# Iter 0, Loss: 2.93630e-02, Loss_ic: 3.25572e-03, Loss_f: 2.51384e-02
# Iter 0, Loss: 2.74712e-02, Loss_ic: 3.10344e-03, Loss_f: 2.31596e-02
# Iter 0, Loss: 2.74013e-02, Loss_ic: 3.10680e-03, Loss_f: 2.30727e-02
# Iter 0, Loss: 2.71048e-02, Loss_ic: 3.12235e-03, Loss_f: 2.26972e-02
# Iter 0, Loss: 2.70641e-02, Loss_ic: 3.12341e-03, Loss_f: 2.26521e-02
# Iter 0, Loss: 2.68854e-02, Loss_ic: 3.12832e-03, Loss_f: 2.24529e-02
# Iter 0, Loss: 2.54437e-02, Loss_ic: 3.19784e-03, Loss_f: 2.06995e-02
# Iter 0, Loss: 2.54255e-02, Loss_ic: 3.19426e-03, Loss_f: 2.06784e-02
# Iter 0, Loss: 2.53457e-02, Loss_ic: 3.17825e-03, Loss_f: 2.05850e-02
# Iter 0, Loss: 2.46778e-02, Loss_ic: 3.01226e-03, Loss_f: 1.97247e-02
# Iter 0, Loss: 2.46626e-02, Loss_ic: 3.01046e-03, Loss_f: 1.97083e-02
# Iter 0, Loss: 2.45953e-02, Loss_ic: 3.00241e-03, Loss_f: 1.96353e-02
# Iter 0, Loss: 2.39728e-02, Loss_ic: 2.91744e-03, Loss_f: 1.89329e-02
# Iter 0, Loss: 2.39478e-02, Loss_ic: 2.91057e-03, Loss_f: 1.89095e-02
# Iter 0, Loss: 2.37304e-02, Loss_ic: 2.84922e-03, Loss_f: 1.87051e-02
# Iter 0, Loss: 2.22242e-02, Loss_ic: 2.28580e-03, Loss_f: 1.72445e-02
# Iter 0, Loss: 2.21938e-02, Loss_ic: 2.28059e-03, Loss_f: 1.72186e-02
# Iter 0, Loss: 2.19248e-02, Loss_ic: 2.23412e-03, Loss_f: 1.69900e-02
# Iter 0, Loss: 1.96726e-02, Loss_ic: 1.81313e-03, Loss_f: 1.51192e-02
# Iter 0, Loss: 1.95703e-02, Loss_ic: 1.79500e-03, Loss_f: 1.50418e-02
# Iter 0, Loss: 1.91190e-02, Loss_ic: 1.71477e-03, Loss_f: 1.47018e-02
# Iter 0, Loss: 1.55131e-02, Loss_ic: 9.85871e-04, Loss_f: 1.22151e-02
# Iter 0, Loss: 1.54326e-02, Loss_ic: 9.77516e-04, Loss_f: 1.21591e-02
# Iter 0, Loss: 1.50806e-02, Loss_ic: 9.41250e-04, Loss_f: 1.19152e-02
# Iter 0, Loss: 1.25295e-02, Loss_ic: 6.95194e-04, Loss_f: 1.03278e-02
# Iter 0, Loss: 1.24854e-02, Loss_ic: 6.90550e-04, Loss_f: 1.02982e-02
# Iter 0, Loss: 1.21024e-02, Loss_ic: 6.49417e-04, Loss_f: 1.00436e-02
# Iter 0, Loss: 9.79592e-03, Loss_ic: 3.06388e-04, Loss_f: 8.77561e-03
# Iter 0, Loss: 9.77406e-03, Loss_ic: 3.06023e-04, Loss_f: 8.75641e-03
# Iter 0, Loss: 9.67933e-03, Loss_ic: 3.04557e-04, Loss_f: 8.67331e-03
# Iter 0, Loss: 9.03903e-03, Loss_ic: 3.07482e-04, Loss_f: 8.12612e-03
# Iter 0, Loss: 9.02779e-03, Loss_ic: 3.07496e-04, Loss_f: 8.11730e-03
# Iter 0, Loss: 8.93276e-03, Loss_ic: 3.08061e-04, Loss_f: 8.04336e-03
# Iter 0, Loss: 8.91689e-03, Loss_ic: 3.07334e-04, Loss_f: 8.03117e-03
# Iter 0, Loss: 8.84697e-03, Loss_ic: 3.04335e-04, Loss_f: 7.97738e-03
# Iter 0, Loss: 8.26115e-03, Loss_ic: 3.02253e-04, Loss_f: 7.51588e-03
# Iter 0, Loss: 8.24883e-03, Loss_ic: 3.02863e-04, Loss_f: 7.50485e-03
# Iter 0, Loss: 8.14237e-03, Loss_ic: 3.08452e-04, Loss_f: 7.40970e-03
# Iter 0, Loss: 7.56333e-03, Loss_ic: 3.74872e-04, Loss_f: 6.90619e-03
# Iter 0, Loss: 7.55574e-03, Loss_ic: 3.73489e-04, Loss_f: 6.90026e-03
# Iter 0, Loss: 7.48869e-03, Loss_ic: 3.61339e-04, Loss_f: 6.84774e-03
# Iter 0, Loss: 6.95040e-03, Loss_ic: 2.70712e-04, Loss_f: 6.40611e-03
# Iter 0, Loss: 6.93027e-03, Loss_ic: 2.67196e-04, Loss_f: 6.39082e-03
# Iter 0, Loss: 6.84134e-03, Loss_ic: 2.51708e-04, Loss_f: 6.32328e-03
# Iter 0, Loss: 6.05335e-03, Loss_ic: 1.18037e-04, Loss_f: 5.72529e-03
# Iter 0, Loss: 6.03468e-03, Loss_ic: 1.15707e-04, Loss_f: 5.71081e-03
# Iter 0, Loss: 5.95219e-03, Loss_ic: 1.05600e-04, Loss_f: 5.64664e-03
# Iter 0, Loss: 5.21675e-03, Loss_ic: 3.53119e-05, Loss_f: 5.05378e-03
# Iter 0, Loss: 5.19847e-03, Loss_ic: 3.43551e-05, Loss_f: 5.03778e-03
# Iter 0, Loss: 5.03951e-03, Loss_ic: 2.71583e-05, Loss_f: 4.89714e-03
# Iter 0, Loss: 3.97803e-03, Loss_ic: 8.05458e-05, Loss_f: 3.80860e-03
# Iter 0, Loss: 3.96254e-03, Loss_ic: 8.11347e-05, Loss_f: 3.79338e-03
# Iter 0, Loss: 3.89426e-03, Loss_ic: 8.39829e-05, Loss_f: 3.72560e-03
# Iter 0, Loss: 3.30758e-03, Loss_ic: 1.41746e-04, Loss_f: 3.06503e-03
# Iter 0, Loss: 3.28893e-03, Loss_ic: 1.40822e-04, Loss_f: 3.04673e-03
# Iter 0, Loss: 3.12887e-03, Loss_ic: 1.33238e-04, Loss_f: 2.88849e-03
# Iter 0, Loss: 2.32255e-03, Loss_ic: 1.03630e-04, Loss_f: 1.98344e-03
# Iter 0, Loss: 2.31459e-03, Loss_ic: 1.02896e-04, Loss_f: 1.97809e-03
# Iter 0, Loss: 2.24686e-03, Loss_ic: 9.64736e-05, Loss_f: 1.93226e-03
# Iter 0, Loss: 2.23867e-03, Loss_ic: 9.58434e-05, Loss_f: 1.92633e-03
# Iter 0, Loss: 2.20272e-03, Loss_ic: 9.30568e-05, Loss_f: 1.90029e-03
# Iter 0, Loss: 1.90589e-03, Loss_ic: 6.82738e-05, Loss_f: 1.68452e-03
# Iter 0, Loss: 1.90199e-03, Loss_ic: 6.76071e-05, Loss_f: 1.68186e-03
# Iter 0, Loss: 1.86822e-03, Loss_ic: 6.17975e-05, Loss_f: 1.65874e-03
# Iter 0, Loss: 1.65833e-03, Loss_ic: 2.26929e-05, Loss_f: 1.50738e-03
# Iter 0, Loss: 1.65667e-03, Loss_ic: 2.25747e-05, Loss_f: 1.50608e-03
# Iter 0, Loss: 1.64232e-03, Loss_ic: 2.15937e-05, Loss_f: 1.49481e-03
# Iter 0, Loss: 1.55784e-03, Loss_ic: 2.02315e-05, Loss_f: 1.41953e-03
# Iter 0, Loss: 1.55619e-03, Loss_ic: 2.02371e-05, Loss_f: 1.41793e-03
# Iter 0, Loss: 1.54179e-03, Loss_ic: 2.03285e-05, Loss_f: 1.40389e-03
# Iter 0, Loss: 1.44772e-03, Loss_ic: 2.54212e-05, Loss_f: 1.29270e-03
# Iter 0, Loss: 1.44576e-03, Loss_ic: 2.53769e-05, Loss_f: 1.29047e-03
# Iter 0, Loss: 1.43704e-03, Loss_ic: 2.52016e-05, Loss_f: 1.28049e-03
# Iter 0, Loss: 1.35116e-03, Loss_ic: 2.57426e-05, Loss_f: 1.17661e-03
# Iter 0, Loss: 1.34432e-03, Loss_ic: 2.56688e-05, Loss_f: 1.16861e-03
# Iter 0, Loss: 1.31422e-03, Loss_ic: 2.53545e-05, Loss_f: 1.13313e-03
# Iter 0, Loss: 1.06504e-03, Loss_ic: 2.37042e-05, Loss_f: 8.08303e-04
# Iter 0, Loss: 1.05993e-03, Loss_ic: 2.35745e-05, Loss_f: 8.02313e-04
# Iter 0, Loss: 1.01694e-03, Loss_ic: 2.24922e-05, Loss_f: 7.51065e-04
# Iter 0, Loss: 1.01247e-03, Loss_ic: 2.22687e-05, Loss_f: 7.45818e-04
# Iter 0, Loss: 9.92905e-04, Loss_ic: 2.13015e-05, Loss_f: 7.22644e-04
# Iter 0, Loss: 8.43449e-04, Loss_ic: 1.46279e-05, Loss_f: 5.21706e-04
# Iter 0, Loss: 8.41921e-04, Loss_ic: 1.45177e-05, Loss_f: 5.20065e-04
# Iter 0, Loss: 8.35218e-04, Loss_ic: 1.40350e-05, Loss_f: 5.12830e-04
# Iter 0, Loss: 7.81666e-04, Loss_ic: 1.01997e-05, Loss_f: 4.50761e-04
# Iter 0, Loss: 7.80919e-04, Loss_ic: 1.01646e-05, Loss_f: 4.49871e-04
# Iter 0, Loss: 7.77626e-04, Loss_ic: 1.00136e-05, Loss_f: 4.45914e-04
# Iter 0, Loss: 7.49589e-04, Loss_ic: 9.17498e-06, Loss_f: 4.08330e-04
# Iter 0, Loss: 7.48880e-04, Loss_ic: 9.16649e-06, Loss_f: 4.07784e-04
# Iter 0, Loss: 7.42727e-04, Loss_ic: 9.11668e-06, Loss_f: 4.03034e-04
# Iter 0, Loss: 7.02770e-04, Loss_ic: 1.12436e-05, Loss_f: 3.70725e-04
# Iter 0, Loss: 7.02217e-04, Loss_ic: 1.12568e-05, Loss_f: 3.70330e-04
# Iter 0, Loss: 6.97427e-04, Loss_ic: 1.14116e-05, Loss_f: 3.66907e-04
# Iter 0, Loss: 6.67643e-04, Loss_ic: 1.65902e-05, Loss_f: 3.45830e-04
# Iter 0, Loss: 6.67032e-04, Loss_ic: 1.65721e-05, Loss_f: 3.45775e-04
# Iter 0, Loss: 6.61726e-04, Loss_ic: 1.64207e-05, Loss_f: 3.45422e-04
# Iter 0, Loss: 6.26907e-04, Loss_ic: 1.58185e-05, Loss_f: 3.55529e-04
# Iter 0, Loss: 6.26487e-04, Loss_ic: 1.57791e-05, Loss_f: 3.55614e-04
# Iter 0, Loss: 6.22823e-04, Loss_ic: 1.54317e-05, Loss_f: 3.56458e-04
# Iter 0, Loss: 5.97263e-04, Loss_ic: 1.27814e-05, Loss_f: 3.72243e-04
# Iter 0, Loss: 5.96961e-04, Loss_ic: 1.27407e-05, Loss_f: 3.72310e-04
# Iter 0, Loss: 5.94325e-04, Loss_ic: 1.23875e-05, Loss_f: 3.72958e-04
# Iter 0, Loss: 5.75205e-04, Loss_ic: 1.01504e-05, Loss_f: 3.83558e-04
# Iter 0, Loss: 5.74854e-04, Loss_ic: 1.01396e-05, Loss_f: 3.83522e-04
# Iter 0, Loss: 5.71823e-04, Loss_ic: 1.00540e-05, Loss_f: 3.83240e-04
# Iter 0, Loss: 5.49152e-04, Loss_ic: 1.01930e-05, Loss_f: 3.84271e-04
# Iter 0, Loss: 5.48739e-04, Loss_ic: 1.02005e-05, Loss_f: 3.84110e-04
# Iter 0, Loss: 5.46911e-04, Loss_ic: 1.02363e-05, Loss_f: 3.83411e-04
# Iter 0, Loss: 5.30501e-04, Loss_ic: 1.08947e-05, Loss_f: 3.78639e-04
# Iter 0, Loss: 5.29847e-04, Loss_ic: 1.08676e-05, Loss_f: 3.78234e-04
# Iter 0, Loss: 5.24198e-04, Loss_ic: 1.06544e-05, Loss_f: 3.74754e-04
# Iter 0, Loss: 4.92082e-04, Loss_ic: 1.14605e-05, Loss_f: 3.56479e-04
# Iter 0, Loss: 4.91670e-04, Loss_ic: 1.14380e-05, Loss_f: 3.56228e-04
# Iter 0, Loss: 4.88087e-04, Loss_ic: 1.12482e-05, Loss_f: 3.54051e-04
# Iter 0, Loss: 4.64857e-04, Loss_ic: 1.06102e-05, Loss_f: 3.39594e-04
# Iter 0, Loss: 4.64544e-04, Loss_ic: 1.06057e-05, Loss_f: 3.39233e-04
# Iter 0, Loss: 4.61795e-04, Loss_ic: 1.05656e-05, Loss_f: 3.36045e-04
# Iter 0, Loss: 4.49920e-04, Loss_ic: 1.03878e-05, Loss_f: 3.21617e-04
# Iter 0, Loss: 4.49413e-04, Loss_ic: 1.03835e-05, Loss_f: 3.20982e-04
# Iter 0, Loss: 4.45035e-04, Loss_ic: 1.03484e-05, Loss_f: 3.15435e-04
# Iter 0, Loss: 4.19433e-04, Loss_ic: 1.03562e-05, Loss_f: 2.76579e-04
# Iter 0, Loss: 4.19298e-04, Loss_ic: 1.03609e-05, Loss_f: 2.76417e-04
# Iter 0, Loss: 4.18695e-04, Loss_ic: 1.03821e-05, Loss_f: 2.75692e-04
# Iter 0, Loss: 4.12784e-04, Loss_ic: 1.06281e-05, Loss_f: 2.68379e-04
# Iter 0, Loss: 4.12478e-04, Loss_ic: 1.06386e-05, Loss_f: 2.68053e-04
# Iter 0, Loss: 4.11129e-04, Loss_ic: 1.06862e-05, Loss_f: 2.66611e-04
# Iter 0, Loss: 4.04566e-04, Loss_ic: 1.09659e-05, Loss_f: 2.59349e-04
# Iter 0, Loss: 4.04263e-04, Loss_ic: 1.09815e-05, Loss_f: 2.59033e-04
# Iter 0, Loss: 4.02928e-04, Loss_ic: 1.10529e-05, Loss_f: 2.57635e-04
# Iter 0, Loss: 3.91454e-04, Loss_ic: 1.19593e-05, Loss_f: 2.44769e-04
# Iter 0, Loss: 3.91254e-04, Loss_ic: 1.19790e-05, Loss_f: 2.44553e-04
# Iter 0, Loss: 3.90363e-04, Loss_ic: 1.20692e-05, Loss_f: 2.43595e-04
# Iter 0, Loss: 3.82270e-04, Loss_ic: 1.31873e-05, Loss_f: 2.34342e-04
# Iter 0, Loss: 3.82021e-04, Loss_ic: 1.32229e-05, Loss_f: 2.34080e-04
# Iter 0, Loss: 3.80914e-04, Loss_ic: 1.33858e-05, Loss_f: 2.32913e-04
# Iter 0, Loss: 3.70665e-04, Loss_ic: 1.54134e-05, Loss_f: 2.21600e-04
# Iter 0, Loss: 3.70288e-04, Loss_ic: 1.54838e-05, Loss_f: 2.21219e-04
# Iter 0, Loss: 3.67003e-04, Loss_ic: 1.61368e-05, Loss_f: 2.17865e-04
# Iter 0, Loss: 3.53226e-04, Loss_ic: 1.99244e-05, Loss_f: 2.03181e-04
# Iter 0, Loss: 3.52692e-04, Loss_ic: 2.00575e-05, Loss_f: 2.02660e-04
# Iter 0, Loss: 3.48040e-04, Loss_ic: 2.12950e-05, Loss_f: 1.98098e-04
# Iter 0, Loss: 3.16512e-04, Loss_ic: 3.76400e-05, Loss_f: 1.63831e-04
# Iter 0, Loss: 3.16118e-04, Loss_ic: 3.77888e-05, Loss_f: 1.63460e-04
# Iter 0, Loss: 3.12663e-04, Loss_ic: 3.91482e-05, Loss_f: 1.60185e-04
# Iter 0, Loss: 2.86783e-04, Loss_ic: 5.47884e-05, Loss_f: 1.33432e-04
# Iter 0, Loss: 2.86400e-04, Loss_ic: 5.49277e-05, Loss_f: 1.33085e-04
# Iter 0, Loss: 2.84714e-04, Loss_ic: 5.55586e-05, Loss_f: 1.31544e-04
# Iter 0, Loss: 2.76568e-04, Loss_ic: 5.91469e-05, Loss_f: 1.23800e-04
# Iter 0, Loss: 2.76244e-04, Loss_ic: 5.92413e-05, Loss_f: 1.23510e-04
# Iter 0, Loss: 2.74819e-04, Loss_ic: 5.96685e-05, Loss_f: 1.22233e-04
# Iter 0, Loss: 2.63394e-04, Loss_ic: 6.45450e-05, Loss_f: 1.11285e-04
# Iter 0, Loss: 2.63296e-04, Loss_ic: 6.45670e-05, Loss_f: 1.11224e-04
# Iter 0, Loss: 2.62863e-04, Loss_ic: 6.46669e-05, Loss_f: 1.10959e-04
# Iter 0, Loss: 2.59436e-04, Loss_ic: 6.58169e-05, Loss_f: 1.08968e-04
# Iter 0, Loss: 2.59399e-04, Loss_ic: 6.58258e-05, Loss_f: 1.08963e-04
# Iter 0, Loss: 2.59269e-04, Loss_ic: 6.58581e-05, Loss_f: 1.08946e-04
# Iter 0, Loss: 2.58616e-04, Loss_ic: 6.60457e-05, Loss_f: 1.08926e-04
# Iter 0, Loss: 2.58581e-04, Loss_ic: 6.60399e-05, Loss_f: 1.08944e-04
# Iter 0, Loss: 2.58429e-04, Loss_ic: 6.60139e-05, Loss_f: 1.09027e-04
# Iter 0, Loss: 2.57340e-04, Loss_ic: 6.57882e-05, Loss_f: 1.09956e-04
# Iter 0, Loss: 2.57309e-04, Loss_ic: 6.57793e-05, Loss_f: 1.09982e-04
# Iter 0, Loss: 2.57170e-04, Loss_ic: 6.57393e-05, Loss_f: 1.10105e-04
# Iter 0, Loss: 2.56482e-04, Loss_ic: 6.55202e-05, Loss_f: 1.10835e-04
# Iter 0, Loss: 2.56424e-04, Loss_ic: 6.54979e-05, Loss_f: 1.10877e-04
# Iter 0, Loss: 2.56089e-04, Loss_ic: 6.53639e-05, Loss_f: 1.11136e-04
# Iter 0, Loss: 2.54529e-04, Loss_ic: 6.46633e-05, Loss_f: 1.12639e-04
# Iter 0, Loss: 2.54429e-04, Loss_ic: 6.46261e-05, Loss_f: 1.12695e-04
# Iter 0, Loss: 2.53625e-04, Loss_ic: 6.43150e-05, Loss_f: 1.13173e-04
# Iter 0, Loss: 2.47921e-04, Loss_ic: 6.12508e-05, Loss_f: 1.19414e-04
# Iter 0, Loss: 2.47813e-04, Loss_ic: 6.12065e-05, Loss_f: 1.19448e-04
# Iter 0, Loss: 2.47331e-04, Loss_ic: 6.10071e-05, Loss_f: 1.19603e-04
# Iter 0, Loss: 2.44808e-04, Loss_ic: 5.99179e-05, Loss_f: 1.20521e-04
# Iter 0, Loss: 2.44323e-04, Loss_ic: 5.97572e-05, Loss_f: 1.20525e-04
# Iter 0, Loss: 2.40097e-04, Loss_ic: 5.83235e-05, Loss_f: 1.20598e-04
# Iter 0, Loss: 2.10869e-04, Loss_ic: 4.51707e-05, Loss_f: 1.25023e-04
# Iter 0, Loss: 2.10433e-04, Loss_ic: 4.50123e-05, Loss_f: 1.24887e-04
# Iter 0, Loss: 2.08494e-04, Loss_ic: 4.43026e-05, Loss_f: 1.24278e-04
# Iter 0, Loss: 1.98517e-04, Loss_ic: 4.05186e-05, Loss_f: 1.21146e-04
# Iter 0, Loss: 1.97359e-04, Loss_ic: 4.01567e-05, Loss_f: 1.20579e-04
# Iter 0, Loss: 1.87396e-04, Loss_ic: 3.69818e-05, Loss_f: 1.15678e-04
# Iter 0, Loss: 1.42407e-04, Loss_ic: 1.42046e-05, Loss_f: 9.45099e-05
# Iter 0, Loss: 1.41997e-04, Loss_ic: 1.41560e-05, Loss_f: 9.42035e-05
# Iter 0, Loss: 1.38471e-04, Loss_ic: 1.37302e-05, Loss_f: 9.15895e-05
# Iter 0, Loss: 1.20350e-04, Loss_ic: 1.05943e-05, Loss_f: 7.99341e-05
# Iter 0, Loss: 1.20187e-04, Loss_ic: 1.05813e-05, Loss_f: 7.98081e-05
# Iter 0, Loss: 1.19467e-04, Loss_ic: 1.05230e-05, Loss_f: 7.92530e-05
# Iter 0, Loss: 1.13092e-04, Loss_ic: 9.92807e-06, Loss_f: 7.45989e-05
# Iter 0, Loss: 1.12903e-04, Loss_ic: 9.89347e-06, Loss_f: 7.44865e-05
# Iter 0, Loss: 1.11303e-04, Loss_ic: 9.59758e-06, Loss_f: 7.35510e-05
# Iter 0, Loss: 1.11153e-04, Loss_ic: 9.58623e-06, Loss_f: 7.34531e-05
# Iter 0, Loss: 1.10494e-04, Loss_ic: 9.53689e-06, Loss_f: 7.30277e-05
# Iter 0, Loss: 1.05315e-04, Loss_ic: 9.21248e-06, Loss_f: 7.01084e-05
# Iter 0, Loss: 1.05269e-04, Loss_ic: 9.20995e-06, Loss_f: 7.00855e-05
# Iter 0, Loss: 1.05063e-04, Loss_ic: 9.19939e-06, Loss_f: 6.99863e-05
# Iter 0, Loss: 1.03429e-04, Loss_ic: 9.18768e-06, Loss_f: 6.93213e-05
# Iter 0, Loss: 1.03407e-04, Loss_ic: 9.18742e-06, Loss_f: 6.93170e-05
# Iter 0, Loss: 1.03311e-04, Loss_ic: 9.18657e-06, Loss_f: 6.92990e-05
# Iter 0, Loss: 1.02810e-04, Loss_ic: 9.19226e-06, Loss_f: 6.92733e-05
# Iter 0, Loss: 1.02793e-04, Loss_ic: 9.19216e-06, Loss_f: 6.92690e-05
# Iter 0, Loss: 1.02716e-04, Loss_ic: 9.19190e-06, Loss_f: 6.92501e-05
# Iter 0, Loss: 1.02019e-04, Loss_ic: 9.20695e-06, Loss_f: 6.91658e-05
# Iter 0, Loss: 1.01988e-04, Loss_ic: 9.20043e-06, Loss_f: 6.91566e-05
# Iter 0, Loss: 1.01852e-04, Loss_ic: 9.17143e-06, Loss_f: 6.91160e-05
# Iter 0, Loss: 1.01149e-04, Loss_ic: 9.01668e-06, Loss_f: 6.89322e-05
# Iter 0, Loss: 1.01059e-04, Loss_ic: 8.99056e-06, Loss_f: 6.89005e-05
# Iter 0, Loss: 1.00276e-04, Loss_ic: 8.76018e-06, Loss_f: 6.86353e-05
# Iter 0, Loss: 9.48713e-05, Loss_ic: 6.80574e-06, Loss_f: 6.79689e-05
# Iter 0, Loss: 9.47822e-05, Loss_ic: 6.77026e-06, Loss_f: 6.79348e-05
# Iter 0, Loss: 9.43863e-05, Loss_ic: 6.61194e-06, Loss_f: 6.77854e-05
# Iter 0, Loss: 9.06653e-05, Loss_ic: 5.02205e-06, Loss_f: 6.65943e-05
# Iter 0, Loss: 9.05075e-05, Loss_ic: 4.96077e-06, Loss_f: 6.65284e-05
# Iter 0, Loss: 8.98128e-05, Loss_ic: 4.69041e-06, Loss_f: 6.62419e-05
# Iter 0, Loss: 8.64616e-05, Loss_ic: 3.36923e-06, Loss_f: 6.49641e-05
# Iter 0, Loss: 8.63097e-05, Loss_ic: 3.32269e-06, Loss_f: 6.48776e-05
# Iter 0, Loss: 8.50124e-05, Loss_ic: 2.92568e-06, Loss_f: 6.41442e-05
# Iter 0, Loss: 8.48553e-05, Loss_ic: 2.87923e-06, Loss_f: 6.40513e-05
# Iter 0, Loss: 8.35181e-05, Loss_ic: 2.48561e-06, Loss_f: 6.32669e-05
# Iter 0, Loss: 8.33801e-05, Loss_ic: 2.45118e-06, Loss_f: 6.31723e-05
# Iter 0, Loss: 8.22022e-05, Loss_ic: 2.15894e-06, Loss_f: 6.23650e-05
# Iter 0, Loss: 8.20760e-05, Loss_ic: 2.12893e-06, Loss_f: 6.22794e-05
# Iter 0, Loss: 8.15218e-05, Loss_ic: 1.99801e-06, Loss_f: 6.19042e-05
# Iter 0, Loss: 7.71293e-05, Loss_ic: 1.04381e-06, Loss_f: 5.89789e-05
# Iter 0, Loss: 7.70877e-05, Loss_ic: 1.03965e-06, Loss_f: 5.89420e-05
# Iter 0, Loss: 7.69109e-05, Loss_ic: 1.02242e-06, Loss_f: 5.87843e-05
# Iter 0, Loss: 7.60975e-05, Loss_ic: 9.60771e-07, Loss_f: 5.80340e-05
# Iter 0, Loss: 7.60729e-05, Loss_ic: 9.58153e-07, Loss_f: 5.80143e-05
# Iter 0, Loss: 7.58625e-05, Loss_ic: 9.37868e-07, Loss_f: 5.78443e-05
# Iter 0, Loss: 7.49920e-05, Loss_ic: 9.50049e-07, Loss_f: 5.70709e-05
# Iter 0, Loss: 7.49818e-05, Loss_ic: 9.51002e-07, Loss_f: 5.70593e-05
# Iter 0, Loss: 7.48933e-05, Loss_ic: 9.60148e-07, Loss_f: 5.69574e-05
# Iter 0, Loss: 7.45172e-05, Loss_ic: 1.02933e-06, Loss_f: 5.64839e-05
# Iter 0, Loss: 7.45045e-05, Loss_ic: 1.03063e-06, Loss_f: 5.64701e-05
# Iter 0, Loss: 7.44623e-05, Loss_ic: 1.03519e-06, Loss_f: 5.64244e-05
# Iter 0, Loss: 7.42312e-05, Loss_ic: 1.06422e-06, Loss_f: 5.61689e-05
# Iter 0, Loss: 7.41972e-05, Loss_ic: 1.06675e-06, Loss_f: 5.61334e-05
# Iter 0, Loss: 7.39122e-05, Loss_ic: 1.08943e-06, Loss_f: 5.58348e-05
# Iter 0, Loss: 7.18766e-05, Loss_ic: 1.40050e-06, Loss_f: 5.35693e-05
# Iter 0, Loss: 7.18389e-05, Loss_ic: 1.40308e-06, Loss_f: 5.35333e-05
# Iter 0, Loss: 7.16704e-05, Loss_ic: 1.41482e-06, Loss_f: 5.33714e-05
# Iter 0, Loss: 7.00036e-05, Loss_ic: 1.56354e-06, Loss_f: 5.17418e-05
# Iter 0, Loss: 6.98823e-05, Loss_ic: 1.56768e-06, Loss_f: 5.16311e-05
# Iter 0, Loss: 6.88252e-05, Loss_ic: 1.60580e-06, Loss_f: 5.06685e-05
# Iter 0, Loss: 6.14765e-05, Loss_ic: 2.06335e-06, Loss_f: 4.40768e-05
# Iter 0, Loss: 6.13786e-05, Loss_ic: 2.06076e-06, Loss_f: 4.39998e-05
# Iter 0, Loss: 6.05216e-05, Loss_ic: 2.03781e-06, Loss_f: 4.33278e-05
# Iter 0, Loss: 5.68316e-05, Loss_ic: 1.92941e-06, Loss_f: 4.05018e-05
# Iter 0, Loss: 5.66799e-05, Loss_ic: 1.91826e-06, Loss_f: 4.03972e-05
# Iter 0, Loss: 5.60111e-05, Loss_ic: 1.86893e-06, Loss_f: 3.99382e-05
# Iter 0, Loss: 5.02373e-05, Loss_ic: 1.41006e-06, Loss_f: 3.62183e-05
# Iter 0, Loss: 5.01425e-05, Loss_ic: 1.39900e-06, Loss_f: 3.61599e-05
# Iter 0, Loss: 4.93294e-05, Loss_ic: 1.30599e-06, Loss_f: 3.56639e-05
# Iter 0, Loss: 4.48649e-05, Loss_ic: 1.05190e-06, Loss_f: 3.33214e-05
# Iter 0, Loss: 4.48396e-05, Loss_ic: 1.05148e-06, Loss_f: 3.33154e-05
# Iter 0, Loss: 4.46835e-05, Loss_ic: 1.04915e-06, Loss_f: 3.32812e-05
# Iter 0, Loss: 4.39029e-05, Loss_ic: 1.08071e-06, Loss_f: 3.32534e-05
# Iter 0, Loss: 4.38953e-05, Loss_ic: 1.08246e-06, Loss_f: 3.32486e-05
# Iter 0, Loss: 4.38549e-05, Loss_ic: 1.09209e-06, Loss_f: 3.32234e-05
# Iter 0, Loss: 4.35799e-05, Loss_ic: 1.18288e-06, Loss_f: 3.30486e-05
# Iter 0, Loss: 4.35682e-05, Loss_ic: 1.18479e-06, Loss_f: 3.30464e-05
# Iter 0, Loss: 4.35163e-05, Loss_ic: 1.19356e-06, Loss_f: 3.30373e-05
# Iter 0, Loss: 4.32030e-05, Loss_ic: 1.27181e-06, Loss_f: 3.30451e-05
# Iter 0, Loss: 4.31909e-05, Loss_ic: 1.27496e-06, Loss_f: 3.30349e-05
# Iter 0, Loss: 4.31377e-05, Loss_ic: 1.28927e-06, Loss_f: 3.29900e-05
# Iter 0, Loss: 4.28077e-05, Loss_ic: 1.42792e-06, Loss_f: 3.26876e-05
# Iter 0, Loss: 4.27998e-05, Loss_ic: 1.42922e-06, Loss_f: 3.26851e-05
# Iter 0, Loss: 4.27697e-05, Loss_ic: 1.43437e-06, Loss_f: 3.26758e-05
# Iter 0, Loss: 4.26158e-05, Loss_ic: 1.46426e-06, Loss_f: 3.26376e-05
# Iter 0, Loss: 4.26024e-05, Loss_ic: 1.46533e-06, Loss_f: 3.26321e-05
# Iter 0, Loss: 4.24908e-05, Loss_ic: 1.47478e-06, Loss_f: 3.25879e-05
# Iter 0, Loss: 4.17366e-05, Loss_ic: 1.57258e-06, Loss_f: 3.24595e-05
# Iter 0, Loss: 4.17210e-05, Loss_ic: 1.57304e-06, Loss_f: 3.24510e-05
# Iter 0, Loss: 4.16710e-05, Loss_ic: 1.57449e-06, Loss_f: 3.24242e-05
# Iter 0, Loss: 4.13920e-05, Loss_ic: 1.58329e-06, Loss_f: 3.22796e-05
# Iter 0, Loss: 4.13471e-05, Loss_ic: 1.58441e-06, Loss_f: 3.22550e-05
# Iter 0, Loss: 4.11490e-05, Loss_ic: 1.58942e-06, Loss_f: 3.21477e-05
# Iter 0, Loss: 3.94412e-05, Loss_ic: 1.64683e-06, Loss_f: 3.13889e-05
# Iter 0, Loss: 3.94110e-05, Loss_ic: 1.64740e-06, Loss_f: 3.13713e-05
# Iter 0, Loss: 3.92775e-05, Loss_ic: 1.65010e-06, Loss_f: 3.12944e-05
# Iter 0, Loss: 3.81148e-05, Loss_ic: 1.68151e-06, Loss_f: 3.07279e-05
# Iter 0, Loss: 3.80898e-05, Loss_ic: 1.68295e-06, Loss_f: 3.07139e-05
# Iter 0, Loss: 3.79414e-05, Loss_ic: 1.69183e-06, Loss_f: 3.06327e-05
# Iter 0, Loss: 3.72783e-05, Loss_ic: 1.73987e-06, Loss_f: 3.03083e-05
# Iter 0, Loss: 3.72520e-05, Loss_ic: 1.74097e-06, Loss_f: 3.02901e-05
# Iter 0, Loss: 3.71479e-05, Loss_ic: 1.74560e-06, Loss_f: 3.02188e-05
# Iter 0, Loss: 3.66306e-05, Loss_ic: 1.77167e-06, Loss_f: 2.98815e-05
# Iter 0, Loss: 3.66041e-05, Loss_ic: 1.77360e-06, Loss_f: 2.98617e-05
# Iter 0, Loss: 3.64875e-05, Loss_ic: 1.78231e-06, Loss_f: 2.97751e-05
# Iter 0, Loss: 3.59228e-05, Loss_ic: 1.83147e-06, Loss_f: 2.93676e-05
# Iter 0, Loss: 3.58971e-05, Loss_ic: 1.83331e-06, Loss_f: 2.93454e-05
# Iter 0, Loss: 3.57833e-05, Loss_ic: 1.84162e-06, Loss_f: 2.92476e-05
# Iter 0, Loss: 3.48442e-05, Loss_ic: 1.93148e-06, Loss_f: 2.84555e-05
# Iter 0, Loss: 3.48279e-05, Loss_ic: 1.93305e-06, Loss_f: 2.84402e-05
# Iter 0, Loss: 3.47555e-05, Loss_ic: 1.93997e-06, Loss_f: 2.83724e-05
# Iter 0, Loss: 3.43988e-05, Loss_ic: 1.97851e-06, Loss_f: 2.80362e-05
# Iter 0, Loss: 3.43778e-05, Loss_ic: 1.98014e-06, Loss_f: 2.80144e-05
# Iter 0, Loss: 3.42847e-05, Loss_ic: 1.98744e-06, Loss_f: 2.79173e-05
# Iter 0, Loss: 3.38294e-05, Loss_ic: 2.02766e-06, Loss_f: 2.74322e-05
# Iter 0, Loss: 3.38056e-05, Loss_ic: 2.02876e-06, Loss_f: 2.74072e-05
# Iter 0, Loss: 3.36004e-05, Loss_ic: 2.03864e-06, Loss_f: 2.71891e-05
# Iter 0, Loss: 3.23983e-05, Loss_ic: 2.13372e-06, Loss_f: 2.57244e-05
# Iter 0, Loss: 3.23895e-05, Loss_ic: 2.13434e-06, Loss_f: 2.57153e-05
# Iter 0, Loss: 3.23496e-05, Loss_ic: 2.13726e-06, Loss_f: 2.56742e-05
# Iter 0, Loss: 3.19511e-05, Loss_ic: 2.17168e-06, Loss_f: 2.52542e-05
# Iter 0, Loss: 3.18963e-05, Loss_ic: 2.16964e-06, Loss_f: 2.52061e-05
# Iter 0, Loss: 3.16545e-05, Loss_ic: 2.16054e-06, Loss_f: 2.49936e-05
# Iter 0, Loss: 3.04733e-05, Loss_ic: 2.11325e-06, Loss_f: 2.39520e-05
# Iter 0, Loss: 3.04111e-05, Loss_ic: 2.11055e-06, Loss_f: 2.39018e-05
# Iter 0, Loss: 3.01373e-05, Loss_ic: 2.09877e-06, Loss_f: 2.36813e-05
# Iter 0, Loss: 2.78560e-05, Loss_ic: 2.01428e-06, Loss_f: 2.18909e-05
# Iter 0, Loss: 2.78230e-05, Loss_ic: 2.01028e-06, Loss_f: 2.18719e-05
# Iter 0, Loss: 2.76772e-05, Loss_ic: 1.99236e-06, Loss_f: 2.17889e-05
# Iter 0, Loss: 2.63915e-05, Loss_ic: 1.81692e-06, Loss_f: 2.11257e-05
# Iter 0, Loss: 2.63634e-05, Loss_ic: 1.81178e-06, Loss_f: 2.11144e-05
# Iter 0, Loss: 2.61909e-05, Loss_ic: 1.77998e-06, Loss_f: 2.10461e-05
# Iter 0, Loss: 2.54167e-05, Loss_ic: 1.62853e-06, Loss_f: 2.07738e-05
# Iter 0, Loss: 2.53792e-05, Loss_ic: 1.62135e-06, Loss_f: 2.07580e-05
# Iter 0, Loss: 2.50551e-05, Loss_ic: 1.55972e-06, Loss_f: 2.06225e-05
# Iter 0, Loss: 2.29794e-05, Loss_ic: 1.14191e-06, Loss_f: 1.98434e-05
# Iter 0, Loss: 2.29567e-05, Loss_ic: 1.13482e-06, Loss_f: 1.98336e-05
# Iter 0, Loss: 2.28562e-05, Loss_ic: 1.10363e-06, Loss_f: 1.97898e-05
# Iter 0, Loss: 2.20369e-05, Loss_ic: 8.76374e-07, Loss_f: 1.93976e-05
# Iter 0, Loss: 2.20074e-05, Loss_ic: 8.70855e-07, Loss_f: 1.93789e-05
# Iter 0, Loss: 2.18767e-05, Loss_ic: 8.46576e-07, Loss_f: 1.92953e-05
# Iter 0, Loss: 2.12332e-05, Loss_ic: 7.28813e-07, Loss_f: 1.88582e-05
# Iter 0, Loss: 2.11946e-05, Loss_ic: 7.23642e-07, Loss_f: 1.88285e-05
# Iter 0, Loss: 2.10245e-05, Loss_ic: 7.01014e-07, Loss_f: 1.86962e-05
# Iter 0, Loss: 2.01964e-05, Loss_ic: 5.95986e-07, Loss_f: 1.80114e-05
# Iter 0, Loss: 2.01542e-05, Loss_ic: 5.91147e-07, Loss_f: 1.79731e-05
# Iter 0, Loss: 1.99690e-05, Loss_ic: 5.70306e-07, Loss_f: 1.78032e-05
# Iter 0, Loss: 1.84743e-05, Loss_ic: 4.31325e-07, Loss_f: 1.62197e-05
# Iter 0, Loss: 1.84461e-05, Loss_ic: 4.30731e-07, Loss_f: 1.61893e-05
# Iter 0, Loss: 1.83258e-05, Loss_ic: 4.28397e-07, Loss_f: 1.60571e-05
# Iter 0, Loss: 1.77754e-05, Loss_ic: 4.50022e-07, Loss_f: 1.51809e-05
# Iter 0, Loss: 1.77542e-05, Loss_ic: 4.48286e-07, Loss_f: 1.51587e-05
# Iter 0, Loss: 1.76383e-05, Loss_ic: 4.39211e-07, Loss_f: 1.50353e-05
# Iter 0, Loss: 1.71892e-05, Loss_ic: 4.18715e-07, Loss_f: 1.44960e-05
# Iter 0, Loss: 1.71809e-05, Loss_ic: 4.18604e-07, Loss_f: 1.44858e-05
# Iter 0, Loss: 1.71520e-05, Loss_ic: 4.18286e-07, Loss_f: 1.44501e-05
# Iter 0, Loss: 1.69991e-05, Loss_ic: 4.17802e-07, Loss_f: 1.42540e-05
# Iter 0, Loss: 1.69853e-05, Loss_ic: 4.17934e-07, Loss_f: 1.42384e-05
# Iter 0, Loss: 1.69246e-05, Loss_ic: 4.18660e-07, Loss_f: 1.41687e-05
# Iter 0, Loss: 1.66291e-05, Loss_ic: 4.25828e-07, Loss_f: 1.38166e-05
# Iter 0, Loss: 1.66131e-05, Loss_ic: 4.26060e-07, Loss_f: 1.37986e-05
# Iter 0, Loss: 1.64823e-05, Loss_ic: 4.28281e-07, Loss_f: 1.36500e-05
# Iter 0, Loss: 1.59655e-05, Loss_ic: 4.45419e-07, Loss_f: 1.30291e-05
# Iter 0, Loss: 1.59534e-05, Loss_ic: 4.45938e-07, Loss_f: 1.30171e-05
# Iter 0, Loss: 1.58489e-05, Loss_ic: 4.50891e-07, Loss_f: 1.29131e-05
# Iter 0, Loss: 1.52675e-05, Loss_ic: 5.21047e-07, Loss_f: 1.23055e-05
# Iter 0, Loss: 1.52608e-05, Loss_ic: 5.20559e-07, Loss_f: 1.23002e-05
# Iter 0, Loss: 1.52306e-05, Loss_ic: 5.18411e-07, Loss_f: 1.22763e-05
# Iter 0, Loss: 1.51099e-05, Loss_ic: 5.10078e-07, Loss_f: 1.21810e-05
# Iter 0, Loss: 1.50989e-05, Loss_ic: 5.09625e-07, Loss_f: 1.21742e-05
# Iter 0, Loss: 1.50502e-05, Loss_ic: 5.07573e-07, Loss_f: 1.21445e-05
# Iter 0, Loss: 1.46225e-05, Loss_ic: 4.94849e-07, Loss_f: 1.18877e-05
# Iter 0, Loss: 1.46141e-05, Loss_ic: 4.94389e-07, Loss_f: 1.18843e-05
# Iter 0, Loss: 1.45765e-05, Loss_ic: 4.92438e-07, Loss_f: 1.18692e-05
# Iter 0, Loss: 1.43960e-05, Loss_ic: 4.84037e-07, Loss_f: 1.17984e-05
# Iter 0, Loss: 1.43890e-05, Loss_ic: 4.83731e-07, Loss_f: 1.17958e-05
# Iter 0, Loss: 1.43652e-05, Loss_ic: 4.82714e-07, Loss_f: 1.17876e-05
# Iter 0, Loss: 1.41494e-05, Loss_ic: 4.75820e-07, Loss_f: 1.17158e-05
# Iter 0, Loss: 1.41466e-05, Loss_ic: 4.75665e-07, Loss_f: 1.17152e-05
# Iter 0, Loss: 1.41339e-05, Loss_ic: 4.75036e-07, Loss_f: 1.17121e-05
# Iter 0, Loss: 1.40844e-05, Loss_ic: 4.72805e-07, Loss_f: 1.17015e-05
# Iter 0, Loss: 1.40824e-05, Loss_ic: 4.72726e-07, Loss_f: 1.17012e-05
# Iter 0, Loss: 1.40734e-05, Loss_ic: 4.72320e-07, Loss_f: 1.16996e-05
# Iter 0, Loss: 1.40407e-05, Loss_ic: 4.71058e-07, Loss_f: 1.16953e-05
# Iter 0, Loss: 1.40392e-05, Loss_ic: 4.70991e-07, Loss_f: 1.16951e-05
# Iter 0, Loss: 1.40326e-05, Loss_ic: 4.70668e-07, Loss_f: 1.16946e-05
# Iter 0, Loss: 1.39787e-05, Loss_ic: 4.68918e-07, Loss_f: 1.16977e-05
# Iter 0, Loss: 1.39780e-05, Loss_ic: 4.68904e-07, Loss_f: 1.16976e-05
# Iter 0, Loss: 1.39777e-05, Loss_ic: 4.68892e-07, Loss_f: 1.16978e-05
# Iter 0, Loss: 1.39738e-05, Loss_ic: 4.68807e-07, Loss_f: 1.16982e-05
# Iter 0, Loss: 1.39540e-05, Loss_ic: 4.68849e-07, Loss_f: 1.17043e-05
# Iter 0, Loss: 1.39535e-05, Loss_ic: 4.68838e-07, Loss_f: 1.17043e-05
# Iter 0, Loss: 1.39530e-05, Loss_ic: 4.68827e-07, Loss_f: 1.17044e-05
# Iter 0, Loss: 1.39484e-05, Loss_ic: 4.68780e-07, Loss_f: 1.17047e-05
# Iter 0, Loss: 1.39394e-05, Loss_ic: 4.68788e-07, Loss_f: 1.17061e-05
# Iter 0, Loss: 1.39385e-05, Loss_ic: 4.68780e-07, Loss_f: 1.17060e-05
# Iter 0, Loss: 1.39378e-05, Loss_ic: 4.68759e-07, Loss_f: 1.17059e-05
# Iter 0, Loss: 1.39309e-05, Loss_ic: 4.68674e-07, Loss_f: 1.17051e-05
# Iter 0, Loss: 1.38915e-05, Loss_ic: 4.69819e-07, Loss_f: 1.17057e-05
# Iter 0, Loss: 1.38907e-05, Loss_ic: 4.69807e-07, Loss_f: 1.17054e-05
# Iter 0, Loss: 1.38865e-05, Loss_ic: 4.69754e-07, Loss_f: 1.17040e-05
# Iter 0, Loss: 1.38760e-05, Loss_ic: 4.69690e-07, Loss_f: 1.17004e-05
# Iter 0, Loss: 1.38102e-05, Loss_ic: 4.73447e-07, Loss_f: 1.16863e-05
# Iter 0, Loss: 1.38090e-05, Loss_ic: 4.73465e-07, Loss_f: 1.16856e-05
# Iter 0, Loss: 1.38078e-05, Loss_ic: 4.73471e-07, Loss_f: 1.16850e-05
# Iter 0, Loss: 1.37970e-05, Loss_ic: 4.73616e-07, Loss_f: 1.16791e-05
# Iter 0, Loss: 1.37310e-05, Loss_ic: 4.75611e-07, Loss_f: 1.16428e-05
# Iter 0, Loss: 1.37253e-05, Loss_ic: 4.75352e-07, Loss_f: 1.16382e-05
# Iter 0, Loss: 1.36880e-05, Loss_ic: 4.73765e-07, Loss_f: 1.16085e-05
# Iter 0, Loss: 1.35263e-05, Loss_ic: 4.69090e-07, Loss_f: 1.14716e-05
# Iter 0, Loss: 1.35177e-05, Loss_ic: 4.68300e-07, Loss_f: 1.14645e-05
# Iter 0, Loss: 1.34627e-05, Loss_ic: 4.63151e-07, Loss_f: 1.14186e-05
# Iter 0, Loss: 1.32279e-05, Loss_ic: 4.40476e-07, Loss_f: 1.12127e-05
# Iter 0, Loss: 1.32115e-05, Loss_ic: 4.40446e-07, Loss_f: 1.11957e-05
# Iter 0, Loss: 1.31428e-05, Loss_ic: 4.41126e-07, Loss_f: 1.11225e-05
# Iter 0, Loss: 1.31309e-05, Loss_ic: 4.40010e-07, Loss_f: 1.11114e-05
# Iter 0, Loss: 1.30749e-05, Loss_ic: 4.34765e-07, Loss_f: 1.10590e-05
# Iter 0, Loss: 1.28085e-05, Loss_ic: 4.10565e-07, Loss_f: 1.08017e-05
# Iter 0, Loss: 1.27950e-05, Loss_ic: 4.09841e-07, Loss_f: 1.07895e-05
# Iter 0, Loss: 1.26795e-05, Loss_ic: 4.04280e-07, Loss_f: 1.06839e-05
# Iter 0, Loss: 1.26589e-05, Loss_ic: 4.02526e-07, Loss_f: 1.06658e-05
# Iter 0, Loss: 1.25489e-05, Loss_ic: 3.93513e-07, Loss_f: 1.05687e-05
# Iter 0, Loss: 1.20811e-05, Loss_ic: 3.63945e-07, Loss_f: 1.01448e-05
# Iter 0, Loss: 1.20658e-05, Loss_ic: 3.63478e-07, Loss_f: 1.01323e-05
# Iter 0, Loss: 1.19651e-05, Loss_ic: 3.61214e-07, Loss_f: 1.00497e-05
# Iter 0, Loss: 1.19519e-05, Loss_ic: 3.60732e-07, Loss_f: 1.00389e-05
# Iter 0, Loss: 1.18388e-05, Loss_ic: 3.56893e-07, Loss_f: 9.94665e-06
# Iter 0, Loss: 1.12310e-05, Loss_ic: 3.63776e-07, Loss_f: 9.47867e-06
# Iter 0, Loss: 1.12289e-05, Loss_ic: 3.63804e-07, Loss_f: 9.47723e-06
# Iter 0, Loss: 1.12240e-05, Loss_ic: 3.63862e-07, Loss_f: 9.47379e-06
# Iter 0, Loss: 1.11937e-05, Loss_ic: 3.64283e-07, Loss_f: 9.45273e-06
# Iter 0, Loss: 1.09959e-05, Loss_ic: 3.69828e-07, Loss_f: 9.31564e-06
# Iter 0, Loss: 1.09931e-05, Loss_ic: 3.69441e-07, Loss_f: 9.31374e-06
# Iter 0, Loss: 1.09760e-05, Loss_ic: 3.67153e-07, Loss_f: 9.30203e-06
# Iter 0, Loss: 1.08492e-05, Loss_ic: 3.51789e-07, Loss_f: 9.20738e-06
# Iter 0, Loss: 1.08473e-05, Loss_ic: 3.51686e-07, Loss_f: 9.20599e-06
# Iter 0, Loss: 1.08388e-05, Loss_ic: 3.51192e-07, Loss_f: 9.19971e-06
# Iter 0, Loss: 1.07951e-05, Loss_ic: 3.49012e-07, Loss_f: 9.16587e-06
# Iter 0, Loss: 1.07938e-05, Loss_ic: 3.48938e-07, Loss_f: 9.16486e-06
# Iter 0, Loss: 1.07882e-05, Loss_ic: 3.48649e-07, Loss_f: 9.16043e-06
# Iter 0, Loss: 1.07427e-05, Loss_ic: 3.48669e-07, Loss_f: 9.12181e-06
# Iter 0, Loss: 1.07420e-05, Loss_ic: 3.48693e-07, Loss_f: 9.12133e-06
# Iter 0, Loss: 1.07388e-05, Loss_ic: 3.48819e-07, Loss_f: 9.11897e-06
# Iter 0, Loss: 1.07325e-05, Loss_ic: 3.49154e-07, Loss_f: 9.11433e-06
# Iter 0, Loss: 1.07314e-05, Loss_ic: 3.49237e-07, Loss_f: 9.11363e-06
# Iter 0, Loss: 1.07268e-05, Loss_ic: 3.49631e-07, Loss_f: 9.11057e-06
# Iter 0, Loss: 1.07047e-05, Loss_ic: 3.52130e-07, Loss_f: 9.09613e-06
# Iter 0, Loss: 1.07038e-05, Loss_ic: 3.52233e-07, Loss_f: 9.09561e-06
# Iter 0, Loss: 1.07004e-05, Loss_ic: 3.52630e-07, Loss_f: 9.09365e-06
# Iter 0, Loss: 1.06890e-05, Loss_ic: 3.54178e-07, Loss_f: 9.08723e-06
# Iter 0, Loss: 1.06882e-05, Loss_ic: 3.54290e-07, Loss_f: 9.08680e-06
# Iter 0, Loss: 1.06843e-05, Loss_ic: 3.54841e-07, Loss_f: 9.08476e-06
# Iter 0, Loss: 1.06659e-05, Loss_ic: 3.58019e-07, Loss_f: 9.07570e-06
# Iter 0, Loss: 1.06652e-05, Loss_ic: 3.58134e-07, Loss_f: 9.07535e-06
# Iter 0, Loss: 1.06639e-05, Loss_ic: 3.58346e-07, Loss_f: 9.07475e-06
# Iter 0, Loss: 1.06555e-05, Loss_ic: 3.59844e-07, Loss_f: 9.07085e-06
# Iter 0, Loss: 1.06547e-05, Loss_ic: 3.59972e-07, Loss_f: 9.07047e-06
# Iter 0, Loss: 1.06510e-05, Loss_ic: 3.60546e-07, Loss_f: 9.06869e-06
# Iter 0, Loss: 1.06398e-05, Loss_ic: 3.62544e-07, Loss_f: 9.06350e-06
# Iter 0, Loss: 1.06390e-05, Loss_ic: 3.62676e-07, Loss_f: 9.06313e-06
# Iter 0, Loss: 1.06351e-05, Loss_ic: 3.63268e-07, Loss_f: 9.06113e-06
# Iter 0, Loss: 1.06258e-05, Loss_ic: 3.64856e-07, Loss_f: 9.05664e-06
# Iter 0, Loss: 1.06248e-05, Loss_ic: 3.64988e-07, Loss_f: 9.05606e-06
# Iter 0, Loss: 1.06231e-05, Loss_ic: 3.65225e-07, Loss_f: 9.05513e-06
# Iter 0, Loss: 1.06165e-05, Loss_ic: 3.66222e-07, Loss_f: 9.05153e-06
# Iter 0, Loss: 1.05837e-05, Loss_ic: 3.72973e-07, Loss_f: 9.03572e-06
# Iter 0, Loss: 1.05831e-05, Loss_ic: 3.73083e-07, Loss_f: 9.03534e-06
# Iter 0, Loss: 1.05799e-05, Loss_ic: 3.73625e-07, Loss_f: 9.03351e-06
# Iter 0, Loss: 1.05647e-05, Loss_ic: 3.76683e-07, Loss_f: 9.02487e-06
# Iter 0, Loss: 1.05637e-05, Loss_ic: 3.76832e-07, Loss_f: 9.02414e-06
# Iter 0, Loss: 1.05608e-05, Loss_ic: 3.77224e-07, Loss_f: 9.02215e-06
# Iter 0, Loss: 1.05443e-05, Loss_ic: 3.79719e-07, Loss_f: 9.01073e-06
# Iter 0, Loss: 1.05426e-05, Loss_ic: 3.79902e-07, Loss_f: 9.00944e-06
# Iter 0, Loss: 1.05349e-05, Loss_ic: 3.80738e-07, Loss_f: 9.00339e-06
# Iter 0, Loss: 1.04989e-05, Loss_ic: 3.85393e-07, Loss_f: 8.97504e-06
# Iter 0, Loss: 1.04964e-05, Loss_ic: 3.85623e-07, Loss_f: 8.97290e-06
# Iter 0, Loss: 1.04848e-05, Loss_ic: 3.86763e-07, Loss_f: 8.96289e-06
# Iter 0, Loss: 1.04282e-05, Loss_ic: 3.93524e-07, Loss_f: 8.91348e-06
# Iter 0, Loss: 1.04247e-05, Loss_ic: 3.93841e-07, Loss_f: 8.91026e-06
# Iter 0, Loss: 1.04136e-05, Loss_ic: 3.94873e-07, Loss_f: 8.90000e-06
# Iter 0, Loss: 1.03529e-05, Loss_ic: 4.01456e-07, Loss_f: 8.84313e-06
# Iter 0, Loss: 1.03474e-05, Loss_ic: 4.01889e-07, Loss_f: 8.83781e-06
# Iter 0, Loss: 1.03280e-05, Loss_ic: 4.03467e-07, Loss_f: 8.81910e-06
# Iter 0, Loss: 1.02259e-05, Loss_ic: 4.13394e-07, Loss_f: 8.71877e-06
# Iter 0, Loss: 1.02180e-05, Loss_ic: 4.14041e-07, Loss_f: 8.71089e-06
# Iter 0, Loss: 1.01827e-05, Loss_ic: 4.17068e-07, Loss_f: 8.67562e-06
# Iter 0, Loss: 9.92383e-06, Loss_ic: 4.47680e-07, Loss_f: 8.40743e-06
# Iter 0, Loss: 9.91453e-06, Loss_ic: 4.48288e-07, Loss_f: 8.39772e-06
# Iter 0, Loss: 9.87364e-06, Loss_ic: 4.51111e-07, Loss_f: 8.35478e-06
# Iter 0, Loss: 9.65218e-06, Loss_ic: 4.79639e-07, Loss_f: 8.10062e-06
# Iter 0, Loss: 9.64199e-06, Loss_ic: 4.80392e-07, Loss_f: 8.09012e-06
# Iter 0, Loss: 9.55483e-06, Loss_ic: 4.87396e-07, Loss_f: 7.99972e-06
# Iter 0, Loss: 9.24281e-06, Loss_ic: 5.27818e-07, Loss_f: 7.65914e-06
# Iter 0, Loss: 9.23552e-06, Loss_ic: 5.28255e-07, Loss_f: 7.65142e-06
# Iter 0, Loss: 9.20298e-06, Loss_ic: 5.30342e-07, Loss_f: 7.61684e-06
# Iter 0, Loss: 9.03828e-06, Loss_ic: 5.42298e-07, Loss_f: 7.44005e-06
# Iter 0, Loss: 9.02186e-06, Loss_ic: 5.42309e-07, Loss_f: 7.42453e-06
# Iter 0, Loss: 8.94922e-06, Loss_ic: 5.42237e-07, Loss_f: 7.35607e-06
# Iter 0, Loss: 8.59375e-06, Loss_ic: 5.42008e-07, Loss_f: 7.02211e-06
# Iter 0, Loss: 8.57390e-06, Loss_ic: 5.41675e-07, Loss_f: 7.00353e-06
# Iter 0, Loss: 8.43838e-06, Loss_ic: 5.39385e-07, Loss_f: 6.87676e-06
# Iter 0, Loss: 7.88177e-06, Loss_ic: 5.29178e-07, Loss_f: 6.35907e-06
# Iter 0, Loss: 7.86893e-06, Loss_ic: 5.28330e-07, Loss_f: 6.34802e-06
# Iter 0, Loss: 7.81251e-06, Loss_ic: 5.24492e-07, Loss_f: 6.29950e-06
# Iter 0, Loss: 7.54726e-06, Loss_ic: 5.04263e-07, Loss_f: 6.07242e-06
# Iter 0, Loss: 7.53708e-06, Loss_ic: 5.03157e-07, Loss_f: 6.06378e-06
# Iter 0, Loss: 7.49260e-06, Loss_ic: 4.98320e-07, Loss_f: 6.02591e-06
# Iter 0, Loss: 7.28739e-06, Loss_ic: 4.74813e-07, Loss_f: 5.84976e-06
# Iter 0, Loss: 7.28142e-06, Loss_ic: 4.74199e-07, Loss_f: 5.84447e-06
# Iter 0, Loss: 7.25515e-06, Loss_ic: 4.71442e-07, Loss_f: 5.82118e-06
# Iter 0, Loss: 7.06046e-06, Loss_ic: 4.46207e-07, Loss_f: 5.64462e-06
# Iter 0, Loss: 7.05845e-06, Loss_ic: 4.45901e-07, Loss_f: 5.64277e-06
# Iter 0, Loss: 7.05155e-06, Loss_ic: 4.44845e-07, Loss_f: 5.63633e-06
# Iter 0, Loss: 7.00756e-06, Loss_ic: 4.37721e-07, Loss_f: 5.59409e-06
# Iter 0, Loss: 7.00634e-06, Loss_ic: 4.37588e-07, Loss_f: 5.59281e-06
# Iter 0, Loss: 7.00091e-06, Loss_ic: 4.37052e-07, Loss_f: 5.58706e-06
# Iter 0, Loss: 6.97530e-06, Loss_ic: 4.34144e-07, Loss_f: 5.55923e-06
# Iter 0, Loss: 6.97438e-06, Loss_ic: 4.33980e-07, Loss_f: 5.55834e-06
# Iter 0, Loss: 6.97022e-06, Loss_ic: 4.33272e-07, Loss_f: 5.55434e-06
# Iter 0, Loss: 6.95840e-06, Loss_ic: 4.31169e-07, Loss_f: 5.54269e-06
# Iter 0, Loss: 6.95750e-06, Loss_ic: 4.31134e-07, Loss_f: 5.54171e-06
# Iter 0, Loss: 6.95358e-06, Loss_ic: 4.30971e-07, Loss_f: 5.53735e-06
# Iter 0, Loss: 6.94320e-06, Loss_ic: 4.30565e-07, Loss_f: 5.52551e-06
# Iter 0, Loss: 6.94260e-06, Loss_ic: 4.30528e-07, Loss_f: 5.52490e-06
# Iter 0, Loss: 6.94179e-06, Loss_ic: 4.30500e-07, Loss_f: 5.52405e-06
# Iter 0, Loss: 6.94002e-06, Loss_ic: 4.30426e-07, Loss_f: 5.52217e-06
# Iter 0, Loss: 6.93600e-06, Loss_ic: 4.30236e-07, Loss_f: 5.51792e-06
# Iter 0, Loss: 6.93547e-06, Loss_ic: 4.30228e-07, Loss_f: 5.51735e-06
# Iter 0, Loss: 6.93298e-06, Loss_ic: 4.30171e-07, Loss_f: 5.51479e-06
# Iter 0, Loss: 6.92838e-06, Loss_ic: 4.30078e-07, Loss_f: 5.50999e-06
# Iter 0, Loss: 6.92782e-06, Loss_ic: 4.30056e-07, Loss_f: 5.50944e-06
# Iter 0, Loss: 6.92670e-06, Loss_ic: 4.30052e-07, Loss_f: 5.50831e-06
# Iter 0, Loss: 6.91977e-06, Loss_ic: 4.29926e-07, Loss_f: 5.50123e-06
# Iter 0, Loss: 6.91929e-06, Loss_ic: 4.29955e-07, Loss_f: 5.50073e-06
# Iter 0, Loss: 6.91711e-06, Loss_ic: 4.29979e-07, Loss_f: 5.49860e-06
# Iter 0, Loss: 6.91161e-06, Loss_ic: 4.30087e-07, Loss_f: 5.49315e-06
# Iter 0, Loss: 6.91116e-06, Loss_ic: 4.30075e-07, Loss_f: 5.49271e-06
# Iter 0, Loss: 6.90911e-06, Loss_ic: 4.30018e-07, Loss_f: 5.49073e-06
# Iter 0, Loss: 6.89923e-06, Loss_ic: 4.29761e-07, Loss_f: 5.48112e-06
# Iter 0, Loss: 6.89883e-06, Loss_ic: 4.29795e-07, Loss_f: 5.48074e-06
# Iter 0, Loss: 6.89829e-06, Loss_ic: 4.29839e-07, Loss_f: 5.48023e-06
# Iter 0, Loss: 6.89776e-06, Loss_ic: 4.29889e-07, Loss_f: 5.47974e-06
# Iter 0, Loss: 6.89202e-06, Loss_ic: 4.30440e-07, Loss_f: 5.47440e-06
# Iter 0, Loss: 6.89151e-06, Loss_ic: 4.30411e-07, Loss_f: 5.47396e-06
# Iter 0, Loss: 6.89077e-06, Loss_ic: 4.30366e-07, Loss_f: 5.47331e-06
# Iter 0, Loss: 6.88566e-06, Loss_ic: 4.30001e-07, Loss_f: 5.46876e-06
# Iter 0, Loss: 6.88503e-06, Loss_ic: 4.30050e-07, Loss_f: 5.46821e-06
# Iter 0, Loss: 6.88432e-06, Loss_ic: 4.30103e-07, Loss_f: 5.46759e-06
# Iter 0, Loss: 6.87864e-06, Loss_ic: 4.30515e-07, Loss_f: 5.46261e-06
# Iter 0, Loss: 6.87788e-06, Loss_ic: 4.30513e-07, Loss_f: 5.46194e-06
# Iter 0, Loss: 6.87455e-06, Loss_ic: 4.30567e-07, Loss_f: 5.45900e-06
# Iter 0, Loss: 6.85837e-06, Loss_ic: 4.30872e-07, Loss_f: 5.44484e-06
# Iter 0, Loss: 6.85754e-06, Loss_ic: 4.30863e-07, Loss_f: 5.44416e-06
# Iter 0, Loss: 6.85633e-06, Loss_ic: 4.30847e-07, Loss_f: 5.44316e-06
# Iter 0, Loss: 6.84763e-06, Loss_ic: 4.30795e-07, Loss_f: 5.43604e-06
# Iter 0, Loss: 6.84641e-06, Loss_ic: 4.30778e-07, Loss_f: 5.43497e-06
# Iter 0, Loss: 6.84470e-06, Loss_ic: 4.30752e-07, Loss_f: 5.43352e-06
# Iter 0, Loss: 6.83241e-06, Loss_ic: 4.30578e-07, Loss_f: 5.42299e-06
# Iter 0, Loss: 6.83077e-06, Loss_ic: 4.30516e-07, Loss_f: 5.42164e-06
# Iter 0, Loss: 6.82520e-06, Loss_ic: 4.30276e-07, Loss_f: 5.41705e-06
# Iter 0, Loss: 6.79108e-06, Loss_ic: 4.28724e-07, Loss_f: 5.38944e-06
# Iter 0, Loss: 6.78922e-06, Loss_ic: 4.28621e-07, Loss_f: 5.38789e-06
# Iter 0, Loss: 6.78575e-06, Loss_ic: 4.28462e-07, Loss_f: 5.38496e-06
# Iter 0, Loss: 6.76313e-06, Loss_ic: 4.27344e-07, Loss_f: 5.36610e-06
# Iter 0, Loss: 6.76053e-06, Loss_ic: 4.27160e-07, Loss_f: 5.36396e-06
# Iter 0, Loss: 6.74291e-06, Loss_ic: 4.25908e-07, Loss_f: 5.34946e-06
# Iter 0, Loss: 6.66712e-06, Loss_ic: 4.19557e-07, Loss_f: 5.28945e-06
# Iter 0, Loss: 6.66457e-06, Loss_ic: 4.19401e-07, Loss_f: 5.28731e-06
# Iter 0, Loss: 6.65333e-06, Loss_ic: 4.18759e-07, Loss_f: 5.27787e-06
# Iter 0, Loss: 6.59783e-06, Loss_ic: 4.15236e-07, Loss_f: 5.23232e-06
# Iter 0, Loss: 6.59387e-06, Loss_ic: 4.14714e-07, Loss_f: 5.22912e-06
# Iter 0, Loss: 6.58270e-06, Loss_ic: 4.13173e-07, Loss_f: 5.22014e-06
# Iter 0, Loss: 6.52116e-06, Loss_ic: 4.03904e-07, Loss_f: 5.17190e-06
# Iter 0, Loss: 6.51557e-06, Loss_ic: 4.03425e-07, Loss_f: 5.16727e-06
# Iter 0, Loss: 6.49095e-06, Loss_ic: 4.01305e-07, Loss_f: 5.14694e-06
# Iter 0, Loss: 6.37373e-06, Loss_ic: 3.89523e-07, Loss_f: 5.05494e-06
# Iter 0, Loss: 6.36770e-06, Loss_ic: 3.88745e-07, Loss_f: 5.05003e-06
# Iter 0, Loss: 6.32266e-06, Loss_ic: 3.82512e-07, Loss_f: 5.01410e-06
# Iter 0, Loss: 6.15372e-06, Loss_ic: 3.34911e-07, Loss_f: 4.91184e-06
# Iter 0, Loss: 6.14715e-06, Loss_ic: 3.34435e-07, Loss_f: 4.90660e-06
# Iter 0, Loss: 6.11837e-06, Loss_ic: 3.32316e-07, Loss_f: 4.88370e-06
# Iter 0, Loss: 5.98804e-06, Loss_ic: 3.22420e-07, Loss_f: 4.78053e-06
# Iter 0, Loss: 5.98112e-06, Loss_ic: 3.21945e-07, Loss_f: 4.77455e-06
# Iter 0, Loss: 5.94197e-06, Loss_ic: 3.19264e-07, Loss_f: 4.74047e-06
# Iter 0, Loss: 5.62878e-06, Loss_ic: 3.00408e-07, Loss_f: 4.44451e-06
# Iter 0, Loss: 5.61818e-06, Loss_ic: 2.99048e-07, Loss_f: 4.43626e-06
# Iter 0, Loss: 5.52629e-06, Loss_ic: 2.86639e-07, Loss_f: 4.36610e-06
# Iter 0, Loss: 5.13995e-06, Loss_ic: 1.88875e-07, Loss_f: 4.08112e-06
# Iter 0, Loss: 5.11898e-06, Loss_ic: 1.87782e-07, Loss_f: 4.06287e-06
# Iter 0, Loss: 5.02725e-06, Loss_ic: 1.82971e-07, Loss_f: 3.98255e-06
# Iter 0, Loss: 4.34808e-06, Loss_ic: 1.40604e-07, Loss_f: 3.36896e-06
# Iter 0, Loss: 4.33474e-06, Loss_ic: 1.40463e-07, Loss_f: 3.35604e-06
# Iter 0, Loss: 4.27817e-06, Loss_ic: 1.39904e-07, Loss_f: 3.30047e-06
# Iter 0, Loss: 4.26151e-06, Loss_ic: 1.39304e-07, Loss_f: 3.28428e-06
# Iter 0, Loss: 4.12437e-06, Loss_ic: 1.34817e-07, Loss_f: 3.14899e-06
# Iter 0, Loss: 4.10878e-06, Loss_ic: 1.34199e-07, Loss_f: 3.13444e-06
# Iter 0, Loss: 4.04197e-06, Loss_ic: 1.31672e-07, Loss_f: 3.07125e-06
# Iter 0, Loss: 3.69704e-06, Loss_ic: 1.27241e-07, Loss_f: 2.69827e-06
# Iter 0, Loss: 3.69000e-06, Loss_ic: 1.26887e-07, Loss_f: 2.69148e-06
# Iter 0, Loss: 3.63901e-06, Loss_ic: 1.24523e-07, Loss_f: 2.64206e-06
# Iter 0, Loss: 3.43408e-06, Loss_ic: 1.30284e-07, Loss_f: 2.38443e-06
# Iter 0, Loss: 3.43055e-06, Loss_ic: 1.29956e-07, Loss_f: 2.38174e-06
# Iter 0, Loss: 3.41521e-06, Loss_ic: 1.28534e-07, Loss_f: 2.37000e-06
# Iter 0, Loss: 3.34483e-06, Loss_ic: 1.21704e-07, Loss_f: 2.31427e-06
# Iter 0, Loss: 3.34289e-06, Loss_ic: 1.21471e-07, Loss_f: 2.31272e-06
# Iter 0, Loss: 3.33416e-06, Loss_ic: 1.20451e-07, Loss_f: 2.30576e-06
# Iter 0, Loss: 3.29197e-06, Loss_ic: 1.15458e-07, Loss_f: 2.27224e-06
# Iter 0, Loss: 3.28901e-06, Loss_ic: 1.15174e-07, Loss_f: 2.26974e-06
# Iter 0, Loss: 3.27743e-06, Loss_ic: 1.14101e-07, Loss_f: 2.25984e-06
# Iter 0, Loss: 3.18641e-06, Loss_ic: 1.07554e-07, Loss_f: 2.17947e-06
# Iter 0, Loss: 3.18471e-06, Loss_ic: 1.07452e-07, Loss_f: 2.17806e-06
# Iter 0, Loss: 3.17714e-06, Loss_ic: 1.07019e-07, Loss_f: 2.17186e-06
# Iter 0, Loss: 3.14144e-06, Loss_ic: 1.04964e-07, Loss_f: 2.14264e-06
# Iter 0, Loss: 3.14004e-06, Loss_ic: 1.04912e-07, Loss_f: 2.14141e-06
# Iter 0, Loss: 3.13627e-06, Loss_ic: 1.04771e-07, Loss_f: 2.13809e-06
# Iter 0, Loss: 3.11520e-06, Loss_ic: 1.03959e-07, Loss_f: 2.11954e-06
# Iter 0, Loss: 3.11390e-06, Loss_ic: 1.03892e-07, Loss_f: 2.11847e-06
# Iter 0, Loss: 3.10815e-06, Loss_ic: 1.03572e-07, Loss_f: 2.11372e-06
# Iter 0, Loss: 3.06333e-06, Loss_ic: 1.01330e-07, Loss_f: 2.07751e-06
# Iter 0, Loss: 3.06251e-06, Loss_ic: 1.01281e-07, Loss_f: 2.07671e-06
# Iter 0, Loss: 3.05887e-06, Loss_ic: 1.01057e-07, Loss_f: 2.07324e-06
# Iter 0, Loss: 3.04827e-06, Loss_ic: 1.00312e-07, Loss_f: 2.06284e-06
# Iter 0, Loss: 3.04774e-06, Loss_ic: 1.00273e-07, Loss_f: 2.06240e-06
# Iter 0, Loss: 3.04534e-06, Loss_ic: 1.00079e-07, Loss_f: 2.06038e-06
# Iter 0, Loss: 3.03006e-06, Loss_ic: 9.86401e-08, Loss_f: 2.04785e-06
# Iter 0, Loss: 3.02949e-06, Loss_ic: 9.86117e-08, Loss_f: 2.04734e-06
# Iter 0, Loss: 3.02818e-06, Loss_ic: 9.85338e-08, Loss_f: 2.04616e-06
# Iter 0, Loss: 3.02029e-06, Loss_ic: 9.80850e-08, Loss_f: 2.03911e-06
# Iter 0, Loss: 3.01949e-06, Loss_ic: 9.80217e-08, Loss_f: 2.03846e-06
# Iter 0, Loss: 3.01584e-06, Loss_ic: 9.77439e-08, Loss_f: 2.03537e-06
# Iter 0, Loss: 3.00243e-06, Loss_ic: 9.66180e-08, Loss_f: 2.02421e-06
# Iter 0, Loss: 3.00150e-06, Loss_ic: 9.65568e-08, Loss_f: 2.02342e-06
# Iter 0, Loss: 2.99826e-06, Loss_ic: 9.63368e-08, Loss_f: 2.02065e-06
# Iter 0, Loss: 2.98210e-06, Loss_ic: 9.51525e-08, Loss_f: 2.00696e-06
# Iter 0, Loss: 2.98113e-06, Loss_ic: 9.50568e-08, Loss_f: 2.00618e-06
# Iter 0, Loss: 2.97670e-06, Loss_ic: 9.46566e-08, Loss_f: 2.00260e-06
# Iter 0, Loss: 2.96467e-06, Loss_ic: 9.34728e-08, Loss_f: 1.99302e-06
# Iter 0, Loss: 2.96346e-06, Loss_ic: 9.33995e-08, Loss_f: 1.99202e-06
# Iter 0, Loss: 2.95410e-06, Loss_ic: 9.28324e-08, Loss_f: 1.98440e-06
# ...
# Iter 70, Loss: 1.77200e-07, Loss_ic: 1.56366e-09, Loss_f: 1.41184e-07
# Iter 70, Loss: 1.77172e-07, Loss_ic: 1.56510e-09, Loss_f: 1.41154e-07
# Iter 70, Loss: 1.76810e-07, Loss_ic: 1.58715e-09, Loss_f: 1.40748e-07
# Iter 70, Loss: 1.75509e-07, Loss_ic: 1.69472e-09, Loss_f: 1.39232e-07
# Iter 70, Loss: 1.75456e-07, Loss_ic: 1.69819e-09, Loss_f: 1.39179e-07
# Iter 70, Loss: 1.75365e-07, Loss_ic: 1.70242e-09, Loss_f: 1.39088e-07
# Iter 70, Loss: 1.75116e-07, Loss_ic: 1.71806e-09, Loss_f: 1.38838e-07
# Iter 70, Loss: 1.73714e-07, Loss_ic: 1.84009e-09, Loss_f: 1.37344e-07
# Iter 70, Loss: 1.73668e-07, Loss_ic: 1.84262e-09, Loss_f: 1.37304e-07
# Iter 70, Loss: 1.73464e-07, Loss_ic: 1.85649e-09, Loss_f: 1.37127e-07
# Iter 70, Loss: 1.72494e-07, Loss_ic: 1.93002e-09, Loss_f: 1.36287e-07
# Iter 70, Loss: 1.72448e-07, Loss_ic: 1.93322e-09, Loss_f: 1.36246e-07
# Iter 70, Loss: 1.72417e-07, Loss_ic: 1.93866e-09, Loss_f: 1.36221e-07
# Iter 70, Loss: 1.72057e-07, Loss_ic: 1.98465e-09, Loss_f: 1.35904e-07
# Iter 70, Loss: 1.72057e-07, Loss_ic: 1.98465e-09, Loss_f: 1.35904e-07
# Iter 80, Loss: 1.57216e-07, Loss_ic: 2.19334e-09, Loss_f: 1.22045e-07
# Iter 80, Loss: 1.57207e-07, Loss_ic: 2.19374e-09, Loss_f: 1.22038e-07
# Iter 80, Loss: 1.57207e-07, Loss_ic: 2.19396e-09, Loss_f: 1.22036e-07
# Iter 80, Loss: 1.57207e-07, Loss_ic: 2.19416e-09, Loss_f: 1.22037e-07
# Iter 80, Loss: 1.57207e-07, Loss_ic: 2.19395e-09, Loss_f: 1.22037e-07
# Iter 80, Loss: 1.57199e-07, Loss_ic: 2.19435e-09, Loss_f: 1.22030e-07
# Iter 80, Loss: 1.57197e-07, Loss_ic: 2.19565e-09, Loss_f: 1.22030e-07
# Iter 80, Loss: 1.57142e-07, Loss_ic: 2.20016e-09, Loss_f: 1.21992e-07
# Iter 80, Loss: 1.57113e-07, Loss_ic: 2.20290e-09, Loss_f: 1.21971e-07
# Iter 80, Loss: 1.56809e-07, Loss_ic: 2.25064e-09, Loss_f: 1.21765e-07
# Iter 80, Loss: 1.56809e-07, Loss_ic: 2.25064e-09, Loss_f: 1.21765e-07
# Iter 90, Loss: 1.63079e-07, Loss_ic: 1.76326e-09, Loss_f: 1.28007e-07
# Iter 90, Loss: 1.63027e-07, Loss_ic: 1.76738e-09, Loss_f: 1.27940e-07
# Iter 90, Loss: 1.63006e-07, Loss_ic: 1.76964e-09, Loss_f: 1.27906e-07
# Iter 90, Loss: 1.62684e-07, Loss_ic: 1.79798e-09, Loss_f: 1.27454e-07
# Iter 90, Loss: 1.62655e-07, Loss_ic: 1.80059e-09, Loss_f: 1.27414e-07
# Iter 90, Loss: 1.62510e-07, Loss_ic: 1.81144e-09, Loss_f: 1.27213e-07
# Iter 90, Loss: 1.62281e-07, Loss_ic: 1.83220e-09, Loss_f: 1.26876e-07
# Iter 90, Loss: 1.62255e-07, Loss_ic: 1.83221e-09, Loss_f: 1.26845e-07
# Iter 90, Loss: 1.62236e-07, Loss_ic: 1.83269e-09, Loss_f: 1.26825e-07
# Iter 90, Loss: 1.62249e-07, Loss_ic: 1.83332e-09, Loss_f: 1.26832e-07
# Iter 90, Loss: 1.62239e-07, Loss_ic: 1.83281e-09, Loss_f: 1.26828e-07
# Iter 90, Loss: 1.62239e-07, Loss_ic: 1.83279e-09, Loss_f: 1.26826e-07
# Iter 90, Loss: 1.62236e-07, Loss_ic: 1.83269e-09, Loss_f: 1.26825e-07
# Iter 90, Loss: 1.62233e-07, Loss_ic: 1.83337e-09, Loss_f: 1.26811e-07
# Iter 90, Loss: 1.62226e-07, Loss_ic: 1.83334e-09, Loss_f: 1.26803e-07
# Iter 90, Loss: 1.62227e-07, Loss_ic: 1.83332e-09, Loss_f: 1.26804e-07
# Iter 90, Loss: 1.62204e-07, Loss_ic: 1.83454e-09, Loss_f: 1.26775e-07
# Iter 90, Loss: 1.62184e-07, Loss_ic: 1.83534e-09, Loss_f: 1.26746e-07
# Iter 90, Loss: 1.62169e-07, Loss_ic: 1.83646e-09, Loss_f: 1.26723e-07
# Iter 90, Loss: 1.61929e-07, Loss_ic: 1.84565e-09, Loss_f: 1.26383e-07
# Iter 90, Loss: 1.61919e-07, Loss_ic: 1.84546e-09, Loss_f: 1.26365e-07
# Iter 90, Loss: 1.61858e-07, Loss_ic: 1.84407e-09, Loss_f: 1.26282e-07
# Iter 90, Loss: 1.61617e-07, Loss_ic: 1.83855e-09, Loss_f: 1.25941e-07
# Iter 90, Loss: 1.61602e-07, Loss_ic: 1.83760e-09, Loss_f: 1.25927e-07
# Iter 90, Loss: 1.61601e-07, Loss_ic: 1.83701e-09, Loss_f: 1.25924e-07
# Iter 90, Loss: 1.61558e-07, Loss_ic: 1.83064e-09, Loss_f: 1.25872e-07
# Iter 90, Loss: 1.61334e-07, Loss_ic: 1.79665e-09, Loss_f: 1.25597e-07
# Iter 90, Loss: 1.61329e-07, Loss_ic: 1.79575e-09, Loss_f: 1.25589e-07
# Iter 90, Loss: 1.61326e-07, Loss_ic: 1.79328e-09, Loss_f: 1.25587e-07
# Iter 90, Loss: 1.61322e-07, Loss_ic: 1.79322e-09, Loss_f: 1.25584e-07
# Iter 90, Loss: 1.61321e-07, Loss_ic: 1.79324e-09, Loss_f: 1.25583e-07
# Iter 90, Loss: 1.61321e-07, Loss_ic: 1.79324e-09, Loss_f: 1.25583e-07
# Iter 90, Loss: 1.61309e-07, Loss_ic: 1.79171e-09, Loss_f: 1.25573e-07
# Iter 90, Loss: 1.61307e-07, Loss_ic: 1.79142e-09, Loss_f: 1.25570e-07
# Iter 90, Loss: 1.61306e-07, Loss_ic: 1.79137e-09, Loss_f: 1.25568e-07
# Iter 90, Loss: 1.61307e-07, Loss_ic: 1.79142e-09, Loss_f: 1.25569e-07
# Iter 90, Loss: 1.61307e-07, Loss_ic: 1.79032e-09, Loss_f: 1.25570e-07
# Iter 90, Loss: 1.61302e-07, Loss_ic: 1.79140e-09, Loss_f: 1.25563e-07
# Iter 90, Loss: 1.61309e-07, Loss_ic: 1.79121e-09, Loss_f: 1.25569e-07
# Iter 90, Loss: 1.61306e-07, Loss_ic: 1.79146e-09, Loss_f: 1.25566e-07
# Iter 90, Loss: 1.61302e-07, Loss_ic: 1.79140e-09, Loss_f: 1.25563e-07
# Iter 90, Loss: 1.61301e-07, Loss_ic: 1.79135e-09, Loss_f: 1.25562e-07
# Iter 90, Loss: 1.61301e-07, Loss_ic: 1.79135e-09, Loss_f: 1.25562e-07
# Iter 90, Loss: 1.61303e-07, Loss_ic: 1.79025e-09, Loss_f: 1.25570e-07
# Iter 90, Loss: 1.61304e-07, Loss_ic: 1.79142e-09, Loss_f: 1.25567e-07
# Iter 90, Loss: 1.61303e-07, Loss_ic: 1.79127e-09, Loss_f: 1.25563e-07
# Iter 90, Loss: 1.61301e-07, Loss_ic: 1.79135e-09, Loss_f: 1.25562e-07
# Iter 90, Loss: 1.61301e-07, Loss_ic: 1.79135e-09, Loss_f: 1.25562e-07
# Iter 90, Loss: 1.61304e-07, Loss_ic: 1.79029e-09, Loss_f: 1.25570e-07
# Iter 90, Loss: 1.61306e-07, Loss_ic: 1.79160e-09, Loss_f: 1.25567e-07
# Iter 90, Loss: 1.61303e-07, Loss_ic: 1.79136e-09, Loss_f: 1.25564e-07
# Iter 90, Loss: 1.61301e-07, Loss_ic: 1.79135e-09, Loss_f: 1.25562e-07
# Iter 90, Loss: 1.61301e-07, Loss_ic: 1.79135e-09, Loss_f: 1.25562e-07
# Iter 90, Loss: 1.61304e-07, Loss_ic: 1.79030e-09, Loss_f: 1.25570e-07
# Iter 90, Loss: 1.61308e-07, Loss_ic: 1.79143e-09, Loss_f: 1.25569e-07
# Iter 90, Loss: 1.61302e-07, Loss_ic: 1.79139e-09, Loss_f: 1.25563e-07
# Iter 90, Loss: 1.61301e-07, Loss_ic: 1.79135e-09, Loss_f: 1.25562e-07
# Iter 90, Loss: 1.61301e-07, Loss_ic: 1.79135e-09, Loss_f: 1.25562e-07
# Iter 90, Loss: 1.61304e-07, Loss_ic: 1.79030e-09, Loss_f: 1.25570e-07
# Iter 90, Loss: 1.61307e-07, Loss_ic: 1.79147e-09, Loss_f: 1.25568e-07
# Iter 90, Loss: 1.61302e-07, Loss_ic: 1.79138e-09, Loss_f: 1.25563e-07
# Iter 90, Loss: 1.61301e-07, Loss_ic: 1.79135e-09, Loss_f: 1.25562e-07
# Iter 90, Loss: 1.61301e-07, Loss_ic: 1.79135e-09, Loss_f: 1.25562e-07
# Iter 90, Loss: 1.61304e-07, Loss_ic: 1.79030e-09, Loss_f: 1.25570e-07
# Iter 90, Loss: 1.61309e-07, Loss_ic: 1.79151e-09, Loss_f: 1.25570e-07
# Iter 90, Loss: 1.61302e-07, Loss_ic: 1.79138e-09, Loss_f: 1.25563e-07
# Iter 90, Loss: 1.61301e-07, Loss_ic: 1.79135e-09, Loss_f: 1.25562e-07
# Iter 90, Loss: 1.61301e-07, Loss_ic: 1.79135e-09, Loss_f: 1.25562e-07
# Iter 100, Loss: 1.82207e-07, Loss_ic: 1.39200e-09, Loss_f: 1.46379e-07
# Iter 100, Loss: 1.82169e-07, Loss_ic: 1.39186e-09, Loss_f: 1.46338e-07
# Iter 100, Loss: 1.82123e-07, Loss_ic: 1.39279e-09, Loss_f: 1.46289e-07
# Iter 100, Loss: 1.82061e-07, Loss_ic: 1.39256e-09, Loss_f: 1.46222e-07
# Iter 100, Loss: 1.81969e-07, Loss_ic: 1.39375e-09, Loss_f: 1.46122e-07
# Iter 100, Loss: 1.81093e-07, Loss_ic: 1.40660e-09, Loss_f: 1.45135e-07
# Iter 100, Loss: 1.81068e-07, Loss_ic: 1.40657e-09, Loss_f: 1.45109e-07
# Iter 100, Loss: 1.81055e-07, Loss_ic: 1.40684e-09, Loss_f: 1.45093e-07
# Iter 100, Loss: 1.80881e-07, Loss_ic: 1.40675e-09, Loss_f: 1.44884e-07
# Iter 100, Loss: 1.80856e-07, Loss_ic: 1.40687e-09, Loss_f: 1.44857e-07
# Iter 100, Loss: 1.80852e-07, Loss_ic: 1.40719e-09, Loss_f: 1.44849e-07
# Iter 100, Loss: 1.80745e-07, Loss_ic: 1.40895e-09, Loss_f: 1.44725e-07
# Iter 100, Loss: 1.80631e-07, Loss_ic: 1.41212e-09, Loss_f: 1.44587e-07
# Iter 100, Loss: 1.80623e-07, Loss_ic: 1.41185e-09, Loss_f: 1.44575e-07
# Iter 100, Loss: 1.80573e-07, Loss_ic: 1.41372e-09, Loss_f: 1.44511e-07
# Iter 100, Loss: 1.80295e-07, Loss_ic: 1.42226e-09, Loss_f: 1.44165e-07
# Iter 100, Loss: 1.80295e-07, Loss_ic: 1.42226e-09, Loss_f: 1.44165e-07
# Iter 110, Loss: 2.05073e-07, Loss_ic: 1.25502e-09, Loss_f: 1.69444e-07
# Iter 110, Loss: 2.04901e-07, Loss_ic: 1.25397e-09, Loss_f: 1.69241e-07
# Iter 110, Loss: 2.04638e-07, Loss_ic: 1.25273e-09, Loss_f: 1.68930e-07
# Iter 110, Loss: 2.02841e-07, Loss_ic: 1.25041e-09, Loss_f: 1.66757e-07
# Iter 110, Loss: 2.02715e-07, Loss_ic: 1.25063e-09, Loss_f: 1.66611e-07
# Iter 110, Loss: 2.02087e-07, Loss_ic: 1.25220e-09, Loss_f: 1.65907e-07
# Iter 110, Loss: 2.00618e-07, Loss_ic: 1.25931e-09, Loss_f: 1.64231e-07
# Iter 110, Loss: 2.00491e-07, Loss_ic: 1.25981e-09, Loss_f: 1.64086e-07
# Iter 110, Loss: 2.00307e-07, Loss_ic: 1.26125e-09, Loss_f: 1.63871e-07
# Iter 110, Loss: 1.99006e-07, Loss_ic: 1.26955e-09, Loss_f: 1.62342e-07
# Iter 110, Loss: 1.98894e-07, Loss_ic: 1.26997e-09, Loss_f: 1.62220e-07
# Iter 110, Loss: 1.98783e-07, Loss_ic: 1.27087e-09, Loss_f: 1.62093e-07
# Iter 110, Loss: 1.98656e-07, Loss_ic: 1.27101e-09, Loss_f: 1.61946e-07
# Iter 110, Loss: 1.97251e-07, Loss_ic: 1.27881e-09, Loss_f: 1.60291e-07
# Iter 110, Loss: 1.97171e-07, Loss_ic: 1.27912e-09, Loss_f: 1.60196e-07
# Iter 110, Loss: 1.96799e-07, Loss_ic: 1.28113e-09, Loss_f: 1.59751e-07
# Iter 110, Loss: 1.95076e-07, Loss_ic: 1.29539e-09, Loss_f: 1.57601e-07
# Iter 110, Loss: 1.95025e-07, Loss_ic: 1.29503e-09, Loss_f: 1.57536e-07
# Iter 110, Loss: 1.94984e-07, Loss_ic: 1.29522e-09, Loss_f: 1.57484e-07
# Iter 110, Loss: 1.94955e-07, Loss_ic: 1.29608e-09, Loss_f: 1.57442e-07
# Iter 110, Loss: 1.94435e-07, Loss_ic: 1.29618e-09, Loss_f: 1.56758e-07
# Iter 110, Loss: 1.94435e-07, Loss_ic: 1.29618e-09, Loss_f: 1.56758e-07
# Iter 120, Loss: 1.76357e-07, Loss_ic: 1.32692e-09, Loss_f: 1.39476e-07
# Iter 120, Loss: 1.76297e-07, Loss_ic: 1.32561e-09, Loss_f: 1.39435e-07
# Iter 120, Loss: 1.76238e-07, Loss_ic: 1.32426e-09, Loss_f: 1.39397e-07
# Iter 120, Loss: 1.75737e-07, Loss_ic: 1.31467e-09, Loss_f: 1.39063e-07
# Iter 120, Loss: 1.73716e-07, Loss_ic: 1.28342e-09, Loss_f: 1.37855e-07
# Iter 120, Loss: 1.73654e-07, Loss_ic: 1.28276e-09, Loss_f: 1.37820e-07
# Iter 120, Loss: 1.73645e-07, Loss_ic: 1.28229e-09, Loss_f: 1.37817e-07
# Iter 120, Loss: 1.73387e-07, Loss_ic: 1.27985e-09, Loss_f: 1.37683e-07
# Iter 120, Loss: 1.72161e-07, Loss_ic: 1.27890e-09, Loss_f: 1.37111e-07
# Iter 120, Loss: 1.72120e-07, Loss_ic: 1.27928e-09, Loss_f: 1.37089e-07
# Iter 120, Loss: 1.72115e-07, Loss_ic: 1.27894e-09, Loss_f: 1.37086e-07
# Iter 120, Loss: 1.71938e-07, Loss_ic: 1.27991e-09, Loss_f: 1.36998e-07
# Iter 120, Loss: 1.71170e-07, Loss_ic: 1.29907e-09, Loss_f: 1.36664e-07
# Iter 120, Loss: 1.71159e-07, Loss_ic: 1.29824e-09, Loss_f: 1.36662e-07
# Iter 120, Loss: 1.71083e-07, Loss_ic: 1.29457e-09, Loss_f: 1.36637e-07
# Iter 120, Loss: 1.71033e-07, Loss_ic: 1.29195e-09, Loss_f: 1.36630e-07
# Iter 120, Loss: 1.71024e-07, Loss_ic: 1.29173e-09, Loss_f: 1.36627e-07
# Iter 120, Loss: 1.70964e-07, Loss_ic: 1.29021e-09, Loss_f: 1.36613e-07
# Iter 120, Loss: 1.70918e-07, Loss_ic: 1.28912e-09, Loss_f: 1.36602e-07
# Iter 120, Loss: 1.70906e-07, Loss_ic: 1.28901e-09, Loss_f: 1.36598e-07
# Iter 120, Loss: 1.70904e-07, Loss_ic: 1.28862e-09, Loss_f: 1.36598e-07
# Iter 120, Loss: 1.70837e-07, Loss_ic: 1.28938e-09, Loss_f: 1.36586e-07
# Iter 120, Loss: 1.70571e-07, Loss_ic: 1.30442e-09, Loss_f: 1.36595e-07
# Iter 120, Loss: 1.70571e-07, Loss_ic: 1.30442e-09, Loss_f: 1.36595e-07
# Iter 130, Loss: 1.63544e-07, Loss_ic: 1.55167e-09, Loss_f: 1.28026e-07
# Iter 130, Loss: 1.63526e-07, Loss_ic: 1.55507e-09, Loss_f: 1.28006e-07
# Iter 130, Loss: 1.63418e-07, Loss_ic: 1.57217e-09, Loss_f: 1.27895e-07
# Iter 130, Loss: 1.63392e-07, Loss_ic: 1.57516e-09, Loss_f: 1.27869e-07
# Iter 130, Loss: 1.63381e-07, Loss_ic: 1.57642e-09, Loss_f: 1.27857e-07
# Iter 130, Loss: 1.63392e-07, Loss_ic: 1.57656e-09, Loss_f: 1.27867e-07
# Iter 130, Loss: 1.63379e-07, Loss_ic: 1.57649e-09, Loss_f: 1.27856e-07
# Iter 130, Loss: 1.63379e-07, Loss_ic: 1.57670e-09, Loss_f: 1.27856e-07
# Iter 130, Loss: 1.63380e-07, Loss_ic: 1.57673e-09, Loss_f: 1.27858e-07
# Iter 130, Loss: 1.63379e-07, Loss_ic: 1.57672e-09, Loss_f: 1.27856e-07
# Iter 130, Loss: 1.63372e-07, Loss_ic: 1.57865e-09, Loss_f: 1.27843e-07
# Iter 130, Loss: 1.63293e-07, Loss_ic: 1.59246e-09, Loss_f: 1.27751e-07
# Iter 130, Loss: 1.63280e-07, Loss_ic: 1.59487e-09, Loss_f: 1.27738e-07
# Iter 130, Loss: 1.63266e-07, Loss_ic: 1.59794e-09, Loss_f: 1.27719e-07
# Iter 130, Loss: 1.63142e-07, Loss_ic: 1.62510e-09, Loss_f: 1.27556e-07
# Iter 130, Loss: 1.63134e-07, Loss_ic: 1.62664e-09, Loss_f: 1.27543e-07
# Iter 130, Loss: 1.63133e-07, Loss_ic: 1.62730e-09, Loss_f: 1.27543e-07
# Iter 130, Loss: 1.63135e-07, Loss_ic: 1.62736e-09, Loss_f: 1.27544e-07
# Iter 130, Loss: 1.63134e-07, Loss_ic: 1.62725e-09, Loss_f: 1.27543e-07
# Iter 130, Loss: 1.63127e-07, Loss_ic: 1.62868e-09, Loss_f: 1.27530e-07
# Iter 130, Loss: 1.63100e-07, Loss_ic: 1.63324e-09, Loss_f: 1.27489e-07
# Iter 130, Loss: 1.62951e-07, Loss_ic: 1.66211e-09, Loss_f: 1.27264e-07
# Iter 130, Loss: 1.62947e-07, Loss_ic: 1.66159e-09, Loss_f: 1.27260e-07
# Iter 130, Loss: 1.62926e-07, Loss_ic: 1.66089e-09, Loss_f: 1.27230e-07
# Iter 130, Loss: 1.62804e-07, Loss_ic: 1.65518e-09, Loss_f: 1.27071e-07
# Iter 130, Loss: 1.62230e-07, Loss_ic: 1.62576e-09, Loss_f: 1.26261e-07
# Iter 130, Loss: 1.62166e-07, Loss_ic: 1.62780e-09, Loss_f: 1.26166e-07
# Iter 130, Loss: 1.62084e-07, Loss_ic: 1.62960e-09, Loss_f: 1.26050e-07
# Iter 130, Loss: 1.62037e-07, Loss_ic: 1.63204e-09, Loss_f: 1.25978e-07
# Iter 130, Loss: 1.61368e-07, Loss_ic: 1.66282e-09, Loss_f: 1.24866e-07
# Iter 130, Loss: 1.61314e-07, Loss_ic: 1.66028e-09, Loss_f: 1.24786e-07
# Iter 130, Loss: 1.61273e-07, Loss_ic: 1.65921e-09, Loss_f: 1.24716e-07
# Iter 130, Loss: 1.60904e-07, Loss_ic: 1.64111e-09, Loss_f: 1.24087e-07
# Iter 130, Loss: 1.60881e-07, Loss_ic: 1.63930e-09, Loss_f: 1.24049e-07
# Iter 130, Loss: 1.60781e-07, Loss_ic: 1.63141e-09, Loss_f: 1.23868e-07
# Iter 130, Loss: 1.60290e-07, Loss_ic: 1.59144e-09, Loss_f: 1.22933e-07
# Iter 130, Loss: 1.60277e-07, Loss_ic: 1.59064e-09, Loss_f: 1.22905e-07
# Iter 130, Loss: 1.60211e-07, Loss_ic: 1.58752e-09, Loss_f: 1.22783e-07
# Iter 130, Loss: 1.60132e-07, Loss_ic: 1.58373e-09, Loss_f: 1.22628e-07
# Iter 130, Loss: 1.60132e-07, Loss_ic: 1.58373e-09, Loss_f: 1.22628e-07
# Iter 140, Loss: 1.15575e-07, Loss_ic: 9.66975e-10, Loss_f: 7.77453e-08
# Iter 140, Loss: 1.15371e-07, Loss_ic: 9.60252e-10, Loss_f: 7.75253e-08
# Iter 140, Loss: 1.14642e-07, Loss_ic: 9.36198e-10, Loss_f: 7.67032e-08
# Iter 140, Loss: 1.14622e-07, Loss_ic: 9.35845e-10, Loss_f: 7.66837e-08
# Iter 140, Loss: 1.14604e-07, Loss_ic: 9.35395e-10, Loss_f: 7.66643e-08
# Iter 140, Loss: 1.14604e-07, Loss_ic: 9.35615e-10, Loss_f: 7.66618e-08
# Iter 140, Loss: 1.14611e-07, Loss_ic: 9.35608e-10, Loss_f: 7.66714e-08
# Iter 140, Loss: 1.14605e-07, Loss_ic: 9.35271e-10, Loss_f: 7.66659e-08
# Iter 140, Loss: 1.14605e-07, Loss_ic: 9.35400e-10, Loss_f: 7.66654e-08
# Iter 140, Loss: 1.14597e-07, Loss_ic: 9.35181e-10, Loss_f: 7.66538e-08
# Iter 140, Loss: 1.14514e-07, Loss_ic: 9.33004e-10, Loss_f: 7.65683e-08
# Iter 140, Loss: 1.14431e-07, Loss_ic: 9.30739e-10, Loss_f: 7.64802e-08
# Iter 140, Loss: 1.13807e-07, Loss_ic: 9.14580e-10, Loss_f: 7.57928e-08
# Iter 140, Loss: 1.13789e-07, Loss_ic: 9.15320e-10, Loss_f: 7.57784e-08
# Iter 140, Loss: 1.13725e-07, Loss_ic: 9.17011e-10, Loss_f: 7.57266e-08
# Iter 140, Loss: 1.13412e-07, Loss_ic: 9.35440e-10, Loss_f: 7.54817e-08
# Iter 140, Loss: 1.13393e-07, Loss_ic: 9.35386e-10, Loss_f: 7.54656e-08
# Iter 140, Loss: 1.13388e-07, Loss_ic: 9.36126e-10, Loss_f: 7.54568e-08
# Iter 140, Loss: 1.13264e-07, Loss_ic: 9.37775e-10, Loss_f: 7.53511e-08
# Iter 140, Loss: 1.12712e-07, Loss_ic: 9.57351e-10, Loss_f: 7.48639e-08
# Iter 140, Loss: 1.12703e-07, Loss_ic: 9.58044e-10, Loss_f: 7.48600e-08
# Iter 140, Loss: 1.12638e-07, Loss_ic: 9.61436e-10, Loss_f: 7.48159e-08
# Iter 140, Loss: 1.12510e-07, Loss_ic: 9.69055e-10, Loss_f: 7.47316e-08
# Iter 140, Loss: 1.12511e-07, Loss_ic: 9.70325e-10, Loss_f: 7.47304e-08
# Iter 140, Loss: 1.12512e-07, Loss_ic: 9.70074e-10, Loss_f: 7.47340e-08
# Iter 140, Loss: 1.12514e-07, Loss_ic: 9.69502e-10, Loss_f: 7.47342e-08
# Iter 140, Loss: 1.12511e-07, Loss_ic: 9.69054e-10, Loss_f: 7.47327e-08
# Iter 140, Loss: 1.12510e-07, Loss_ic: 9.69055e-10, Loss_f: 7.47316e-08
# Iter 140, Loss: 1.12510e-07, Loss_ic: 9.69055e-10, Loss_f: 7.47316e-08

# %%
#torch.save(model.state_dict(),"Param_model_2.pt")

# %%
def test_set(max_space,obs,param,mean,std):

    t = np.linspace(0,max_space,obs)

    sol = (t - t**2) / (2*np.exp(param))

    noise_sol_test = sol + np.random.normal(mean,std, len(t))

    return t, noise_sol_test

# %%
import matplotlib.pyplot as plt
from matplotlib import cm


param_trained =  samples_param(min_param , max_param,6)


# Plotting
fig = plt.figure(figsize=(25,25))
plt.subplots_adjust(hspace=0.25)

for n,pr in enumerate(param_trained):

    t, noise_sol_test = test_set(ns,500,pr,mean,std)

    data_test = np.hstack((t.flatten()[:,None], np.ones_like(t).flatten()[:,None]*(pr)))

    u_pred = model(torch.tensor(data_test).float()).detach().cpu().numpy()

    plt.subplot(8, 2, n + 1)

    plt.plot(t, u_pred, label = fr"PINN $\alpha$ = {pr:.1f}", color = "red",linewidth = '3')

    plt.scatter(t,noise_sol_test, label = "Observations",color= "blue",alpha = 0.5)

    plt.xlabel("t")
    plt.ylabel("u")
    plt.legend(frameon=False)

# %% [markdown]
# ## MCMC Step

# %%
def log_prior_alpha(alpha): #function to evaluate prior pdf of given parameters
    return norm.logpdf(alpha,loc = 0,scale = 1.5)

def proposals(alpha,dt):
    return np.random.normal(alpha,dt)

# %%
def log_likelihood(surrogate,alpha,t,y_dat,sig = std):
    
    data_ = np.hstack((t.flatten()[:,None], np.ones_like(t).flatten()[:,None]*(alpha)))

    surg = surrogate(torch.tensor(data_).float()).detach().cpu().numpy().reshape(-1,)
        
    #return np.sum(-np.log(np.sqrt(2* np.pi*sig)) - ((y_dat-surg)**2) / (2*sig))

    return np.sum(- ((y_dat-surg)**2) / (2*sig**2))

def log_likelihood_ex(alpha,t,y,sig = std):

    surg_exact = (t - t**2) / (2*np.exp(alpha))

    #return np.sum(-np.log(np.sqrt(2* np.pi*sig**2)) - ((y-surg_exact)**2) / (2*sig**2))
    return np.sum(-((y-surg_exact)**2) / (2*sig**2))

# %%
def log_posterior_ex(alpha,t,y):
    return  log_likelihood_ex(alpha,t,y) + log_prior_alpha(alpha)

def log_posterior_nn(model,alpha,t,y):
    return  log_likelihood(model,alpha,t,y) + log_prior_alpha(alpha)

# %%
theta_h = 0.314
t, noise_sol_test = test_set(ns,1000,theta_h,mean,std)

# %%
alpha_ = np.linspace(-1,1,200)

alpha_fc,alpha_fc_2,alpha_fc_3 = [],[],[]
alpha_fc_nn,alpha_fc_2_nn,alpha_fc_3_nn = [],[],[]


for alp in alpha_:
    alpha_fc.append(log_posterior_ex(alp,t[:100],noise_sol_test[:100]))
    alpha_fc_nn.append(log_posterior_nn(model,alp,t[:100],noise_sol_test[:100]))
    
    alpha_fc_2.append(log_posterior_ex(alp,t[:500],noise_sol_test[:500]))
    alpha_fc_2_nn.append(log_posterior_nn(model,alp,t[:500],noise_sol_test[:500]))
    
    alpha_fc_3.append(log_posterior_ex(alp,t,noise_sol_test))
    alpha_fc_3_nn.append(log_posterior_nn(model,alp,t,noise_sol_test))

# %%
fig = plt.figure(figsize=(18,8))
plt.subplots_adjust(hspace=0.25)

plt.subplot(2, 2, 1)
plt.plot(alpha_,alpha_fc ,linestyle = '--', label = "100 obs")
plt.plot(alpha_,alpha_fc_2,linestyle = ':', label = "500 obs")
plt.plot(alpha_,alpha_fc_3, label = "all obs")

plt.axvline(x = theta_h, color = 'black', label = 'Real')

plt.title("Exact Solution Estimation")
plt.ylabel("Log-Posterior")
plt.xlabel(r"$\alpha$")
plt.legend(frameon =False)


plt.subplot(2, 2, 2)
plt.plot(alpha_,alpha_fc_nn ,linestyle = '--', label = "100 obs")
plt.plot(alpha_,alpha_fc_2_nn,linestyle = ':', label = "500 obs")
plt.plot(alpha_,alpha_fc_3_nn, label = "all obs")

plt.axvline(x = theta_h, color = 'black', label = 'Real')

plt.title("NN Solution Estimation",color = "red")
plt.ylabel("Log-Posterior")
plt.xlabel(r"$\alpha$")
plt.legend(frameon =False)


plt.subplot(2, 2, 3)
plt.plot(alpha_,200*np.exp(alpha_fc)/np.sum(np.exp(alpha_fc)) ,linestyle = '--', label = "100 obs")
plt.plot(alpha_,200*np.exp(alpha_fc_2)/np.sum(np.exp(alpha_fc_2)),linestyle = ':', label = "500 obs")
plt.plot(alpha_,200*np.exp(alpha_fc_3)/np.sum(np.exp(alpha_fc_3)), label = "all obs")

plt.axvline(x = theta_h, color = 'black', label = 'Real')

plt.title("Exact Solution Estimation")
plt.xlabel(r"$\alpha$")
plt.xlim(0,0.5)
plt.legend(frameon =False)


plt.subplot(2, 2, 4)
plt.plot(alpha_,200*np.exp(alpha_fc_nn)/np.sum(np.exp(alpha_fc_nn)) ,linestyle = '--', label = "100 obs")
plt.plot(alpha_,200*np.exp(alpha_fc_2_nn)/np.sum(np.exp(alpha_fc_2_nn)),linestyle = ':', label = "500 obs")
plt.plot(alpha_,200*np.exp(alpha_fc_3_nn)/np.sum(np.exp(alpha_fc_3_nn)), label = "all obs")

plt.axvline(x = theta_h, color = 'black', label = 'Real')

plt.title("NN Solution Estimation",color = "red")
plt.xlabel(r"$\alpha$")
plt.xlim(0,0.5)
plt.legend(frameon =False)

# %%
def Metropolis_Hastings(t,y_dat,nChains, exact = False):

    alpha = 5

    alpha_samp = []
    acceptance_rate, dt = 0, 0.5

    dt_tracker = []
    for i in range(nChains):

        log_posterior =  log_posterior_ex(alpha,t,y_dat) if exact else log_posterior_nn(model,alpha,t,y_dat)
        #log_posterior = log_posterior_ex(alpha,t,y_dat)

        alpha_proposal = proposals(alpha,dt)

        log_posterior_proposal = log_posterior_ex(alpha_proposal,t,y_dat) if exact else log_posterior_nn(model,alpha_proposal,t,y_dat)
        #log_posterior_proposal = log_posterior_ex(alpha_proposal,t,y_dat)

        accept_u = np.random.uniform(0,1)

        ratio = np.exp(log_posterior_proposal-log_posterior, dtype=np.float64)

        a = np.min([1.,ratio])

        if accept_u < a:
            alpha = alpha_proposal
            acceptance_rate += 1
        
        dt = dt + dt*(a - 0.234)/ (i+1) 
        dt_tracker.append(dt)
        alpha_samp.append(alpha)


    print(f"Acceptance Rate: {acceptance_rate/nChains:.3f}")

    return alpha_samp,dt_tracker

# %%
def acf(x, length=20):
    return np.array([1]+[np.corrcoef(x[:-i], x[i:])[0,1] for i in range(1, length)])

# %%
alpha_samp,dt_tracker = Metropolis_Hastings(t,noise_sol_test,100000)
# Out:
# /tmp/ipykernel_2216271/1792166774.py:21: RuntimeWarning: overflow encountered in exp
#   ratio = np.exp(log_posterior_proposal-log_posterior, dtype=np.float64)
# Acceptance Rate: 0.012

# %%
alpha_samp_true,dt_tracker_true = Metropolis_Hastings(t,noise_sol_test,100000,exact = True)
# Out:
# /tmp/ipykernel_2216271/1792166774.py:21: RuntimeWarning: overflow encountered in exp
#   ratio = np.exp(log_posterior_proposal-log_posterior, dtype=np.float64)
# Acceptance Rate: 0.006

# %%
import seaborn as sns

fig = plt.figure(figsize=(20,10))
plt.suptitle("Surrogate MCMC")
plt.subplots_adjust(hspace=0.25)

plt.subplot(2, 2, 1)
plt.plot(alpha_samp)
plt.xlabel("Itaration")
plt.ylim(0.3,0.35)

plt.subplot(2, 2, 2)
plt.plot(acf(alpha_samp,200),color = "red")
plt.xlabel(r"$lag$")
plt.ylabel(r"autocorrelation")


plt.subplot(2, 2, 3)
#plt.hist(alpha_samp[200:],color = "orange",alpha = 0.5)
#plt.plot(alpha_,200*np.exp(alpha_fc_3)/np.sum(np.exp(alpha_fc_3)), label = "all obs")
sns.kdeplot(alpha_samp[200:],bw_adjust=2)
plt.xlabel(r"$\alpha$")
#plt.xlim(0.3,0.32)

plt.subplot(2, 2, 4)
plt.plot(dt_tracker,color = "black")
plt.xlabel("Iteration")
# Out:
# Text(0.5, 0, 'Iteration')

# %%
fig = plt.figure(figsize=(20,10))
plt.suptitle("Exact MCMC")

plt.subplots_adjust(hspace=0.25)

plt.subplot(2, 2, 1)
plt.plot(alpha_samp_true)
plt.xlabel("Itaration")
plt.ylim(0.3,0.35)


plt.subplot(2, 2, 2)
plt.plot(acf(alpha_samp_true,200),color = "red")
plt.xlabel(r"$lag$")
plt.ylabel(r"autocorrelation")


plt.subplot(2, 2, 3)
plt.hist(alpha_samp_true[200:],color = "orange",alpha = 0.5)
plt.xlabel(r"$\alpha$")

plt.subplot(2, 2, 4)
plt.plot(dt_tracker_true,color = "black")
plt.xlabel("Iteration")
# Out:
# Text(0.5, 0, 'Iteration')
