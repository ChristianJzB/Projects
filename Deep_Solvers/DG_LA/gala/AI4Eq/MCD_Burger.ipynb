# %%
import os
import re

os.chdir("../..")

import torch
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset

from collections import OrderedDict

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from pyDOE import lhs
from scipy.stats import uniform,norm
from scipy.interpolate import griddata

from gala.Galab import llaplace
from NN import DNN_Ensemble

np.random.seed(1234)

# CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")

# %% [markdown]
# ## Burgers Equation
#
# $$\frac{\partial u}{\partial t} + u\frac{\partial u}{\partial x} - \frac{0.01}{\pi}\frac{\partial^{2} u}{\partial x^{2}}=0$$
# $$u(x,0) = -sin( \pi x),  u(-1,t)=u(1,t)=0$$

# %% [markdown]
# ## Feed Forward Neural Network

# %%
# Deep neural network
class DNN(torch.nn.Module):
    def __init__(self, layers):
        super(DNN, self).__init__()

        # Number of layers
        self.depth = len(layers) - 1
        
        # Activation Function
        self.activation = torch.nn.Tanh
        
        # The following loop organized the layers of the NN         
        layer_list = list()
        for i in range(self.depth - 1): 
            layer_list.append(
                ('layer_%d' % i, torch.nn.Linear(layers[i], layers[i+1])))
            layer_list.append(('activation_%d' % i, self.activation()))
        layer_list.append(
            ('layer_%d' % (self.depth - 1), torch.nn.Linear(layers[-2], layers[-1]))
        )
        layerDict = OrderedDict(layer_list)
        
        # Deploy layers
        self.layers = torch.nn.Sequential(layerDict)

    def forward(self, x):
        out = self.layers(x)
        return out

# %%
# Deep neural network
class Dropout_DNN(torch.nn.Module):
    def __init__(self, layers):
        super(Dropout_DNN, self).__init__()

        # Number of layers
        self.depth = len(layers) - 1
        
        # Activation Function
        self.activation = torch.nn.Tanh
        
        # The following loop organized the layers of the NN         
        layer_list = list()
        for i in range(self.depth - 1): 
            layer_list.append(('layer_%d' % i, torch.nn.Linear(layers[i], layers[i+1])))
            layer_list.append(('activation_%d' % i, self.activation()))
            layer_list.append(('dropout_%d' % i, torch.nn.Dropout(p = 0.1)))

        layer_list.append(
            ('layer_%d' % (self.depth - 1), torch.nn.Linear(layers[-2], layers[-1]))
        )
        layerDict = OrderedDict(layer_list)
        
        # Deploy layers
        self.layers = torch.nn.Sequential(layerDict)

    def forward(self, x):
        out = self.layers(x)
        return out

# %% [markdown]
# ## Parametric PINN for Inverse Problems

# %%
def de(self,data_domain):
    """ The pytorch autograd version of calculating residual """
    u = self(data_domain)
    
    du = torch.autograd.grad(
        u, data_domain, 
        grad_outputs=torch.ones_like(u),
        retain_graph=True,
        create_graph=True
    )[0]

    ddu_x = torch.autograd.grad(
        du[:,0],data_domain, 
        grad_outputs=torch.ones_like(du[:,0]),
        retain_graph=True,
        create_graph=True
        )[0]
    
    f = du[:,1].reshape(-1,1) + u.reshape(-1,1)*du[:,0].reshape(-1,1) - data_domain[:,2].reshape(-1,1)*ddu_x[:,0].reshape(-1,1)

    return f

def ini_c(self,data_inic):
    u = self(data_inic)
    return u + torch.sin(torch.pi*data_inic[:,0].reshape(-1,1))

def left_bc(self,data_lbc):
    u = self(data_lbc)
    return u

def right_bc(self,data_rbc):
    u = self(data_rbc)
    return u

# %%
DNN.de = de
DNN.ini_c = ini_c
DNN.left_bc = left_bc
DNN.right_bc = right_bc

Dropout_DNN.de = de
Dropout_DNN.ini_c = ini_c
Dropout_DNN.left_bc = left_bc
Dropout_DNN.right_bc = right_bc

# %%
def samples_space(size,maxl=1):
    t_f_train = lhs(2, size)*maxl
    t_f_train[:,0] = t_f_train[:,0]*(2)-1
    t_f_train[:,1] = t_f_train[:,1]*(0.5)
    return t_f_train

def samples_param(min,max,size = 100):
    return np.random.uniform(min,max,size = size)

# %%
def data_pde(size,minp,maxp):

    xy, param = samples_space(size),samples_param(minp,maxp,(size,1)).reshape(-1,1)
    pde_domain = torch.tensor(np.hstack((xy,param.reshape(-1,1)))).float()
    
    x,y, param  = torch.tensor(xy[:,0]).reshape(-1,1),torch.tensor(xy[:,1]).reshape(-1,1),torch.tensor(param).reshape(-1,1)

    ini_c = torch.cat([x,torch.zeros_like(x).float(),param],axis = 1).float()

    left_bc = torch.cat([torch.ones_like(x).float()*(-1),y, param],axis = 1).float()

    right_bc = torch.cat([torch.ones_like(x).float(),y, param],axis = 1).float()

    return pde_domain,ini_c,left_bc,right_bc

# %%
def train_adam(pinn,loss,optimizer,epochs, sample_size = 100,minval_param = 0.2,maxval_param = 2,repetitions=1):
      print("Starting Adam Training")
      train_loss=[]
      for i in range(epochs):
        pde_domain,ini_c,left_bc,right_bc = data_pde(sample_size,minval_param,maxval_param)
        
        pde_domain,ini_c = Variable(pde_domain,requires_grad=True),Variable(ini_c,requires_grad=True)
        left_bc,right_bc = Variable(left_bc,requires_grad=True),Variable(right_bc,requires_grad=True)
        
        for _ in range(repetitions):
                optimizer.zero_grad()

                pde_pred,ini_c_pred = pinn.de(pde_domain), pinn.ini_c(ini_c)
                left_bc_pred,right_bc_pred = pinn.left_bc(left_bc),pinn.right_bc(right_bc)

                loss_pde,loss_ini = loss(pde_pred,torch.zeros_like(pde_pred)),loss(ini_c_pred,torch.zeros_like(pde_pred))
                loss_lbc,loss_rbc = loss(left_bc_pred,torch.zeros_like(pde_pred)),loss(right_bc_pred,torch.zeros_like(pde_pred))

                Loss =  loss_pde + loss_ini + loss_lbc + loss_rbc
                train_loss.append(Loss.item())
                if i % 10 == 0:
                        print('Iter %d, Loss: %.5e, Loss_PDE: %.5e, Loss_ini: %.5e, Loss_lbc: %.5e,Loss_rbc: %.5e' % (i, 
                                                                         Loss.item(),loss_pde.item(),loss_ini.item(), loss_lbc.item(), loss_rbc.item()))
                                
                Loss.backward() 

                optimizer.step() 

                #sheduler.step()
      return train_loss

# %%
def train_LBFGS(pinn,loss,optimizer, sample_size = 100, minval_param = 0.2,maxval_param = 2):
    print("Starting Training: LBFGS optimizer")
    train_loss=[]

    pde_domain,ini_c,left_bc,right_bc = data_pde(sample_size,minval_param,maxval_param)
    
    pde_domain,ini_c = Variable(pde_domain,requires_grad=True),Variable(ini_c,requires_grad=True)
    left_bc,right_bc = Variable(left_bc,requires_grad=True),Variable(right_bc,requires_grad=True)
    

    def loss_func_train():
        optimizer.zero_grad()
        
        pde_pred,ini_c_pred = pinn.de(pde_domain), pinn.ini_c(ini_c)
        left_bc_pred,right_bc_pred = pinn.left_bc(left_bc),pinn.right_bc(right_bc)

        loss_pde,loss_ini = loss(pde_pred,torch.zeros_like(pde_pred)),loss(ini_c_pred,torch.zeros_like(pde_pred))
        loss_lbc,loss_rbc = loss(left_bc_pred,torch.zeros_like(pde_pred)),loss(right_bc_pred,torch.zeros_like(pde_pred))

        Loss =  loss_pde + loss_ini + loss_lbc + loss_rbc
        train_loss.append(Loss.item())

        print('Loss: %.5e, Loss_PDE: %.5e, Loss_ini: %.5e, Loss_lbc: %.5e,Loss_rbc: %.5e' % ( 
                                                            Loss.item(),loss_pde.item(),loss_ini.item(), loss_lbc.item(), loss_rbc.item()))

        Loss.backward() 

        return Loss

    optimizer.step(loss_func_train) 
    return train_loss

# %%
# Number of observations
epochs = 1200
nobs = 3000
#nobs = 500
lr = 0.01

min_param , max_param = 0.0001, 0.05

layers = [3] + 3*[40] + [1]

model = Dropout_DNN(layers)

# model.load_state_dict(torch.load(f"../Projects-1/Physics _Informed_NN/GaLA/Gala_models/BurgEq_4_30.pt"))
# model.eval()

# %%
loss = torch.nn.MSELoss(reduction ='mean')

optimizer = torch.optim.Adam(model.parameters(), lr = lr)

loss_history = train_adam(model,loss,optimizer,epochs, nobs,min_param,max_param)

optimizer = torch.optim.LBFGS(
    model.parameters(), lr=lr, max_iter=50000, max_eval=None, tolerance_grad=1e-5, tolerance_change=1.0 * np.finfo(float).eps,line_search_fn="strong_wolfe" 
    )

loss_history_b = train_LBFGS(model,loss,optimizer, nobs*2,min_param,max_param)
# Out:
# Starting Adam Training
# Iter 0, Loss: 5.12868e-01, Loss_PDE: 1.90527e-03, Loss_ini: 4.88341e-01, Loss_lbc: 5.42945e-03,Loss_rbc: 1.71925e-02
# Iter 10, Loss: 4.65695e-01, Loss_PDE: 1.92538e-03, Loss_ini: 3.71094e-01, Loss_lbc: 5.43559e-02,Loss_rbc: 3.83198e-02
# Iter 20, Loss: 4.55365e-01, Loss_PDE: 2.08023e-03, Loss_ini: 3.77427e-01, Loss_lbc: 4.46691e-02,Loss_rbc: 3.11886e-02
# Iter 30, Loss: 4.34677e-01, Loss_PDE: 9.35303e-04, Loss_ini: 3.85769e-01, Loss_lbc: 1.99869e-02,Loss_rbc: 2.79858e-02
# Iter 40, Loss: 3.77624e-01, Loss_PDE: 1.29851e-03, Loss_ini: 3.21460e-01, Loss_lbc: 2.52138e-02,Loss_rbc: 2.96507e-02
# Iter 50, Loss: 3.03520e-01, Loss_PDE: 3.02255e-02, Loss_ini: 2.10502e-01, Loss_lbc: 2.86598e-02,Loss_rbc: 3.41333e-02
# Iter 60, Loss: 2.60317e-01, Loss_PDE: 2.11786e-02, Loss_ini: 1.76747e-01, Loss_lbc: 3.08470e-02,Loss_rbc: 3.15443e-02
# Iter 70, Loss: 2.34397e-01, Loss_PDE: 4.41366e-02, Loss_ini: 1.41025e-01, Loss_lbc: 2.41813e-02,Loss_rbc: 2.50538e-02
# Iter 80, Loss: 2.09811e-01, Loss_PDE: 3.19550e-02, Loss_ini: 1.29678e-01, Loss_lbc: 2.14429e-02,Loss_rbc: 2.67349e-02
# Iter 90, Loss: 1.97412e-01, Loss_PDE: 3.29272e-02, Loss_ini: 1.26189e-01, Loss_lbc: 1.58370e-02,Loss_rbc: 2.24588e-02
# Iter 100, Loss: 1.87890e-01, Loss_PDE: 3.76771e-02, Loss_ini: 1.10693e-01, Loss_lbc: 1.96544e-02,Loss_rbc: 1.98652e-02
# Iter 110, Loss: 1.78948e-01, Loss_PDE: 3.94225e-02, Loss_ini: 1.09204e-01, Loss_lbc: 1.48351e-02,Loss_rbc: 1.54861e-02
# Iter 120, Loss: 1.70437e-01, Loss_PDE: 4.09645e-02, Loss_ini: 1.03510e-01, Loss_lbc: 1.28070e-02,Loss_rbc: 1.31561e-02
# Iter 130, Loss: 1.65301e-01, Loss_PDE: 4.30704e-02, Loss_ini: 9.20329e-02, Loss_lbc: 1.48341e-02,Loss_rbc: 1.53637e-02
# Iter 140, Loss: 1.61323e-01, Loss_PDE: 4.08702e-02, Loss_ini: 9.19695e-02, Loss_lbc: 1.49440e-02,Loss_rbc: 1.35397e-02
# Iter 150, Loss: 1.53039e-01, Loss_PDE: 4.39344e-02, Loss_ini: 8.39796e-02, Loss_lbc: 1.38905e-02,Loss_rbc: 1.12345e-02
# Iter 160, Loss: 1.48709e-01, Loss_PDE: 4.11131e-02, Loss_ini: 8.03379e-02, Loss_lbc: 1.34762e-02,Loss_rbc: 1.37820e-02
# Iter 170, Loss: 1.42810e-01, Loss_PDE: 4.11064e-02, Loss_ini: 8.27544e-02, Loss_lbc: 9.58014e-03,Loss_rbc: 9.36858e-03
# Iter 180, Loss: 1.35244e-01, Loss_PDE: 3.83418e-02, Loss_ini: 6.83617e-02, Loss_lbc: 1.51762e-02,Loss_rbc: 1.33642e-02
# Iter 190, Loss: 1.29061e-01, Loss_PDE: 4.42770e-02, Loss_ini: 6.62973e-02, Loss_lbc: 8.06251e-03,Loss_rbc: 1.04240e-02
# Iter 200, Loss: 1.25624e-01, Loss_PDE: 4.18557e-02, Loss_ini: 5.64862e-02, Loss_lbc: 1.22471e-02,Loss_rbc: 1.50348e-02
# Iter 210, Loss: 1.19242e-01, Loss_PDE: 4.25653e-02, Loss_ini: 6.04566e-02, Loss_lbc: 7.37693e-03,Loss_rbc: 8.84303e-03
# Iter 220, Loss: 1.12887e-01, Loss_PDE: 4.10804e-02, Loss_ini: 5.26439e-02, Loss_lbc: 9.47466e-03,Loss_rbc: 9.68812e-03
# Iter 230, Loss: 1.11196e-01, Loss_PDE: 3.61328e-02, Loss_ini: 5.75485e-02, Loss_lbc: 8.78399e-03,Loss_rbc: 8.73039e-03
# Iter 240, Loss: 1.10106e-01, Loss_PDE: 4.37418e-02, Loss_ini: 4.90343e-02, Loss_lbc: 7.44465e-03,Loss_rbc: 9.88488e-03
# Iter 250, Loss: 1.07729e-01, Loss_PDE: 4.03324e-02, Loss_ini: 4.73440e-02, Loss_lbc: 1.08307e-02,Loss_rbc: 9.22182e-03
# Iter 260, Loss: 1.07410e-01, Loss_PDE: 4.10757e-02, Loss_ini: 5.32932e-02, Loss_lbc: 5.73199e-03,Loss_rbc: 7.30934e-03
# Iter 270, Loss: 1.02591e-01, Loss_PDE: 3.98791e-02, Loss_ini: 4.99535e-02, Loss_lbc: 6.28384e-03,Loss_rbc: 6.47462e-03
# Iter 280, Loss: 1.07664e-01, Loss_PDE: 4.33756e-02, Loss_ini: 4.44058e-02, Loss_lbc: 1.15163e-02,Loss_rbc: 8.36675e-03
# Iter 290, Loss: 1.05236e-01, Loss_PDE: 4.62193e-02, Loss_ini: 4.62086e-02, Loss_lbc: 6.25929e-03,Loss_rbc: 6.54862e-03
# Iter 300, Loss: 9.78726e-02, Loss_PDE: 3.86585e-02, Loss_ini: 4.46368e-02, Loss_lbc: 6.96095e-03,Loss_rbc: 7.61629e-03
# Iter 310, Loss: 9.75588e-02, Loss_PDE: 3.76052e-02, Loss_ini: 4.63790e-02, Loss_lbc: 6.44785e-03,Loss_rbc: 7.12672e-03
# Iter 320, Loss: 9.64545e-02, Loss_PDE: 3.72178e-02, Loss_ini: 4.76412e-02, Loss_lbc: 5.70733e-03,Loss_rbc: 5.88818e-03
# Iter 330, Loss: 9.82629e-02, Loss_PDE: 3.86992e-02, Loss_ini: 4.80426e-02, Loss_lbc: 5.57024e-03,Loss_rbc: 5.95089e-03
# Iter 340, Loss: 9.66401e-02, Loss_PDE: 3.73728e-02, Loss_ini: 4.78966e-02, Loss_lbc: 5.29582e-03,Loss_rbc: 6.07497e-03
# Iter 350, Loss: 9.48057e-02, Loss_PDE: 4.28474e-02, Loss_ini: 4.08232e-02, Loss_lbc: 5.46652e-03,Loss_rbc: 5.66851e-03
# Iter 360, Loss: 9.38951e-02, Loss_PDE: 3.83060e-02, Loss_ini: 4.37454e-02, Loss_lbc: 5.05700e-03,Loss_rbc: 6.78669e-03
# Iter 370, Loss: 9.58255e-02, Loss_PDE: 3.85569e-02, Loss_ini: 3.84879e-02, Loss_lbc: 9.43375e-03,Loss_rbc: 9.34692e-03
# Iter 380, Loss: 9.02325e-02, Loss_PDE: 3.68324e-02, Loss_ini: 4.25712e-02, Loss_lbc: 5.36874e-03,Loss_rbc: 5.46003e-03
# Iter 390, Loss: 8.66704e-02, Loss_PDE: 3.30442e-02, Loss_ini: 4.27974e-02, Loss_lbc: 4.78426e-03,Loss_rbc: 6.04455e-03
# Iter 400, Loss: 8.78264e-02, Loss_PDE: 3.38507e-02, Loss_ini: 4.21483e-02, Loss_lbc: 5.41896e-03,Loss_rbc: 6.40850e-03
# Iter 410, Loss: 8.90784e-02, Loss_PDE: 3.84152e-02, Loss_ini: 4.01702e-02, Loss_lbc: 5.07843e-03,Loss_rbc: 5.41459e-03
# Iter 420, Loss: 8.62985e-02, Loss_PDE: 3.65600e-02, Loss_ini: 3.97438e-02, Loss_lbc: 4.49530e-03,Loss_rbc: 5.49947e-03
# Iter 430, Loss: 8.54146e-02, Loss_PDE: 3.35630e-02, Loss_ini: 4.06034e-02, Loss_lbc: 5.51284e-03,Loss_rbc: 5.73532e-03
# Iter 440, Loss: 8.45098e-02, Loss_PDE: 3.49154e-02, Loss_ini: 3.81991e-02, Loss_lbc: 4.91798e-03,Loss_rbc: 6.47731e-03
# Iter 450, Loss: 8.57789e-02, Loss_PDE: 3.40979e-02, Loss_ini: 4.23023e-02, Loss_lbc: 5.01185e-03,Loss_rbc: 4.36687e-03
# Iter 460, Loss: 8.59669e-02, Loss_PDE: 3.96211e-02, Loss_ini: 3.75533e-02, Loss_lbc: 4.23391e-03,Loss_rbc: 4.55852e-03
# Iter 470, Loss: 8.27121e-02, Loss_PDE: 3.83914e-02, Loss_ini: 3.41413e-02, Loss_lbc: 5.55262e-03,Loss_rbc: 4.62681e-03
# Iter 480, Loss: 8.44805e-02, Loss_PDE: 4.26498e-02, Loss_ini: 3.20735e-02, Loss_lbc: 4.77326e-03,Loss_rbc: 4.98398e-03
# Iter 490, Loss: 8.31551e-02, Loss_PDE: 4.06850e-02, Loss_ini: 3.32271e-02, Loss_lbc: 4.60989e-03,Loss_rbc: 4.63308e-03
# Iter 500, Loss: 8.14529e-02, Loss_PDE: 3.97579e-02, Loss_ini: 3.31304e-02, Loss_lbc: 4.23115e-03,Loss_rbc: 4.33348e-03
# Iter 510, Loss: 8.46984e-02, Loss_PDE: 3.80846e-02, Loss_ini: 3.33709e-02, Loss_lbc: 7.29535e-03,Loss_rbc: 5.94752e-03
# Iter 520, Loss: 8.30774e-02, Loss_PDE: 3.55909e-02, Loss_ini: 3.87977e-02, Loss_lbc: 4.35058e-03,Loss_rbc: 4.33827e-03
# Iter 530, Loss: 7.98486e-02, Loss_PDE: 3.35816e-02, Loss_ini: 3.58313e-02, Loss_lbc: 4.98002e-03,Loss_rbc: 5.45561e-03
# Iter 540, Loss: 8.12206e-02, Loss_PDE: 3.71320e-02, Loss_ini: 3.42262e-02, Loss_lbc: 4.42457e-03,Loss_rbc: 5.43778e-03
# Iter 550, Loss: 8.52198e-02, Loss_PDE: 3.75177e-02, Loss_ini: 3.92135e-02, Loss_lbc: 4.13479e-03,Loss_rbc: 4.35381e-03
# Iter 560, Loss: 8.37485e-02, Loss_PDE: 4.18629e-02, Loss_ini: 2.93050e-02, Loss_lbc: 5.06033e-03,Loss_rbc: 7.52016e-03
# Iter 570, Loss: 7.77925e-02, Loss_PDE: 3.81584e-02, Loss_ini: 3.01052e-02, Loss_lbc: 4.99843e-03,Loss_rbc: 4.53043e-03
# Iter 580, Loss: 7.69688e-02, Loss_PDE: 3.50754e-02, Loss_ini: 3.37503e-02, Loss_lbc: 4.03519e-03,Loss_rbc: 4.10789e-03
# Iter 590, Loss: 7.68014e-02, Loss_PDE: 3.56834e-02, Loss_ini: 3.26339e-02, Loss_lbc: 4.04992e-03,Loss_rbc: 4.43421e-03
# Iter 600, Loss: 7.80973e-02, Loss_PDE: 3.71379e-02, Loss_ini: 3.09658e-02, Loss_lbc: 4.97856e-03,Loss_rbc: 5.01503e-03
# Iter 610, Loss: 7.76847e-02, Loss_PDE: 3.70757e-02, Loss_ini: 3.22148e-02, Loss_lbc: 3.87560e-03,Loss_rbc: 4.51850e-03
# Iter 620, Loss: 7.47640e-02, Loss_PDE: 3.37723e-02, Loss_ini: 3.13099e-02, Loss_lbc: 5.16851e-03,Loss_rbc: 4.51333e-03
# Iter 630, Loss: 7.74397e-02, Loss_PDE: 3.48258e-02, Loss_ini: 3.36836e-02, Loss_lbc: 4.24302e-03,Loss_rbc: 4.68730e-03
# Iter 640, Loss: 7.48968e-02, Loss_PDE: 3.00249e-02, Loss_ini: 3.57922e-02, Loss_lbc: 4.30826e-03,Loss_rbc: 4.77149e-03
# Iter 650, Loss: 7.59788e-02, Loss_PDE: 3.33030e-02, Loss_ini: 3.42663e-02, Loss_lbc: 3.89550e-03,Loss_rbc: 4.51394e-03
# Iter 660, Loss: 7.50660e-02, Loss_PDE: 3.71685e-02, Loss_ini: 2.75852e-02, Loss_lbc: 5.43473e-03,Loss_rbc: 4.87752e-03
# Iter 670, Loss: 7.65552e-02, Loss_PDE: 3.26153e-02, Loss_ini: 3.54115e-02, Loss_lbc: 3.91535e-03,Loss_rbc: 4.61297e-03
# Iter 680, Loss: 7.35759e-02, Loss_PDE: 3.36447e-02, Loss_ini: 3.10420e-02, Loss_lbc: 4.52620e-03,Loss_rbc: 4.36301e-03
# Iter 690, Loss: 7.67023e-02, Loss_PDE: 3.80799e-02, Loss_ini: 2.66776e-02, Loss_lbc: 6.68646e-03,Loss_rbc: 5.25831e-03
# Iter 700, Loss: 7.31376e-02, Loss_PDE: 3.20631e-02, Loss_ini: 3.32271e-02, Loss_lbc: 3.71911e-03,Loss_rbc: 4.12822e-03
# Iter 710, Loss: 7.47025e-02, Loss_PDE: 3.27774e-02, Loss_ini: 3.26970e-02, Loss_lbc: 4.48986e-03,Loss_rbc: 4.73833e-03
# Iter 720, Loss: 7.15790e-02, Loss_PDE: 3.11767e-02, Loss_ini: 3.20466e-02, Loss_lbc: 4.21335e-03,Loss_rbc: 4.14238e-03
# Iter 730, Loss: 7.24040e-02, Loss_PDE: 3.38979e-02, Loss_ini: 2.88861e-02, Loss_lbc: 5.03853e-03,Loss_rbc: 4.58146e-03
# Iter 740, Loss: 7.07723e-02, Loss_PDE: 3.55941e-02, Loss_ini: 2.61232e-02, Loss_lbc: 3.77700e-03,Loss_rbc: 5.27799e-03
# Iter 750, Loss: 7.35838e-02, Loss_PDE: 3.54506e-02, Loss_ini: 2.97955e-02, Loss_lbc: 4.32931e-03,Loss_rbc: 4.00839e-03
# Iter 760, Loss: 7.08060e-02, Loss_PDE: 3.50335e-02, Loss_ini: 2.73318e-02, Loss_lbc: 3.84622e-03,Loss_rbc: 4.59458e-03
# Iter 770, Loss: 6.90256e-02, Loss_PDE: 2.70064e-02, Loss_ini: 3.34761e-02, Loss_lbc: 4.32915e-03,Loss_rbc: 4.21396e-03
# Iter 780, Loss: 6.99905e-02, Loss_PDE: 2.98942e-02, Loss_ini: 3.27010e-02, Loss_lbc: 3.60282e-03,Loss_rbc: 3.79255e-03
# Iter 790, Loss: 7.04245e-02, Loss_PDE: 3.48480e-02, Loss_ini: 2.58704e-02, Loss_lbc: 5.00310e-03,Loss_rbc: 4.70295e-03
# Iter 800, Loss: 6.94904e-02, Loss_PDE: 3.43797e-02, Loss_ini: 2.56359e-02, Loss_lbc: 4.77193e-03,Loss_rbc: 4.70297e-03
# Iter 810, Loss: 7.04331e-02, Loss_PDE: 2.95870e-02, Loss_ini: 3.33654e-02, Loss_lbc: 3.81759e-03,Loss_rbc: 3.66311e-03
# Iter 820, Loss: 7.11746e-02, Loss_PDE: 2.96395e-02, Loss_ini: 3.14730e-02, Loss_lbc: 5.23728e-03,Loss_rbc: 4.82486e-03
# Iter 830, Loss: 6.72681e-02, Loss_PDE: 2.85181e-02, Loss_ini: 3.07419e-02, Loss_lbc: 3.94129e-03,Loss_rbc: 4.06683e-03
# Iter 840, Loss: 6.68697e-02, Loss_PDE: 3.14313e-02, Loss_ini: 2.59781e-02, Loss_lbc: 5.14174e-03,Loss_rbc: 4.31860e-03
# Iter 850, Loss: 6.76918e-02, Loss_PDE: 3.04014e-02, Loss_ini: 2.97275e-02, Loss_lbc: 3.70459e-03,Loss_rbc: 3.85833e-03
# Iter 860, Loss: 6.69033e-02, Loss_PDE: 2.78370e-02, Loss_ini: 3.05916e-02, Loss_lbc: 3.76668e-03,Loss_rbc: 4.70806e-03
# Iter 870, Loss: 6.67197e-02, Loss_PDE: 3.06009e-02, Loss_ini: 2.82385e-02, Loss_lbc: 4.06182e-03,Loss_rbc: 3.81849e-03
# Iter 880, Loss: 6.55485e-02, Loss_PDE: 3.21155e-02, Loss_ini: 2.44572e-02, Loss_lbc: 4.30355e-03,Loss_rbc: 4.67230e-03
# Iter 890, Loss: 6.60965e-02, Loss_PDE: 3.12505e-02, Loss_ini: 2.76406e-02, Loss_lbc: 3.44880e-03,Loss_rbc: 3.75655e-03
# Iter 900, Loss: 6.50687e-02, Loss_PDE: 2.68107e-02, Loss_ini: 2.85589e-02, Loss_lbc: 4.99679e-03,Loss_rbc: 4.70236e-03
# Iter 910, Loss: 6.45969e-02, Loss_PDE: 2.78708e-02, Loss_ini: 2.69962e-02, Loss_lbc: 4.94105e-03,Loss_rbc: 4.78884e-03
# Iter 920, Loss: 6.16781e-02, Loss_PDE: 2.71002e-02, Loss_ini: 2.72185e-02, Loss_lbc: 3.61103e-03,Loss_rbc: 3.74843e-03
# Iter 930, Loss: 6.61195e-02, Loss_PDE: 3.34674e-02, Loss_ini: 2.41015e-02, Loss_lbc: 4.81159e-03,Loss_rbc: 3.73897e-03
# Iter 940, Loss: 6.35572e-02, Loss_PDE: 2.63621e-02, Loss_ini: 2.94775e-02, Loss_lbc: 3.89781e-03,Loss_rbc: 3.81981e-03
# Iter 950, Loss: 6.21517e-02, Loss_PDE: 2.62600e-02, Loss_ini: 2.71092e-02, Loss_lbc: 3.98938e-03,Loss_rbc: 4.79305e-03
# Iter 960, Loss: 6.20543e-02, Loss_PDE: 2.64258e-02, Loss_ini: 2.78673e-02, Loss_lbc: 3.97903e-03,Loss_rbc: 3.78219e-03
# Iter 970, Loss: 6.36759e-02, Loss_PDE: 2.95983e-02, Loss_ini: 2.68136e-02, Loss_lbc: 3.59593e-03,Loss_rbc: 3.66806e-03
# Iter 980, Loss: 6.40544e-02, Loss_PDE: 2.83885e-02, Loss_ini: 2.42147e-02, Loss_lbc: 5.11868e-03,Loss_rbc: 6.33262e-03
# Iter 990, Loss: 6.45050e-02, Loss_PDE: 2.64711e-02, Loss_ini: 3.09275e-02, Loss_lbc: 3.56836e-03,Loss_rbc: 3.53804e-03
# Iter 1000, Loss: 6.16873e-02, Loss_PDE: 2.62788e-02, Loss_ini: 2.72030e-02, Loss_lbc: 3.88247e-03,Loss_rbc: 4.32308e-03
# Iter 1010, Loss: 6.23076e-02, Loss_PDE: 3.06926e-02, Loss_ini: 2.37022e-02, Loss_lbc: 3.77489e-03,Loss_rbc: 4.13783e-03
# Iter 1020, Loss: 6.45310e-02, Loss_PDE: 2.90581e-02, Loss_ini: 2.51008e-02, Loss_lbc: 4.51193e-03,Loss_rbc: 5.86024e-03
# Iter 1030, Loss: 6.26809e-02, Loss_PDE: 2.85345e-02, Loss_ini: 2.65059e-02, Loss_lbc: 4.02795e-03,Loss_rbc: 3.61257e-03
# Iter 1040, Loss: 6.16903e-02, Loss_PDE: 2.74050e-02, Loss_ini: 2.65464e-02, Loss_lbc: 3.47322e-03,Loss_rbc: 4.26562e-03
# Iter 1050, Loss: 6.12355e-02, Loss_PDE: 2.62376e-02, Loss_ini: 2.80611e-02, Loss_lbc: 3.25300e-03,Loss_rbc: 3.68378e-03
# Iter 1060, Loss: 5.97702e-02, Loss_PDE: 2.59335e-02, Loss_ini: 2.53098e-02, Loss_lbc: 4.15408e-03,Loss_rbc: 4.37282e-03
# Iter 1070, Loss: 6.56646e-02, Loss_PDE: 3.23125e-02, Loss_ini: 2.48738e-02, Loss_lbc: 4.38652e-03,Loss_rbc: 4.09175e-03
# Iter 1080, Loss: 5.90381e-02, Loss_PDE: 2.56415e-02, Loss_ini: 2.61704e-02, Loss_lbc: 3.39888e-03,Loss_rbc: 3.82738e-03
# Iter 1090, Loss: 6.17054e-02, Loss_PDE: 2.83269e-02, Loss_ini: 2.54033e-02, Loss_lbc: 3.81624e-03,Loss_rbc: 4.15893e-03
# Iter 1100, Loss: 6.11258e-02, Loss_PDE: 2.68116e-02, Loss_ini: 2.73475e-02, Loss_lbc: 3.49177e-03,Loss_rbc: 3.47499e-03
# Iter 1110, Loss: 6.19439e-02, Loss_PDE: 2.98044e-02, Loss_ini: 2.41525e-02, Loss_lbc: 4.35861e-03,Loss_rbc: 3.62834e-03
# Iter 1120, Loss: 6.18452e-02, Loss_PDE: 2.82579e-02, Loss_ini: 2.62272e-02, Loss_lbc: 3.62515e-03,Loss_rbc: 3.73497e-03
# Iter 1130, Loss: 6.12323e-02, Loss_PDE: 2.79597e-02, Loss_ini: 2.49503e-02, Loss_lbc: 3.99406e-03,Loss_rbc: 4.32824e-03
# Iter 1140, Loss: 5.92465e-02, Loss_PDE: 2.56749e-02, Loss_ini: 2.59165e-02, Loss_lbc: 3.61808e-03,Loss_rbc: 4.03700e-03
# Iter 1150, Loss: 5.80037e-02, Loss_PDE: 2.63032e-02, Loss_ini: 2.35931e-02, Loss_lbc: 4.15954e-03,Loss_rbc: 3.94795e-03
# Iter 1160, Loss: 6.13291e-02, Loss_PDE: 2.98925e-02, Loss_ini: 2.30405e-02, Loss_lbc: 3.60451e-03,Loss_rbc: 4.79163e-03
# Iter 1170, Loss: 5.77264e-02, Loss_PDE: 2.73085e-02, Loss_ini: 2.25642e-02, Loss_lbc: 3.97069e-03,Loss_rbc: 3.88291e-03
# Iter 1180, Loss: 6.04193e-02, Loss_PDE: 2.78143e-02, Loss_ini: 2.55016e-02, Loss_lbc: 3.55574e-03,Loss_rbc: 3.54761e-03
# Iter 1190, Loss: 5.88292e-02, Loss_PDE: 2.57267e-02, Loss_ini: 2.33574e-02, Loss_lbc: 4.77999e-03,Loss_rbc: 4.96513e-03
# Starting Training: LBFGS optimizer
# Loss: 5.85381e-02, Loss_PDE: 2.70184e-02, Loss_ini: 2.37982e-02, Loss_lbc: 3.89832e-03,Loss_rbc: 3.82326e-03
# Loss: 5.91877e-02, Loss_PDE: 2.75927e-02, Loss_ini: 2.36872e-02, Loss_lbc: 3.91870e-03,Loss_rbc: 3.98913e-03
# Loss: 5.96783e-02, Loss_PDE: 2.76558e-02, Loss_ini: 2.42008e-02, Loss_lbc: 3.86013e-03,Loss_rbc: 3.96152e-03
# Loss: 5.90256e-02, Loss_PDE: 2.73449e-02, Loss_ini: 2.39625e-02, Loss_lbc: 3.91820e-03,Loss_rbc: 3.79997e-03
# Loss: 5.86608e-02, Loss_PDE: 2.72785e-02, Loss_ini: 2.36389e-02, Loss_lbc: 3.82923e-03,Loss_rbc: 3.91410e-03

# %%
#path = f"./gala/AI4eq/Models/burgers_{nobs}.pt"
path = f"./gala/AI4eq/Models/burgers_mcd.pt"
torch.save(model.state_dict(),path)

# %%
def MCD (dropout_model,X_star, samples = 1000):
    dropout_model.train()

    predictions = []

    for _ in range(samples):
        pred = dropout_model(X_star)  # Perform a forward pass with dropout
        predictions.append(pred.cpu().detach().numpy())  # Store the result

    predictions_mcd = np.array(predictions)
    return np.mean(predictions_mcd, axis=0),np.std(predictions_mcd, axis=0)

# %%
x = np.linspace(-1,1,100)
y = np.linspace(0,1,100)

xx, yy = np.meshgrid(x, y)
xx, yy = torch.tensor(xx).reshape(-1,1).float(),torch.tensor(yy).reshape(-1,1).float()


X_star = torch.cat([xx,yy,torch.ones_like(xx)*(0.005)],axis = 1)
mean, std = MCD (model,X_star, samples = 1000)

fig, axs = plt.subplots(2,1, figsize=(10, 5))

xx,yy = np.meshgrid(x, y)

U_pred = griddata(np.hstack([xx.reshape(-1,1),yy.reshape(-1,1)]), mean[:,0], (xx,yy), method='cubic')
U_sigma = griddata(np.hstack([xx.reshape(-1,1),yy.reshape(-1,1)]), std[:,0], (xx,yy), method='cubic')

axs[0].contourf(y.flatten(), x.flatten(), U_pred.T,cmap='rainbow')

axs[1].plot(x,U_pred[75,:])
axs[1].fill_between(x.reshape(-1), U_pred[75,:]+U_sigma[75,:],U_pred[75,:]-U_sigma[75,:],alpha=0.4, color = "red",label = r"NN Uncertainty ($\sigma^{2})$")
