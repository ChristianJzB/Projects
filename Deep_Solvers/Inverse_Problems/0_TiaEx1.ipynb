# %%
import os
import re

os.chdir("/home/s2113174/Projects-1")
#os.chdir("d://Projects//Projects-1/")

import torch
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset

from collections import OrderedDict

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from pyDOE import lhs
from scipy.stats import uniform,norm

from Galab import llaplace

np.random.seed(1234)

# CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")

# %% [markdown]
# ## Making the data for an Inverse Problem following the parametric ODE
#
# $$-\frac{d}{dx}(e^{\theta}\frac{du(x)}{dx}) = 1, \quad x\in (0,1),\theta \in [-1,1]$$
# $$u(0) = 0, u(1)=1$$
#
# with solution
# $$ u(x) = \frac{x - x^{2}}{2 e^{\theta}}$$
#
# ## The Problem consist in infering $ \alpha $

# %%
ns = 1
t= np.linspace(0,ns,1000)
mean, std = 0,np.sqrt(1e-4)

Exact = (t - t**2) / 2*np.exp(0.314)

noise_sol = Exact + np.random.normal(mean,std, len(t))

plt.scatter(t,noise_sol)
plt.xlabel("T")
plt.ylabel("Observations")
# Out:
# Text(0, 0.5, 'Observations')

# %% [markdown]
# ## Feed Forward Neural Network

# %%
# Deep neural network
class DNN(torch.nn.Module):
    def __init__(self, layers):
        super(DNN, self).__init__()

        # Number of layers
        self.depth = len(layers) - 1
        
        # Activation Function
        self.activation = torch.nn.Tanh
        
        # The following loop organized the layers of the NN         
        layer_list = list()
        for i in range(self.depth - 1): 
            layer_list.append(
                ('layer_%d' % i, torch.nn.Linear(layers[i], layers[i+1])))
            layer_list.append(('activation_%d' % i, self.activation()))
        layer_list.append(
            ('layer_%d' % (self.depth - 1), torch.nn.Linear(layers[-2], layers[-1]))
        )
        layerDict = OrderedDict(layer_list)
        
        # Deploy layers
        self.layers = torch.nn.Sequential(layerDict)

    def forward(self, x):
        out = self.layers(x)
        return out

# %% [markdown]
# ## Parametric PINN for Inverse Problems

# %%
def de(self,data_domain):
    """ The pytorch autograd version of calculating residual """
    u = self(data_domain)
    
    u_t = torch.autograd.grad(
        u, data_domain, 
        grad_outputs=torch.ones_like(u),
        retain_graph=True,
        create_graph=True
    )[0]

    u_tt = torch.autograd.grad(
        u_t[:,0], data_domain, 
        grad_outputs=torch.ones_like(u_t[:,0]),
        retain_graph=True,
        create_graph=True
    )[0]
    
    f = -torch.exp(data_domain[:,1].reshape(-1,1))*u_tt[:,0].reshape(-1,1) - 1
    return f

def left_bc(self,data_lbc):
    u = self(data_lbc)
    return u

def right_bc(self,data_rbc):
    u = self(data_rbc)
    return u

# %%
def DE(self,t,pr):
    """ The pytorch autograd version of calculating residual """
    u = self(torch.cat([t, pr], dim=1))
    
    u_t = torch.autograd.grad(
        u, t, 
        grad_outputs=torch.ones_like(u),
        retain_graph=True,
        create_graph=True
    )[0]

    u_tt = torch.autograd.grad(
        u_t, t, 
        grad_outputs=torch.ones_like(u_t),
        retain_graph=True,
        create_graph=True
    )[0]
    
    f = -torch.exp(pr)*u_tt - 1
    return f

# %%
DNN.DE = DE
DNN.de = de
DNN.left_bc = left_bc
DNN.right_bc = right_bc

# %%
def samples_space(size,maxl):
    t_f_train = lhs(1, size)*maxl
    return t_f_train

def samples_param(min,max,size = 100):
    return np.random.uniform(min,max,size = size)

# %%
def data_pde(size,maxl,minp,maxp):

    x, param = samples_space(size,maxl),samples_param(minp,maxp,(size,1)).reshape(-1,1)

    pde_domain = torch.tensor(np.hstack((x,param.reshape(-1,1)))).float()
    
    x, param  = torch.tensor(x).reshape(-1,1),torch.tensor(param).reshape(-1,1)

    left_bc = torch.cat([torch.zeros_like(x).float(), param],axis = 1).float()

    right_bc = torch.cat([torch.ones_like(x).float(), param],axis = 1).float()

    return pde_domain,left_bc,right_bc

# %%
def train_adam(pinn,loss,optimizer,epochs, sample_size = 100, bound_limit = 1,minval_param = 0.2,maxval_param = 2):
     
     print("Starting Adam Training")

     for i in range(epochs):
        pde_domain,left_bc,right_bc = data_pde(sample_size,bound_limit,minval_param,maxval_param)
        
        pde_domain = Variable(pde_domain,requires_grad=True)
        left_bc,right_bc = Variable(left_bc,requires_grad=True),Variable(right_bc,requires_grad=True)
        
        for _ in range(15):
                optimizer.zero_grad()

                pde_pred = pinn.de(pde_domain)
                left_bc_pred,right_bc_pred = pinn.left_bc(left_bc),pinn.right_bc(right_bc)

                loss_pde = loss(pde_pred,torch.zeros_like(pde_pred))
                loss_lbc,loss_rbc = loss(left_bc_pred,torch.zeros_like(pde_pred)),loss(right_bc_pred,torch.zeros_like(pde_pred))

                Loss =  loss_pde + loss_lbc + loss_rbc

                if epochs % 10 == 0:
                        print('Iter %d, Loss: %.5e, Loss_PDE: %.5e, Loss_lbc: %.5e,Loss_rbc: %.5e' % (i, 
                                                                         Loss.item(),loss_pde.item(), loss_lbc.item(), loss_rbc.item()))
                                
                Loss.backward() 

                optimizer.step()

# %%
def train_LBFGS(pinn,loss,optimizer, sample_size = 100, bound_limit = 1,minval_param = 0.2,maxval_param = 2):
    
    print("Starting Training: LBFGS optimizer")

    pde_domain,left_bc,right_bc = data_pde(sample_size,bound_limit,minval_param,maxval_param)
        
    pde_domain = Variable(pde_domain,requires_grad=True)
    left_bc,right_bc = Variable(left_bc,requires_grad=True),Variable(right_bc,requires_grad=True)
    

    def loss_func_train():
        optimizer.zero_grad()
        
        pde_pred = pinn.de(pde_domain)
        left_bc_pred,right_bc_pred = pinn.left_bc(left_bc),pinn.right_bc(right_bc)

        loss_pde = loss(pde_pred,torch.zeros_like(pde_pred))
        loss_lbc,loss_rbc = loss(left_bc_pred,torch.zeros_like(pde_pred)),loss(right_bc_pred,torch.zeros_like(pde_pred))

        Loss =  loss_pde + loss_lbc + loss_rbc

        print(' Loss: %.5e, Loss_PDE: %.5e, Loss_lbc: %.5e,Loss_rbc: %.5e' % (Loss.item(),loss_pde.item(), loss_lbc.item(), loss_rbc.item()))
                        
        Loss.backward() 

        return Loss

    optimizer.step(loss_func_train)

# %%
# Number of observations
epochs = 150
nobs = 500
lr = 0.01

min_param , max_param = -1, 1

space = 1

layers = [2] + 1*[20] + [1]
model = DNN(layers)

# %%
loss = torch.nn.MSELoss(reduction ='mean')

optimizer = torch.optim.Adam(model.parameters(), lr = lr)

dta_set = train_adam(model,loss,optimizer,epochs, nobs,space,min_param,max_param)

optimizer = torch.optim.LBFGS(
    model.parameters(), lr=lr, max_iter=50000, max_eval=None, tolerance_grad=1e-5, tolerance_change=1.0 * np.finfo(float).eps,line_search_fn="strong_wolfe" 
    )

train_LBFGS(model,loss,optimizer, nobs,space,min_param,max_param)

# model.load_state_dict(torch.load("Param_model_2.pt"))
# model.eval()
# Out:
# Starting Adam Training
# Iter 0, Loss: 1.26280e+00, Loss_PDE: 1.10738e+00, Loss_lbc: 2.38914e-02,Loss_rbc: 1.31536e-01
# Iter 0, Loss: 1.15527e+00, Loss_PDE: 1.05628e+00, Loss_lbc: 3.10039e-02,Loss_rbc: 6.79932e-02
# Iter 0, Loss: 1.08409e+00, Loss_PDE: 1.01126e+00, Loss_lbc: 4.13460e-02,Loss_rbc: 3.14883e-02
# Iter 0, Loss: 1.03450e+00, Loss_PDE: 9.72217e-01, Loss_lbc: 4.83537e-02,Loss_rbc: 1.39304e-02
# Iter 0, Loss: 9.94868e-01, Loss_PDE: 9.37879e-01, Loss_lbc: 5.04018e-02,Loss_rbc: 6.58798e-03
# Iter 0, Loss: 9.59500e-01, Loss_PDE: 9.06997e-01, Loss_lbc: 4.83736e-02,Loss_rbc: 4.12980e-03
# Iter 0, Loss: 9.26207e-01, Loss_PDE: 8.78582e-01, Loss_lbc: 4.37251e-02,Loss_rbc: 3.89930e-03
# Iter 0, Loss: 8.94105e-01, Loss_PDE: 8.51633e-01, Loss_lbc: 3.78253e-02,Loss_rbc: 4.64628e-03
# Iter 0, Loss: 8.62673e-01, Loss_PDE: 8.25041e-01, Loss_lbc: 3.18523e-02,Loss_rbc: 5.77968e-03
# Iter 0, Loss: 8.31429e-01, Loss_PDE: 7.97938e-01, Loss_lbc: 2.64915e-02,Loss_rbc: 6.99940e-03
# Iter 0, Loss: 8.00047e-01, Loss_PDE: 7.70015e-01, Loss_lbc: 2.18845e-02,Loss_rbc: 8.14732e-03
# Iter 0, Loss: 7.68372e-01, Loss_PDE: 7.41192e-01, Loss_lbc: 1.80240e-02,Loss_rbc: 9.15627e-03
# Iter 0, Loss: 7.36305e-01, Loss_PDE: 7.11414e-01, Loss_lbc: 1.48906e-02,Loss_rbc: 1.00003e-02
# Iter 0, Loss: 7.03739e-01, Loss_PDE: 6.80649e-01, Loss_lbc: 1.24306e-02,Loss_rbc: 1.06594e-02
# Iter 0, Loss: 6.70559e-01, Loss_PDE: 6.48914e-01, Loss_lbc: 1.05385e-02,Loss_rbc: 1.11063e-02
# Iter 1, Loss: 6.33347e-01, Loss_PDE: 6.13087e-01, Loss_lbc: 8.98793e-03,Loss_rbc: 1.12722e-02
# Iter 1, Loss: 5.98509e-01, Loss_PDE: 5.79528e-01, Loss_lbc: 7.76143e-03,Loss_rbc: 1.12197e-02
# Iter 1, Loss: 5.63128e-01, Loss_PDE: 5.45530e-01, Loss_lbc: 6.66509e-03,Loss_rbc: 1.09330e-02
# Iter 1, Loss: 5.27481e-01, Loss_PDE: 5.11427e-01, Loss_lbc: 5.59888e-03,Loss_rbc: 1.04552e-02
# Iter 1, Loss: 4.92000e-01, Loss_PDE: 4.77619e-01, Loss_lbc: 4.52149e-03,Loss_rbc: 9.86021e-03
# Iter 1, Loss: 4.57254e-01, Loss_PDE: 4.44567e-01, Loss_lbc: 3.45059e-03,Loss_rbc: 9.23683e-03
# Iter 1, Loss: 4.23885e-01, Loss_PDE: 4.12773e-01, Loss_lbc: 2.44719e-03,Loss_rbc: 8.66434e-03
# Iter 1, Loss: 3.92538e-01, Loss_PDE: 3.82764e-01, Loss_lbc: 1.58899e-03,Loss_rbc: 8.18519e-03
# Iter 1, Loss: 3.63786e-01, Loss_PDE: 3.55060e-01, Loss_lbc: 9.41253e-04,Loss_rbc: 7.78536e-03
# Iter 1, Loss: 3.38070e-01, Loss_PDE: 3.30143e-01, Loss_lbc: 5.35322e-04,Loss_rbc: 7.39239e-03
# Iter 1, Loss: 3.15672e-01, Loss_PDE: 3.08411e-01, Loss_lbc: 3.63515e-04,Loss_rbc: 6.89784e-03
# Iter 1, Loss: 2.96721e-01, Loss_PDE: 2.90127e-01, Loss_lbc: 3.92323e-04,Loss_rbc: 6.20150e-03
# Iter 1, Loss: 2.81222e-01, Loss_PDE: 2.75373e-01, Loss_lbc: 5.87223e-04,Loss_rbc: 5.26247e-03
# Iter 1, Loss: 2.69085e-01, Loss_PDE: 2.64014e-01, Loss_lbc: 9.36220e-04,Loss_rbc: 4.13462e-03
# Iter 1, Loss: 2.60125e-01, Loss_PDE: 2.55699e-01, Loss_lbc: 1.45922e-03,Loss_rbc: 2.96652e-03
# Iter 2, Loss: 2.60997e-01, Loss_PDE: 2.56660e-01, Loss_lbc: 2.30236e-03,Loss_rbc: 2.03440e-03
# Iter 2, Loss: 2.55493e-01, Loss_PDE: 2.50889e-01, Loss_lbc: 3.17529e-03,Loss_rbc: 1.42873e-03
# Iter 2, Loss: 2.52073e-01, Loss_PDE: 2.46690e-01, Loss_lbc: 4.18533e-03,Loss_rbc: 1.19725e-03
# Iter 2, Loss: 2.50120e-01, Loss_PDE: 2.43548e-01, Loss_lbc: 5.26763e-03,Loss_rbc: 1.30431e-03
# Iter 2, Loss: 2.48900e-01, Loss_PDE: 2.40949e-01, Loss_lbc: 6.31866e-03,Loss_rbc: 1.63222e-03
# Iter 2, Loss: 2.47676e-01, Loss_PDE: 2.38411e-01, Loss_lbc: 7.22663e-03,Loss_rbc: 2.03913e-03
# Iter 2, Loss: 2.45841e-01, Loss_PDE: 2.35505e-01, Loss_lbc: 7.91263e-03,Loss_rbc: 2.42300e-03
# Iter 2, Loss: 2.42984e-01, Loss_PDE: 2.31874e-01, Loss_lbc: 8.35707e-03,Loss_rbc: 2.75305e-03
# Iter 2, Loss: 2.38906e-01, Loss_PDE: 2.27256e-01, Loss_lbc: 8.59629e-03,Loss_rbc: 3.05395e-03
# Iter 2, Loss: 2.33568e-01, Loss_PDE: 2.21511e-01, Loss_lbc: 8.69508e-03,Loss_rbc: 3.36146e-03
# Iter 2, Loss: 2.27048e-01, Loss_PDE: 2.14651e-01, Loss_lbc: 8.71400e-03,Loss_rbc: 3.68331e-03
# Iter 2, Loss: 2.19523e-01, Loss_PDE: 2.06846e-01, Loss_lbc: 8.68830e-03,Loss_rbc: 3.98852e-03
# Iter 2, Loss: 2.11257e-01, Loss_PDE: 1.98407e-01, Loss_lbc: 8.62361e-03,Loss_rbc: 4.22569e-03
# Iter 2, Loss: 2.02594e-01, Loss_PDE: 1.89739e-01, Loss_lbc: 8.50330e-03,Loss_rbc: 4.35172e-03
# Iter 2, Loss: 1.93920e-01, Loss_PDE: 1.81271e-01, Loss_lbc: 8.29883e-03,Loss_rbc: 4.35026e-03
# Iter 3, Loss: 1.88212e-01, Loss_PDE: 1.76032e-01, Loss_lbc: 7.94236e-03,Loss_rbc: 4.23754e-03
# Iter 3, Loss: 1.80115e-01, Loss_PDE: 1.68501e-01, Loss_lbc: 7.56214e-03,Loss_rbc: 4.05104e-03
# Iter 3, Loss: 1.72819e-01, Loss_PDE: 1.61908e-01, Loss_lbc: 7.09468e-03,Loss_rbc: 3.81662e-03
# Iter 3, Loss: 1.66369e-01, Loss_PDE: 1.56295e-01, Loss_lbc: 6.52542e-03,Loss_rbc: 3.54867e-03
# Iter 3, Loss: 1.60664e-01, Loss_PDE: 1.51541e-01, Loss_lbc: 5.85872e-03,Loss_rbc: 3.26416e-03
# Iter 3, Loss: 1.55504e-01, Loss_PDE: 1.47390e-01, Loss_lbc: 5.12293e-03,Loss_rbc: 2.99120e-03
# Iter 3, Loss: 1.50649e-01, Loss_PDE: 1.43517e-01, Loss_lbc: 4.36520e-03,Loss_rbc: 2.76700e-03
# Iter 3, Loss: 1.45877e-01, Loss_PDE: 1.39620e-01, Loss_lbc: 3.63441e-03,Loss_rbc: 2.62260e-03
# Iter 3, Loss: 1.41014e-01, Loss_PDE: 1.35488e-01, Loss_lbc: 2.96206e-03,Loss_rbc: 2.56376e-03
# Iter 3, Loss: 1.35949e-01, Loss_PDE: 1.31031e-01, Loss_lbc: 2.35491e-03,Loss_rbc: 2.56286e-03
# Iter 3, Loss: 1.30648e-01, Loss_PDE: 1.26274e-01, Loss_lbc: 1.80466e-03,Loss_rbc: 2.56939e-03
# Iter 3, Loss: 1.25155e-01, Loss_PDE: 1.21314e-01, Loss_lbc: 1.30791e-03,Loss_rbc: 2.53391e-03
# Iter 3, Loss: 1.19586e-01, Loss_PDE: 1.16273e-01, Loss_lbc: 8.81949e-04,Loss_rbc: 2.43106e-03
# Iter 3, Loss: 1.14100e-01, Loss_PDE: 1.11268e-01, Loss_lbc: 5.63907e-04,Loss_rbc: 2.26806e-03
# Iter 3, Loss: 1.08850e-01, Loss_PDE: 1.06383e-01, Loss_lbc: 3.91739e-04,Loss_rbc: 2.07493e-03
# Iter 4, Loss: 1.00207e-01, Loss_PDE: 9.77051e-02, Loss_lbc: 3.86448e-04,Loss_rbc: 2.11553e-03
# Iter 4, Loss: 9.61105e-02, Loss_PDE: 9.36800e-02, Loss_lbc: 4.99507e-04,Loss_rbc: 1.93102e-03
# Iter 4, Loss: 9.24083e-02, Loss_PDE: 8.99838e-02, Loss_lbc: 6.70112e-04,Loss_rbc: 1.75430e-03
# Iter 4, Loss: 8.90382e-02, Loss_PDE: 8.66224e-02, Loss_lbc: 8.24558e-04,Loss_rbc: 1.59131e-03
# Iter 4, Loss: 8.59508e-02, Loss_PDE: 8.35979e-02, Loss_lbc: 9.10249e-04,Loss_rbc: 1.44259e-03
# Iter 4, Loss: 8.31388e-02, Loss_PDE: 8.09097e-02, Loss_lbc: 9.15478e-04,Loss_rbc: 1.31365e-03
# Iter 4, Loss: 8.06353e-02, Loss_PDE: 7.85562e-02, Loss_lbc: 8.64435e-04,Loss_rbc: 1.21471e-03
# Iter 4, Loss: 7.84847e-02, Loss_PDE: 7.65372e-02, Loss_lbc: 7.94770e-04,Loss_rbc: 1.15271e-03
# Iter 4, Loss: 7.67058e-02, Loss_PDE: 7.48462e-02, Loss_lbc: 7.34279e-04,Loss_rbc: 1.12528e-03
# Iter 4, Loss: 7.52647e-02, Loss_PDE: 7.34524e-02, Loss_lbc: 6.90211e-04,Loss_rbc: 1.12213e-03
# Iter 4, Loss: 7.40717e-02, Loss_PDE: 7.22853e-02, Loss_lbc: 6.54990e-04,Loss_rbc: 1.13142e-03
# Iter 4, Loss: 7.30056e-02, Loss_PDE: 7.12387e-02, Loss_lbc: 6.21739e-04,Loss_rbc: 1.14520e-03
# Iter 4, Loss: 7.19554e-02, Loss_PDE: 7.01967e-02, Loss_lbc: 5.97568e-04,Loss_rbc: 1.16109e-03
# Iter 4, Loss: 7.08536e-02, Loss_PDE: 6.90671e-02, Loss_lbc: 6.05910e-04,Loss_rbc: 1.18059e-03
# Iter 4, Loss: 6.96923e-02, Loss_PDE: 6.78082e-02, Loss_lbc: 6.76925e-04,Loss_rbc: 1.20720e-03
# Iter 5, Loss: 6.96954e-02, Loss_PDE: 6.75968e-02, Loss_lbc: 8.40122e-04,Loss_rbc: 1.25850e-03
# Iter 5, Loss: 6.85866e-02, Loss_PDE: 6.62132e-02, Loss_lbc: 1.06976e-03,Loss_rbc: 1.30366e-03
# Iter 5, Loss: 6.75156e-02, Loss_PDE: 6.48271e-02, Loss_lbc: 1.32992e-03,Loss_rbc: 1.35864e-03
# Iter 5, Loss: 6.64602e-02, Loss_PDE: 6.34792e-02, Loss_lbc: 1.55192e-03,Loss_rbc: 1.42907e-03
# Iter 5, Loss: 6.53859e-02, Loss_PDE: 6.21977e-02, Loss_lbc: 1.66911e-03,Loss_rbc: 1.51911e-03
# Iter 5, Loss: 6.42663e-02, Loss_PDE: 6.09872e-02, Loss_lbc: 1.65276e-03,Loss_rbc: 1.62630e-03
# Iter 5, Loss: 6.31067e-02, Loss_PDE: 5.98390e-02, Loss_lbc: 1.53036e-03,Loss_rbc: 1.73737e-03
# Iter 5, Loss: 6.19441e-02, Loss_PDE: 5.87464e-02, Loss_lbc: 1.36862e-03,Loss_rbc: 1.82911e-03
# Iter 5, Loss: 6.08183e-02, Loss_PDE: 5.77095e-02, Loss_lbc: 1.23146e-03,Loss_rbc: 1.87742e-03
# Iter 5, Loss: 5.97437e-02, Loss_PDE: 5.67264e-02, Loss_lbc: 1.14566e-03,Loss_rbc: 1.87166e-03
# Iter 5, Loss: 5.87086e-02, Loss_PDE: 5.57865e-02, Loss_lbc: 1.09845e-03,Loss_rbc: 1.82363e-03
# Iter 5, Loss: 5.76989e-02, Loss_PDE: 5.48757e-02, Loss_lbc: 1.06178e-03,Loss_rbc: 1.76137e-03
# Iter 5, Loss: 5.67177e-02, Loss_PDE: 5.39894e-02, Loss_lbc: 1.01755e-03,Loss_rbc: 1.71076e-03
# Iter 5, Loss: 5.57831e-02, Loss_PDE: 5.31375e-02, Loss_lbc: 9.65218e-04,Loss_rbc: 1.68040e-03
# Iter 5, Loss: 5.49117e-02, Loss_PDE: 5.23357e-02, Loss_lbc: 9.13804e-04,Loss_rbc: 1.66219e-03
# Iter 6, Loss: 5.28207e-02, Loss_PDE: 5.02151e-02, Loss_lbc: 9.47160e-04,Loss_rbc: 1.65846e-03
# Iter 6, Loss: 5.18525e-02, Loss_PDE: 4.93188e-02, Loss_lbc: 9.30616e-04,Loss_rbc: 1.60307e-03
# Iter 6, Loss: 5.10331e-02, Loss_PDE: 4.85533e-02, Loss_lbc: 9.39812e-04,Loss_rbc: 1.53997e-03
# Iter 6, Loss: 5.03380e-02, Loss_PDE: 4.79071e-02, Loss_lbc: 9.51633e-04,Loss_rbc: 1.47932e-03
# Iter 6, Loss: 4.95665e-02, Loss_PDE: 4.72017e-02, Loss_lbc: 9.40049e-04,Loss_rbc: 1.42474e-03
# Iter 6, Loss: 4.86961e-02, Loss_PDE: 4.63792e-02, Loss_lbc: 9.09521e-04,Loss_rbc: 1.40742e-03
# Iter 6, Loss: 4.78714e-02, Loss_PDE: 4.55460e-02, Loss_lbc: 8.88035e-04,Loss_rbc: 1.43738e-03
# Iter 6, Loss: 4.71305e-02, Loss_PDE: 4.47837e-02, Loss_lbc: 8.91957e-04,Loss_rbc: 1.45480e-03
# Iter 6, Loss: 4.63764e-02, Loss_PDE: 4.40605e-02, Loss_lbc: 9.16738e-04,Loss_rbc: 1.39920e-03
# Iter 6, Loss: 4.55899e-02, Loss_PDE: 4.33316e-02, Loss_lbc: 9.53608e-04,Loss_rbc: 1.30467e-03
# Iter 6, Loss: 4.48678e-02, Loss_PDE: 4.26207e-02, Loss_lbc: 9.92135e-04,Loss_rbc: 1.25490e-03
# Iter 6, Loss: 4.42394e-02, Loss_PDE: 4.19666e-02, Loss_lbc: 1.01396e-03,Loss_rbc: 1.25887e-03
# Iter 6, Loss: 4.36206e-02, Loss_PDE: 4.13650e-02, Loss_lbc: 1.01112e-03,Loss_rbc: 1.24455e-03
# Iter 6, Loss: 4.29764e-02, Loss_PDE: 4.07971e-02, Loss_lbc: 1.00627e-03,Loss_rbc: 1.17304e-03
# Iter 6, Loss: 4.23770e-02, Loss_PDE: 4.02615e-02, Loss_lbc: 1.02838e-03,Loss_rbc: 1.08715e-03
# Iter 7, Loss: 4.29701e-02, Loss_PDE: 4.09261e-02, Loss_lbc: 1.04206e-03,Loss_rbc: 1.00189e-03
# Iter 7, Loss: 4.24704e-02, Loss_PDE: 4.04120e-02, Loss_lbc: 1.08447e-03,Loss_rbc: 9.73962e-04
# Iter 7, Loss: 4.19614e-02, Loss_PDE: 3.99002e-02, Loss_lbc: 1.10094e-03,Loss_rbc: 9.60244e-04
# Iter 7, Loss: 4.14255e-02, Loss_PDE: 3.93849e-02, Loss_lbc: 1.08544e-03,Loss_rbc: 9.55187e-04
# Iter 7, Loss: 4.09158e-02, Loss_PDE: 3.88678e-02, Loss_lbc: 1.06392e-03,Loss_rbc: 9.84147e-04
# Iter 7, Loss: 4.04689e-02, Loss_PDE: 3.83648e-02, Loss_lbc: 1.05820e-03,Loss_rbc: 1.04597e-03
# Iter 7, Loss: 4.00395e-02, Loss_PDE: 3.78882e-02, Loss_lbc: 1.06283e-03,Loss_rbc: 1.08843e-03
# Iter 7, Loss: 3.95723e-02, Loss_PDE: 3.74386e-02, Loss_lbc: 1.06372e-03,Loss_rbc: 1.06999e-03
# Iter 7, Loss: 3.90804e-02, Loss_PDE: 3.70065e-02, Loss_lbc: 1.06050e-03,Loss_rbc: 1.01334e-03
# Iter 7, Loss: 3.86035e-02, Loss_PDE: 3.65745e-02, Loss_lbc: 1.05888e-03,Loss_rbc: 9.70059e-04
# Iter 7, Loss: 3.81426e-02, Loss_PDE: 3.61283e-02, Loss_lbc: 1.05570e-03,Loss_rbc: 9.58542e-04
# Iter 7, Loss: 3.76799e-02, Loss_PDE: 3.56720e-02, Loss_lbc: 1.04508e-03,Loss_rbc: 9.62871e-04
# Iter 7, Loss: 3.72193e-02, Loss_PDE: 3.52182e-02, Loss_lbc: 1.03132e-03,Loss_rbc: 9.69838e-04
# Iter 7, Loss: 3.67659e-02, Loss_PDE: 3.47626e-02, Loss_lbc: 1.02473e-03,Loss_rbc: 9.78586e-04
# Iter 7, Loss: 3.63066e-02, Loss_PDE: 3.42897e-02, Loss_lbc: 1.02953e-03,Loss_rbc: 9.87433e-04
# Iter 8, Loss: 3.53631e-02, Loss_PDE: 3.34007e-02, Loss_lbc: 1.02777e-03,Loss_rbc: 9.34668e-04
# Iter 8, Loss: 3.49424e-02, Loss_PDE: 3.29402e-02, Loss_lbc: 1.05102e-03,Loss_rbc: 9.51125e-04
# Iter 8, Loss: 3.45244e-02, Loss_PDE: 3.24838e-02, Loss_lbc: 1.07136e-03,Loss_rbc: 9.69281e-04
# Iter 8, Loss: 3.41101e-02, Loss_PDE: 3.20493e-02, Loss_lbc: 1.07943e-03,Loss_rbc: 9.81369e-04
# Iter 8, Loss: 3.36896e-02, Loss_PDE: 3.16390e-02, Loss_lbc: 1.07148e-03,Loss_rbc: 9.79124e-04
# Iter 8, Loss: 3.32576e-02, Loss_PDE: 3.12432e-02, Loss_lbc: 1.05113e-03,Loss_rbc: 9.63217e-04
# Iter 8, Loss: 3.28266e-02, Loss_PDE: 3.08533e-02, Loss_lbc: 1.02683e-03,Loss_rbc: 9.46403e-04
# Iter 8, Loss: 3.24129e-02, Loss_PDE: 3.04650e-02, Loss_lbc: 1.00734e-03,Loss_rbc: 9.40613e-04
# Iter 8, Loss: 3.20132e-02, Loss_PDE: 3.00708e-02, Loss_lbc: 9.98498e-04,Loss_rbc: 9.43950e-04
# Iter 8, Loss: 3.16107e-02, Loss_PDE: 2.96618e-02, Loss_lbc: 1.00220e-03,Loss_rbc: 9.46742e-04
# Iter 8, Loss: 3.12006e-02, Loss_PDE: 2.92379e-02, Loss_lbc: 1.01703e-03,Loss_rbc: 9.45583e-04
# Iter 8, Loss: 3.07928e-02, Loss_PDE: 2.88094e-02, Loss_lbc: 1.03957e-03,Loss_rbc: 9.43868e-04
# Iter 8, Loss: 3.03946e-02, Loss_PDE: 2.83857e-02, Loss_lbc: 1.06596e-03,Loss_rbc: 9.43018e-04
# Iter 8, Loss: 3.00025e-02, Loss_PDE: 2.79687e-02, Loss_lbc: 1.09261e-03,Loss_rbc: 9.41178e-04
# Iter 8, Loss: 2.96109e-02, Loss_PDE: 2.75567e-02, Loss_lbc: 1.11585e-03,Loss_rbc: 9.38341e-04
# Iter 9, Loss: 2.79005e-02, Loss_PDE: 2.56797e-02, Loss_lbc: 1.13161e-03,Loss_rbc: 1.08922e-03
# Iter 9, Loss: 2.74580e-02, Loss_PDE: 2.52232e-02, Loss_lbc: 1.14857e-03,Loss_rbc: 1.08627e-03
# Iter 9, Loss: 2.70143e-02, Loss_PDE: 2.47671e-02, Loss_lbc: 1.16182e-03,Loss_rbc: 1.08541e-03
# Iter 9, Loss: 2.65674e-02, Loss_PDE: 2.43114e-02, Loss_lbc: 1.16877e-03,Loss_rbc: 1.08725e-03
# Iter 9, Loss: 2.61248e-02, Loss_PDE: 2.38507e-02, Loss_lbc: 1.17305e-03,Loss_rbc: 1.10099e-03
# Iter 9, Loss: 2.57246e-02, Loss_PDE: 2.34140e-02, Loss_lbc: 1.17885e-03,Loss_rbc: 1.13179e-03
# Iter 9, Loss: 2.53713e-02, Loss_PDE: 2.30277e-02, Loss_lbc: 1.18525e-03,Loss_rbc: 1.15832e-03
# Iter 9, Loss: 2.50423e-02, Loss_PDE: 2.26913e-02, Loss_lbc: 1.19007e-03,Loss_rbc: 1.16091e-03
# Iter 9, Loss: 2.47352e-02, Loss_PDE: 2.23918e-02, Loss_lbc: 1.19199e-03,Loss_rbc: 1.15140e-03
# Iter 9, Loss: 2.44459e-02, Loss_PDE: 2.21087e-02, Loss_lbc: 1.18886e-03,Loss_rbc: 1.14833e-03
# Iter 9, Loss: 2.41517e-02, Loss_PDE: 2.18170e-02, Loss_lbc: 1.18272e-03,Loss_rbc: 1.15193e-03
# Iter 9, Loss: 2.38441e-02, Loss_PDE: 2.15052e-02, Loss_lbc: 1.18164e-03,Loss_rbc: 1.15721e-03
# Iter 9, Loss: 2.35297e-02, Loss_PDE: 2.11797e-02, Loss_lbc: 1.18860e-03,Loss_rbc: 1.16143e-03
# Iter 9, Loss: 2.32069e-02, Loss_PDE: 2.08530e-02, Loss_lbc: 1.19662e-03,Loss_rbc: 1.15732e-03
# Iter 9, Loss: 2.28801e-02, Loss_PDE: 2.05382e-02, Loss_lbc: 1.19979e-03,Loss_rbc: 1.14205e-03
# Iter 10, Loss: 2.21225e-02, Loss_PDE: 1.99828e-02, Loss_lbc: 1.07038e-03,Loss_rbc: 1.06925e-03
# Iter 10, Loss: 2.18451e-02, Loss_PDE: 1.97178e-02, Loss_lbc: 1.05741e-03,Loss_rbc: 1.06991e-03
# Iter 10, Loss: 2.15816e-02, Loss_PDE: 1.94638e-02, Loss_lbc: 1.03504e-03,Loss_rbc: 1.08275e-03
# Iter 10, Loss: 2.13624e-02, Loss_PDE: 1.92595e-02, Loss_lbc: 1.01127e-03,Loss_rbc: 1.09159e-03
# Iter 10, Loss: 2.11472e-02, Loss_PDE: 1.90684e-02, Loss_lbc: 9.92183e-04,Loss_rbc: 1.08665e-03
# Iter 10, Loss: 2.09158e-02, Loss_PDE: 1.88554e-02, Loss_lbc: 9.82365e-04,Loss_rbc: 1.07805e-03
# Iter 10, Loss: 2.06793e-02, Loss_PDE: 1.86293e-02, Loss_lbc: 9.78013e-04,Loss_rbc: 1.07194e-03
# Iter 10, Loss: 2.04373e-02, Loss_PDE: 1.84042e-02, Loss_lbc: 9.67955e-04,Loss_rbc: 1.06520e-03
# Iter 10, Loss: 2.01998e-02, Loss_PDE: 1.81812e-02, Loss_lbc: 9.49530e-04,Loss_rbc: 1.06913e-03
# Iter 10, Loss: 1.99805e-02, Loss_PDE: 1.79618e-02, Loss_lbc: 9.27520e-04,Loss_rbc: 1.09121e-03
# Iter 10, Loss: 1.97638e-02, Loss_PDE: 1.77521e-02, Loss_lbc: 8.99666e-04,Loss_rbc: 1.11200e-03
# Iter 10, Loss: 1.95419e-02, Loss_PDE: 1.75595e-02, Loss_lbc: 8.62496e-04,Loss_rbc: 1.11992e-03
# Iter 10, Loss: 1.93352e-02, Loss_PDE: 1.73832e-02, Loss_lbc: 8.22991e-04,Loss_rbc: 1.12903e-03
# Iter 10, Loss: 1.91460e-02, Loss_PDE: 1.72115e-02, Loss_lbc: 7.90061e-04,Loss_rbc: 1.14444e-03
# Iter 10, Loss: 1.89595e-02, Loss_PDE: 1.70378e-02, Loss_lbc: 7.65205e-04,Loss_rbc: 1.15644e-03
# Iter 11, Loss: 1.61721e-02, Loss_PDE: 1.43461e-02, Loss_lbc: 7.34432e-04,Loss_rbc: 1.09153e-03
# Iter 11, Loss: 1.59852e-02, Loss_PDE: 1.41767e-02, Loss_lbc: 7.14628e-04,Loss_rbc: 1.09386e-03
# Iter 11, Loss: 1.58017e-02, Loss_PDE: 1.40027e-02, Loss_lbc: 6.94226e-04,Loss_rbc: 1.10480e-03
# Iter 11, Loss: 1.56430e-02, Loss_PDE: 1.38554e-02, Loss_lbc: 6.71015e-04,Loss_rbc: 1.11657e-03
# Iter 11, Loss: 1.55041e-02, Loss_PDE: 1.37344e-02, Loss_lbc: 6.44802e-04,Loss_rbc: 1.12494e-03
# Iter 11, Loss: 1.53584e-02, Loss_PDE: 1.36080e-02, Loss_lbc: 6.18504e-04,Loss_rbc: 1.13194e-03
# Iter 11, Loss: 1.52010e-02, Loss_PDE: 1.34661e-02, Loss_lbc: 5.95458e-04,Loss_rbc: 1.13939e-03
# Iter 11, Loss: 1.50495e-02, Loss_PDE: 1.33269e-02, Loss_lbc: 5.78024e-04,Loss_rbc: 1.14461e-03
# Iter 11, Loss: 1.49072e-02, Loss_PDE: 1.31956e-02, Loss_lbc: 5.68502e-04,Loss_rbc: 1.14306e-03
# Iter 11, Loss: 1.47637e-02, Loss_PDE: 1.30594e-02, Loss_lbc: 5.68842e-04,Loss_rbc: 1.13539e-03
# Iter 11, Loss: 1.46161e-02, Loss_PDE: 1.29136e-02, Loss_lbc: 5.77517e-04,Loss_rbc: 1.12499e-03
# Iter 11, Loss: 1.44701e-02, Loss_PDE: 1.27665e-02, Loss_lbc: 5.90190e-04,Loss_rbc: 1.11336e-03
# Iter 11, Loss: 1.43338e-02, Loss_PDE: 1.26259e-02, Loss_lbc: 6.03800e-04,Loss_rbc: 1.10404e-03
# Iter 11, Loss: 1.42090e-02, Loss_PDE: 1.24950e-02, Loss_lbc: 6.14664e-04,Loss_rbc: 1.09931e-03
# Iter 11, Loss: 1.40840e-02, Loss_PDE: 1.23736e-02, Loss_lbc: 6.16328e-04,Loss_rbc: 1.09407e-03
# Iter 12, Loss: 1.62596e-02, Loss_PDE: 1.44860e-02, Loss_lbc: 6.29271e-04,Loss_rbc: 1.14427e-03
# Iter 12, Loss: 1.60884e-02, Loss_PDE: 1.43402e-02, Loss_lbc: 6.14222e-04,Loss_rbc: 1.13396e-03
# Iter 12, Loss: 1.59519e-02, Loss_PDE: 1.42188e-02, Loss_lbc: 6.02021e-04,Loss_rbc: 1.13106e-03
# Iter 12, Loss: 1.58301e-02, Loss_PDE: 1.41109e-02, Loss_lbc: 5.96160e-04,Loss_rbc: 1.12302e-03
# Iter 12, Loss: 1.56853e-02, Loss_PDE: 1.39824e-02, Loss_lbc: 5.92186e-04,Loss_rbc: 1.11071e-03
# Iter 12, Loss: 1.55441e-02, Loss_PDE: 1.38548e-02, Loss_lbc: 5.88377e-04,Loss_rbc: 1.10097e-03
# Iter 12, Loss: 1.54291e-02, Loss_PDE: 1.37519e-02, Loss_lbc: 5.91837e-04,Loss_rbc: 1.08535e-03
# Iter 12, Loss: 1.53211e-02, Loss_PDE: 1.36567e-02, Loss_lbc: 5.99841e-04,Loss_rbc: 1.06456e-03
# Iter 12, Loss: 1.51968e-02, Loss_PDE: 1.35512e-02, Loss_lbc: 5.96350e-04,Loss_rbc: 1.04926e-03
# Iter 12, Loss: 1.50656e-02, Loss_PDE: 1.34438e-02, Loss_lbc: 5.81954e-04,Loss_rbc: 1.03989e-03
# Iter 12, Loss: 1.49484e-02, Loss_PDE: 1.33426e-02, Loss_lbc: 5.72448e-04,Loss_rbc: 1.03332e-03
# Iter 12, Loss: 1.48308e-02, Loss_PDE: 1.32373e-02, Loss_lbc: 5.67216e-04,Loss_rbc: 1.02632e-03
# Iter 12, Loss: 1.46997e-02, Loss_PDE: 1.31253e-02, Loss_lbc: 5.58183e-04,Loss_rbc: 1.01612e-03
# Iter 12, Loss: 1.45795e-02, Loss_PDE: 1.30232e-02, Loss_lbc: 5.49845e-04,Loss_rbc: 1.00644e-03
# Iter 12, Loss: 1.44750e-02, Loss_PDE: 1.29325e-02, Loss_lbc: 5.44046e-04,Loss_rbc: 9.98503e-04
# Iter 13, Loss: 1.35430e-02, Loss_PDE: 1.19608e-02, Loss_lbc: 5.47687e-04,Loss_rbc: 1.03456e-03
# Iter 13, Loss: 1.34182e-02, Loss_PDE: 1.18574e-02, Loss_lbc: 5.46139e-04,Loss_rbc: 1.01468e-03
# Iter 13, Loss: 1.33001e-02, Loss_PDE: 1.17512e-02, Loss_lbc: 5.53432e-04,Loss_rbc: 9.95482e-04
# Iter 13, Loss: 1.31862e-02, Loss_PDE: 1.16407e-02, Loss_lbc: 5.65035e-04,Loss_rbc: 9.80439e-04
# Iter 13, Loss: 1.30594e-02, Loss_PDE: 1.15200e-02, Loss_lbc: 5.73966e-04,Loss_rbc: 9.65413e-04
# Iter 13, Loss: 1.29354e-02, Loss_PDE: 1.14051e-02, Loss_lbc: 5.80202e-04,Loss_rbc: 9.50104e-04
# Iter 13, Loss: 1.28193e-02, Loss_PDE: 1.13067e-02, Loss_lbc: 5.76696e-04,Loss_rbc: 9.35899e-04
# Iter 13, Loss: 1.26971e-02, Loss_PDE: 1.12169e-02, Loss_lbc: 5.57118e-04,Loss_rbc: 9.23070e-04
# Iter 13, Loss: 1.25716e-02, Loss_PDE: 1.11338e-02, Loss_lbc: 5.30094e-04,Loss_rbc: 9.07780e-04
# Iter 13, Loss: 1.24590e-02, Loss_PDE: 1.10637e-02, Loss_lbc: 5.06318e-04,Loss_rbc: 8.89040e-04
# Iter 13, Loss: 1.23605e-02, Loss_PDE: 1.09994e-02, Loss_lbc: 4.87711e-04,Loss_rbc: 8.73388e-04
# Iter 13, Loss: 1.22657e-02, Loss_PDE: 1.09305e-02, Loss_lbc: 4.73196e-04,Loss_rbc: 8.61996e-04
# Iter 13, Loss: 1.21775e-02, Loss_PDE: 1.08659e-02, Loss_lbc: 4.62115e-04,Loss_rbc: 8.49529e-04
# Iter 13, Loss: 1.20988e-02, Loss_PDE: 1.08111e-02, Loss_lbc: 4.53328e-04,Loss_rbc: 8.34313e-04
# Iter 13, Loss: 1.20185e-02, Loss_PDE: 1.07545e-02, Loss_lbc: 4.46221e-04,Loss_rbc: 8.17738e-04
# Iter 14, Loss: 1.35678e-02, Loss_PDE: 1.23001e-02, Loss_lbc: 4.57224e-04,Loss_rbc: 8.10525e-04
# Iter 14, Loss: 1.34362e-02, Loss_PDE: 1.21887e-02, Loss_lbc: 4.47902e-04,Loss_rbc: 7.99608e-04
# Iter 14, Loss: 1.33010e-02, Loss_PDE: 1.20833e-02, Loss_lbc: 4.36493e-04,Loss_rbc: 7.81173e-04
# Iter 14, Loss: 1.31818e-02, Loss_PDE: 1.19985e-02, Loss_lbc: 4.28060e-04,Loss_rbc: 7.55197e-04
# Iter 14, Loss: 1.30684e-02, Loss_PDE: 1.19078e-02, Loss_lbc: 4.27485e-04,Loss_rbc: 7.33071e-04
# Iter 14, Loss: 1.29544e-02, Loss_PDE: 1.18063e-02, Loss_lbc: 4.30529e-04,Loss_rbc: 7.17552e-04
# Iter 14, Loss: 1.28519e-02, Loss_PDE: 1.17173e-02, Loss_lbc: 4.26885e-04,Loss_rbc: 7.07704e-04
# Iter 14, Loss: 1.27636e-02, Loss_PDE: 1.16434e-02, Loss_lbc: 4.16764e-04,Loss_rbc: 7.03406e-04
# Iter 14, Loss: 1.26730e-02, Loss_PDE: 1.15684e-02, Loss_lbc: 4.08397e-04,Loss_rbc: 6.96121e-04
# Iter 14, Loss: 1.25738e-02, Loss_PDE: 1.14869e-02, Loss_lbc: 4.03137e-04,Loss_rbc: 6.83765e-04
# Iter 14, Loss: 1.24653e-02, Loss_PDE: 1.13955e-02, Loss_lbc: 3.95686e-04,Loss_rbc: 6.74103e-04
# Iter 14, Loss: 1.23503e-02, Loss_PDE: 1.12989e-02, Loss_lbc: 3.82791e-04,Loss_rbc: 6.68583e-04
# Iter 14, Loss: 1.22433e-02, Loss_PDE: 1.12124e-02, Loss_lbc: 3.66028e-04,Loss_rbc: 6.64859e-04
# Iter 14, Loss: 1.21450e-02, Loss_PDE: 1.11321e-02, Loss_lbc: 3.49513e-04,Loss_rbc: 6.63367e-04
# Iter 14, Loss: 1.20485e-02, Loss_PDE: 1.10461e-02, Loss_lbc: 3.36775e-04,Loss_rbc: 6.65652e-04
# Iter 15, Loss: 1.26433e-02, Loss_PDE: 1.15846e-02, Loss_lbc: 3.50358e-04,Loss_rbc: 7.08303e-04
# Iter 15, Loss: 1.25540e-02, Loss_PDE: 1.14982e-02, Loss_lbc: 3.42527e-04,Loss_rbc: 7.13316e-04
# Iter 15, Loss: 1.24625e-02, Loss_PDE: 1.14173e-02, Loss_lbc: 3.32017e-04,Loss_rbc: 7.13213e-04
# Iter 15, Loss: 1.23642e-02, Loss_PDE: 1.13358e-02, Loss_lbc: 3.19824e-04,Loss_rbc: 7.08532e-04
# Iter 15, Loss: 1.22696e-02, Loss_PDE: 1.12588e-02, Loss_lbc: 3.10537e-04,Loss_rbc: 7.00238e-04
# Iter 15, Loss: 1.21780e-02, Loss_PDE: 1.11834e-02, Loss_lbc: 3.07106e-04,Loss_rbc: 6.87426e-04
# Iter 15, Loss: 1.20858e-02, Loss_PDE: 1.11052e-02, Loss_lbc: 3.05469e-04,Loss_rbc: 6.75096e-04
# Iter 15, Loss: 1.19935e-02, Loss_PDE: 1.10262e-02, Loss_lbc: 2.99868e-04,Loss_rbc: 6.67414e-04
# Iter 15, Loss: 1.19016e-02, Loss_PDE: 1.09465e-02, Loss_lbc: 2.90830e-04,Loss_rbc: 6.64194e-04
# Iter 15, Loss: 1.18133e-02, Loss_PDE: 1.08689e-02, Loss_lbc: 2.80858e-04,Loss_rbc: 6.63542e-04
# Iter 15, Loss: 1.17291e-02, Loss_PDE: 1.07968e-02, Loss_lbc: 2.70296e-04,Loss_rbc: 6.61936e-04
# Iter 15, Loss: 1.16476e-02, Loss_PDE: 1.07287e-02, Loss_lbc: 2.60044e-04,Loss_rbc: 6.58867e-04
# Iter 15, Loss: 1.15659e-02, Loss_PDE: 1.06617e-02, Loss_lbc: 2.51167e-04,Loss_rbc: 6.52993e-04
# Iter 15, Loss: 1.14830e-02, Loss_PDE: 1.05967e-02, Loss_lbc: 2.44354e-04,Loss_rbc: 6.41978e-04
# Iter 15, Loss: 1.14015e-02, Loss_PDE: 1.05330e-02, Loss_lbc: 2.38818e-04,Loss_rbc: 6.29660e-04
# Iter 16, Loss: 9.37896e-03, Loss_PDE: 8.63686e-03, Loss_lbc: 2.00388e-04,Loss_rbc: 5.41708e-04
# Iter 16, Loss: 9.23096e-03, Loss_PDE: 8.49159e-03, Loss_lbc: 1.94335e-04,Loss_rbc: 5.45041e-04
# Iter 16, Loss: 9.11096e-03, Loss_PDE: 8.38527e-03, Loss_lbc: 1.86589e-04,Loss_rbc: 5.39108e-04
# Iter 16, Loss: 9.02100e-03, Loss_PDE: 8.31529e-03, Loss_lbc: 1.78725e-04,Loss_rbc: 5.26985e-04
# Iter 16, Loss: 8.96267e-03, Loss_PDE: 8.26308e-03, Loss_lbc: 1.71762e-04,Loss_rbc: 5.27825e-04
# Iter 16, Loss: 8.90529e-03, Loss_PDE: 8.23180e-03, Loss_lbc: 1.56788e-04,Loss_rbc: 5.16703e-04
# Iter 16, Loss: 8.85303e-03, Loss_PDE: 8.21255e-03, Loss_lbc: 1.38955e-04,Loss_rbc: 5.01518e-04
# Iter 16, Loss: 8.80704e-03, Loss_PDE: 8.18104e-03, Loss_lbc: 1.26811e-04,Loss_rbc: 4.99194e-04
# Iter 16, Loss: 8.74281e-03, Loss_PDE: 8.12609e-03, Loss_lbc: 1.17405e-04,Loss_rbc: 4.99316e-04
# Iter 16, Loss: 8.67496e-03, Loss_PDE: 8.05554e-03, Loss_lbc: 1.12602e-04,Loss_rbc: 5.06824e-04
# Iter 16, Loss: 8.60162e-03, Loss_PDE: 7.97895e-03, Loss_lbc: 1.12182e-04,Loss_rbc: 5.10486e-04
# Iter 16, Loss: 8.53007e-03, Loss_PDE: 7.91889e-03, Loss_lbc: 1.12700e-04,Loss_rbc: 4.98485e-04
# Iter 16, Loss: 8.46011e-03, Loss_PDE: 7.87409e-03, Loss_lbc: 1.15377e-04,Loss_rbc: 4.70639e-04
# Iter 16, Loss: 8.39439e-03, Loss_PDE: 7.83393e-03, Loss_lbc: 1.24759e-04,Loss_rbc: 4.35697e-04
# Iter 16, Loss: 8.34939e-03, Loss_PDE: 7.80054e-03, Loss_lbc: 1.40735e-04,Loss_rbc: 4.08119e-04
# Iter 17, Loss: 1.02815e-02, Loss_PDE: 9.71386e-03, Loss_lbc: 1.51228e-04,Loss_rbc: 4.16410e-04
# Iter 17, Loss: 1.01588e-02, Loss_PDE: 9.60369e-03, Loss_lbc: 1.57545e-04,Loss_rbc: 3.97610e-04
# Iter 17, Loss: 1.00620e-02, Loss_PDE: 9.52116e-03, Loss_lbc: 1.56381e-04,Loss_rbc: 3.84436e-04
# Iter 17, Loss: 9.97229e-03, Loss_PDE: 9.45451e-03, Loss_lbc: 1.39913e-04,Loss_rbc: 3.77864e-04
# Iter 17, Loss: 9.87391e-03, Loss_PDE: 9.37426e-03, Loss_lbc: 1.18936e-04,Loss_rbc: 3.80719e-04
# Iter 17, Loss: 9.80323e-03, Loss_PDE: 9.30704e-03, Loss_lbc: 1.14737e-04,Loss_rbc: 3.81454e-04
# Iter 17, Loss: 9.71873e-03, Loss_PDE: 9.23925e-03, Loss_lbc: 1.17845e-04,Loss_rbc: 3.61633e-04
# Iter 17, Loss: 9.59935e-03, Loss_PDE: 9.15140e-03, Loss_lbc: 1.21137e-04,Loss_rbc: 3.26820e-04
# Iter 17, Loss: 9.49913e-03, Loss_PDE: 9.07318e-03, Loss_lbc: 1.28559e-04,Loss_rbc: 2.97386e-04
# Iter 17, Loss: 9.42393e-03, Loss_PDE: 9.01110e-03, Loss_lbc: 1.30280e-04,Loss_rbc: 2.82547e-04
# Iter 17, Loss: 9.35127e-03, Loss_PDE: 8.94986e-03, Loss_lbc: 1.24885e-04,Loss_rbc: 2.76519e-04
# Iter 17, Loss: 9.28487e-03, Loss_PDE: 8.89487e-03, Loss_lbc: 1.21119e-04,Loss_rbc: 2.68872e-04
# Iter 17, Loss: 9.21360e-03, Loss_PDE: 8.83696e-03, Loss_lbc: 1.19371e-04,Loss_rbc: 2.57271e-04
# Iter 17, Loss: 9.13353e-03, Loss_PDE: 8.76791e-03, Loss_lbc: 1.21468e-04,Loss_rbc: 2.44158e-04
# Iter 17, Loss: 9.07010e-03, Loss_PDE: 8.70777e-03, Loss_lbc: 1.30613e-04,Loss_rbc: 2.31719e-04
# Iter 18, Loss: 9.69246e-03, Loss_PDE: 9.32604e-03, Loss_lbc: 1.44899e-04,Loss_rbc: 2.21520e-04
# Iter 18, Loss: 9.56976e-03, Loss_PDE: 9.19900e-03, Loss_lbc: 1.55012e-04,Loss_rbc: 2.15745e-04
# Iter 18, Loss: 9.48887e-03, Loss_PDE: 9.11403e-03, Loss_lbc: 1.62015e-04,Loss_rbc: 2.12825e-04
# Iter 18, Loss: 9.41664e-03, Loss_PDE: 9.05889e-03, Loss_lbc: 1.49206e-04,Loss_rbc: 2.08535e-04
# Iter 18, Loss: 9.31877e-03, Loss_PDE: 8.98480e-03, Loss_lbc: 1.30767e-04,Loss_rbc: 2.03201e-04
# Iter 18, Loss: 9.26601e-03, Loss_PDE: 8.92889e-03, Loss_lbc: 1.35734e-04,Loss_rbc: 2.01387e-04
# Iter 18, Loss: 9.20940e-03, Loss_PDE: 8.86571e-03, Loss_lbc: 1.44499e-04,Loss_rbc: 1.99186e-04
# Iter 18, Loss: 9.12151e-03, Loss_PDE: 8.78973e-03, Loss_lbc: 1.41396e-04,Loss_rbc: 1.90380e-04
# Iter 18, Loss: 9.06158e-03, Loss_PDE: 8.73700e-03, Loss_lbc: 1.41614e-04,Loss_rbc: 1.82962e-04
# Iter 18, Loss: 9.00225e-03, Loss_PDE: 8.68033e-03, Loss_lbc: 1.34404e-04,Loss_rbc: 1.87511e-04
# Iter 18, Loss: 8.93146e-03, Loss_PDE: 8.60948e-03, Loss_lbc: 1.19104e-04,Loss_rbc: 2.02879e-04
# Iter 18, Loss: 8.89124e-03, Loss_PDE: 8.55269e-03, Loss_lbc: 1.17561e-04,Loss_rbc: 2.20995e-04
# Iter 18, Loss: 8.84282e-03, Loss_PDE: 8.49790e-03, Loss_lbc: 1.15898e-04,Loss_rbc: 2.29019e-04
# Iter 18, Loss: 8.77391e-03, Loss_PDE: 8.44579e-03, Loss_lbc: 1.05438e-04,Loss_rbc: 2.22687e-04
# Iter 18, Loss: 8.73084e-03, Loss_PDE: 8.41708e-03, Loss_lbc: 1.03819e-04,Loss_rbc: 2.09949e-04
# Iter 19, Loss: 9.52823e-03, Loss_PDE: 9.19005e-03, Loss_lbc: 1.14492e-04,Loss_rbc: 2.23685e-04
# Iter 19, Loss: 9.42100e-03, Loss_PDE: 9.08600e-03, Loss_lbc: 1.24143e-04,Loss_rbc: 2.10859e-04
# Iter 19, Loss: 9.36865e-03, Loss_PDE: 9.03244e-03, Loss_lbc: 1.32653e-04,Loss_rbc: 2.03563e-04
# Iter 19, Loss: 9.29628e-03, Loss_PDE: 8.96977e-03, Loss_lbc: 1.17195e-04,Loss_rbc: 2.09318e-04
# Iter 19, Loss: 9.20428e-03, Loss_PDE: 8.87561e-03, Loss_lbc: 1.03086e-04,Loss_rbc: 2.25582e-04
# Iter 19, Loss: 9.16765e-03, Loss_PDE: 8.82672e-03, Loss_lbc: 1.03143e-04,Loss_rbc: 2.37788e-04
# Iter 19, Loss: 9.11691e-03, Loss_PDE: 8.78017e-03, Loss_lbc: 1.00984e-04,Loss_rbc: 2.35755e-04
# Iter 19, Loss: 9.04417e-03, Loss_PDE: 8.72692e-03, Loss_lbc: 1.06933e-04,Loss_rbc: 2.10313e-04
# Iter 19, Loss: 9.00453e-03, Loss_PDE: 8.70255e-03, Loss_lbc: 1.27711e-04,Loss_rbc: 1.74267e-04
# Iter 19, Loss: 8.96082e-03, Loss_PDE: 8.66731e-03, Loss_lbc: 1.45345e-04,Loss_rbc: 1.48168e-04
# Iter 19, Loss: 8.92210e-03, Loss_PDE: 8.63521e-03, Loss_lbc: 1.50730e-04,Loss_rbc: 1.36166e-04
# Iter 19, Loss: 8.89002e-03, Loss_PDE: 8.61459e-03, Loss_lbc: 1.43770e-04,Loss_rbc: 1.31659e-04
# Iter 19, Loss: 8.83045e-03, Loss_PDE: 8.57335e-03, Loss_lbc: 1.23504e-04,Loss_rbc: 1.33602e-04
# Iter 19, Loss: 8.78072e-03, Loss_PDE: 8.53209e-03, Loss_lbc: 1.05896e-04,Loss_rbc: 1.42737e-04
# Iter 19, Loss: 8.74938e-03, Loss_PDE: 8.49842e-03, Loss_lbc: 9.84903e-05,Loss_rbc: 1.52468e-04
# Iter 20, Loss: 6.98120e-03, Loss_PDE: 6.79005e-03, Loss_lbc: 8.46119e-05,Loss_rbc: 1.06537e-04
# Iter 20, Loss: 6.86443e-03, Loss_PDE: 6.65531e-03, Loss_lbc: 9.29259e-05,Loss_rbc: 1.16193e-04
# Iter 20, Loss: 6.79466e-03, Loss_PDE: 6.58263e-03, Loss_lbc: 9.52303e-05,Loss_rbc: 1.16800e-04
# Iter 20, Loss: 6.72923e-03, Loss_PDE: 6.53259e-03, Loss_lbc: 8.25317e-05,Loss_rbc: 1.14099e-04
# Iter 20, Loss: 6.70988e-03, Loss_PDE: 6.48014e-03, Loss_lbc: 1.03989e-04,Loss_rbc: 1.25754e-04
# Iter 20, Loss: 6.66009e-03, Loss_PDE: 6.44899e-03, Loss_lbc: 1.06901e-04,Loss_rbc: 1.04201e-04
# Iter 20, Loss: 6.57694e-03, Loss_PDE: 6.39854e-03, Loss_lbc: 8.57670e-05,Loss_rbc: 9.26347e-05
# Iter 20, Loss: 6.52679e-03, Loss_PDE: 6.36003e-03, Loss_lbc: 7.36020e-05,Loss_rbc: 9.31590e-05
# Iter 20, Loss: 6.49708e-03, Loss_PDE: 6.34261e-03, Loss_lbc: 5.89374e-05,Loss_rbc: 9.55285e-05
# Iter 20, Loss: 6.45415e-03, Loss_PDE: 6.29749e-03, Loss_lbc: 4.79285e-05,Loss_rbc: 1.08729e-04
# Iter 20, Loss: 6.43562e-03, Loss_PDE: 6.26088e-03, Loss_lbc: 4.58511e-05,Loss_rbc: 1.28896e-04
# Iter 20, Loss: 6.39988e-03, Loss_PDE: 6.22254e-03, Loss_lbc: 4.47312e-05,Loss_rbc: 1.32616e-04
# Iter 20, Loss: 6.36158e-03, Loss_PDE: 6.20035e-03, Loss_lbc: 4.23275e-05,Loss_rbc: 1.18902e-04
# Iter 20, Loss: 6.33437e-03, Loss_PDE: 6.19098e-03, Loss_lbc: 4.57916e-05,Loss_rbc: 9.75906e-05
# Iter 20, Loss: 6.30428e-03, Loss_PDE: 6.16464e-03, Loss_lbc: 5.70837e-05,Loss_rbc: 8.25621e-05
# Iter 21, Loss: 7.02341e-03, Loss_PDE: 6.87059e-03, Loss_lbc: 7.16212e-05,Loss_rbc: 8.11986e-05
# Iter 21, Loss: 6.96395e-03, Loss_PDE: 6.80632e-03, Loss_lbc: 6.92204e-05,Loss_rbc: 8.84150e-05
# Iter 21, Loss: 6.93324e-03, Loss_PDE: 6.80588e-03, Loss_lbc: 4.75433e-05,Loss_rbc: 7.98220e-05
# Iter 21, Loss: 6.90071e-03, Loss_PDE: 6.75923e-03, Loss_lbc: 4.70433e-05,Loss_rbc: 9.44404e-05
# Iter 21, Loss: 6.87733e-03, Loss_PDE: 6.72947e-03, Loss_lbc: 3.55511e-05,Loss_rbc: 1.12308e-04
# Iter 21, Loss: 6.84856e-03, Loss_PDE: 6.70636e-03, Loss_lbc: 3.44137e-05,Loss_rbc: 1.07783e-04
# Iter 21, Loss: 6.83376e-03, Loss_PDE: 6.68062e-03, Loss_lbc: 4.17845e-05,Loss_rbc: 1.11356e-04
# Iter 21, Loss: 6.77194e-03, Loss_PDE: 6.66106e-03, Loss_lbc: 2.83145e-05,Loss_rbc: 8.25568e-05
# Iter 21, Loss: 6.75708e-03, Loss_PDE: 6.64766e-03, Loss_lbc: 3.70038e-05,Loss_rbc: 7.24142e-05
# Iter 21, Loss: 6.72454e-03, Loss_PDE: 6.62247e-03, Loss_lbc: 4.18114e-05,Loss_rbc: 6.02634e-05
# Iter 21, Loss: 6.70109e-03, Loss_PDE: 6.58865e-03, Loss_lbc: 4.60460e-05,Loss_rbc: 6.63997e-05
# Iter 21, Loss: 6.65490e-03, Loss_PDE: 6.55563e-03, Loss_lbc: 4.28409e-05,Loss_rbc: 5.64269e-05
# Iter 21, Loss: 6.63584e-03, Loss_PDE: 6.53468e-03, Loss_lbc: 3.89929e-05,Loss_rbc: 6.21681e-05
# Iter 21, Loss: 6.60329e-03, Loss_PDE: 6.49927e-03, Loss_lbc: 3.67357e-05,Loss_rbc: 6.72850e-05
# Iter 21, Loss: 6.58976e-03, Loss_PDE: 6.48486e-03, Loss_lbc: 3.68932e-05,Loss_rbc: 6.80068e-05
# Iter 22, Loss: 6.86534e-03, Loss_PDE: 6.77226e-03, Loss_lbc: 3.80404e-05,Loss_rbc: 5.50399e-05
# Iter 22, Loss: 6.84985e-03, Loss_PDE: 6.73205e-03, Loss_lbc: 3.99765e-05,Loss_rbc: 7.78247e-05
# Iter 22, Loss: 6.80900e-03, Loss_PDE: 6.70687e-03, Loss_lbc: 4.31820e-05,Loss_rbc: 5.89477e-05
# Iter 22, Loss: 6.79526e-03, Loss_PDE: 6.67008e-03, Loss_lbc: 5.23268e-05,Loss_rbc: 7.28555e-05
# Iter 22, Loss: 6.76689e-03, Loss_PDE: 6.65676e-03, Loss_lbc: 4.43681e-05,Loss_rbc: 6.57625e-05
# Iter 22, Loss: 6.74704e-03, Loss_PDE: 6.63532e-03, Loss_lbc: 5.15825e-05,Loss_rbc: 6.01361e-05
# Iter 22, Loss: 6.70588e-03, Loss_PDE: 6.60046e-03, Loss_lbc: 5.35532e-05,Loss_rbc: 5.18692e-05
# Iter 22, Loss: 6.69639e-03, Loss_PDE: 6.59133e-03, Loss_lbc: 5.35416e-05,Loss_rbc: 5.15202e-05
# Iter 22, Loss: 6.66248e-03, Loss_PDE: 6.56228e-03, Loss_lbc: 4.89164e-05,Loss_rbc: 5.12820e-05
# Iter 22, Loss: 6.63297e-03, Loss_PDE: 6.52091e-03, Loss_lbc: 4.75508e-05,Loss_rbc: 6.45094e-05
# Iter 22, Loss: 6.60822e-03, Loss_PDE: 6.49628e-03, Loss_lbc: 4.09430e-05,Loss_rbc: 7.10035e-05
# Iter 22, Loss: 6.58163e-03, Loss_PDE: 6.46977e-03, Loss_lbc: 3.83821e-05,Loss_rbc: 7.34837e-05
# Iter 22, Loss: 6.55626e-03, Loss_PDE: 6.44493e-03, Loss_lbc: 4.36180e-05,Loss_rbc: 6.77152e-05
# Iter 22, Loss: 6.53166e-03, Loss_PDE: 6.42838e-03, Loss_lbc: 4.17794e-05,Loss_rbc: 6.15008e-05
# Iter 22, Loss: 6.50834e-03, Loss_PDE: 6.40633e-03, Loss_lbc: 4.33785e-05,Loss_rbc: 5.86297e-05
# Iter 23, Loss: 7.33171e-03, Loss_PDE: 7.21735e-03, Loss_lbc: 4.25146e-05,Loss_rbc: 7.18430e-05
# Iter 23, Loss: 7.28949e-03, Loss_PDE: 7.17781e-03, Loss_lbc: 4.05931e-05,Loss_rbc: 7.10804e-05
# Iter 23, Loss: 7.24748e-03, Loss_PDE: 7.14133e-03, Loss_lbc: 3.52111e-05,Loss_rbc: 7.09379e-05
# Iter 23, Loss: 7.20976e-03, Loss_PDE: 7.09937e-03, Loss_lbc: 3.06049e-05,Loss_rbc: 7.97870e-05
# Iter 23, Loss: 7.16136e-03, Loss_PDE: 7.05951e-03, Loss_lbc: 2.84754e-05,Loss_rbc: 7.33751e-05
# Iter 23, Loss: 7.12498e-03, Loss_PDE: 7.02685e-03, Loss_lbc: 2.94186e-05,Loss_rbc: 6.87197e-05
# Iter 23, Loss: 7.07755e-03, Loss_PDE: 6.98461e-03, Loss_lbc: 3.32563e-05,Loss_rbc: 5.96891e-05
# Iter 23, Loss: 7.04646e-03, Loss_PDE: 6.95688e-03, Loss_lbc: 4.12297e-05,Loss_rbc: 4.83467e-05
# Iter 23, Loss: 7.01526e-03, Loss_PDE: 6.92654e-03, Loss_lbc: 4.79441e-05,Loss_rbc: 4.07749e-05
# Iter 23, Loss: 6.98506e-03, Loss_PDE: 6.89992e-03, Loss_lbc: 4.47437e-05,Loss_rbc: 4.03960e-05
# Iter 23, Loss: 6.95513e-03, Loss_PDE: 6.87465e-03, Loss_lbc: 4.18548e-05,Loss_rbc: 3.86281e-05
# Iter 23, Loss: 6.92347e-03, Loss_PDE: 6.84482e-03, Loss_lbc: 3.83020e-05,Loss_rbc: 4.03500e-05
# Iter 23, Loss: 6.89763e-03, Loss_PDE: 6.81624e-03, Loss_lbc: 3.56513e-05,Loss_rbc: 4.57415e-05
# Iter 23, Loss: 6.87046e-03, Loss_PDE: 6.78722e-03, Loss_lbc: 3.67856e-05,Loss_rbc: 4.64486e-05
# Iter 23, Loss: 6.83768e-03, Loss_PDE: 6.75565e-03, Loss_lbc: 4.10171e-05,Loss_rbc: 4.10067e-05
# Iter 24, Loss: 5.70339e-03, Loss_PDE: 5.63377e-03, Loss_lbc: 3.88936e-05,Loss_rbc: 3.07330e-05
# Iter 24, Loss: 5.66866e-03, Loss_PDE: 5.59990e-03, Loss_lbc: 3.84521e-05,Loss_rbc: 3.03111e-05
# Iter 24, Loss: 5.63716e-03, Loss_PDE: 5.56418e-03, Loss_lbc: 4.13763e-05,Loss_rbc: 3.16025e-05
# Iter 24, Loss: 5.60321e-03, Loss_PDE: 5.52754e-03, Loss_lbc: 4.27956e-05,Loss_rbc: 3.28796e-05
# Iter 24, Loss: 5.56653e-03, Loss_PDE: 5.49144e-03, Loss_lbc: 4.12682e-05,Loss_rbc: 3.38245e-05
# Iter 24, Loss: 5.53050e-03, Loss_PDE: 5.45572e-03, Loss_lbc: 3.94167e-05,Loss_rbc: 3.53599e-05
# Iter 24, Loss: 5.49979e-03, Loss_PDE: 5.42505e-03, Loss_lbc: 3.64615e-05,Loss_rbc: 3.82791e-05
# Iter 24, Loss: 5.47837e-03, Loss_PDE: 5.40183e-03, Loss_lbc: 3.36021e-05,Loss_rbc: 4.29366e-05
# Iter 24, Loss: 5.45610e-03, Loss_PDE: 5.37532e-03, Loss_lbc: 3.18149e-05,Loss_rbc: 4.89576e-05
# Iter 24, Loss: 5.43524e-03, Loss_PDE: 5.35034e-03, Loss_lbc: 3.08847e-05,Loss_rbc: 5.40115e-05
# Iter 24, Loss: 5.41487e-03, Loss_PDE: 5.32868e-03, Loss_lbc: 3.12485e-05,Loss_rbc: 5.49392e-05
# Iter 24, Loss: 5.39627e-03, Loss_PDE: 5.30857e-03, Loss_lbc: 3.53141e-05,Loss_rbc: 5.23826e-05
# Iter 24, Loss: 5.37851e-03, Loss_PDE: 5.28864e-03, Loss_lbc: 3.96474e-05,Loss_rbc: 5.02175e-05
# Iter 24, Loss: 5.35813e-03, Loss_PDE: 5.26725e-03, Loss_lbc: 3.99035e-05,Loss_rbc: 5.09807e-05
# Iter 24, Loss: 5.33750e-03, Loss_PDE: 5.24499e-03, Loss_lbc: 3.79168e-05,Loss_rbc: 5.45947e-05
# Iter 25, Loss: 6.24466e-03, Loss_PDE: 6.13876e-03, Loss_lbc: 3.49906e-05,Loss_rbc: 7.09009e-05
# Iter 25, Loss: 6.17409e-03, Loss_PDE: 6.05244e-03, Loss_lbc: 3.65887e-05,Loss_rbc: 8.50662e-05
# Iter 25, Loss: 6.17110e-03, Loss_PDE: 6.03703e-03, Loss_lbc: 4.00276e-05,Loss_rbc: 9.40434e-05
# Iter 25, Loss: 6.11716e-03, Loss_PDE: 5.99468e-03, Loss_lbc: 3.81395e-05,Loss_rbc: 8.43474e-05
# Iter 25, Loss: 6.11366e-03, Loss_PDE: 5.98216e-03, Loss_lbc: 6.71441e-05,Loss_rbc: 6.43568e-05
# Iter 25, Loss: 6.08144e-03, Loss_PDE: 5.95527e-03, Loss_lbc: 7.42862e-05,Loss_rbc: 5.18872e-05
# Iter 25, Loss: 6.05644e-03, Loss_PDE: 5.94482e-03, Loss_lbc: 6.19364e-05,Loss_rbc: 4.96784e-05
# Iter 25, Loss: 6.04332e-03, Loss_PDE: 5.92714e-03, Loss_lbc: 5.77797e-05,Loss_rbc: 5.83946e-05
# Iter 25, Loss: 5.99752e-03, Loss_PDE: 5.89730e-03, Loss_lbc: 4.08289e-05,Loss_rbc: 5.93945e-05
# Iter 25, Loss: 5.99391e-03, Loss_PDE: 5.88401e-03, Loss_lbc: 3.67471e-05,Loss_rbc: 7.31571e-05
# Iter 25, Loss: 5.95390e-03, Loss_PDE: 5.84684e-03, Loss_lbc: 3.29512e-05,Loss_rbc: 7.41132e-05
# Iter 25, Loss: 5.93075e-03, Loss_PDE: 5.82161e-03, Loss_lbc: 4.45638e-05,Loss_rbc: 6.45733e-05
# Iter 25, Loss: 5.90006e-03, Loss_PDE: 5.79997e-03, Loss_lbc: 4.79694e-05,Loss_rbc: 5.21201e-05
# Iter 25, Loss: 5.87312e-03, Loss_PDE: 5.77851e-03, Loss_lbc: 4.81493e-05,Loss_rbc: 4.64616e-05
# Iter 25, Loss: 5.85417e-03, Loss_PDE: 5.76297e-03, Loss_lbc: 4.83280e-05,Loss_rbc: 4.28760e-05
# Iter 26, Loss: 7.38951e-03, Loss_PDE: 7.29693e-03, Loss_lbc: 4.30239e-05,Loss_rbc: 4.95596e-05
# Iter 26, Loss: 7.20747e-03, Loss_PDE: 7.10491e-03, Loss_lbc: 5.07171e-05,Loss_rbc: 5.18450e-05
# Iter 26, Loss: 7.21664e-03, Loss_PDE: 7.10222e-03, Loss_lbc: 5.94770e-05,Loss_rbc: 5.49480e-05
# Iter 26, Loss: 7.12448e-03, Loss_PDE: 7.01992e-03, Loss_lbc: 4.22222e-05,Loss_rbc: 6.23388e-05
# Iter 26, Loss: 7.13548e-03, Loss_PDE: 6.97484e-03, Loss_lbc: 8.74375e-05,Loss_rbc: 7.31967e-05
# Iter 26, Loss: 7.08398e-03, Loss_PDE: 6.92177e-03, Loss_lbc: 8.93637e-05,Loss_rbc: 7.28433e-05
# Iter 26, Loss: 7.00444e-03, Loss_PDE: 6.87742e-03, Loss_lbc: 6.20037e-05,Loss_rbc: 6.50188e-05
# Iter 26, Loss: 7.01491e-03, Loss_PDE: 6.86612e-03, Loss_lbc: 8.89490e-05,Loss_rbc: 5.98461e-05
# Iter 26, Loss: 6.93885e-03, Loss_PDE: 6.79158e-03, Loss_lbc: 9.65195e-05,Loss_rbc: 5.07484e-05
# Iter 26, Loss: 6.93038e-03, Loss_PDE: 6.78562e-03, Loss_lbc: 9.59210e-05,Loss_rbc: 4.88425e-05
# Iter 26, Loss: 6.84546e-03, Loss_PDE: 6.71392e-03, Loss_lbc: 7.78969e-05,Loss_rbc: 5.36492e-05
# Iter 26, Loss: 6.80234e-03, Loss_PDE: 6.66945e-03, Loss_lbc: 6.90297e-05,Loss_rbc: 6.38599e-05
# Iter 26, Loss: 6.77975e-03, Loss_PDE: 6.63889e-03, Loss_lbc: 5.69651e-05,Loss_rbc: 8.38985e-05
# Iter 26, Loss: 6.73010e-03, Loss_PDE: 6.57997e-03, Loss_lbc: 4.47750e-05,Loss_rbc: 1.05359e-04
# Iter 26, Loss: 6.70728e-03, Loss_PDE: 6.55083e-03, Loss_lbc: 5.00107e-05,Loss_rbc: 1.06440e-04
# Iter 27, Loss: 5.12691e-03, Loss_PDE: 5.00961e-03, Loss_lbc: 5.12962e-05,Loss_rbc: 6.59966e-05
# Iter 27, Loss: 5.07186e-03, Loss_PDE: 4.95128e-03, Loss_lbc: 6.29296e-05,Loss_rbc: 5.76439e-05
# Iter 27, Loss: 5.03426e-03, Loss_PDE: 4.90652e-03, Loss_lbc: 7.69918e-05,Loss_rbc: 5.07410e-05
# Iter 27, Loss: 5.02370e-03, Loss_PDE: 4.89913e-03, Loss_lbc: 7.69568e-05,Loss_rbc: 4.76108e-05
# Iter 27, Loss: 4.98518e-03, Loss_PDE: 4.87372e-03, Loss_lbc: 5.95373e-05,Loss_rbc: 5.19206e-05
# Iter 27, Loss: 4.95911e-03, Loss_PDE: 4.84565e-03, Loss_lbc: 4.92176e-05,Loss_rbc: 6.42386e-05
# Iter 27, Loss: 4.92573e-03, Loss_PDE: 4.82169e-03, Loss_lbc: 3.00404e-05,Loss_rbc: 7.40016e-05
# Iter 27, Loss: 4.91301e-03, Loss_PDE: 4.79914e-03, Loss_lbc: 2.58681e-05,Loss_rbc: 8.80022e-05
# Iter 27, Loss: 4.89072e-03, Loss_PDE: 4.78021e-03, Loss_lbc: 2.65246e-05,Loss_rbc: 8.39887e-05
# Iter 27, Loss: 4.85195e-03, Loss_PDE: 4.75141e-03, Loss_lbc: 2.56855e-05,Loss_rbc: 7.48547e-05
# Iter 27, Loss: 4.81442e-03, Loss_PDE: 4.71656e-03, Loss_lbc: 3.20844e-05,Loss_rbc: 6.57755e-05
# Iter 27, Loss: 4.78508e-03, Loss_PDE: 4.68246e-03, Loss_lbc: 4.27682e-05,Loss_rbc: 5.98497e-05
# Iter 27, Loss: 4.77463e-03, Loss_PDE: 4.66463e-03, Loss_lbc: 5.21242e-05,Loss_rbc: 5.78719e-05
# Iter 27, Loss: 4.75704e-03, Loss_PDE: 4.64427e-03, Loss_lbc: 5.72482e-05,Loss_rbc: 5.55232e-05
# Iter 27, Loss: 4.73117e-03, Loss_PDE: 4.62296e-03, Loss_lbc: 5.60415e-05,Loss_rbc: 5.21674e-05
# Iter 28, Loss: 5.85043e-03, Loss_PDE: 5.72866e-03, Loss_lbc: 4.94676e-05,Loss_rbc: 7.22980e-05
# Iter 28, Loss: 5.82121e-03, Loss_PDE: 5.66710e-03, Loss_lbc: 4.30983e-05,Loss_rbc: 1.11009e-04
# Iter 28, Loss: 5.77253e-03, Loss_PDE: 5.62155e-03, Loss_lbc: 4.15854e-05,Loss_rbc: 1.09397e-04
# Iter 28, Loss: 5.74940e-03, Loss_PDE: 5.58395e-03, Loss_lbc: 4.65524e-05,Loss_rbc: 1.18895e-04
# Iter 28, Loss: 5.68529e-03, Loss_PDE: 5.54344e-03, Loss_lbc: 4.98330e-05,Loss_rbc: 9.20186e-05
# Iter 28, Loss: 5.66226e-03, Loss_PDE: 5.51648e-03, Loss_lbc: 6.91264e-05,Loss_rbc: 7.66502e-05
# Iter 28, Loss: 5.61542e-03, Loss_PDE: 5.47567e-03, Loss_lbc: 7.81204e-05,Loss_rbc: 6.16260e-05
# Iter 28, Loss: 5.59068e-03, Loss_PDE: 5.44080e-03, Loss_lbc: 7.89065e-05,Loss_rbc: 7.09751e-05
# Iter 28, Loss: 5.54415e-03, Loss_PDE: 5.40361e-03, Loss_lbc: 7.39504e-05,Loss_rbc: 6.65940e-05
# Iter 28, Loss: 5.51860e-03, Loss_PDE: 5.37143e-03, Loss_lbc: 6.49387e-05,Loss_rbc: 8.22301e-05
# Iter 28, Loss: 5.49694e-03, Loss_PDE: 5.34440e-03, Loss_lbc: 5.97575e-05,Loss_rbc: 9.27773e-05
# Iter 28, Loss: 5.46456e-03, Loss_PDE: 5.32021e-03, Loss_lbc: 6.26702e-05,Loss_rbc: 8.16804e-05
# Iter 28, Loss: 5.44248e-03, Loss_PDE: 5.29950e-03, Loss_lbc: 6.98028e-05,Loss_rbc: 7.31708e-05
# Iter 28, Loss: 5.41070e-03, Loss_PDE: 5.27460e-03, Loss_lbc: 7.67583e-05,Loss_rbc: 5.93447e-05
# Iter 28, Loss: 5.39113e-03, Loss_PDE: 5.24732e-03, Loss_lbc: 8.04947e-05,Loss_rbc: 6.33151e-05
# Iter 29, Loss: 4.55493e-03, Loss_PDE: 4.42720e-03, Loss_lbc: 7.76760e-05,Loss_rbc: 5.00470e-05
# Iter 29, Loss: 4.46820e-03, Loss_PDE: 4.32423e-03, Loss_lbc: 6.96654e-05,Loss_rbc: 7.42990e-05
# Iter 29, Loss: 4.41955e-03, Loss_PDE: 4.29950e-03, Loss_lbc: 6.64533e-05,Loss_rbc: 5.36028e-05
# Iter 29, Loss: 4.40153e-03, Loss_PDE: 4.27686e-03, Loss_lbc: 6.42110e-05,Loss_rbc: 6.04510e-05
# Iter 29, Loss: 4.36188e-03, Loss_PDE: 4.26924e-03, Loss_lbc: 4.36581e-05,Loss_rbc: 4.89804e-05
# Iter 29, Loss: 4.34360e-03, Loss_PDE: 4.23273e-03, Loss_lbc: 4.41657e-05,Loss_rbc: 6.67091e-05
# Iter 29, Loss: 4.30501e-03, Loss_PDE: 4.19049e-03, Loss_lbc: 4.18604e-05,Loss_rbc: 7.26661e-05
# Iter 29, Loss: 4.29489e-03, Loss_PDE: 4.17791e-03, Loss_lbc: 4.15621e-05,Loss_rbc: 7.54203e-05
# Iter 29, Loss: 4.26433e-03, Loss_PDE: 4.14988e-03, Loss_lbc: 5.47602e-05,Loss_rbc: 5.96864e-05
# Iter 29, Loss: 4.23753e-03, Loss_PDE: 4.13214e-03, Loss_lbc: 5.31920e-05,Loss_rbc: 5.22020e-05
# Iter 29, Loss: 4.22225e-03, Loss_PDE: 4.11256e-03, Loss_lbc: 5.76917e-05,Loss_rbc: 5.19946e-05
# Iter 29, Loss: 4.18901e-03, Loss_PDE: 4.08571e-03, Loss_lbc: 5.56777e-05,Loss_rbc: 4.76204e-05
# Iter 29, Loss: 4.18035e-03, Loss_PDE: 4.06963e-03, Loss_lbc: 4.65572e-05,Loss_rbc: 6.41588e-05
# Iter 29, Loss: 4.16221e-03, Loss_PDE: 4.05424e-03, Loss_lbc: 4.65451e-05,Loss_rbc: 6.14320e-05
# Iter 29, Loss: 4.14586e-03, Loss_PDE: 4.03150e-03, Loss_lbc: 4.86353e-05,Loss_rbc: 6.57229e-05
# Iter 30, Loss: 4.49589e-03, Loss_PDE: 4.38086e-03, Loss_lbc: 5.23525e-05,Loss_rbc: 6.26781e-05
# Iter 30, Loss: 4.47737e-03, Loss_PDE: 4.36258e-03, Loss_lbc: 5.67380e-05,Loss_rbc: 5.80535e-05
# Iter 30, Loss: 4.44831e-03, Loss_PDE: 4.32674e-03, Loss_lbc: 6.31145e-05,Loss_rbc: 5.84546e-05
# Iter 30, Loss: 4.42083e-03, Loss_PDE: 4.29533e-03, Loss_lbc: 6.77149e-05,Loss_rbc: 5.77846e-05
# Iter 30, Loss: 4.40428e-03, Loss_PDE: 4.26391e-03, Loss_lbc: 6.87096e-05,Loss_rbc: 7.16544e-05
# Iter 30, Loss: 4.37733e-03, Loss_PDE: 4.24263e-03, Loss_lbc: 6.85824e-05,Loss_rbc: 6.61166e-05
# Iter 30, Loss: 4.36436e-03, Loss_PDE: 4.22401e-03, Loss_lbc: 7.49614e-05,Loss_rbc: 6.53825e-05
# Iter 30, Loss: 4.34334e-03, Loss_PDE: 4.20624e-03, Loss_lbc: 7.05494e-05,Loss_rbc: 6.65589e-05
# Iter 30, Loss: 4.32176e-03, Loss_PDE: 4.18731e-03, Loss_lbc: 6.85925e-05,Loss_rbc: 6.58588e-05
# Iter 30, Loss: 4.29644e-03, Loss_PDE: 4.16244e-03, Loss_lbc: 6.80778e-05,Loss_rbc: 6.59262e-05
# Iter 30, Loss: 4.26886e-03, Loss_PDE: 4.13917e-03, Loss_lbc: 5.99332e-05,Loss_rbc: 6.97587e-05
# Iter 30, Loss: 4.25309e-03, Loss_PDE: 4.12008e-03, Loss_lbc: 5.69292e-05,Loss_rbc: 7.60801e-05
# Iter 30, Loss: 4.23339e-03, Loss_PDE: 4.10447e-03, Loss_lbc: 5.61182e-05,Loss_rbc: 7.28060e-05
# Iter 30, Loss: 4.21421e-03, Loss_PDE: 4.08718e-03, Loss_lbc: 5.53579e-05,Loss_rbc: 7.16666e-05
# Iter 30, Loss: 4.19436e-03, Loss_PDE: 4.06838e-03, Loss_lbc: 5.50581e-05,Loss_rbc: 7.09253e-05
# Iter 31, Loss: 3.86732e-03, Loss_PDE: 3.73858e-03, Loss_lbc: 5.49578e-05,Loss_rbc: 7.37859e-05
# Iter 31, Loss: 3.84865e-03, Loss_PDE: 3.70959e-03, Loss_lbc: 5.78951e-05,Loss_rbc: 8.11581e-05
# Iter 31, Loss: 3.81409e-03, Loss_PDE: 3.66887e-03, Loss_lbc: 5.89048e-05,Loss_rbc: 8.63110e-05
# Iter 31, Loss: 3.79285e-03, Loss_PDE: 3.63903e-03, Loss_lbc: 6.35700e-05,Loss_rbc: 9.02481e-05
# Iter 31, Loss: 3.77107e-03, Loss_PDE: 3.61549e-03, Loss_lbc: 7.46341e-05,Loss_rbc: 8.09414e-05
# Iter 31, Loss: 3.74564e-03, Loss_PDE: 3.59009e-03, Loss_lbc: 8.33580e-05,Loss_rbc: 7.21974e-05
# Iter 31, Loss: 3.73250e-03, Loss_PDE: 3.57425e-03, Loss_lbc: 8.92039e-05,Loss_rbc: 6.90444e-05
# Iter 31, Loss: 3.71007e-03, Loss_PDE: 3.55299e-03, Loss_lbc: 8.98538e-05,Loss_rbc: 6.72320e-05
# Iter 31, Loss: 3.68872e-03, Loss_PDE: 3.53654e-03, Loss_lbc: 8.27744e-05,Loss_rbc: 6.93994e-05
# Iter 31, Loss: 3.67300e-03, Loss_PDE: 3.52499e-03, Loss_lbc: 7.44497e-05,Loss_rbc: 7.35629e-05
# Iter 31, Loss: 3.65137e-03, Loss_PDE: 3.50844e-03, Loss_lbc: 6.85731e-05,Loss_rbc: 7.43541e-05
# Iter 31, Loss: 3.63468e-03, Loss_PDE: 3.49704e-03, Loss_lbc: 6.61070e-05,Loss_rbc: 7.15315e-05
# Iter 31, Loss: 3.61705e-03, Loss_PDE: 3.48662e-03, Loss_lbc: 6.45054e-05,Loss_rbc: 6.59318e-05
# Iter 31, Loss: 3.59587e-03, Loss_PDE: 3.47102e-03, Loss_lbc: 6.46260e-05,Loss_rbc: 6.02275e-05
# Iter 31, Loss: 3.57879e-03, Loss_PDE: 3.45612e-03, Loss_lbc: 6.42938e-05,Loss_rbc: 5.83821e-05
# Iter 32, Loss: 3.52109e-03, Loss_PDE: 3.40280e-03, Loss_lbc: 6.11533e-05,Loss_rbc: 5.71307e-05
# Iter 32, Loss: 3.47834e-03, Loss_PDE: 3.35767e-03, Loss_lbc: 5.92536e-05,Loss_rbc: 6.14098e-05
# Iter 32, Loss: 3.44105e-03, Loss_PDE: 3.32801e-03, Loss_lbc: 5.59332e-05,Loss_rbc: 5.71056e-05
# Iter 32, Loss: 3.42395e-03, Loss_PDE: 3.31275e-03, Loss_lbc: 5.54535e-05,Loss_rbc: 5.57467e-05
# Iter 32, Loss: 3.39943e-03, Loss_PDE: 3.29935e-03, Loss_lbc: 5.10710e-05,Loss_rbc: 4.90122e-05
# Iter 32, Loss: 3.37637e-03, Loss_PDE: 3.28497e-03, Loss_lbc: 4.45960e-05,Loss_rbc: 4.68000e-05
# Iter 32, Loss: 3.36509e-03, Loss_PDE: 3.27754e-03, Loss_lbc: 3.77012e-05,Loss_rbc: 4.98522e-05
# Iter 32, Loss: 3.35612e-03, Loss_PDE: 3.27203e-03, Loss_lbc: 3.58274e-05,Loss_rbc: 4.82648e-05
# Iter 32, Loss: 3.35332e-03, Loss_PDE: 3.26582e-03, Loss_lbc: 3.74466e-05,Loss_rbc: 5.00538e-05
# Iter 32, Loss: 3.34658e-03, Loss_PDE: 3.25486e-03, Loss_lbc: 3.73801e-05,Loss_rbc: 5.43451e-05
# Iter 32, Loss: 3.32738e-03, Loss_PDE: 3.24095e-03, Loss_lbc: 3.75243e-05,Loss_rbc: 4.88986e-05
# Iter 32, Loss: 3.31124e-03, Loss_PDE: 3.22755e-03, Loss_lbc: 3.70567e-05,Loss_rbc: 4.66315e-05
# Iter 32, Loss: 3.29805e-03, Loss_PDE: 3.21050e-03, Loss_lbc: 3.86202e-05,Loss_rbc: 4.89293e-05
# Iter 32, Loss: 3.27924e-03, Loss_PDE: 3.19281e-03, Loss_lbc: 4.15365e-05,Loss_rbc: 4.48961e-05
# Iter 32, Loss: 3.26045e-03, Loss_PDE: 3.17265e-03, Loss_lbc: 4.35682e-05,Loss_rbc: 4.42303e-05
# Iter 33, Loss: 4.78615e-03, Loss_PDE: 4.69086e-03, Loss_lbc: 4.91087e-05,Loss_rbc: 4.61759e-05
# Iter 33, Loss: 4.72550e-03, Loss_PDE: 4.62996e-03, Loss_lbc: 5.39513e-05,Loss_rbc: 4.15913e-05
# Iter 33, Loss: 4.69207e-03, Loss_PDE: 4.59364e-03, Loss_lbc: 5.69623e-05,Loss_rbc: 4.14656e-05
# Iter 33, Loss: 4.66948e-03, Loss_PDE: 4.56382e-03, Loss_lbc: 6.26162e-05,Loss_rbc: 4.30373e-05
# Iter 33, Loss: 4.64498e-03, Loss_PDE: 4.52713e-03, Loss_lbc: 7.45290e-05,Loss_rbc: 4.33249e-05
# Iter 33, Loss: 4.59990e-03, Loss_PDE: 4.49157e-03, Loss_lbc: 6.68609e-05,Loss_rbc: 4.14692e-05
# Iter 33, Loss: 4.57260e-03, Loss_PDE: 4.45000e-03, Loss_lbc: 7.53044e-05,Loss_rbc: 4.72988e-05
# Iter 33, Loss: 4.54098e-03, Loss_PDE: 4.42334e-03, Loss_lbc: 7.57770e-05,Loss_rbc: 4.18650e-05
# Iter 33, Loss: 4.53911e-03, Loss_PDE: 4.41219e-03, Loss_lbc: 8.22836e-05,Loss_rbc: 4.46347e-05
# Iter 33, Loss: 4.50997e-03, Loss_PDE: 4.37921e-03, Loss_lbc: 8.89482e-05,Loss_rbc: 4.18113e-05
# Iter 33, Loss: 4.48910e-03, Loss_PDE: 4.35175e-03, Loss_lbc: 9.27477e-05,Loss_rbc: 4.46080e-05
# ...
#  Loss: 1.16024e-05, Loss_PDE: 1.05370e-05, Loss_lbc: 8.29919e-07,Loss_rbc: 2.35511e-07
#  Loss: 1.15905e-05, Loss_PDE: 1.05237e-05, Loss_lbc: 8.32130e-07,Loss_rbc: 2.34744e-07
#  Loss: 1.15579e-05, Loss_PDE: 1.04856e-05, Loss_lbc: 8.39439e-07,Loss_rbc: 2.32919e-07
#  Loss: 1.15546e-05, Loss_PDE: 1.04820e-05, Loss_lbc: 8.39784e-07,Loss_rbc: 2.32851e-07
#  Loss: 1.15398e-05, Loss_PDE: 1.04657e-05, Loss_lbc: 8.41627e-07,Loss_rbc: 2.32480e-07
#  Loss: 1.14946e-05, Loss_PDE: 1.04129e-05, Loss_lbc: 8.49616e-07,Loss_rbc: 2.32042e-07
#  Loss: 1.14920e-05, Loss_PDE: 1.04098e-05, Loss_lbc: 8.50272e-07,Loss_rbc: 2.31960e-07
#  Loss: 1.14823e-05, Loss_PDE: 1.03977e-05, Loss_lbc: 8.52965e-07,Loss_rbc: 2.31632e-07
#  Loss: 1.14466e-05, Loss_PDE: 1.03490e-05, Loss_lbc: 8.66787e-07,Loss_rbc: 2.30811e-07
#  Loss: 1.14448e-05, Loss_PDE: 1.03468e-05, Loss_lbc: 8.67238e-07,Loss_rbc: 2.30776e-07
#  Loss: 1.14367e-05, Loss_PDE: 1.03366e-05, Loss_lbc: 8.69465e-07,Loss_rbc: 2.30649e-07
#  Loss: 1.14192e-05, Loss_PDE: 1.03136e-05, Loss_lbc: 8.74998e-07,Loss_rbc: 2.30613e-07
#  Loss: 1.14173e-05, Loss_PDE: 1.03112e-05, Loss_lbc: 8.75507e-07,Loss_rbc: 2.30577e-07
#  Loss: 1.14089e-05, Loss_PDE: 1.03007e-05, Loss_lbc: 8.77705e-07,Loss_rbc: 2.30475e-07
#  Loss: 1.13683e-05, Loss_PDE: 1.02471e-05, Loss_lbc: 8.91025e-07,Loss_rbc: 2.30221e-07
#  Loss: 1.13663e-05, Loss_PDE: 1.02444e-05, Loss_lbc: 8.91642e-07,Loss_rbc: 2.30184e-07
#  Loss: 1.13571e-05, Loss_PDE: 1.02326e-05, Loss_lbc: 8.94462e-07,Loss_rbc: 2.30089e-07
#  Loss: 1.13156e-05, Loss_PDE: 1.01722e-05, Loss_lbc: 9.11754e-07,Loss_rbc: 2.31699e-07
#  Loss: 1.13139e-05, Loss_PDE: 1.01699e-05, Loss_lbc: 9.12309e-07,Loss_rbc: 2.31612e-07
#  Loss: 1.13061e-05, Loss_PDE: 1.01600e-05, Loss_lbc: 9.14760e-07,Loss_rbc: 2.31315e-07
#  Loss: 1.12677e-05, Loss_PDE: 1.01090e-05, Loss_lbc: 9.29017e-07,Loss_rbc: 2.29719e-07
#  Loss: 1.12658e-05, Loss_PDE: 1.01067e-05, Loss_lbc: 9.29475e-07,Loss_rbc: 2.29556e-07
#  Loss: 1.12616e-05, Loss_PDE: 1.01020e-05, Loss_lbc: 9.30403e-07,Loss_rbc: 2.29252e-07
#  Loss: 1.12360e-05, Loss_PDE: 1.00717e-05, Loss_lbc: 9.36962e-07,Loss_rbc: 2.27295e-07
#  Loss: 1.12333e-05, Loss_PDE: 1.00687e-05, Loss_lbc: 9.37513e-07,Loss_rbc: 2.27100e-07
#  Loss: 1.12288e-05, Loss_PDE: 1.00636e-05, Loss_lbc: 9.38509e-07,Loss_rbc: 2.26694e-07
#  Loss: 1.11979e-05, Loss_PDE: 1.00283e-05, Loss_lbc: 9.45583e-07,Loss_rbc: 2.23982e-07
#  Loss: 1.11944e-05, Loss_PDE: 1.00248e-05, Loss_lbc: 9.45970e-07,Loss_rbc: 2.23643e-07
#  Loss: 1.11911e-05, Loss_PDE: 1.00215e-05, Loss_lbc: 9.46319e-07,Loss_rbc: 2.23276e-07
#  Loss: 1.11587e-05, Loss_PDE: 9.98855e-06, Loss_lbc: 9.50552e-07,Loss_rbc: 2.19548e-07
#  Loss: 1.11549e-05, Loss_PDE: 9.98470e-06, Loss_lbc: 9.51052e-07,Loss_rbc: 2.19132e-07
#  Loss: 1.11381e-05, Loss_PDE: 9.96754e-06, Loss_lbc: 9.53298e-07,Loss_rbc: 2.17271e-07
#  Loss: 1.10731e-05, Loss_PDE: 9.89904e-06, Loss_lbc: 9.64751e-07,Loss_rbc: 2.09272e-07
#  Loss: 1.10692e-05, Loss_PDE: 9.89542e-06, Loss_lbc: 9.65051e-07,Loss_rbc: 2.08762e-07
#  Loss: 1.10577e-05, Loss_PDE: 9.88435e-06, Loss_lbc: 9.66174e-07,Loss_rbc: 2.07184e-07
#  Loss: 1.09961e-05, Loss_PDE: 9.82390e-06, Loss_lbc: 9.73847e-07,Loss_rbc: 1.98352e-07
#  Loss: 1.09931e-05, Loss_PDE: 9.82121e-06, Loss_lbc: 9.74007e-07,Loss_rbc: 1.97883e-07
#  Loss: 1.09792e-05, Loss_PDE: 9.80858e-06, Loss_lbc: 9.74756e-07,Loss_rbc: 1.95861e-07
#  Loss: 1.09462e-05, Loss_PDE: 9.77817e-06, Loss_lbc: 9.77239e-07,Loss_rbc: 1.90820e-07
#  Loss: 1.09426e-05, Loss_PDE: 9.77473e-06, Loss_lbc: 9.77585e-07,Loss_rbc: 1.90312e-07
#  Loss: 1.09267e-05, Loss_PDE: 9.75941e-06, Loss_lbc: 9.79232e-07,Loss_rbc: 1.88061e-07
#  Loss: 1.08527e-05, Loss_PDE: 9.68553e-06, Loss_lbc: 9.90331e-07,Loss_rbc: 1.76794e-07
#  Loss: 1.08499e-05, Loss_PDE: 9.68307e-06, Loss_lbc: 9.90381e-07,Loss_rbc: 1.76398e-07
#  Loss: 1.08457e-05, Loss_PDE: 9.67945e-06, Loss_lbc: 9.90485e-07,Loss_rbc: 1.75760e-07
#  Loss: 1.08232e-05, Loss_PDE: 9.65965e-06, Loss_lbc: 9.91413e-07,Loss_rbc: 1.72164e-07
#  Loss: 1.08196e-05, Loss_PDE: 9.65656e-06, Loss_lbc: 9.91319e-07,Loss_rbc: 1.71700e-07
#  Loss: 1.08168e-05, Loss_PDE: 9.65427e-06, Loss_lbc: 9.91234e-07,Loss_rbc: 1.71319e-07
#  Loss: 1.07910e-05, Loss_PDE: 9.63227e-06, Loss_lbc: 9.91011e-07,Loss_rbc: 1.67764e-07
#  Loss: 1.07886e-05, Loss_PDE: 9.62996e-06, Loss_lbc: 9.91242e-07,Loss_rbc: 1.67411e-07
#  Loss: 1.07767e-05, Loss_PDE: 9.61856e-06, Loss_lbc: 9.92250e-07,Loss_rbc: 1.65910e-07
#  Loss: 1.07575e-05, Loss_PDE: 9.59968e-06, Loss_lbc: 9.94516e-07,Loss_rbc: 1.63321e-07
#  Loss: 1.07550e-05, Loss_PDE: 9.59757e-06, Loss_lbc: 9.94404e-07,Loss_rbc: 1.63011e-07
#  Loss: 1.07486e-05, Loss_PDE: 9.59234e-06, Loss_lbc: 9.94095e-07,Loss_rbc: 1.62215e-07
#  Loss: 1.07119e-05, Loss_PDE: 9.56109e-06, Loss_lbc: 9.93112e-07,Loss_rbc: 1.57687e-07
#  Loss: 1.07096e-05, Loss_PDE: 9.55852e-06, Loss_lbc: 9.93620e-07,Loss_rbc: 1.57464e-07
#  Loss: 1.06995e-05, Loss_PDE: 9.54690e-06, Loss_lbc: 9.96069e-07,Loss_rbc: 1.56501e-07
#  Loss: 1.06684e-05, Loss_PDE: 9.50875e-06, Loss_lbc: 1.00640e-06,Loss_rbc: 1.53299e-07
#  Loss: 1.06663e-05, Loss_PDE: 9.50676e-06, Loss_lbc: 1.00640e-06,Loss_rbc: 1.53113e-07
#  Loss: 1.06638e-05, Loss_PDE: 9.50452e-06, Loss_lbc: 1.00638e-06,Loss_rbc: 1.52887e-07
#  Loss: 1.06441e-05, Loss_PDE: 9.48647e-06, Loss_lbc: 1.00650e-06,Loss_rbc: 1.51142e-07
#  Loss: 1.06422e-05, Loss_PDE: 9.48432e-06, Loss_lbc: 1.00686e-06,Loss_rbc: 1.51020e-07
#  Loss: 1.06336e-05, Loss_PDE: 9.47452e-06, Loss_lbc: 1.00859e-06,Loss_rbc: 1.50530e-07
#  Loss: 1.05930e-05, Loss_PDE: 9.42547e-06, Loss_lbc: 1.01917e-06,Loss_rbc: 1.48321e-07
#  Loss: 1.05907e-05, Loss_PDE: 9.42321e-06, Loss_lbc: 1.01940e-06,Loss_rbc: 1.48122e-07
#  Loss: 1.05869e-05, Loss_PDE: 9.41930e-06, Loss_lbc: 1.01979e-06,Loss_rbc: 1.47783e-07
#  Loss: 1.05822e-05, Loss_PDE: 9.41449e-06, Loss_lbc: 1.02035e-06,Loss_rbc: 1.47400e-07
#  Loss: 1.05804e-05, Loss_PDE: 9.41250e-06, Loss_lbc: 1.02062e-06,Loss_rbc: 1.47325e-07
#  Loss: 1.05775e-05, Loss_PDE: 9.40924e-06, Loss_lbc: 1.02108e-06,Loss_rbc: 1.47219e-07
#  Loss: 1.05581e-05, Loss_PDE: 9.38696e-06, Loss_lbc: 1.02464e-06,Loss_rbc: 1.46529e-07
#  Loss: 1.05564e-05, Loss_PDE: 9.38489e-06, Loss_lbc: 1.02506e-06,Loss_rbc: 1.46472e-07
#  Loss: 1.05540e-05, Loss_PDE: 9.38192e-06, Loss_lbc: 1.02568e-06,Loss_rbc: 1.46432e-07
#  Loss: 1.05511e-05, Loss_PDE: 9.37826e-06, Loss_lbc: 1.02651e-06,Loss_rbc: 1.46365e-07
#  Loss: 1.05234e-05, Loss_PDE: 9.34192e-06, Loss_lbc: 1.03549e-06,Loss_rbc: 1.46022e-07
#  Loss: 1.05218e-05, Loss_PDE: 9.34001e-06, Loss_lbc: 1.03578e-06,Loss_rbc: 1.45978e-07
#  Loss: 1.05142e-05, Loss_PDE: 9.33102e-06, Loss_lbc: 1.03734e-06,Loss_rbc: 1.45814e-07
#  Loss: 1.05036e-05, Loss_PDE: 9.31788e-06, Loss_lbc: 1.03998e-06,Loss_rbc: 1.45719e-07
#  Loss: 1.05017e-05, Loss_PDE: 9.31539e-06, Loss_lbc: 1.04062e-06,Loss_rbc: 1.45735e-07
#  Loss: 1.04944e-05, Loss_PDE: 9.30526e-06, Loss_lbc: 1.04331e-06,Loss_rbc: 1.45830e-07
#  Loss: 1.04776e-05, Loss_PDE: 9.28122e-06, Loss_lbc: 1.05019e-06,Loss_rbc: 1.46229e-07
#  Loss: 1.04762e-05, Loss_PDE: 9.27918e-06, Loss_lbc: 1.05078e-06,Loss_rbc: 1.46244e-07
#  Loss: 1.04741e-05, Loss_PDE: 9.27605e-06, Loss_lbc: 1.05171e-06,Loss_rbc: 1.46297e-07
#  Loss: 1.04681e-05, Loss_PDE: 9.26720e-06, Loss_lbc: 1.05445e-06,Loss_rbc: 1.46432e-07
#  Loss: 1.04337e-05, Loss_PDE: 9.21117e-06, Loss_lbc: 1.07465e-06,Loss_rbc: 1.47902e-07
#  Loss: 1.04327e-05, Loss_PDE: 9.20963e-06, Loss_lbc: 1.07513e-06,Loss_rbc: 1.47969e-07
#  Loss: 1.04280e-05, Loss_PDE: 9.20240e-06, Loss_lbc: 1.07736e-06,Loss_rbc: 1.48246e-07
#  Loss: 1.04192e-05, Loss_PDE: 9.18799e-06, Loss_lbc: 1.08233e-06,Loss_rbc: 1.48877e-07
#  Loss: 1.04182e-05, Loss_PDE: 9.18614e-06, Loss_lbc: 1.08307e-06,Loss_rbc: 1.48957e-07
#  Loss: 1.04136e-05, Loss_PDE: 9.17781e-06, Loss_lbc: 1.08649e-06,Loss_rbc: 1.49286e-07
#  Loss: 1.04087e-05, Loss_PDE: 9.16827e-06, Loss_lbc: 1.09072e-06,Loss_rbc: 1.49734e-07
#  Loss: 1.04076e-05, Loss_PDE: 9.16636e-06, Loss_lbc: 1.09142e-06,Loss_rbc: 1.49812e-07
#  Loss: 1.04067e-05, Loss_PDE: 9.16503e-06, Loss_lbc: 1.09182e-06,Loss_rbc: 1.49852e-07
#  Loss: 1.04069e-05, Loss_PDE: 9.16502e-06, Loss_lbc: 1.09197e-06,Loss_rbc: 1.49884e-07
#  Loss: 1.04069e-05, Loss_PDE: 9.16524e-06, Loss_lbc: 1.09184e-06,Loss_rbc: 1.49861e-07
#  Loss: 1.04068e-05, Loss_PDE: 9.16511e-06, Loss_lbc: 1.09185e-06,Loss_rbc: 1.49866e-07
#  Loss: 1.04067e-05, Loss_PDE: 9.16503e-06, Loss_lbc: 1.09182e-06,Loss_rbc: 1.49852e-07
#  Loss: 1.04062e-05, Loss_PDE: 9.16372e-06, Loss_lbc: 1.09253e-06,Loss_rbc: 1.49941e-07
#  Loss: 1.04019e-05, Loss_PDE: 9.15604e-06, Loss_lbc: 1.09560e-06,Loss_rbc: 1.50293e-07
#  Loss: 1.03925e-05, Loss_PDE: 9.13786e-06, Loss_lbc: 1.10336e-06,Loss_rbc: 1.51247e-07
#  Loss: 1.03915e-05, Loss_PDE: 9.13607e-06, Loss_lbc: 1.10408e-06,Loss_rbc: 1.51330e-07
#  Loss: 1.03890e-05, Loss_PDE: 9.13153e-06, Loss_lbc: 1.10592e-06,Loss_rbc: 1.51539e-07
#  Loss: 1.03802e-05, Loss_PDE: 9.11462e-06, Loss_lbc: 1.11309e-06,Loss_rbc: 1.52463e-07
#  Loss: 1.03789e-05, Loss_PDE: 9.11242e-06, Loss_lbc: 1.11394e-06,Loss_rbc: 1.52549e-07
#  Loss: 1.03787e-05, Loss_PDE: 9.11174e-06, Loss_lbc: 1.11431e-06,Loss_rbc: 1.52607e-07
#  Loss: 1.03724e-05, Loss_PDE: 9.09940e-06, Loss_lbc: 1.11982e-06,Loss_rbc: 1.53231e-07
#  Loss: 1.03565e-05, Loss_PDE: 9.06463e-06, Loss_lbc: 1.13659e-06,Loss_rbc: 1.55277e-07
#  Loss: 1.03557e-05, Loss_PDE: 9.06294e-06, Loss_lbc: 1.13733e-06,Loss_rbc: 1.55399e-07
#  Loss: 1.03518e-05, Loss_PDE: 9.05514e-06, Loss_lbc: 1.14067e-06,Loss_rbc: 1.55952e-07
#  Loss: 1.03331e-05, Loss_PDE: 9.01411e-06, Loss_lbc: 1.15971e-06,Loss_rbc: 1.59326e-07
#  Loss: 1.03323e-05, Loss_PDE: 9.01233e-06, Loss_lbc: 1.16056e-06,Loss_rbc: 1.59442e-07
#  Loss: 1.03312e-05, Loss_PDE: 9.00970e-06, Loss_lbc: 1.16188e-06,Loss_rbc: 1.59615e-07
#  Loss: 1.03253e-05, Loss_PDE: 8.99592e-06, Loss_lbc: 1.16885e-06,Loss_rbc: 1.60550e-07
#  Loss: 1.02995e-05, Loss_PDE: 8.92131e-06, Loss_lbc: 1.21139e-06,Loss_rbc: 1.66781e-07
#  Loss: 1.02990e-05, Loss_PDE: 8.92015e-06, Loss_lbc: 1.21186e-06,Loss_rbc: 1.66944e-07
#  Loss: 1.02955e-05, Loss_PDE: 8.91381e-06, Loss_lbc: 1.21395e-06,Loss_rbc: 1.67764e-07
#  Loss: 1.02923e-05, Loss_PDE: 8.90725e-06, Loss_lbc: 1.21637e-06,Loss_rbc: 1.68705e-07
#  Loss: 1.02914e-05, Loss_PDE: 8.90560e-06, Loss_lbc: 1.21694e-06,Loss_rbc: 1.68849e-07
#  Loss: 1.02914e-05, Loss_PDE: 8.90529e-06, Loss_lbc: 1.21717e-06,Loss_rbc: 1.68924e-07
#  Loss: 1.02912e-05, Loss_PDE: 8.90515e-06, Loss_lbc: 1.21716e-06,Loss_rbc: 1.68904e-07
#  Loss: 1.02912e-05, Loss_PDE: 8.90515e-06, Loss_lbc: 1.21716e-06,Loss_rbc: 1.68902e-07
#  Loss: 1.02912e-05, Loss_PDE: 8.90515e-06, Loss_lbc: 1.21716e-06,Loss_rbc: 1.68902e-07
#  Loss: 1.02904e-05, Loss_PDE: 8.90355e-06, Loss_lbc: 1.21776e-06,Loss_rbc: 1.69068e-07
#  Loss: 1.02903e-05, Loss_PDE: 8.90308e-06, Loss_lbc: 1.21804e-06,Loss_rbc: 1.69149e-07
#  Loss: 1.02903e-05, Loss_PDE: 8.90307e-06, Loss_lbc: 1.21807e-06,Loss_rbc: 1.69150e-07
#  Loss: 1.02903e-05, Loss_PDE: 8.90308e-06, Loss_lbc: 1.21804e-06,Loss_rbc: 1.69152e-07
#  Loss: 1.02903e-05, Loss_PDE: 8.90308e-06, Loss_lbc: 1.21804e-06,Loss_rbc: 1.69149e-07
#  Loss: 1.02897e-05, Loss_PDE: 8.90178e-06, Loss_lbc: 1.21862e-06,Loss_rbc: 1.69304e-07
#  Loss: 1.02867e-05, Loss_PDE: 8.89555e-06, Loss_lbc: 1.22114e-06,Loss_rbc: 1.70002e-07
#  Loss: 1.02802e-05, Loss_PDE: 8.88141e-06, Loss_lbc: 1.22711e-06,Loss_rbc: 1.71676e-07
#  Loss: 1.02794e-05, Loss_PDE: 8.87972e-06, Loss_lbc: 1.22780e-06,Loss_rbc: 1.71850e-07
#  Loss: 1.02776e-05, Loss_PDE: 8.87578e-06, Loss_lbc: 1.22953e-06,Loss_rbc: 1.72314e-07
#  Loss: 1.02664e-05, Loss_PDE: 8.85057e-06, Loss_lbc: 1.24044e-06,Loss_rbc: 1.75376e-07
#  Loss: 1.02654e-05, Loss_PDE: 8.84881e-06, Loss_lbc: 1.24101e-06,Loss_rbc: 1.75555e-07
#  Loss: 1.02641e-05, Loss_PDE: 8.84637e-06, Loss_lbc: 1.24187e-06,Loss_rbc: 1.75858e-07
#  Loss: 1.02546e-05, Loss_PDE: 8.82793e-06, Loss_lbc: 1.24843e-06,Loss_rbc: 1.78241e-07
#  Loss: 1.02541e-05, Loss_PDE: 8.82657e-06, Loss_lbc: 1.24908e-06,Loss_rbc: 1.78441e-07
#  Loss: 1.02509e-05, Loss_PDE: 8.81975e-06, Loss_lbc: 1.25185e-06,Loss_rbc: 1.79272e-07
#  Loss: 1.02466e-05, Loss_PDE: 8.80989e-06, Loss_lbc: 1.25607e-06,Loss_rbc: 1.80586e-07
#  Loss: 1.02459e-05, Loss_PDE: 8.80858e-06, Loss_lbc: 1.25654e-06,Loss_rbc: 1.80733e-07
#  Loss: 1.02451e-05, Loss_PDE: 8.80719e-06, Loss_lbc: 1.25702e-06,Loss_rbc: 1.80917e-07
#  Loss: 1.02388e-05, Loss_PDE: 8.79491e-06, Loss_lbc: 1.26153e-06,Loss_rbc: 1.82383e-07
#  Loss: 1.02381e-05, Loss_PDE: 8.79351e-06, Loss_lbc: 1.26200e-06,Loss_rbc: 1.82547e-07
#  Loss: 1.02378e-05, Loss_PDE: 8.79301e-06, Loss_lbc: 1.26220e-06,Loss_rbc: 1.82631e-07
#  Loss: 1.02345e-05, Loss_PDE: 8.78554e-06, Loss_lbc: 1.26526e-06,Loss_rbc: 1.83696e-07
#  Loss: 1.02199e-05, Loss_PDE: 8.74725e-06, Loss_lbc: 1.28252e-06,Loss_rbc: 1.90105e-07
#  Loss: 1.02197e-05, Loss_PDE: 8.74688e-06, Loss_lbc: 1.28263e-06,Loss_rbc: 1.90160e-07
#  Loss: 1.02186e-05, Loss_PDE: 8.74501e-06, Loss_lbc: 1.28316e-06,Loss_rbc: 1.90396e-07
#  Loss: 1.02132e-05, Loss_PDE: 8.73496e-06, Loss_lbc: 1.28639e-06,Loss_rbc: 1.91830e-07
#  Loss: 1.02129e-05, Loss_PDE: 8.73446e-06, Loss_lbc: 1.28653e-06,Loss_rbc: 1.91925e-07
#  Loss: 1.02133e-05, Loss_PDE: 8.73480e-06, Loss_lbc: 1.28656e-06,Loss_rbc: 1.91907e-07
#  Loss: 1.02129e-05, Loss_PDE: 8.73449e-06, Loss_lbc: 1.28652e-06,Loss_rbc: 1.91911e-07
#  Loss: 1.02129e-05, Loss_PDE: 8.73447e-06, Loss_lbc: 1.28653e-06,Loss_rbc: 1.91923e-07
#  Loss: 1.02129e-05, Loss_PDE: 8.73446e-06, Loss_lbc: 1.28653e-06,Loss_rbc: 1.91925e-07
#  Loss: 1.02128e-05, Loss_PDE: 8.73422e-06, Loss_lbc: 1.28667e-06,Loss_rbc: 1.91957e-07
#  Loss: 1.02124e-05, Loss_PDE: 8.73277e-06, Loss_lbc: 1.28736e-06,Loss_rbc: 1.92239e-07
#  Loss: 1.02095e-05, Loss_PDE: 8.72481e-06, Loss_lbc: 1.29095e-06,Loss_rbc: 1.93786e-07
#  Loss: 1.02093e-05, Loss_PDE: 8.72447e-06, Loss_lbc: 1.29104e-06,Loss_rbc: 1.93796e-07
#  Loss: 1.02096e-05, Loss_PDE: 8.72478e-06, Loss_lbc: 1.29101e-06,Loss_rbc: 1.93803e-07
#  Loss: 1.02093e-05, Loss_PDE: 8.72448e-06, Loss_lbc: 1.29104e-06,Loss_rbc: 1.93799e-07
#  Loss: 1.02093e-05, Loss_PDE: 8.72447e-06, Loss_lbc: 1.29104e-06,Loss_rbc: 1.93796e-07
#  Loss: 1.02093e-05, Loss_PDE: 8.72440e-06, Loss_lbc: 1.29104e-06,Loss_rbc: 1.93829e-07
#  Loss: 1.02092e-05, Loss_PDE: 8.72399e-06, Loss_lbc: 1.29125e-06,Loss_rbc: 1.93956e-07
#  Loss: 1.02091e-05, Loss_PDE: 8.72391e-06, Loss_lbc: 1.29126e-06,Loss_rbc: 1.93944e-07
#  Loss: 1.02091e-05, Loss_PDE: 8.72391e-06, Loss_lbc: 1.29126e-06,Loss_rbc: 1.93944e-07
#  Loss: 1.02091e-05, Loss_PDE: 8.72391e-06, Loss_lbc: 1.29126e-06,Loss_rbc: 1.93944e-07
#  Loss: 1.02090e-05, Loss_PDE: 8.72371e-06, Loss_lbc: 1.29130e-06,Loss_rbc: 1.93974e-07
#  Loss: 1.02087e-05, Loss_PDE: 8.72344e-06, Loss_lbc: 1.29131e-06,Loss_rbc: 1.93979e-07
#  Loss: 1.02088e-05, Loss_PDE: 8.72347e-06, Loss_lbc: 1.29132e-06,Loss_rbc: 1.93986e-07
#  Loss: 1.02087e-05, Loss_PDE: 8.72344e-06, Loss_lbc: 1.29131e-06,Loss_rbc: 1.93979e-07
#  Loss: 1.02089e-05, Loss_PDE: 8.72354e-06, Loss_lbc: 1.29134e-06,Loss_rbc: 1.93995e-07
#  Loss: 1.02087e-05, Loss_PDE: 8.72339e-06, Loss_lbc: 1.29129e-06,Loss_rbc: 1.93974e-07
#  Loss: 1.02088e-05, Loss_PDE: 8.72347e-06, Loss_lbc: 1.29132e-06,Loss_rbc: 1.93993e-07
#  Loss: 1.02087e-05, Loss_PDE: 8.72339e-06, Loss_lbc: 1.29128e-06,Loss_rbc: 1.93976e-07
#  Loss: 1.02087e-05, Loss_PDE: 8.72343e-06, Loss_lbc: 1.29130e-06,Loss_rbc: 1.93968e-07
#  Loss: 1.02087e-05, Loss_PDE: 8.72339e-06, Loss_lbc: 1.29128e-06,Loss_rbc: 1.93976e-07
#  Loss: 1.02089e-05, Loss_PDE: 8.72353e-06, Loss_lbc: 1.29136e-06,Loss_rbc: 1.93995e-07
#  Loss: 1.02086e-05, Loss_PDE: 8.72337e-06, Loss_lbc: 1.29129e-06,Loss_rbc: 1.93974e-07
#  Loss: 1.02088e-05, Loss_PDE: 8.72356e-06, Loss_lbc: 1.29130e-06,Loss_rbc: 1.93989e-07
#  Loss: 1.02087e-05, Loss_PDE: 8.72338e-06, Loss_lbc: 1.29130e-06,Loss_rbc: 1.93977e-07
#  Loss: 1.02086e-05, Loss_PDE: 8.72337e-06, Loss_lbc: 1.29129e-06,Loss_rbc: 1.93974e-07
#  Loss: 1.02088e-05, Loss_PDE: 8.72349e-06, Loss_lbc: 1.29135e-06,Loss_rbc: 1.93999e-07
#  Loss: 1.02087e-05, Loss_PDE: 8.72342e-06, Loss_lbc: 1.29131e-06,Loss_rbc: 1.93974e-07
#  Loss: 1.02087e-05, Loss_PDE: 8.72342e-06, Loss_lbc: 1.29130e-06,Loss_rbc: 1.93975e-07
#  Loss: 1.02086e-05, Loss_PDE: 8.72337e-06, Loss_lbc: 1.29129e-06,Loss_rbc: 1.93974e-07

# %%
#torch.save(model.state_dict(),"Param_model_2.pt")

pde_domain,left_bc,right_bc = data_pde(nobs,space,min_param,max_param)

pde = {"PDE":["de","left_bc","right_bc"], 
       "data_set":{"de" : Variable(pde_domain,requires_grad=True),
                   "left_bc":left_bc,
                   "right_bc" :right_bc}}

llp = llaplace(model,sigma_noise=1, prior_precision=1)
llp.fit(pde=pde, hessian_structure = "full")

# %%
log_prior, log_sigma = torch.ones(1, requires_grad=True), torch.ones(1, requires_grad=True)
#hyper_optimizer = torch.optim.Adam([log_prior, log_sigma], lr=1e-1)
hyper_optimizer = torch.optim.Adam([log_prior], lr=1e-1)
llp.sigma_noise = torch.tensor([0.1*np.sqrt(1/12*(1 + 4) )]).float()

error = 1
logprior,logsigma = [],[]

while  error > 1e-5:
    log_prior_x, log_sigma_x = log_prior.detach().numpy()[0],log_sigma.detach().numpy()[0]

    hyper_optimizer.zero_grad()
    #neg_marglik = - llp.log_marginal_likelihood(log_prior.exp(), log_sigma.exp())
    neg_marglik = - llp.log_marginal_likelihood(log_prior.exp())
    neg_marglik.backward(retain_graph=True)
    hyper_optimizer.step()


    logprior.append(log_prior.detach().numpy()[0])
    logsigma.append(log_sigma.detach().numpy()[0])

    error = abs(log_prior.detach().numpy()[0] - log_prior_x) + abs(log_sigma.detach().numpy()[0]-log_sigma_x)

# %%
fig, axs = plt.subplots(1, 2, figsize=(9, 3))
axs[0].plot(np.exp(logsigma))
axs[0].set_ylim((-0.02,0.2))

axs[1].plot(np.exp(logprior))

# %%
def test_set(max_space,obs,param,mean,std):

    t = np.linspace(0,max_space,obs)

    sol = (t - t**2) / (2*np.exp(param))

    noise_sol_test = sol + np.random.normal(mean,std, len(t))

    return t, noise_sol_test

# %%
param_trained =  samples_param(min_param , max_param,6)
#llp.temperature = torch.tensor(500)

# Plotting
fig = plt.figure(figsize=(25,25))
plt.subplots_adjust(hspace=0.25)

for n,pr in enumerate(param_trained):
    pr=pr+1
    t, noise_sol_test = test_set(ns,50,pr,mean,std)

    data_test = torch.tensor(np.hstack((t.flatten()[:,None], np.ones_like(t).flatten()[:,None]*(pr)))).float()

    u_pred = model(data_test).detach().cpu().numpy()

    f_mu, f_sigma = llp(data_test)

    f_mu, f_sigma= f_mu.cpu().numpy(), f_sigma.squeeze().sqrt().cpu().numpy().reshape(-1,1)

    plt.subplot(8, 2, n + 1)

    plt.plot(t, u_pred, label = fr"Garlekin $\alpha$ = {pr:.1f}", color = "red",linewidth = '3')
    plt.scatter(t,noise_sol_test, label = "Observations",color= "blue",alpha = 0.5)

    plt.plot(t,f_mu,color = "blue", label = f"NN",linewidth=1)
    plt.fill_between(t.reshape(-1), (f_mu+2*f_sigma).reshape(-1),(f_mu-2*f_sigma).reshape(-1),alpha=0.4, color = "red",label = r"NN Uncertainty ($\sigma^{2})$")


    plt.xlabel("t")
    plt.ylabel("u")
    plt.legend(frameon=False)

# %% [markdown]
# ## MCMC Step

# %%
def log_prior_alpha(alpha): #function to evaluate prior pdf of given parameters
    return norm.logpdf(alpha,loc = 0,scale = 1.5)

def proposals(alpha,dt):
    return np.random.normal(alpha,dt)

# %%
def log_likelihood_marginal(surrogate,alpha,t,y_dat,sig = std):
    
    data_ = np.hstack((t.flatten()[:,None], np.ones_like(t).flatten()[:,None]*(alpha)))

    surg_mu, surg_sigma = surrogate(torch.tensor(data_).float())
    surg_mu, surg_sigma = surg_mu.cpu().numpy().reshape(-1),surg_sigma.squeeze().cpu().numpy()
    #return np.sum(-np.log(np.sqrt(2* np.pi*sig)) - ((y_dat-surg)**2) / (2*sig))

    #return np.sum(- ((y_dat-surg_mu)**2) / (2*(sig**2+surg_sigma))) - (0.5)*np.sum(np.log(sig**2+surg_sigma)) -  y_dat.shape[0]*(0.5)*np.log(2*np.pi) 
    return np.sum(- ((y_dat-surg_mu)**2) / (2*(sig**2+surg_sigma)))

def log_likelihood(surrogate,alpha,t,y_dat,sig = std):
    
    data_ = np.hstack((t.flatten()[:,None], np.ones_like(t).flatten()[:,None]*(alpha)))

    surg = surrogate(torch.tensor(data_).float()).detach().cpu().numpy().reshape(-1,)
        
    #return np.sum(-np.log(np.sqrt(2* np.pi*sig)) - ((y_dat-surg)**2) / (2*sig))

    return np.sum(- ((y_dat-surg)**2) / (2*sig**2))

def log_likelihood_ex(alpha,t,y,sig = std):

    surg_exact = (t - t**2) / (2*np.exp(alpha))

    #return np.sum(-np.log(np.sqrt(2* np.pi*sig**2)) - ((y-surg_exact)**2) / (2*sig**2))
    return np.sum(-((y-surg_exact)**2) / (2*sig**2))

# %%
def log_posterior_ex(alpha,t,y):
    return  log_likelihood_ex(alpha,t,y) + log_prior_alpha(alpha)

def log_posterior_nn_marginal(model,alpha,t,y):
    return  log_likelihood_marginal(model,alpha,t,y) + log_prior_alpha(alpha)
#    return  log_likelihood(model,alpha,t,y) 

def log_posterior_nn(model,alpha,t,y):
    return  log_likelihood(model,alpha,t,y) + log_prior_alpha(alpha)

# %%
theta_h = 0.314
t, noise_sol_test = test_set(ns,1000,theta_h,mean,std)

# %%
data_ = np.hstack((t.flatten()[:,None], np.ones_like(t).flatten()[:,None]*(0.5)))

surg_mu, surg_sigma = llp(torch.tensor(data_).float())
surg_mu, surg_sigma = surg_mu.cpu().numpy().reshape(-1),surg_sigma.squeeze().cpu().numpy()

print(np.sum(- ((noise_sol_test-surg_mu)**2) / (2*(std**2+surg_sigma))))

#np.sum(- ((y_dat-surg_mu)**2) / (2*(sig**2+surg_sigma))) - (0.5)*np.sum(np.log(sig**2+surg_sigma)) -  y_dat.shape[0]*(0.5)*np.log(2*np.pi)
# Out:
# -593.1628991991604

# %%
alpha_ = np.linspace(-1,1,200)

alpha_fc,alpha_fc_2,alpha_fc_3 = [],[],[]
alpha_fc_nn,alpha_fc_2_nn,alpha_fc_3_nn = [],[],[]


for alp in alpha_:
    alpha_fc.append(log_posterior_ex(alp,t[:50],noise_sol_test[:50]))
    alpha_fc_nn.append(log_posterior_nn_marginal(llp,alp,t[:50],noise_sol_test[:50]))
    
    alpha_fc_2.append(log_posterior_ex(alp,t[:500],noise_sol_test[:500]))
    alpha_fc_2_nn.append(log_posterior_nn_marginal(llp,alp,t[:500],noise_sol_test[:500]))
    
    alpha_fc_3.append(log_posterior_ex(alp,t,noise_sol_test))
    alpha_fc_3_nn.append(log_posterior_nn_marginal(llp,alp,t,noise_sol_test))

# %%
fig = plt.figure(figsize=(18,8))
plt.subplots_adjust(hspace=0.25)

plt.subplot(2, 2, 1)
plt.plot(alpha_,alpha_fc ,linestyle = '--', label = "100 obs")
plt.plot(alpha_,alpha_fc_2,linestyle = ':', label = "500 obs")
plt.plot(alpha_,alpha_fc_3, label = "all obs")

plt.axvline(x = theta_h, color = 'black', label = 'Real')

plt.title("Exact Solution Estimation")
plt.ylabel("Log-Posterior")
plt.xlabel(r"$\alpha$")
plt.legend(frameon =False)


plt.subplot(2, 2, 2)
plt.plot(alpha_,alpha_fc_nn ,linestyle = '--', label = "100 obs")
plt.plot(alpha_,alpha_fc_2_nn,linestyle = ':', label = "500 obs")
plt.plot(alpha_,alpha_fc_3_nn, label = "all obs")

plt.axvline(x = theta_h, color = 'black', label = 'Real')

plt.title("NN Solution Estimation",color = "red")
plt.ylabel("Log-Posterior")
plt.xlabel(r"$\alpha$")
plt.legend(frameon =False)


plt.subplot(2, 2, 3)
plt.plot(alpha_,200*np.exp(alpha_fc)/np.sum(np.exp(alpha_fc)) ,linestyle = '--', label = "100 obs")
plt.plot(alpha_,200*np.exp(alpha_fc_2)/np.sum(np.exp(alpha_fc_2)),linestyle = ':', label = "500 obs")
plt.plot(alpha_,200*np.exp(alpha_fc_3)/np.sum(np.exp(alpha_fc_3)), label = "all obs")

plt.axvline(x = theta_h, color = 'black', label = 'Real')

plt.title("Exact Solution Estimation")
plt.xlabel(r"$\alpha$")
plt.xlim(0,0.5)
plt.legend(frameon =False)


plt.subplot(2, 2, 4)
plt.plot(alpha_,200*np.exp(alpha_fc_nn)/np.sum(np.exp(alpha_fc_nn)) ,linestyle = '--', label = "100 obs")
plt.plot(alpha_,200*np.exp(alpha_fc_2_nn)/np.sum(np.exp(alpha_fc_2_nn)),linestyle = ':', label = "500 obs")
plt.plot(alpha_,200*np.exp(alpha_fc_3_nn)/np.sum(np.exp(alpha_fc_3_nn)), label = "all obs")

plt.axvline(x = theta_h, color = 'black', label = 'Real')

plt.title("NN Solution Estimation",color = "red")
plt.xlabel(r"$\alpha$")
#plt.xlim(0,0.5)
plt.legend(frameon =False)

# %%
def Metropolis_Hastings_marginal(t,y_dat,nChains, exact = False):

    alpha = 0.5

    alpha_samp = []
    acceptance_rate, dt = 0, 0.5

    dt_tracker = []
    for i in range(nChains):

        log_posterior =  log_posterior_ex(alpha,t,y_dat) if exact else log_posterior_nn_marginal(llp,alpha,t,y_dat)
        #log_posterior = log_posterior_ex(alpha,t,y_dat)

        alpha_proposal = proposals(alpha,dt)

        log_posterior_proposal = log_posterior_ex(alpha_proposal,t,y_dat) if exact else log_posterior_nn_marginal(llp,alpha_proposal,t,y_dat)
        #log_posterior_proposal = log_posterior_ex(alpha_proposal,t,y_dat)

        accept_u = np.random.uniform(0,1)

        ratio = np.exp(log_posterior_proposal-log_posterior, dtype=np.float64)

        a = np.min([1.,ratio])

        if accept_u < a:
            alpha = alpha_proposal
            acceptance_rate += 1
        
        dt = dt + dt*(a - 0.234)/ (i+1) 
        dt_tracker.append(dt)
        alpha_samp.append(alpha)


    print(f"Acceptance Rate: {acceptance_rate/nChains:.3f}")

    return alpha_samp,dt_tracker

# %%
def Metropolis_Hastings(t,y_dat,nChains, exact = False):

    alpha = 0.5

    alpha_samp = []
    acceptance_rate, dt = 0, 0.5

    dt_tracker = []
    for i in range(nChains):

        log_posterior =  log_posterior_ex(alpha,t,y_dat) if exact else log_posterior_nn(model,alpha,t,y_dat)
        #log_posterior = log_posterior_ex(alpha,t,y_dat)

        alpha_proposal = proposals(alpha,dt)

        log_posterior_proposal = log_posterior_ex(alpha_proposal,t,y_dat) if exact else log_posterior_nn(model,alpha_proposal,t,y_dat)
        #log_posterior_proposal = log_posterior_ex(alpha_proposal,t,y_dat)

        accept_u = np.random.uniform(0,1)

        ratio = np.exp(log_posterior_proposal-log_posterior, dtype=np.float64)

        a = np.min([1.,ratio])

        if accept_u < a:
            alpha = alpha_proposal
            acceptance_rate += 1
        
        dt = dt + dt*(a - 0.234)/ (i+1) 
        dt_tracker.append(dt)
        alpha_samp.append(alpha)


    print(f"Acceptance Rate: {acceptance_rate/nChains:.3f}")

    return alpha_samp,dt_tracker

# %%
def acf(x, length=20):
    return np.array([1]+[np.corrcoef(x[:-i], x[i:])[0,1] for i in range(1, length)])

# %%
alpha_samp_marginal,dt_tracker_marginal = Metropolis_Hastings_marginal(t,noise_sol_test,100000)
# Out:
# Acceptance Rate: 0.095

# %%
alpha_samp_true,dt_tracker_true = Metropolis_Hastings_marginal(t,noise_sol_test,100000,exact = True)
# Out:
# Acceptance Rate: 0.084

# %%
alpha_samp,dt_tracker = Metropolis_Hastings(t,noise_sol_test,100000)
# Out:
# Acceptance Rate: 0.088

# %%
import seaborn as sns

fig = plt.figure(figsize=(20,10))
plt.suptitle("Surrogate MCMC")
plt.subplots_adjust(hspace=0.25)

plt.subplot(2, 2, 1)
plt.plot(alpha_samp_marginal)
plt.xlabel("Itaration")
#plt.ylim(0.3,0.35)

plt.subplot(2, 2, 2)
plt.plot(acf(alpha_samp_marginal,200),color = "red")
plt.xlabel(r"$lag$")
plt.ylabel(r"autocorrelation")


plt.subplot(2, 2, 3)
#plt.hist(alpha_samp[200:],color = "orange",alpha = 0.5)
#plt.plot(alpha_,200*np.exp(alpha_fc_3)/np.sum(np.exp(alpha_fc_3)), label = "all obs")
sns.kdeplot(alpha_samp_marginal,bw_adjust=2, label ="marginal")
sns.kdeplot(alpha_samp,bw_adjust=2, label = "mean")
plt.xlabel(r"$\alpha$")
#plt.xlim(0.3,0.32)
plt.legend(frameon=False)

plt.subplot(2, 2, 4)
plt.plot(dt_tracker_marginal,color = "black")
plt.xlabel("Iteration")
# Out:
# Text(0.5, 0, 'Iteration')

# %%
fig = plt.figure(figsize=(20,10))
plt.suptitle("Exact MCMC")

plt.subplots_adjust(hspace=0.25)

plt.subplot(2, 2, 1)
plt.plot(alpha_samp_true)
plt.xlabel("Itaration")
plt.ylim(0.3,0.35)


plt.subplot(2, 2, 2)
plt.plot(acf(alpha_samp_true,200),color = "red")
plt.xlabel(r"$lag$")
plt.ylabel(r"autocorrelation")


plt.subplot(2, 2, 3)
plt.hist(alpha_samp_true[200:],color = "orange",alpha = 0.5)
plt.xlabel(r"$\alpha$")

plt.subplot(2, 2, 4)
plt.plot(dt_tracker_true,color = "black")
plt.xlabel("Iteration")
# Out:
# Text(0.5, 0, 'Iteration')
