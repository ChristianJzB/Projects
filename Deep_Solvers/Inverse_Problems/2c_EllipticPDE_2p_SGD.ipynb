# %%
import torch
from torch.autograd import Variable
from torch.utils.data import DataLoader

from Sampling import MetropolisHastingsSampler
from FEM_Solver import  RootFinder,FEMSolver
from utilities import *

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from GaLa import llaplace
from NN import DNN

#np.random.seed(1234)

# CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")

# %% [markdown]
# # Tiaming Experiment 3
#
# $$-\frac{d}{dx}(e^{k(x,\theta)}\frac{du(x)}{dx}) = 4x, \quad x\in (0,1),\theta \in [-1,1]$$
# $$u(0) = 0, u(1)=2$$
#
# where $k(x,\theta)$ has the following form:
#
# $$
# k(x,\theta) =exp \left( \sum_{n=1}^{2} \sqrt a_{n} \theta_{n} b_{n}(x)  \right)
# $$
#
# where $a_{n} = \frac{8}{w_{n}^{2} + 16}$ and $b_{n} = A_{n}\left(  \text{sin}(w_{n}x) + \frac{w_{n}}{4} \text{cos}(w_{n}x) \right)$, $w_{n}$ is the $n_{th}$ solution of the equation $\text{tan} (w_{n}) = \frac{8w_{n}}{w_{n}^{2}-16}$ and $A_{n}$ is a constant of normalization which makes $\|b_{n}\| = 1$.

# %% [markdown]
# ## Computing Roots

# %%
def tang_eq(x):
    return np.tan(x) - 8*(x/(x**2 - 16))

intervals = [(1,2),(2,3),(3.8,4.1),(4.1,4.6),(4.7,4.8),(7.2,7.3),(7.3,8),(10,10.2),(10.2,11.5),(13,13.2),(14,14.5)]
n = 2

root_finder = RootFinder(n, tang_eq, intervals)
roots = root_finder.find_roots()
root_finder.plot_equation()

print(f"The first {n} roots are: {roots}")

theta_t = np.array([0.09762701, 0.43037873, 0.20552675, 0.08976637, -0.1526904, 0.29178823, -0.12482558, 0.783546, 0.92732552, -0.23311696])
# Out:
# The first 2 roots are: [1.5707963267941523, 2.153747972623023]

# %%
def k_function(data_domain,w=roots):
    
    x = data_domain[:,0].reshape(-1,1)
    theta = data_domain[:,1:].reshape(x.shape[0],-1)

    A = torch.sqrt(1 / ( (1/8)*(5 + (w / 2)**2) +  (torch.sin(2*w) / (4*w))*((w / 4)**2 - 1) - (torch.cos(2*w)/8)))
    
    bn =  A*(torch.sin(w*x) + ((w)/(4))*torch.cos(w*x))

    an = torch.sqrt(8 / (w**2 + 16))

    return torch.sum(an*bn*theta,dim=1)

def de(self,data_domain,k = k_function,roots = torch.tensor(roots,dtype=float).reshape(1,-1)):
    """ The pytorch autograd version of calculating residual """
    u = self(data_domain)

    du = torch.autograd.grad(
        u, data_domain, 
        grad_outputs=torch.ones_like(u),
        retain_graph=True,
        create_graph=True
    )[0]

    k = k(data_domain,roots)
    
    ddu_x = torch.autograd.grad(
        torch.exp(k).reshape(-1,1)*du[:,0].reshape(-1,1),data_domain, 
        grad_outputs=torch.ones_like(du[:,0].reshape(-1,1)),
        retain_graph=True,
        create_graph=True
        )[0]
        
    return ddu_x[:,0].reshape(-1,1) + 4*data_domain[:,0].reshape(-1,1)


def bc_l(self,data_bc):
    u = self(data_bc)
    return u.reshape(-1,1)

def bc_r(self,data_bc):
    u = self(data_bc)
    return u.reshape(-1,1)- 2

DNN.de = de
DNN.bc_l = bc_l
DNN.bc_r = bc_r

# %%
# Number of observations
epochs = 500

N = [150,500,1000,1500]
sample_size = [1,50,75,125,150]
weights = [5,10,20]

lr = 0.01

# %%
# data_parameters = samples_param(3000, nparam=2)
# param_train, param_test = data_parameters[:1500,:],  data_parameters[1500:,:]

# for w in weights:
#     for nobs in N:

#         dataset = dGDataset(size = nobs, param=param_train)

#         x_val,param_val, sol_val = generate_test_data(nobs,param =param_test, vert=30)

#         for ss in sample_size:
#                 layers = [3] + 1*[w] + [1]
                
#                 model = DNN(layers)

#                 dataloader = DataLoader(dataset, batch_size=ss, shuffle=False)

#                 loss = torch.nn.MSELoss(reduction ='mean')

#                 optimizer = torch.optim.SGD(model.parameters(), lr = lr)
#                 #my_lr_scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer=optimizer, gamma=decayRate)

#                 loss_adam = train_adam(dataloader,model, loss, optimizer, epochs,param_val,x_val,sol_val, device)


#                 np.save(f'./Models/SGD_train_w{w}_N{nobs}_batch{ss}.npy', loss_adam[0])
#                 np.save(f'./Models/SGD_test_w{w}_N{nobs}_batch{ss}.npy', loss_adam[1]) 

#                 path = f"./Models/1dElliptic_SGD_PDE2_w{w}_N{nobs}_batch{ss}.pt"
#                 torch.save(model.state_dict(),path)

# %%
w,nobs =  5,1500

plot_loss_dynamics(w, nobs, sample_size, file_prefix="", optimizer="SGD",
                   include_lbfgs=False,adltrain=0.4, adltest=0.4, lbfgsltrain=0.03, lbfgsltest=0.02)

# %% [markdown]
# # Error Analysis

# %%
ntest, vert = 1500, 30

x_test,param_test, sol_test = generate_test_data(ntest, vert=vert)

# %%
path = "./Models/1dElliptic_SGD_PDE2_w{w}_N{nobs}_batch{ss}.pt"

plot_mean_error(weights, sample_size, N, param_test, x_test, sol_test, DNN,path)

# %%
plot_nn_vs_fem(weights, param_test, x_test, sol_test, sample_size,path ,DNN, nobs=500)

# %%
# Define intervals for root finding
intervals = [(1, 2), (2, 3), (3.8, 4.1), (4.1, 4.6), (4.7, 4.8), 
                 (7.2, 7.3), (7.3, 8), (10, 10.2), (10.2, 11.5), 
                 (13, 13.2), (14, 14.5)]
    
def tang_eq(x):
    """Equation for root-finding."""
    return np.tan(x) - 8 * (x / (x**2 - 16))

    # Initialize root finder and find roots (assuming RootFinder class is already implemented)
root_finder = RootFinder(2, tang_eq, intervals)

roots = root_finder.find_roots()

NNpr, grid = 5, 75

results, X, Y = compute_max_error(N, NNpr, roots ,grid=75, 
                  model_dir='./Models/', model_prefix='1dElliptic_SGD_PDE2',batch = 1)

plot_max_errors(N, results, X, Y, NNpr)

# %%
NNpr, grid = 20, 75

results, X, Y = compute_max_error(N, NNpr, roots ,grid=75, 
                  model_dir='./Models/', model_prefix='1dElliptic_SGD_PDE2',batch = 1)

plot_max_errors(N, results, X, Y, NNpr)

# %% [markdown]
# # Generating Artificial Data for Inverse Problem

# %% [markdown]
# # Inverse problem through MCMC

# %%
obs = 15
theta_th=np.array([0.098, 0.430])
mean, var = 0,[1e-5,1e-3,1e-2]


# for vr in var:
#     st = np.sqrt(vr)
#     obs_points, obs_sol = generate_noisy_obs(obs, theta_t=theta_th, mean=mean, std=st,vert=5000)

#     sampler = MetropolisHastingsSampler(obs_points, obs_sol, sig = st,numerical = True, roots=roots, vert=500)

#     samp_num,dt_tracker_num = sampler.run_sampler(n_chains=100000)

#     np.save(f'./Models/FEM_var{vr}_SGD_Samples.npy', samp_num)

#     for nobs in N:
#         layers = [3] + 1*[20] + [1]
#         model = DNN(layers)
#         model.load_state_dict(torch.load(f"./Models/1dElliptic_SGD_PDE2_w20_N{nobs}_batch1.pt"))
#         model.eval()

#         sampler = MetropolisHastingsSampler(obs_points, obs_sol,surrogate=model, sig = st)
#         nsamples, dt_progres = sampler.run_sampler(n_chains=100000)

#         np.save(f'./Models/NN_{nobs}var{vr}_SGD_Samples.npy', nsamples)
# Out:
# Iteration 0, Acceptance Rate: 1.000, Step Size: 0.8830
# Iteration 10000, Acceptance Rate: 0.019, Step Size: 0.1359
# Iteration 20000, Acceptance Rate: 0.025, Step Size: 0.1180
# Iteration 30000, Acceptance Rate: 0.028, Step Size: 0.1089
# Iteration 40000, Acceptance Rate: 0.032, Step Size: 0.1030
# Iteration 50000, Acceptance Rate: 0.034, Step Size: 0.0988
# Iteration 60000, Acceptance Rate: 0.037, Step Size: 0.0955
# Iteration 70000, Acceptance Rate: 0.039, Step Size: 0.0929
# Iteration 80000, Acceptance Rate: 0.041, Step Size: 0.0907
# Iteration 90000, Acceptance Rate: 0.042, Step Size: 0.0887
# Final Acceptance Rate: 0.044
# Iteration 0, Acceptance Rate: 0.000, Step Size: 0.3830
# Iteration 10000, Acceptance Rate: 0.015, Step Size: 0.0661
# Iteration 20000, Acceptance Rate: 0.017, Step Size: 0.0570
# Iteration 30000, Acceptance Rate: 0.019, Step Size: 0.0524
# Iteration 40000, Acceptance Rate: 0.022, Step Size: 0.0493
# Iteration 50000, Acceptance Rate: 0.023, Step Size: 0.0472
# Iteration 60000, Acceptance Rate: 0.025, Step Size: 0.0455
# Iteration 70000, Acceptance Rate: 0.026, Step Size: 0.0441
# Iteration 80000, Acceptance Rate: 0.028, Step Size: 0.0430
# Iteration 90000, Acceptance Rate: 0.029, Step Size: 0.0420
# Final Acceptance Rate: 0.030
# Iteration 0, Acceptance Rate: 1.000, Step Size: 0.8830
# Iteration 10000, Acceptance Rate: 0.004, Step Size: 0.2686
# Iteration 20000, Acceptance Rate: 0.004, Step Size: 0.2290
# Iteration 30000, Acceptance Rate: 0.005, Step Size: 0.2087
# Iteration 40000, Acceptance Rate: 0.005, Step Size: 0.1955
# Iteration 50000, Acceptance Rate: 0.006, Step Size: 0.1858
# Iteration 60000, Acceptance Rate: 0.006, Step Size: 0.1783
# Iteration 70000, Acceptance Rate: 0.006, Step Size: 0.1722
# Iteration 80000, Acceptance Rate: 0.007, Step Size: 0.1671
# Iteration 90000, Acceptance Rate: 0.007, Step Size: 0.1628
# Final Acceptance Rate: 0.007
# Iteration 0, Acceptance Rate: 0.000, Step Size: 0.3830
# Iteration 10000, Acceptance Rate: 0.026, Step Size: 0.0859
# Iteration 20000, Acceptance Rate: 0.033, Step Size: 0.0751
# Iteration 30000, Acceptance Rate: 0.037, Step Size: 0.0696
# Iteration 40000, Acceptance Rate: 0.041, Step Size: 0.0660
# Iteration 50000, Acceptance Rate: 0.044, Step Size: 0.0635
# Iteration 60000, Acceptance Rate: 0.047, Step Size: 0.0615
# Iteration 70000, Acceptance Rate: 0.050, Step Size: 0.0599
# Iteration 80000, Acceptance Rate: 0.051, Step Size: 0.0585
# Iteration 90000, Acceptance Rate: 0.053, Step Size: 0.0574
# Final Acceptance Rate: 0.054
# Iteration 0, Acceptance Rate: 0.000, Step Size: 0.3830
# Iteration 10000, Acceptance Rate: 0
# Iteration 0, Acceptance Rate: 0.000, Step Size: 0.3830
# Iteration 10000, Acceptance Rate: 0.277, Step Size: 0.6433
# Iteration 20000, Acceptance Rate: 0.269, Step Size: 0.6557
# Iteration 30000, Acceptance Rate: 0.266, Step Size: 0.6622
# Iteration 40000, Acceptance Rate: 0.263, Step Size: 0.6658
# Iteration 50000, Acceptance Rate: 0.262, Step Size: 0.6688
# Iteration 60000, Acceptance Rate: 0.261, Step Size: 0.6716
# Iteration 70000, Acceptance Rate: 0.261, Step Size: 0.6738
# Iteration 80000, Acceptance Rate: 0.259, Step Size: 0.6753
# Iteration 90000, Acceptance Rate: 0.259, Step Size: 0.6771
# Final Acceptance Rate: 0.257

# %%
for vr in var:
    samp_num = np.load(f'./Models/FEM_var{vr}_SGD_Samples.npy')

    samples = dict()

    for nobs in N:
        samples[nobs] = np.load(f'./Models/NN_{nobs}var{vr}_SGD_Samples.npy')

    plot_posterior_distributions(samples, N, samp_num,sufix="Var:" + str(vr))

# %%
obs = 100
theta_th=np.array([0.098, 0.430])
mean, var = 0,[1e-5,1e-3,1e-2]


# for vr in var:
#     st = np.sqrt(vr)
#     obs_points, obs_sol = generate_noisy_obs(obs, theta_t=theta_th, mean=mean, std=st,vert=5000)

#     sampler = MetropolisHastingsSampler(obs_points, obs_sol, sig = st,numerical = True, roots=roots, vert=500)

#     samp_num,dt_tracker_num = sampler.run_sampler(n_chains=100000)

#     np.save(f'./Models/FEM_var{vr}_obs150_adam_Samples.npy', samp_num)

#     for nobs in N:
#         layers = [3] + 1*[20] + [1]
#         model = DNN(layers)
#         model.load_state_dict(torch.load(f"./Models/1dElliptic_adam_PDE2_w20_N{nobs}_batch150.pt"))
#         model.eval()

#         sampler = MetropolisHastingsSampler(obs_points, obs_sol,surrogate=model, sig = st)
#         nsamples, dt_progres = sampler.run_sampler(n_chains=100000)

#         np.save(f'./Models/NN_{nobs}var{vr}_obs150_adam_Samples.npy', nsamples)
# Out:
# Iteration 0, Acceptance Rate: 1.000, Step Size: 0.8830
# Iteration 10000, Acceptance Rate: 0.004, Step Size: 0.1309
# Iteration 20000, Acceptance Rate: 0.004, Step Size: 0.1116
# Iteration 30000, Acceptance Rate: 0.005, Step Size: 0.1018
# Iteration 40000, Acceptance Rate: 0.006, Step Size: 0.0954
# Iteration 50000, Acceptance Rate: 0.007, Step Size: 0.0907
# Iteration 60000, Acceptance Rate: 0.007, Step Size: 0.0871
# Iteration 70000, Acceptance Rate: 0.007, Step Size: 0.0841
# Iteration 80000, Acceptance Rate: 0.008, Step Size: 0.0816
# Iteration 90000, Acceptance Rate: 0.008, Step Size: 0.0795
# Final Acceptance Rate: 0.008
# Iteration 0, Acceptance Rate: 0.000, Step Size: 0.3830
# Iteration 10000, Acceptance Rate: 0.001, Step Size: 0.0672
# Iteration 20000, Acceptance Rate: 0.001, Step Size: 0.0572
# Iteration 30000, Acceptance Rate: 0.000, Step Size: 0.0520
# Iteration 40000, Acceptance Rate: 0.000, Step Size: 0.0486
# Iteration 50000, Acceptance Rate: 0.000, Step Size: 0.0461
# Iteration 60000, Acceptance Rate: 0.000, Step Size: 0.0442
# Iteration 70000, Acceptance Rate: 0.000, Step Size: 0.0427
# Iteration 80000, Acceptance Rate: 0.000, Step Size: 0.0413
# Iteration 90000, Acceptance Rate: 0.000, Step Size: 0.0402
# Final Acceptance Rate: 0.000
# Iteration 0, Acceptance Rate: 1.000, Step Size: 0.8830
# Iteration 10000, Acceptance Rate: 0.002, Step Size: 0.1310
# Iteration 20000, Acceptance Rate: 0.002, Step Size: 0.1115
# Iteration 0, Acceptance Rate: 0.000, Step Size: 0.3830
# Iteration 10000, Acceptance Rate: 0.143, Step Size: 0.1128
# Iteration 20000, Acceptance Rate: 0.155, Step Size: 0.1078
# Iteration 30000, Acceptance Rate: 0.162, Step Size: 0.1053
# Iteration 40000, Acceptance Rate: 0.169, Step Size: 0.1038
# Iteration 50000, Acceptance Rate: 0.172, Step Size: 0.1027
# Iteration 60000, Acceptance Rate: 0.175, Step Size: 0.1018
# Iteration 70000, Acceptance Rate: 0.177, Step Size: 0.1011
# Iteration 80000, Acceptance Rate: 0.179, Step Size: 0.1006
# Iteration 90000, Acceptance Rate: 0.180, Step Size: 0.1000
# Final Acceptance Rate: 0.181
# Iteration 0, Acceptance Rate: 1.000, Step Size: 0.8830
# Iteration 10000, Acceptance Rate: 0.066, Step Size: 0.1661
# Iteration 20000, Acceptance Rate: 0.077, Step Size: 0.1500
# Iteration 30000, Acceptance Rate: 0.085, Step Size: 0.1421
# Iteration 40000, Acceptance Rate: 0.091, Step Size: 0.1373
# Iteration 50000, Acceptance Rate: 0.097, Step Size: 0.1338
# Iteration 60000, Acceptance Rate: 0.100, Step Size: 0.1310
# Iteration 70000, Acceptance Rate: 0.104, Step Size: 0.1288
# Iteration 80000, Acceptance Rate: 0.107, Step Size: 0.1270
# Iteration 90000, Acceptance Rate: 0.110, Step Size: 0.1255
# Final Acceptance Rate: 0.113
# Iteration 0, Acceptance Rate: 0.000, Step Size: 0.3830
# Iteration 10000, Acceptance Rate: 0.153, Step Size: 0.1501
# Iteration 20000, Acceptance Rate: 0.163, Step Size: 0.1438
# Iteration 30000, Acceptance Rate: 0.170, Step Size: 0.1409
# Iteration 40000, Acceptance Rate: 0.175, Step Size: 0.1391
# Iteration 50000, Acceptance Rate: 0.177, Step Size: 0.1376
# Iteration 60000, Acceptance Rate: 0.178, Step Size: 0.1364
# Iteration 70000, Acceptance Rate: 0.179, Step Size: 0.1354
# Iteration 80000, Acceptance Rate: 0.181, Step Size: 0.1347
# Iteration 90000, Acceptance Rate: 0.183, Step Size: 0.1342
# Final Acceptance Rate: 0.184
# Iteration 0, Acceptance Rate: 0.000, Step Size: 0.3830
# Iteration 10000, Acceptance Rate: 0.224, Step Size: 0.2898
# Iteration 20000, Acceptance Rate: 0.230, Step Size: 0.2896
# Iteration 30000, Acceptance Rate: 0.229, Step Size: 0.2889
# Iteration 40000, Acceptance Rate: 0.231, Step Size: 0.2890
# Iteration 50000, Acceptance Rate: 0.229, Step Size: 0.2886
# Iteration 60000, Acceptance Rate: 0.229, Step Size: 0.2882
# Iteration 70000, Acceptance Rate: 0.228, Step Size: 0.2879
# Iteration 80000, Acceptance Rate: 0.228, Step Size: 0.2876
# Iteration 90000, Acceptance Rate: 0.227, Step Size: 0.2874
# Final Acceptance Rate: 0.227
# Iteration 0, Acceptance Rate: 0.000, Step Size: 0.3830
# Iteration 10000, Acceptance Rate: 0.196, Step Size: 0.3117
# Iteration 20000, Acceptance Rate: 0.200, Step Size: 0.3058
# Iteration 30000, Acceptance Rate: 0.204, Step Size: 0.3029
# Iteration 40000, Acceptance Rate: 0.205, Step Size: 0.3008
# Iteration 50000, Acceptance Rate: 0.207, Step Size: 0.2995
# Iteration 60000, Acceptance Rate: 0.209, Step Size: 0.2984
# Iteration 70000, Acceptance Rate: 0.209, Step Size: 0.2974
# Iteration 80000, Acceptance Rate: 0.208, Step Size: 0.2964
# Iteration 90000, Acceptance Rate: 0.210, Step Size: 0.2959
# Final Acceptance Rate: 0.210
# Iteration 0, Acceptance Rate: 0.000, Step Size: 0.3830
# Iteration 10000, Acceptance Rate: 0.225, Step Size: 0.2937
# Iteration 20000, Acceptance Rate: 0.230, Step Size: 0.2932
# Iteration 30000, Acceptance Rate: 0.229, Step Size: 0.2927
# Iteration 40000, Acceptance Rate: 0.228, Step Size: 0.2921
# Iteration 50000, Acceptance Rate: 0.228, Step Size: 0.2917
# Iteration 60000, Acceptance Rate: 0.228, Step Size: 0.2914
# Iteration 70000, Acceptance Rate: 0.228, Step Size: 0.2910
# Iteration 80000, Acceptance Rate: 0.229, Step Size: 0.2911
# Iteration 90000, Acceptance Rate: 0.228, Step Size: 0.2909
# Final Acceptance Rate: 0.229
# Iteration 0, Acceptance Rate: 0.000, Step Size: 0.3830
# Iteration 10000, Acceptance Rate: 0.172, Step Size: 0.2511
# Iteration 20000, Acceptance Rate: 0.178, Step Size: 0.2432
# Iteration 30000, Acceptance Rate: 0.182, Step Size: 0.2387
# Iteration 40000, Acceptance Rate: 0.186, Step Size: 0.2362
# Iteration 50000, Acceptance Rate: 0.188, Step Size: 0.2343
# Iteration 60000, Acceptance Rate: 0.191, Step Size: 0.2332
# Iteration 70000, Acceptance Rate: 0.194, Step Size: 0.2322
# Iteration 80000, Acceptance Rate: 0.194, Step Size: 0.2311
# Iteration 90000, Acceptance Rate: 0.194, Step Size: 0.2300
# Final Acceptance Rate: 0.196
# Iteration 0, Acceptance Rate: 0.000, Step Size: 0.3830
# Iteration 10000, Acceptance Rate: 0.181, Step Size: 0.2962
# Iteration 20000, Acceptance Rate: 0.188, Step Size: 0.2877
# Iteration 30000, Acceptance Rate: 0.193, Step Size: 0.2839
# Iteration 40000, Acceptance Rate: 0.194, Step Size: 0.2808
# Iteration 50000, Acceptance Rate: 0.197, Step Size: 0.2790
# Iteration 60000, Acceptance Rate: 0.197, Step Size: 0.2772
# Iteration 70000, Acceptance Rate: 0.198, Step Size: 0.2760
# Iteration 80000, Acceptance Rate: 0.200, Step Size: 0.2752
# Iteration 90000, Acceptance Rate: 0.203, Step Size: 0.2748
# Final Acceptance Rate: 0.203

# %%
for vr in var:
    samp_num = np.load(f'./Models/FEM_var{vr}_obs150_adam_Samples.npy')

    samples = dict()

    for nobs in N:
        samples[nobs] = np.load(f'./Models/NN_{nobs}var{vr}_obs150_adam_Samples.npy')

    plot_posterior_distributions(samples, N, samp_num,sufix="Var:" + str(vr))

# %%
#plot_mcmc_parameters(samples, theta_t, tracker, N, samples[nobs])

# %%
#samples,tracker = dict(),dict()

#samp_num,dt_tracker_num = np.load(f'./Models/FEM_adam_Samples.npy'),np.load(f'./Models/FEM_adam_Step.npy')
# for nobs in N:
#     samples[nobs] = np.load(f'./Models/NN_{nobs}_adam_Samples.npy')
#     tracker[nobs] = np.load(f'./Models/NN_{nobs}_adam_Step.npy')

plot_posterior_distributions(samples, N, samp_num)

# %% [markdown]
# # Inverse Problem with Uncertainty in the Surrogate

# %%
# deepGala = dict()

# layers = [3] + 1*[20] + [1]

# for nobs in N:
#        data_int,left_bc,right_bc = generate_data(nobs)

#        model = DNN(layers)
#        path = f"./Models/1dElliptic_adam_PDE2_w20_N{nobs}_batch150.pt"
#        model.load_state_dict(torch.load(path))
#        model.eval()

#        pde = {"PDE":["de","bc_l","bc_r"], 
#               "data_set":{"de" : Variable(data_int,requires_grad=True),
#                      "bc_l":left_bc,
#                      "bc_r" :right_bc}}

#        llp = llaplace(model)
#        llp.fit(pde=pde, hessian_structure = "full")

#        log_prior, log_sigma = torch.ones(1, requires_grad=True), torch.ones(1, requires_grad=True)
#        hyper_optimizer = torch.optim.Adam([log_prior, log_sigma], lr=1e-1)
       
#        for i in range(5000):
#               hyper_optimizer.zero_grad()
#               neg_marglik = - llp.log_marginal_likelihood(log_prior.exp(), log_sigma.exp())
#               neg_marglik.backward(retain_graph=True)
#               hyper_optimizer.step()
#        deepGala[str(nobs)] = llp

# %%
# # Plotting
# fig = plt.figure(figsize=(25,25))
# plt.subplots_adjust(hspace=0.25)
# colors = ["blue","orange","green"]

# for n,(pr1) in enumerate(param_test[:4]):

#     data_test = torch.tensor(np.hstack((x_test, np.ones((x_test.shape[0],pr1.shape[0]))*(pr1)))).float()
#     numerical_sol = sol_test[n,:]

#     plt.subplot(8, 2, n + 1)
#     llp = deepGala[str(N[-1])]

#     u_mean, u_sigma = llp(data_test)
#     u_mean, u_sigma = u_mean.detach().cpu().numpy(), u_sigma[:,:,0].sqrt().detach().cpu().numpy()
#     numerical_sol = numerical_sol.reshape(u_mean.shape)

#     plt.scatter(x_test, u_mean, label = fr"NN_training_{1500}",alpha=0.6 )
#     plt.fill_between(x_test.reshape(-1), (u_mean+2*u_sigma).reshape(-1),(u_mean-2*u_sigma).reshape(-1),alpha=0.4, color = "red",label = r"NN Uncertainty ($\sigma^{2})$")

#     plt.plot(x_test, numerical_sol, label = "Numerical Solution")

#     plt.title(fr"Parameters: $\theta_{1}$ = {pr1[0]:.1g} and  $\theta_{2}$ = {pr1[1]:.1g}")
#     plt.xlabel("x")
#     plt.ylabel("u")
#     plt.legend(frameon=False)

# %%
samples_dg,tracker_dg = dict(),dict()

# for nob in N:
#     dgl = deepGala[str(nob)]

#     sampler = MetropolisHastingsSampler(obs_points, obs_sol,surrogate=dgl ,sig = std,mean = False)
#     alpha_samples, dt_progression = sampler.run_sampler(n_chains=100000)
#     samples_dg[nob], tracker_dg[nob] = alpha_samples,dt_progression
#     np.save(f'./Models/dgl_{nob}_adam_Samples.npy', samples_dg[nob])
#     np.save(f'./Models/dgl_{nob}_adam_Step.npy', tracker_dg[nob])

for nob in N:
    samples_dg[nob]= np.load(f'./Models/dgl_{nob}_adam_Samples.npy')
    tracker_dg[nob] = np.load(f'./Models/dgl_{nob}_adam_Step.npy')

# %%
plot_posterior_distributions(samples, N, samp_num)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 plot_posterior_distributions(samples, N, samp_num)
#
# File ~/Projects-1/Deep_Solvers/Inverse_Problems/utilities.py:390, in plot_posterior_distributions(samples, nobs, samp_num)
#     388 # Plotting for parameter 1
#     389 for obs in nobs:
# --> 390     sns.kdeplot(samples[obs][:, 0],  bw_adjust=2,label=f"NN({str(obs)})", ax=axs[0])
#     392 sns.kdeplot(samp_num[:, 0], label="FEM", color="black", linestyle="--", bw_adjust=2, linewidth=0.75, ax=axs[0])
#     393 axs[0].set_xlabel(r"$\theta_{1}$")
#
# KeyError: 150

# %%
plot_posterior_distributions(samples_dg, N, samp_num)
