# %%
import torch
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset

from collections import OrderedDict

import numpy as np
import matplotlib.pyplot as plt


import os
import re


os.chdir("/home/s2113174/Projects-1")

np.random.seed(1234)

# CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")

# %% [markdown]
# ## Making the data for an Inverse Problem following the ODE
#
# $$\frac{du}{dt} - cos(2\pi t)=0$$
#
# with solution
# $$ u(t) = \frac{sin ( 2 \pi t )}{2 \pi} + 1$$
#
# ## The Inverse parametric equation will be
#
# $$\frac{du}{dt} - \alpha cos( 2 \pi t)=0$$

# %%
t= np.linspace(0,3,1000)
mean, std = 0,0.05

Exact = (1/ (2*np.pi))*np.sin(2*np.pi*t)+1

noise_sol = Exact + np.random.normal(mean,std, len(t))

plt.scatter(t,noise_sol)
plt.xlabel("T")
plt.ylabel("Observations")
# Out:
# Text(0, 0.5, 'Observations')

# %% [markdown]
# ## Feed Forward Neural Network

# %%
# the deep neural network
class DNN(torch.nn.Module):
    def __init__(self, layers):
        super(DNN, self).__init__()
        
        # parameters
        self.depth = len(layers) - 1
        
        # set up layer order dict
        self.activation = torch.nn.Tanh
        
        layer_list = list()
        for i in range(self.depth - 1): 
            layer_list.append(
                ('layer_%d' % i, torch.nn.Linear(layers[i], layers[i+1]))
            )
            layer_list.append(('activation_%d' % i, self.activation()))
            
        layer_list.append(
            ('layer_%d' % (self.depth - 1), torch.nn.Linear(layers[-2], layers[-1]))
        )
        layerDict = OrderedDict(layer_list)
        
        # deploy layers
        self.layers = torch.nn.Sequential(layerDict)

    def forward(self, x):
        out = self.layers(x)
        return out

# %% [markdown]
# ## PINN for Inverse Problems

# %%
def register_parameters(self,alpha,alpha_name):

    for param,name in zip(alpha, alpha_name):
        _param = torch.nn.Parameter(torch.tensor(param, requires_grad=True).reshape(-1).float().to(device))

        #if re.compile("weight").search(name):
        #    _param = torch.clamp(_param,0,1)
    
        setattr(self, name, _param)
        self.register_parameter(name, getattr(self,name))

def clamp_weights(self,param_names):
    pr = torch.clamp(self.weight_eps,0,1).to(device)
    self.weight_eps = torch.nn.Parameter(pr).to(device)
    #for pnames in param_names:
    #    if hasattr(self, pnames):
    #        pr = torch.clamp(getattr(self,pnames),0,1)
    #        setattr(self, pnames,pr)        
        

def PINN(self,t):
    """ The pytorch autograd version of calculating residual """
    u = self(t)
    
    u_t = torch.autograd.grad(
        u, t, 
        grad_outputs=torch.ones_like(u),
        retain_graph=True,
        create_graph=True
    )[0]
    
    f = u_t - self.alpha*torch.cos( 2*torch.pi *t)
    return f

# %%
DNN.register_parameters = register_parameters
#DNN.clamp_weights = clamp_weights
DNN.PINN = PINN
weight_eps = 0.3

# %%
def train(pinn, loss, optimizer,data_loader,epochs, weighting = False):
  pinn.train()

  print("Starting Training")

  for epoch in range(epochs):
    itr_loss = 0.0   

    for _,(X,y) in enumerate(data_loader):
      iter = 0

      X, y = Variable(X, requires_grad=True), Variable(y)

      def loss_func_train():

        optimizer.zero_grad()

        u_pred,f_pred = pinn(X),pinn.PINN(X)

        loss_u,loss_f = loss(u_pred,y),loss(f_pred,torch.zeros_like(y))

        if weighting:
          Loss = weight_eps * loss_u + (1 - weight_eps) * loss_f
        else:
          Loss = loss_u + loss_f
          
        Loss.backward() 
        
        #with torch.no_grad():
        #torch.nn.utils.clip_grad
        #  pinn.weight_eps.clamp_(0, 1)


        if iter % 100 == 0:
          if weighting:
              print(
                'Iter %d, Loss: %.5e, Loss_u: %.5e, Loss_f: %.5e, Alpha:%.3f' % (iter, Loss.item(), loss_u.item(), loss_f.item(),
                                                                                           pinn.alpha.item())
                  )
          else:
              print(
                'Iter %d, Loss: %.5e, Loss_u: %.5e, Loss_f: %.5e, Alpha:%.3f' % (iter, Loss.item(), loss_u.item(), loss_f.item(),pinn.alpha.item())
                  )
          
        return Loss

      optimizer.step(loss_func_train) 

      iter += 1
     
      oupt = pinn(X)  

      loss_val = loss_func_train() 

      itr_loss += loss_val.item()  

    print("iteration = %4d   loss = %0.4f" % (epoch + 1, itr_loss))

# %%
# Number of observations
nobs = 500
lr = 0.1
epochs = 10

layers = [1]+2*[12] +[1]

data_training = np.hstack((t.flatten()[:,None], noise_sol.flatten()[:,None]))

idx = np.random.choice(data_training.shape[0], nobs, replace=False)

X_u_train = torch.from_numpy(data_training[idx, :]).float().to(device)

x,y = X_u_train[:,0:1].reshape(-1,1),X_u_train[:,1:2].reshape(-1,1)

X_u_train = TensorDataset(x,y)
X_u_train = DataLoader(X_u_train,batch_size=100)

# %%
plt.scatter(x,y,linestyle='dashed', label = "Observations",color= "orange")

plt.xlabel("T")
plt.ylabel("Y")
plt.legend(frameon=False)

# %%
model = DNN(layers)
#model.register_parameters(np.array([0.5,0.5]),np.array(["alpha","weight_eps"]))
model.register_parameters(np.array([0.5]),np.array(["alpha"]))
#model.clamp_weights("weight_eps")

# %%
loss = torch.nn.MSELoss(reduction ='mean')

optimizer = torch.optim.LBFGS(
    model.parameters(), lr=lr, max_iter=50000, max_eval=None, tolerance_grad=1e-5, tolerance_change=1.0 * np.finfo(float).eps,line_search_fn="strong_wolfe" 
    )

# %%
train(model, loss, optimizer,X_u_train,epochs,True)
# Out:
# Starting Training
# Iter 0, Loss: 3.84739e-01, Loss_u: 9.87142e-01, Loss_f: 1.26566e-01, Alpha:0.500
# Iter 0, Loss: 3.70475e-01, Loss_u: 9.44101e-01, Loss_f: 1.24635e-01, Alpha:0.496
# Iter 0, Loss: 2.56339e-01, Loss_u: 6.00823e-01, Loss_f: 1.08702e-01, Alpha:0.464
# Iter 0, Loss: 2.10075e-01, Loss_u: 4.71446e-01, Loss_f: 9.80593e-02, Alpha:0.440
# Iter 0, Loss: 4.24552e-02, Loss_u: 2.84933e-02, Loss_f: 4.84389e-02, Alpha:0.271
# Iter 0, Loss: 4.04658e-02, Loss_u: 2.82073e-02, Loss_f: 4.57195e-02, Alpha:0.262
# Iter 0, Loss: 2.53554e-02, Loss_u: 2.57929e-02, Loss_f: 2.51680e-02, Alpha:0.181
# Iter 0, Loss: 2.19179e-02, Loss_u: 2.46750e-02, Loss_f: 2.07363e-02, Alpha:0.162
# Iter 0, Loss: 6.34177e-03, Loss_u: 1.82471e-02, Loss_f: 1.23951e-03, Alpha:-0.010
# Iter 0, Loss: 6.22187e-03, Loss_u: 1.80474e-02, Loss_f: 1.15379e-03, Alpha:-0.010
# Iter 0, Loss: 5.47202e-03, Loss_u: 1.66938e-02, Loss_f: 6.62707e-04, Alpha:-0.012
# Iter 0, Loss: 5.41092e-03, Loss_u: 1.66098e-02, Loss_f: 6.11379e-04, Alpha:-0.011
# Iter 0, Loss: 5.13400e-03, Loss_u: 1.59873e-02, Loss_f: 4.82581e-04, Alpha:-0.000
# Iter 0, Loss: 5.12510e-03, Loss_u: 1.59824e-02, Loss_f: 4.71998e-04, Alpha:-0.000
# Iter 0, Loss: 5.08865e-03, Loss_u: 1.59653e-02, Loss_f: 4.27216e-04, Alpha:0.001
# Iter 0, Loss: 5.05858e-03, Loss_u: 1.59553e-02, Loss_f: 3.88549e-04, Alpha:0.002
# Iter 0, Loss: 4.88957e-03, Loss_u: 1.58876e-02, Loss_f: 1.76149e-04, Alpha:0.005
# Iter 0, Loss: 4.88098e-03, Loss_u: 1.58846e-02, Loss_f: 1.65145e-04, Alpha:0.005
# Iter 0, Loss: 4.83606e-03, Loss_u: 1.58639e-02, Loss_f: 1.09819e-04, Alpha:0.001
# Iter 0, Loss: 4.83538e-03, Loss_u: 1.58679e-02, Loss_f: 1.07164e-04, Alpha:0.001
# Iter 0, Loss: 4.83314e-03, Loss_u: 1.58858e-02, Loss_f: 9.62703e-05, Alpha:0.000
# Iter 0, Loss: 4.83295e-03, Loss_u: 1.58881e-02, Loss_f: 9.50168e-05, Alpha:-0.000
# Iter 0, Loss: 4.83205e-03, Loss_u: 1.59090e-02, Loss_f: 8.47830e-05, Alpha:-0.001
# Iter 0, Loss: 4.83203e-03, Loss_u: 1.59093e-02, Loss_f: 8.46391e-05, Alpha:-0.001
# Iter 0, Loss: 4.83194e-03, Loss_u: 1.59105e-02, Loss_f: 8.39959e-05, Alpha:-0.001
# Iter 0, Loss: 4.83162e-03, Loss_u: 1.59155e-02, Loss_f: 8.13671e-05, Alpha:-0.001
# Iter 0, Loss: 4.83140e-03, Loss_u: 1.59169e-02, Loss_f: 8.04764e-05, Alpha:-0.001
# Iter 0, Loss: 4.82988e-03, Loss_u: 1.59282e-02, Loss_f: 7.34639e-05, Alpha:-0.001
# Iter 0, Loss: 4.82947e-03, Loss_u: 1.59291e-02, Loss_f: 7.24806e-05, Alpha:-0.001
# Iter 0, Loss: 4.82786e-03, Loss_u: 1.59320e-02, Loss_f: 6.89561e-05, Alpha:-0.001
# Iter 0, Loss: 4.82721e-03, Loss_u: 1.59312e-02, Loss_f: 6.83670e-05, Alpha:-0.001
# Iter 0, Loss: 4.82439e-03, Loss_u: 1.59193e-02, Loss_f: 6.94121e-05, Alpha:-0.001
# Iter 0, Loss: 4.82424e-03, Loss_u: 1.59200e-02, Loss_f: 6.89007e-05, Alpha:-0.001
# Iter 0, Loss: 4.82411e-03, Loss_u: 1.59202e-02, Loss_f: 6.86476e-05, Alpha:-0.001
# Iter 0, Loss: 4.82400e-03, Loss_u: 1.59200e-02, Loss_f: 6.85572e-05, Alpha:-0.001
# Iter 0, Loss: 4.82353e-03, Loss_u: 1.59184e-02, Loss_f: 6.85766e-05, Alpha:-0.000
# Iter 0, Loss: 4.82353e-03, Loss_u: 1.59185e-02, Loss_f: 6.85528e-05, Alpha:-0.000
# Iter 0, Loss: 4.82353e-03, Loss_u: 1.59184e-02, Loss_f: 6.85749e-05, Alpha:-0.000
# Iter 0, Loss: 4.82352e-03, Loss_u: 1.59182e-02, Loss_f: 6.86535e-05, Alpha:-0.000
# Iter 0, Loss: 4.82352e-03, Loss_u: 1.59181e-02, Loss_f: 6.86865e-05, Alpha:-0.000
# Iter 0, Loss: 4.82352e-03, Loss_u: 1.59178e-02, Loss_f: 6.88383e-05, Alpha:-0.000
# Iter 0, Loss: 4.82352e-03, Loss_u: 1.59177e-02, Loss_f: 6.88645e-05, Alpha:-0.000
# Iter 0, Loss: 4.82352e-03, Loss_u: 1.59178e-02, Loss_f: 6.88405e-05, Alpha:-0.000
# Iter 0, Loss: 4.82352e-03, Loss_u: 1.59178e-02, Loss_f: 6.88385e-05, Alpha:-0.000
# Iter 0, Loss: 4.82352e-03, Loss_u: 1.59178e-02, Loss_f: 6.88383e-05, Alpha:-0.000
# Iter 0, Loss: 4.40786e-03, Loss_u: 1.45232e-02, Loss_f: 7.27294e-05, Alpha:-0.000
# Iter 0, Loss: 4.36855e-03, Loss_u: 1.43670e-02, Loss_f: 8.34848e-05, Alpha:-0.001
# Iter 0, Loss: 4.33507e-03, Loss_u: 1.42357e-02, Loss_f: 9.19453e-05, Alpha:-0.001
# Iter 0, Loss: 4.30310e-03, Loss_u: 1.41201e-02, Loss_f: 9.58262e-05, Alpha:-0.001
# Iter 0, Loss: 4.27643e-03, Loss_u: 1.40095e-02, Loss_f: 1.05120e-04, Alpha:-0.001
# Iter 0, Loss: 4.26066e-03, Loss_u: 1.39460e-02, Loss_f: 1.09806e-04, Alpha:-0.001
# Iter 0, Loss: 4.24841e-03, Loss_u: 1.38943e-02, Loss_f: 1.14443e-04, Alpha:-0.001
# Iter 0, Loss: 4.23851e-03, Loss_u: 1.38515e-02, Loss_f: 1.18645e-04, Alpha:-0.001
# Iter 0, Loss: 4.23049e-03, Loss_u: 1.38156e-02, Loss_f: 1.22567e-04, Alpha:-0.001
# Iter 0, Loss: 4.22401e-03, Loss_u: 1.37856e-02, Loss_f: 1.26190e-04, Alpha:-0.001
# Iter 0, Loss: 4.21876e-03, Loss_u: 1.37603e-02, Loss_f: 1.29538e-04, Alpha:-0.001
# Iter 0, Loss: 4.21451e-03, Loss_u: 1.37389e-02, Loss_f: 1.32619e-04, Alpha:-0.001
# Iter 0, Loss: 4.21107e-03, Loss_u: 1.37209e-02, Loss_f: 1.35449e-04, Alpha:-0.001
# Iter 0, Loss: 4.20829e-03, Loss_u: 1.37055e-02, Loss_f: 1.38042e-04, Alpha:-0.001
# Iter 0, Loss: 4.20604e-03, Loss_u: 1.36925e-02, Loss_f: 1.40413e-04, Alpha:-0.001
# Iter 0, Loss: 4.20422e-03, Loss_u: 1.36814e-02, Loss_f: 1.42578e-04, Alpha:-0.001
# Iter 0, Loss: 4.20275e-03, Loss_u: 1.36719e-02, Loss_f: 1.44551e-04, Alpha:-0.001
# Iter 0, Loss: 4.20155e-03, Loss_u: 1.36637e-02, Loss_f: 1.46347e-04, Alpha:-0.001
# Iter 0, Loss: 4.20058e-03, Loss_u: 1.36567e-02, Loss_f: 1.47980e-04, Alpha:-0.001
# Iter 0, Loss: 4.19980e-03, Loss_u: 1.36506e-02, Loss_f: 1.49463e-04, Alpha:-0.001
# Iter 0, Loss: 4.19917e-03, Loss_u: 1.36453e-02, Loss_f: 1.50809e-04, Alpha:-0.001
# Iter 0, Loss: 4.19865e-03, Loss_u: 1.36408e-02, Loss_f: 1.52028e-04, Alpha:-0.001
# Iter 0, Loss: 4.19824e-03, Loss_u: 1.36368e-02, Loss_f: 1.53133e-04, Alpha:-0.001
# Iter 0, Loss: 4.19691e-03, Loss_u: 1.36205e-02, Loss_f: 1.58244e-04, Alpha:-0.001
# Iter 0, Loss: 4.19682e-03, Loss_u: 1.36190e-02, Loss_f: 1.58758e-04, Alpha:-0.001
# Iter 0, Loss: 4.19655e-03, Loss_u: 1.36126e-02, Loss_f: 1.61107e-04, Alpha:-0.001
# Iter 0, Loss: 4.19654e-03, Loss_u: 1.36120e-02, Loss_f: 1.61338e-04, Alpha:-0.001
# Iter 0, Loss: 4.19648e-03, Loss_u: 1.36094e-02, Loss_f: 1.62372e-04, Alpha:-0.001
# Iter 0, Loss: 4.19648e-03, Loss_u: 1.36091e-02, Loss_f: 1.62476e-04, Alpha:-0.001
# Iter 0, Loss: 4.19647e-03, Loss_u: 1.36090e-02, Loss_f: 1.62544e-04, Alpha:-0.001
# Iter 0, Loss: 4.19647e-03, Loss_u: 1.36088e-02, Loss_f: 1.62629e-04, Alpha:-0.001
# Iter 0, Loss: 4.19647e-03, Loss_u: 1.36085e-02, Loss_f: 1.62728e-04, Alpha:-0.001
# Iter 0, Loss: 4.19647e-03, Loss_u: 1.36084e-02, Loss_f: 1.62794e-04, Alpha:-0.001
# Iter 0, Loss: 4.19646e-03, Loss_u: 1.36077e-02, Loss_f: 1.63094e-04, Alpha:-0.001
# Iter 0, Loss: 4.19646e-03, Loss_u: 1.36076e-02, Loss_f: 1.63124e-04, Alpha:-0.001
# Iter 0, Loss: 4.19646e-03, Loss_u: 1.36076e-02, Loss_f: 1.63136e-04, Alpha:-0.001
# Iter 0, Loss: 3.86215e-03, Loss_u: 1.24317e-02, Loss_f: 1.89487e-04, Alpha:-0.001
# Iter 0, Loss: 3.86214e-03, Loss_u: 1.24318e-02, Loss_f: 1.89418e-04, Alpha:-0.001
# Iter 0, Loss: 3.86213e-03, Loss_u: 1.24320e-02, Loss_f: 1.89321e-04, Alpha:-0.001
# Iter 0, Loss: 3.86202e-03, Loss_u: 1.24334e-02, Loss_f: 1.88573e-04, Alpha:-0.001
# Iter 0, Loss: 3.86170e-03, Loss_u: 1.24381e-02, Loss_f: 1.86096e-04, Alpha:-0.001
# Iter 0, Loss: 3.86103e-03, Loss_u: 1.24413e-02, Loss_f: 1.83765e-04, Alpha:-0.001
# Iter 0, Loss: 3.85607e-03, Loss_u: 1.24705e-02, Loss_f: 1.64153e-04, Alpha:-0.000
# Iter 0, Loss: 3.85400e-03, Loss_u: 1.24756e-02, Loss_f: 1.59022e-04, Alpha:-0.000
# Iter 0, Loss: 3.83960e-03, Loss_u: 1.25191e-02, Loss_f: 1.19803e-04, Alpha:0.001
# Iter 0, Loss: 3.83631e-03, Loss_u: 1.25204e-02, Loss_f: 1.14544e-04, Alpha:0.001
# Iter 0, Loss: 3.81441e-03, Loss_u: 1.25280e-02, Loss_f: 8.00112e-05, Alpha:0.003
# Iter 0, Loss: 3.81176e-03, Loss_u: 1.25244e-02, Loss_f: 7.77662e-05, Alpha:0.003
# Iter 0, Loss: 3.79878e-03, Loss_u: 1.25087e-02, Loss_f: 6.59507e-05, Alpha:0.004
# Iter 0, Loss: 3.79815e-03, Loss_u: 1.25106e-02, Loss_f: 6.42361e-05, Alpha:0.004
# Iter 0, Loss: 3.79562e-03, Loss_u: 1.25189e-02, Loss_f: 5.70532e-05, Alpha:0.003
# Iter 0, Loss: 3.79381e-03, Loss_u: 1.25206e-02, Loss_f: 5.37772e-05, Alpha:0.003
# Iter 0, Loss: 3.78279e-03, Loss_u: 1.25170e-02, Loss_f: 3.95651e-05, Alpha:0.000
# Iter 0, Loss: 3.78184e-03, Loss_u: 1.25129e-02, Loss_f: 3.99632e-05, Alpha:0.000
# Iter 0, Loss: 3.78078e-03, Loss_u: 1.25087e-02, Loss_f: 4.02383e-05, Alpha:0.000
# Iter 0, Loss: 3.77785e-03, Loss_u: 1.24742e-02, Loss_f: 5.08506e-05, Alpha:0.000
# Iter 0, Loss: 3.77765e-03, Loss_u: 1.24752e-02, Loss_f: 5.01098e-05, Alpha:0.001
# Iter 0, Loss: 3.77662e-03, Loss_u: 1.24850e-02, Loss_f: 4.44516e-05, Alpha:0.001
# Iter 0, Loss: 3.77656e-03, Loss_u: 1.24846e-02, Loss_f: 4.45277e-05, Alpha:0.002
# Iter 0, Loss: 3.77636e-03, Loss_u: 1.24828e-02, Loss_f: 4.50191e-05, Alpha:0.002
# Iter 0, Loss: 3.77634e-03, Loss_u: 1.24827e-02, Loss_f: 4.50526e-05, Alpha:0.002
# Iter 0, Loss: 3.77631e-03, Loss_u: 1.24824e-02, Loss_f: 4.51364e-05, Alpha:0.002
# Iter 0, Loss: 3.77630e-03, Loss_u: 1.24823e-02, Loss_f: 4.51335e-05, Alpha:0.002
# Iter 0, Loss: 3.77628e-03, Loss_u: 1.24823e-02, Loss_f: 4.51343e-05, Alpha:0.002
# Iter 0, Loss: 3.77626e-03, Loss_u: 1.24823e-02, Loss_f: 4.51055e-05, Alpha:0.002
# Iter 0, Loss: 3.77623e-03, Loss_u: 1.24824e-02, Loss_f: 4.50047e-05, Alpha:0.002
# Iter 0, Loss: 3.77622e-03, Loss_u: 1.24825e-02, Loss_f: 4.49738e-05, Alpha:0.002
# Iter 0, Loss: 3.77621e-03, Loss_u: 1.24827e-02, Loss_f: 4.48441e-05, Alpha:0.002
# Iter 0, Loss: 3.77621e-03, Loss_u: 1.24828e-02, Loss_f: 4.48148e-05, Alpha:0.002
# Iter 0, Loss: 3.77620e-03, Loss_u: 1.24831e-02, Loss_f: 4.46862e-05, Alpha:0.002
# Iter 0, Loss: 3.77620e-03, Loss_u: 1.24831e-02, Loss_f: 4.46618e-05, Alpha:0.002
# Iter 0, Loss: 3.77620e-03, Loss_u: 1.24834e-02, Loss_f: 4.45535e-05, Alpha:0.002
# Iter 0, Loss: 3.77620e-03, Loss_u: 1.24834e-02, Loss_f: 4.45333e-05, Alpha:0.002
# Iter 0, Loss: 3.77620e-03, Loss_u: 1.24834e-02, Loss_f: 4.45315e-05, Alpha:0.002
# Iter 0, Loss: 3.77620e-03, Loss_u: 1.24834e-02, Loss_f: 4.45315e-05, Alpha:0.002
# Iter 0, Loss: 3.77620e-03, Loss_u: 1.24834e-02, Loss_f: 4.45315e-05, Alpha:0.002
# Iter 0, Loss: 3.77620e-03, Loss_u: 1.24834e-02, Loss_f: 4.45315e-05, Alpha:0.002
# Iter 0, Loss: 3.77620e-03, Loss_u: 1.24835e-02, Loss_f: 4.45134e-05, Alpha:0.002
# Iter 0, Loss: 3.77620e-03, Loss_u: 1.24835e-02, Loss_f: 4.45132e-05, Alpha:0.002
# Iter 0, Loss: 3.77620e-03, Loss_u: 1.24835e-02, Loss_f: 4.45132e-05, Alpha:0.002
# Iter 0, Loss: 3.77620e-03, Loss_u: 1.24835e-02, Loss_f: 4.45132e-05, Alpha:0.002
# Iter 0, Loss: 3.77620e-03, Loss_u: 1.24835e-02, Loss_f: 4.44968e-05, Alpha:0.002
# Iter 0, Loss: 3.77620e-03, Loss_u: 1.24835e-02, Loss_f: 4.44917e-05, Alpha:0.002
# Iter 0, Loss: 3.77620e-03, Loss_u: 1.24835e-02, Loss_f: 4.44916e-05, Alpha:0.002
# Iter 0, Loss: 3.77620e-03, Loss_u: 1.24835e-02, Loss_f: 4.44916e-05, Alpha:0.002
# Iter 0, Loss: 3.77620e-03, Loss_u: 1.24835e-02, Loss_f: 4.44916e-05, Alpha:0.002
# Iter 0, Loss: 3.77620e-03, Loss_u: 1.24835e-02, Loss_f: 4.44917e-05, Alpha:0.002
# Iter 0, Loss: 3.77620e-03, Loss_u: 1.24835e-02, Loss_f: 4.44916e-05, Alpha:0.002
# Iter 0, Loss: 4.37614e-03, Loss_u: 1.44633e-02, Loss_f: 5.30752e-05, Alpha:0.002
# Iter 0, Loss: 4.37146e-03, Loss_u: 1.44298e-02, Loss_f: 6.07258e-05, Alpha:0.002
# Iter 0, Loss: 4.36878e-03, Loss_u: 1.44082e-02, Loss_f: 6.61552e-05, Alpha:0.002
# Iter 0, Loss: 4.36684e-03, Loss_u: 1.43904e-02, Loss_f: 7.10216e-05, Alpha:0.001
# Iter 0, Loss: 4.36537e-03, Loss_u: 1.43754e-02, Loss_f: 7.53550e-05, Alpha:0.001
# Iter 0, Loss: 4.36424e-03, Loss_u: 1.43626e-02, Loss_f: 7.92168e-05, Alpha:0.001
# Iter 0, Loss: 4.36334e-03, Loss_u: 1.43516e-02, Loss_f: 8.26723e-05, Alpha:0.001
# Iter 0, Loss: 4.36264e-03, Loss_u: 1.43420e-02, Loss_f: 8.57746e-05, Alpha:0.001
# Iter 0, Loss: 4.36207e-03, Loss_u: 1.43336e-02, Loss_f: 8.85678e-05, Alpha:0.000
# Iter 0, Loss: 4.36161e-03, Loss_u: 1.43262e-02, Loss_f: 9.10878e-05, Alpha:0.000
# Iter 0, Loss: 4.36125e-03, Loss_u: 1.43196e-02, Loss_f: 9.33652e-05, Alpha:0.000
# Iter 0, Loss: 4.36095e-03, Loss_u: 1.43138e-02, Loss_f: 9.54264e-05, Alpha:0.000
# Iter 0, Loss: 4.36071e-03, Loss_u: 1.43087e-02, Loss_f: 9.72939e-05, Alpha:-0.000
# Iter 0, Loss: 4.36052e-03, Loss_u: 1.43041e-02, Loss_f: 9.89877e-05, Alpha:-0.000
# Iter 0, Loss: 4.35984e-03, Loss_u: 1.42806e-02, Loss_f: 1.08097e-04, Alpha:-0.001
# Iter 0, Loss: 4.35981e-03, Loss_u: 1.42789e-02, Loss_f: 1.08778e-04, Alpha:-0.001
# Iter 0, Loss: 4.35972e-03, Loss_u: 1.42713e-02, Loss_f: 1.11889e-04, Alpha:-0.001
# Iter 0, Loss: 4.35971e-03, Loss_u: 1.42705e-02, Loss_f: 1.12208e-04, Alpha:-0.001
# Iter 0, Loss: 4.35970e-03, Loss_u: 1.42697e-02, Loss_f: 1.12538e-04, Alpha:-0.001
# Iter 0, Loss: 4.35969e-03, Loss_u: 1.42690e-02, Loss_f: 1.12831e-04, Alpha:-0.001
# Iter 0, Loss: 4.35969e-03, Loss_u: 1.42685e-02, Loss_f: 1.13059e-04, Alpha:-0.001
# Iter 0, Loss: 4.35968e-03, Loss_u: 1.42678e-02, Loss_f: 1.13348e-04, Alpha:-0.001
# Iter 0, Loss: 4.35966e-03, Loss_u: 1.42647e-02, Loss_f: 1.14655e-04, Alpha:-0.001
# Iter 0, Loss: 4.35965e-03, Loss_u: 1.42642e-02, Loss_f: 1.14841e-04, Alpha:-0.001
# Iter 0, Loss: 4.35964e-03, Loss_u: 1.42622e-02, Loss_f: 1.15685e-04, Alpha:-0.001
# Iter 0, Loss: 4.35964e-03, Loss_u: 1.42618e-02, Loss_f: 1.15871e-04, Alpha:-0.001
# Iter 0, Loss: 4.35963e-03, Loss_u: 1.42613e-02, Loss_f: 1.16057e-04, Alpha:-0.001
# Iter 0, Loss: 4.35962e-03, Loss_u: 1.42606e-02, Loss_f: 1.16359e-04, Alpha:-0.001
# Iter 0, Loss: 4.35960e-03, Loss_u: 1.42589e-02, Loss_f: 1.17038e-04, Alpha:-0.001
# Iter 0, Loss: 4.35958e-03, Loss_u: 1.42580e-02, Loss_f: 1.17409e-04, Alpha:-0.001
# Iter 0, Loss: 4.35952e-03, Loss_u: 1.42538e-02, Loss_f: 1.19112e-04, Alpha:-0.001
# Iter 0, Loss: 4.35950e-03, Loss_u: 1.42529e-02, Loss_f: 1.19476e-04, Alpha:-0.001
# Iter 0, Loss: 4.35942e-03, Loss_u: 1.42487e-02, Loss_f: 1.21165e-04, Alpha:-0.001
# Iter 0, Loss: 4.35939e-03, Loss_u: 1.42476e-02, Loss_f: 1.21594e-04, Alpha:-0.001
# Iter 0, Loss: 4.35928e-03, Loss_u: 1.42428e-02, Loss_f: 1.23480e-04, Alpha:-0.001
# Iter 0, Loss: 4.35922e-03, Loss_u: 1.42414e-02, Loss_f: 1.23978e-04, Alpha:-0.001
# Iter 0, Loss: 4.35913e-03, Loss_u: 1.42389e-02, Loss_f: 1.24924e-04, Alpha:-0.001
# Iter 0, Loss: 4.35903e-03, Loss_u: 1.42372e-02, Loss_f: 1.25509e-04, Alpha:-0.001
# Iter 0, Loss: 4.35869e-03, Loss_u: 1.42278e-02, Loss_f: 1.29076e-04, Alpha:-0.002
# Iter 0, Loss: 4.35861e-03, Loss_u: 1.42269e-02, Loss_f: 1.29330e-04, Alpha:-0.002
# Iter 0, Loss: 4.35842e-03, Loss_u: 1.42240e-02, Loss_f: 1.30306e-04, Alpha:-0.002
# Iter 0, Loss: 4.35826e-03, Loss_u: 1.42237e-02, Loss_f: 1.30218e-04, Alpha:-0.002
# Iter 0, Loss: 4.35757e-03, Loss_u: 1.42179e-02, Loss_f: 1.31711e-04, Alpha:-0.002
# Iter 0, Loss: 4.35739e-03, Loss_u: 1.42187e-02, Loss_f: 1.31123e-04, Alpha:-0.002
# Iter 0, Loss: 4.35671e-03, Loss_u: 1.42206e-02, Loss_f: 1.29353e-04, Alpha:-0.001
# Iter 0, Loss: 4.35645e-03, Loss_u: 1.42232e-02, Loss_f: 1.27831e-04, Alpha:-0.001
# Iter 0, Loss: 4.35508e-03, Loss_u: 1.42376e-02, Loss_f: 1.19699e-04, Alpha:-0.001
# Iter 0, Loss: 4.35493e-03, Loss_u: 1.42377e-02, Loss_f: 1.19455e-04, Alpha:-0.001
# Iter 0, Loss: 4.35449e-03, Loss_u: 1.42345e-02, Loss_f: 1.20185e-04, Alpha:-0.001
# Iter 0, Loss: 4.35430e-03, Loss_u: 1.42370e-02, Loss_f: 1.18851e-04, Alpha:-0.001
# Iter 0, Loss: 4.35416e-03, Loss_u: 1.42385e-02, Loss_f: 1.18026e-04, Alpha:-0.001
# Iter 0, Loss: 4.35365e-03, Loss_u: 1.42430e-02, Loss_f: 1.15350e-04, Alpha:-0.000
# Iter 0, Loss: 4.35355e-03, Loss_u: 1.42437e-02, Loss_f: 1.14915e-04, Alpha:-0.000
# Iter 0, Loss: 4.35316e-03, Loss_u: 1.42448e-02, Loss_f: 1.13900e-04, Alpha:-0.000
# Iter 0, Loss: 4.35304e-03, Loss_u: 1.42457e-02, Loss_f: 1.13349e-04, Alpha:-0.000
# Iter 0, Loss: 4.35260e-03, Loss_u: 1.42470e-02, Loss_f: 1.12156e-04, Alpha:-0.000
# Iter 0, Loss: 4.35248e-03, Loss_u: 1.42446e-02, Loss_f: 1.13010e-04, Alpha:-0.000
# Iter 0, Loss: 4.35229e-03, Loss_u: 1.42447e-02, Loss_f: 1.12683e-04, Alpha:-0.001
# Iter 0, Loss: 4.35218e-03, Loss_u: 1.42442e-02, Loss_f: 1.12732e-04, Alpha:-0.001
# Iter 0, Loss: 4.35183e-03, Loss_u: 1.42368e-02, Loss_f: 1.15425e-04, Alpha:-0.001
# Iter 0, Loss: 4.35175e-03, Loss_u: 1.42370e-02, Loss_f: 1.15201e-04, Alpha:-0.001
# Iter 0, Loss: 4.35149e-03, Loss_u: 1.42367e-02, Loss_f: 1.14966e-04, Alpha:-0.001
# Iter 0, Loss: 4.35143e-03, Loss_u: 1.42371e-02, Loss_f: 1.14703e-04, Alpha:-0.001
# Iter 0, Loss: 4.35119e-03, Loss_u: 1.42379e-02, Loss_f: 1.14010e-04, Alpha:-0.001
# Iter 0, Loss: 4.35113e-03, Loss_u: 1.42366e-02, Loss_f: 1.14494e-04, Alpha:-0.001
# Iter 0, Loss: 4.35104e-03, Loss_u: 1.42369e-02, Loss_f: 1.14239e-04, Alpha:-0.001
# Iter 0, Loss: 4.35099e-03, Loss_u: 1.42363e-02, Loss_f: 1.14426e-04, Alpha:-0.001
# Iter 0, Loss: 4.35089e-03, Loss_u: 1.42342e-02, Loss_f: 1.15188e-04, Alpha:-0.001
# Iter 0, Loss: 4.35085e-03, Loss_u: 1.42340e-02, Loss_f: 1.15221e-04, Alpha:-0.001
# Iter 0, Loss: 4.35069e-03, Loss_u: 1.42305e-02, Loss_f: 1.16468e-04, Alpha:-0.001
# Iter 0, Loss: 4.35065e-03, Loss_u: 1.42310e-02, Loss_f: 1.16226e-04, Alpha:-0.001
# Iter 0, Loss: 4.35057e-03, Loss_u: 1.42317e-02, Loss_f: 1.15820e-04, Alpha:-0.001
# Iter 0, Loss: 4.35052e-03, Loss_u: 1.42313e-02, Loss_f: 1.15921e-04, Alpha:-0.000
# Iter 0, Loss: 4.35034e-03, Loss_u: 1.42266e-02, Loss_f: 1.17662e-04, Alpha:-0.000
# Iter 0, Loss: 4.35028e-03, Loss_u: 1.42282e-02, Loss_f: 1.16885e-04, Alpha:-0.000
# Iter 0, Loss: 4.35022e-03, Loss_u: 1.42284e-02, Loss_f: 1.16730e-04, Alpha:-0.000
# Iter 0, Loss: 4.35013e-03, Loss_u: 1.42299e-02, Loss_f: 1.15938e-04, Alpha:-0.000
# Iter 0, Loss: 4.35006e-03, Loss_u: 1.42302e-02, Loss_f: 1.15718e-04, Alpha:-0.000
# Iter 0, Loss: 4.34999e-03, Loss_u: 1.42311e-02, Loss_f: 1.15234e-04, Alpha:-0.000
# Iter 0, Loss: 4.34985e-03, Loss_u: 1.42320e-02, Loss_f: 1.14649e-04, Alpha:-0.000
# Iter 0, Loss: 4.34981e-03, Loss_u: 1.42329e-02, Loss_f: 1.14203e-04, Alpha:-0.000
# Iter 0, Loss: 4.34972e-03, Loss_u: 1.42349e-02, Loss_f: 1.13217e-04, Alpha:-0.000
# Iter 0, Loss: 4.34969e-03, Loss_u: 1.42353e-02, Loss_f: 1.13018e-04, Alpha:-0.000
# Iter 0, Loss: 4.34959e-03, Loss_u: 1.42361e-02, Loss_f: 1.12507e-04, Alpha:-0.000
# Iter 0, Loss: 4.34957e-03, Loss_u: 1.42372e-02, Loss_f: 1.11997e-04, Alpha:-0.000
# Iter 0, Loss: 4.34954e-03, Loss_u: 1.42371e-02, Loss_f: 1.12018e-04, Alpha:-0.000
# Iter 0, Loss: 4.34951e-03, Loss_u: 1.42379e-02, Loss_f: 1.11649e-04, Alpha:-0.000
# Iter 0, Loss: 4.34949e-03, Loss_u: 1.42382e-02, Loss_f: 1.11459e-04, Alpha:-0.000
# Iter 0, Loss: 4.34940e-03, Loss_u: 1.42387e-02, Loss_f: 1.11142e-04, Alpha:-0.000
# Iter 0, Loss: 4.34939e-03, Loss_u: 1.42390e-02, Loss_f: 1.10963e-04, Alpha:-0.000
# Iter 0, Loss: 4.34932e-03, Loss_u: 1.42402e-02, Loss_f: 1.10378e-04, Alpha:-0.000
# Iter 0, Loss: 4.34930e-03, Loss_u: 1.42404e-02, Loss_f: 1.10261e-04, Alpha:-0.000
# Iter 0, Loss: 4.34927e-03, Loss_u: 1.42406e-02, Loss_f: 1.10147e-04, Alpha:-0.000
# Iter 0, Loss: 4.34922e-03, Loss_u: 1.42405e-02, Loss_f: 1.10080e-04, Alpha:-0.000
# Iter 0, Loss: 4.34903e-03, Loss_u: 1.42372e-02, Loss_f: 1.11240e-04, Alpha:-0.000
# Iter 0, Loss: 4.34891e-03, Loss_u: 1.42367e-02, Loss_f: 1.11296e-04, Alpha:-0.000
# Iter 0, Loss: 4.34874e-03, Loss_u: 1.42228e-02, Loss_f: 1.17014e-04, Alpha:0.000
# Iter 0, Loss: 4.34865e-03, Loss_u: 1.42289e-02, Loss_f: 1.14272e-04, Alpha:0.000
# Iter 0, Loss: 4.34851e-03, Loss_u: 1.42288e-02, Loss_f: 1.14114e-04, Alpha:0.000
# Iter 0, Loss: 4.34797e-03, Loss_u: 1.42245e-02, Loss_f: 1.15156e-04, Alpha:0.000
# Iter 0, Loss: 4.34779e-03, Loss_u: 1.42238e-02, Loss_f: 1.15211e-04, Alpha:0.000
# Iter 0, Loss: 4.34747e-03, Loss_u: 1.42160e-02, Loss_f: 1.18107e-04, Alpha:0.000
# Iter 0, Loss: 4.34723e-03, Loss_u: 1.42145e-02, Loss_f: 1.18422e-04, Alpha:0.000
# Iter 0, Loss: 4.34697e-03, Loss_u: 1.42094e-02, Loss_f: 1.20220e-04, Alpha:0.000
# Iter 0, Loss: 4.34670e-03, Loss_u: 1.42079e-02, Loss_f: 1.20451e-04, Alpha:0.000
# Iter 0, Loss: 4.34590e-03, Loss_u: 1.41904e-02, Loss_f: 1.26803e-04, Alpha:0.000
# Iter 0, Loss: 4.34566e-03, Loss_u: 1.41902e-02, Loss_f: 1.26587e-04, Alpha:-0.000
# Iter 0, Loss: 4.34542e-03, Loss_u: 1.41882e-02, Loss_f: 1.27108e-04, Alpha:-0.000
# Iter 0, Loss: 4.34440e-03, Loss_u: 1.41663e-02, Loss_f: 1.34995e-04, Alpha:-0.000
# Iter 0, Loss: 4.34403e-03, Loss_u: 1.41694e-02, Loss_f: 1.33146e-04, Alpha:-0.000
# Iter 0, Loss: 4.34358e-03, Loss_u: 1.41692e-02, Loss_f: 1.32620e-04, Alpha:0.000
# Iter 0, Loss: 4.34196e-03, Loss_u: 1.41619e-02, Loss_f: 1.33412e-04, Alpha:0.000
# Iter 0, Loss: 4.34132e-03, Loss_u: 1.41629e-02, Loss_f: 1.32061e-04, Alpha:0.000
# Iter 0, Loss: 4.34040e-03, Loss_u: 1.41679e-02, Loss_f: 1.28640e-04, Alpha:0.000
# Iter 0, Loss: 4.33974e-03, Loss_u: 1.41699e-02, Loss_f: 1.26816e-04, Alpha:0.000
# Iter 0, Loss: 4.33918e-03, Loss_u: 1.41747e-02, Loss_f: 1.23934e-04, Alpha:0.000
# Iter 0, Loss: 4.33875e-03, Loss_u: 1.41773e-02, Loss_f: 1.22217e-04, Alpha:0.000
# Iter 0, Loss: 4.33836e-03, Loss_u: 1.41813e-02, Loss_f: 1.19963e-04, Alpha:0.001
# Iter 0, Loss: 4.33798e-03, Loss_u: 1.41826e-02, Loss_f: 1.18849e-04, Alpha:0.001
# Iter 0, Loss: 4.33760e-03, Loss_u: 1.41856e-02, Loss_f: 1.17014e-04, Alpha:0.001
# Iter 0, Loss: 4.33726e-03, Loss_u: 1.41862e-02, Loss_f: 1.16291e-04, Alpha:0.001
# Iter 0, Loss: 4.33695e-03, Loss_u: 1.41878e-02, Loss_f: 1.15179e-04, Alpha:0.001
# Iter 0, Loss: 4.33670e-03, Loss_u: 1.41879e-02, Loss_f: 1.14738e-04, Alpha:0.001
# Iter 0, Loss: 4.33644e-03, Loss_u: 1.41878e-02, Loss_f: 1.14447e-04, Alpha:0.001
# Iter 0, Loss: 4.33561e-03, Loss_u: 1.41926e-02, Loss_f: 1.11185e-04, Alpha:0.001
# Iter 0, Loss: 4.33551e-03, Loss_u: 1.41916e-02, Loss_f: 1.11473e-04, Alpha:0.001
# Iter 0, Loss: 4.33513e-03, Loss_u: 1.41884e-02, Loss_f: 1.12324e-04, Alpha:0.002
# Iter 0, Loss: 4.33501e-03, Loss_u: 1.41870e-02, Loss_f: 1.12749e-04, Alpha:0.002
# Iter 0, Loss: 4.33464e-03, Loss_u: 1.41834e-02, Loss_f: 1.13733e-04, Alpha:0.002
# Iter 0, Loss: 4.33445e-03, Loss_u: 1.41795e-02, Loss_f: 1.15128e-04, Alpha:0.002
# Iter 0, Loss: 4.33409e-03, Loss_u: 1.41775e-02, Loss_f: 1.15469e-04, Alpha:0.002
# Iter 0, Loss: 4.33392e-03, Loss_u: 1.41751e-02, Loss_f: 1.16293e-04, Alpha:0.002
# Iter 0, Loss: 4.33348e-03, Loss_u: 1.41682e-02, Loss_f: 1.18602e-04, Alpha:0.002
# Iter 0, Loss: 4.33322e-03, Loss_u: 1.41634e-02, Loss_f: 1.20294e-04, Alpha:0.002
# Iter 0, Loss: 4.33231e-03, Loss_u: 1.41428e-02, Loss_f: 1.27797e-04, Alpha:0.003
# Iter 0, Loss: 4.33209e-03, Loss_u: 1.41412e-02, Loss_f: 1.28204e-04, Alpha:0.003
# Iter 0, Loss: 4.33150e-03, Loss_u: 1.41367e-02, Loss_f: 1.29269e-04, Alpha:0.003
# Iter 0, Loss: 4.33110e-03, Loss_u: 1.41322e-02, Loss_f: 1.30619e-04, Alpha:0.003
# Iter 0, Loss: 4.33084e-03, Loss_u: 1.41297e-02, Loss_f: 1.31330e-04, Alpha:0.003
# Iter 0, Loss: 4.32994e-03, Loss_u: 1.41188e-02, Loss_f: 1.34730e-04, Alpha:0.003
# Iter 0, Loss: 4.32976e-03, Loss_u: 1.41182e-02, Loss_f: 1.34725e-04, Alpha:0.003
# Iter 0, Loss: 4.32913e-03, Loss_u: 1.41156e-02, Loss_f: 1.34915e-04, Alpha:0.003
# Iter 0, Loss: 4.32900e-03, Loss_u: 1.41132e-02, Loss_f: 1.35753e-04, Alpha:0.003
# Iter 0, Loss: 4.32885e-03, Loss_u: 1.41109e-02, Loss_f: 1.36538e-04, Alpha:0.003
# Iter 0, Loss: 4.32876e-03, Loss_u: 1.41100e-02, Loss_f: 1.36793e-04, Alpha:0.003
# Iter 0, Loss: 4.32870e-03, Loss_u: 1.41091e-02, Loss_f: 1.37119e-04, Alpha:0.003
# Iter 0, Loss: 4.32865e-03, Loss_u: 1.41084e-02, Loss_f: 1.37338e-04, Alpha:0.004
# Iter 0, Loss: 4.32856e-03, Loss_u: 1.41068e-02, Loss_f: 1.37889e-04, Alpha:0.004
# Iter 0, Loss: 4.32853e-03, Loss_u: 1.41063e-02, Loss_f: 1.38058e-04, Alpha:0.004
# Iter 0, Loss: 4.32851e-03, Loss_u: 1.41058e-02, Loss_f: 1.38256e-04, Alpha:0.004
# Iter 0, Loss: 4.32849e-03, Loss_u: 1.41054e-02, Loss_f: 1.38390e-04, Alpha:0.004
# Iter 0, Loss: 4.32844e-03, Loss_u: 1.41036e-02, Loss_f: 1.39067e-04, Alpha:0.004
# Iter 0, Loss: 4.32844e-03, Loss_u: 1.41035e-02, Loss_f: 1.39128e-04, Alpha:0.004
# Iter 0, Loss: 4.32843e-03, Loss_u: 1.41034e-02, Loss_f: 1.39172e-04, Alpha:0.004
# Iter 0, Loss: 4.32843e-03, Loss_u: 1.41032e-02, Loss_f: 1.39251e-04, Alpha:0.004
# Iter 0, Loss: 4.32843e-03, Loss_u: 1.41031e-02, Loss_f: 1.39270e-04, Alpha:0.004
# Iter 0, Loss: 4.32843e-03, Loss_u: 1.41030e-02, Loss_f: 1.39338e-04, Alpha:0.004
# Iter 0, Loss: 4.32843e-03, Loss_u: 1.41029e-02, Loss_f: 1.39353e-04, Alpha:0.004
# Iter 0, Loss: 4.32843e-03, Loss_u: 1.41028e-02, Loss_f: 1.39391e-04, Alpha:0.004
# Iter 0, Loss: 4.32843e-03, Loss_u: 1.41028e-02, Loss_f: 1.39409e-04, Alpha:0.004
# Iter 0, Loss: 4.32842e-03, Loss_u: 1.41026e-02, Loss_f: 1.39493e-04, Alpha:0.004
# Iter 0, Loss: 3.91209e-03, Loss_u: 1.26468e-02, Loss_f: 1.68639e-04, Alpha:0.004
# Iter 0, Loss: 3.91215e-03, Loss_u: 1.26462e-02, Loss_f: 1.69003e-04, Alpha:0.004
# Iter 0, Loss: 3.91208e-03, Loss_u: 1.26467e-02, Loss_f: 1.68690e-04, Alpha:0.004
# Iter 0, Loss: 3.91205e-03, Loss_u: 1.26465e-02, Loss_f: 1.68710e-04, Alpha:0.004
# Iter 0, Loss: 3.91189e-03, Loss_u: 1.26458e-02, Loss_f: 1.68802e-04, Alpha:0.004
# Iter 0, Loss: 3.91129e-03, Loss_u: 1.26428e-02, Loss_f: 1.69223e-04, Alpha:0.004
# Iter 0, Loss: 3.90970e-03, Loss_u: 1.26410e-02, Loss_f: 1.67728e-04, Alpha:0.004
# Iter 0, Loss: 3.89787e-03, Loss_u: 1.26293e-02, Loss_f: 1.55838e-04, Alpha:0.003
# Iter 0, Loss: 3.89354e-03, Loss_u: 1.26291e-02, Loss_f: 1.49746e-04, Alpha:0.003
# Iter 0, Loss: 3.86966e-03, Loss_u: 1.26644e-02, Loss_f: 1.00489e-04, Alpha:-0.000
# Iter 0, Loss: 3.86687e-03, Loss_u: 1.26691e-02, Loss_f: 9.44721e-05, Alpha:-0.001
# Iter 0, Loss: 3.85441e-03, Loss_u: 1.27279e-02, Loss_f: 5.14728e-05, Alpha:-0.002
# Iter 0, Loss: 3.85104e-03, Loss_u: 1.27209e-02, Loss_f: 4.96859e-05, Alpha:-0.002
# Iter 0, Loss: 3.83618e-03, Loss_u: 1.26986e-02, Loss_f: 3.80225e-05, Alpha:-0.000
# Iter 0, Loss: 3.83503e-03, Loss_u: 1.26977e-02, Loss_f: 3.67590e-05, Alpha:-0.000
# Iter 0, Loss: 3.82734e-03, Loss_u: 1.26906e-02, Loss_f: 2.87888e-05, Alpha:0.000
# Iter 0, Loss: 3.82648e-03, Loss_u: 1.26898e-02, Loss_f: 2.79163e-05, Alpha:0.001
# Iter 0, Loss: 3.82294e-03, Loss_u: 1.26851e-02, Loss_f: 2.48528e-05, Alpha:0.002
# Iter 0, Loss: 3.82271e-03, Loss_u: 1.26839e-02, Loss_f: 2.50447e-05, Alpha:0.002
# Iter 0, Loss: 3.82185e-03, Loss_u: 1.26785e-02, Loss_f: 2.61366e-05, Alpha:0.002
# Iter 0, Loss: 3.82154e-03, Loss_u: 1.26776e-02, Loss_f: 2.60910e-05, Alpha:0.002
# Iter 0, Loss: 3.81974e-03, Loss_u: 1.26691e-02, Loss_f: 2.71567e-05, Alpha:0.003
# Iter 0, Loss: 3.81960e-03, Loss_u: 1.26680e-02, Loss_f: 2.74106e-05, Alpha:0.003
# Iter 0, Loss: 3.81907e-03, Loss_u: 1.26631e-02, Loss_f: 2.87837e-05, Alpha:0.003
# Iter 0, Loss: 3.81891e-03, Loss_u: 1.26625e-02, Loss_f: 2.87805e-05, Alpha:0.003
# Iter 0, Loss: 3.81847e-03, Loss_u: 1.26606e-02, Loss_f: 2.89769e-05, Alpha:0.003
# Iter 0, Loss: 3.81834e-03, Loss_u: 1.26599e-02, Loss_f: 2.91096e-05, Alpha:0.003
# Iter 0, Loss: 3.81790e-03, Loss_u: 1.26564e-02, Loss_f: 2.99502e-05, Alpha:0.003
# Iter 0, Loss: 3.81779e-03, Loss_u: 1.26557e-02, Loss_f: 3.00903e-05, Alpha:0.003
# Iter 0, Loss: 3.81721e-03, Loss_u: 1.26492e-02, Loss_f: 3.20739e-05, Alpha:0.003
# Iter 0, Loss: 3.81714e-03, Loss_u: 1.26487e-02, Loss_f: 3.21640e-05, Alpha:0.003
# Iter 0, Loss: 3.81698e-03, Loss_u: 1.26476e-02, Loss_f: 3.24318e-05, Alpha:0.003
# Iter 0, Loss: 3.81682e-03, Loss_u: 1.26463e-02, Loss_f: 3.27740e-05, Alpha:0.003
# Iter 0, Loss: 3.81616e-03, Loss_u: 1.26355e-02, Loss_f: 3.64567e-05, Alpha:0.004
# Iter 0, Loss: 3.81610e-03, Loss_u: 1.26358e-02, Loss_f: 3.62140e-05, Alpha:0.004
# Iter 0, Loss: 3.81604e-03, Loss_u: 1.26358e-02, Loss_f: 3.61313e-05, Alpha:0.004
# Iter 0, Loss: 3.81596e-03, Loss_u: 1.26359e-02, Loss_f: 3.60085e-05, Alpha:0.004
# Iter 0, Loss: 3.81591e-03, Loss_u: 1.26361e-02, Loss_f: 3.58286e-05, Alpha:0.004
# Iter 0, Loss: 3.81582e-03, Loss_u: 1.26366e-02, Loss_f: 3.54732e-05, Alpha:0.004
# Iter 0, Loss: 3.81577e-03, Loss_u: 1.26367e-02, Loss_f: 3.53669e-05, Alpha:0.004
# Iter 0, Loss: 3.81560e-03, Loss_u: 1.26372e-02, Loss_f: 3.49183e-05, Alpha:0.004
# Iter 0, Loss: 3.81557e-03, Loss_u: 1.26376e-02, Loss_f: 3.47246e-05, Alpha:0.004
# Iter 0, Loss: 3.81547e-03, Loss_u: 1.26393e-02, Loss_f: 3.38434e-05, Alpha:0.004
# Iter 0, Loss: 3.81544e-03, Loss_u: 1.26394e-02, Loss_f: 3.37418e-05, Alpha:0.004
# Iter 0, Loss: 3.81533e-03, Loss_u: 1.26401e-02, Loss_f: 3.32715e-05, Alpha:0.004
# Iter 0, Loss: 3.81529e-03, Loss_u: 1.26405e-02, Loss_f: 3.30599e-05, Alpha:0.004
# Iter 0, Loss: 3.81517e-03, Loss_u: 1.26424e-02, Loss_f: 3.20756e-05, Alpha:0.004
# Iter 0, Loss: 3.81513e-03, Loss_u: 1.26425e-02, Loss_f: 3.19609e-05, Alpha:0.003
# Iter 0, Loss: 3.81500e-03, Loss_u: 1.26434e-02, Loss_f: 3.14208e-05, Alpha:0.003
# Iter 0, Loss: 3.81497e-03, Loss_u: 1.26435e-02, Loss_f: 3.12910e-05, Alpha:0.003
# Iter 0, Loss: 3.81483e-03, Loss_u: 1.26445e-02, Loss_f: 3.06986e-05, Alpha:0.003
# Iter 0, Loss: 3.81479e-03, Loss_u: 1.26444e-02, Loss_f: 3.06740e-05, Alpha:0.003
# Iter 0, Loss: 3.81464e-03, Loss_u: 1.26441e-02, Loss_f: 3.05956e-05, Alpha:0.003
# Iter 0, Loss: 3.81460e-03, Loss_u: 1.26441e-02, Loss_f: 3.05167e-05, Alpha:0.003
# Iter 0, Loss: 3.81441e-03, Loss_u: 1.26443e-02, Loss_f: 3.01829e-05, Alpha:0.003
# Iter 0, Loss: 3.81437e-03, Loss_u: 1.26439e-02, Loss_f: 3.03041e-05, Alpha:0.003
# Iter 0, Loss: 3.81422e-03, Loss_u: 1.26417e-02, Loss_f: 3.10167e-05, Alpha:0.003
# Iter 0, Loss: 3.81416e-03, Loss_u: 1.26423e-02, Loss_f: 3.06872e-05, Alpha:0.003
# Iter 0, Loss: 3.81411e-03, Loss_u: 1.26420e-02, Loss_f: 3.07347e-05, Alpha:0.003
# Iter 0, Loss: 3.81395e-03, Loss_u: 1.26404e-02, Loss_f: 3.11836e-05, Alpha:0.003
# Iter 0, Loss: 3.81392e-03, Loss_u: 1.26405e-02, Loss_f: 3.11115e-05, Alpha:0.003
# Iter 0, Loss: 3.81383e-03, Loss_u: 1.26407e-02, Loss_f: 3.08798e-05, Alpha:0.003
# Iter 0, Loss: 3.81382e-03, Loss_u: 1.26406e-02, Loss_f: 3.08894e-05, Alpha:0.003
# Iter 0, Loss: 3.81379e-03, Loss_u: 1.26404e-02, Loss_f: 3.09377e-05, Alpha:0.003
# Iter 0, Loss: 3.81376e-03, Loss_u: 1.26421e-02, Loss_f: 3.01928e-05, Alpha:0.003
# Iter 0, Loss: 3.81374e-03, Loss_u: 1.26421e-02, Loss_f: 3.01558e-05, Alpha:0.003
# Iter 0, Loss: 3.81367e-03, Loss_u: 1.26414e-02, Loss_f: 3.03704e-05, Alpha:0.003
# Iter 0, Loss: 3.81367e-03, Loss_u: 1.26416e-02, Loss_f: 3.02677e-05, Alpha:0.003
# Iter 0, Loss: 3.81366e-03, Loss_u: 1.26417e-02, Loss_f: 3.02048e-05, Alpha:0.003
# Iter 0, Loss: 3.81366e-03, Loss_u: 1.26419e-02, Loss_f: 3.01234e-05, Alpha:0.003
# Iter 0, Loss: 3.81365e-03, Loss_u: 1.26420e-02, Loss_f: 3.00550e-05, Alpha:0.003
# Iter 0, Loss: 3.81364e-03, Loss_u: 1.26427e-02, Loss_f: 2.97636e-05, Alpha:0.003
# Iter 0, Loss: 3.81364e-03, Loss_u: 1.26428e-02, Loss_f: 2.97206e-05, Alpha:0.003
# Iter 0, Loss: 3.81363e-03, Loss_u: 1.26432e-02, Loss_f: 2.95420e-05, Alpha:0.003
# Iter 0, Loss: 3.81363e-03, Loss_u: 1.26433e-02, Loss_f: 2.95028e-05, Alpha:0.003
# Iter 0, Loss: 3.81363e-03, Loss_u: 1.26433e-02, Loss_f: 2.94925e-05, Alpha:0.003
# Iter 0, Loss: 3.81363e-03, Loss_u: 1.26434e-02, Loss_f: 2.94501e-05, Alpha:0.003
# Iter 0, Loss: 3.81363e-03, Loss_u: 1.26438e-02, Loss_f: 2.92692e-05, Alpha:0.003
# Iter 0, Loss: 3.81363e-03, Loss_u: 1.26439e-02, Loss_f: 2.92411e-05, Alpha:0.003
# Iter 0, Loss: 3.81363e-03, Loss_u: 1.26439e-02, Loss_f: 2.92399e-05, Alpha:0.003
# Iter 0, Loss: 3.81363e-03, Loss_u: 1.26439e-02, Loss_f: 2.92400e-05, Alpha:0.003
# Iter 0, Loss: 3.81363e-03, Loss_u: 1.26439e-02, Loss_f: 2.92400e-05, Alpha:0.003
# Iter 0, Loss: 3.81363e-03, Loss_u: 1.26439e-02, Loss_f: 2.92400e-05, Alpha:0.003
# Iter 0, Loss: 3.81363e-03, Loss_u: 1.26439e-02, Loss_f: 2.92400e-05, Alpha:0.003
# Iter 0, Loss: 3.81363e-03, Loss_u: 1.26439e-02, Loss_f: 2.92400e-05, Alpha:0.003
# Iter 0, Loss: 3.81363e-03, Loss_u: 1.26439e-02, Loss_f: 2.92400e-05, Alpha:0.003
# Iter 0, Loss: 3.81363e-03, Loss_u: 1.26439e-02, Loss_f: 2.92147e-05, Alpha:0.003
# Iter 0, Loss: 3.81363e-03, Loss_u: 1.26439e-02, Loss_f: 2.92387e-05, Alpha:0.003
# Iter 0, Loss: 3.81363e-03, Loss_u: 1.26439e-02, Loss_f: 2.92397e-05, Alpha:0.003
# Iter 0, Loss: 3.81363e-03, Loss_u: 1.26439e-02, Loss_f: 2.92400e-05, Alpha:0.003
# iteration =    1   loss = 0.0209
# Iter 0, Loss: 4.94650e-03, Loss_u: 1.64261e-02, Loss_f: 2.66775e-05, Alpha:0.003
# Iter 0, Loss: 4.89927e-03, Loss_u: 1.62523e-02, Loss_f: 3.36973e-05, Alpha:0.002
# Iter 0, Loss: 5.40660e-03, Loss_u: 1.63301e-02, Loss_f: 7.25083e-04, Alpha:0.001
# Iter 0, Loss: 4.83056e-03, Loss_u: 1.58192e-02, Loss_f: 1.21132e-04, Alpha:0.001
# Iter 0, Loss: 4.84285e-03, Loss_u: 1.60371e-02, Loss_f: 4.53189e-05, Alpha:0.002
# Iter 0, Loss: 4.82831e-03, Loss_u: 1.58821e-02, Loss_f: 9.09836e-05, Alpha:0.001
# Iter 0, Loss: 4.82579e-03, Loss_u: 1.58951e-02, Loss_f: 8.17795e-05, Alpha:0.001
# Iter 0, Loss: 4.82535e-03, Loss_u: 1.58952e-02, Loss_f: 8.11016e-05, Alpha:0.001
# Iter 0, Loss: 4.82382e-03, Loss_u: 1.58953e-02, Loss_f: 7.89250e-05, Alpha:0.001
# Iter 0, Loss: 4.82362e-03, Loss_u: 1.58944e-02, Loss_f: 7.90078e-05, Alpha:0.001
# Iter 0, Loss: 4.82347e-03, Loss_u: 1.58942e-02, Loss_f: 7.88799e-05, Alpha:0.000
# Iter 0, Loss: 4.82335e-03, Loss_u: 1.58941e-02, Loss_f: 7.87263e-05, Alpha:0.000
# Iter 0, Loss: 4.82296e-03, Loss_u: 1.58931e-02, Loss_f: 7.86297e-05, Alpha:0.000
# Iter 0, Loss: 4.82292e-03, Loss_u: 1.58934e-02, Loss_f: 7.84281e-05, Alpha:0.000
# Iter 0, Loss: 4.82280e-03, Loss_u: 1.58950e-02, Loss_f: 7.75797e-05, Alpha:0.000
# Iter 0, Loss: 4.82277e-03, Loss_u: 1.58953e-02, Loss_f: 7.74185e-05, Alpha:0.000
# Iter 0, Loss: 4.82270e-03, Loss_u: 1.58960e-02, Loss_f: 7.69863e-05, Alpha:0.000
# Iter 0, Loss: 4.82266e-03, Loss_u: 1.58968e-02, Loss_f: 7.66131e-05, Alpha:0.000
# Iter 0, Loss: 4.82249e-03, Loss_u: 1.59003e-02, Loss_f: 7.48830e-05, Alpha:-0.000
# Iter 0, Loss: 4.82245e-03, Loss_u: 1.59008e-02, Loss_f: 7.45950e-05, Alpha:-0.000
# Iter 0, Loss: 4.82235e-03, Loss_u: 1.59026e-02, Loss_f: 7.36842e-05, Alpha:-0.000
# Iter 0, Loss: 4.82229e-03, Loss_u: 1.59033e-02, Loss_f: 7.32960e-05, Alpha:-0.000
# Iter 0, Loss: 4.82202e-03, Loss_u: 1.59115e-02, Loss_f: 6.93686e-05, Alpha:-0.000
# Iter 0, Loss: 4.82199e-03, Loss_u: 1.59115e-02, Loss_f: 6.93558e-05, Alpha:-0.000
# Iter 0, Loss: 4.82189e-03, Loss_u: 1.59111e-02, Loss_f: 6.93666e-05, Alpha:-0.000
# Iter 0, Loss: 4.82183e-03, Loss_u: 1.59105e-02, Loss_f: 6.95443e-05, Alpha:-0.000
# Iter 0, Loss: 4.82179e-03, Loss_u: 1.59101e-02, Loss_f: 6.96805e-05, Alpha:-0.000
# Iter 0, Loss: 4.82176e-03, Loss_u: 1.59097e-02, Loss_f: 6.98014e-05, Alpha:-0.000
# Iter 0, Loss: 4.82173e-03, Loss_u: 1.59093e-02, Loss_f: 6.99071e-05, Alpha:-0.000
# Iter 0, Loss: 4.82171e-03, Loss_u: 1.59090e-02, Loss_f: 6.99993e-05, Alpha:-0.000
# Iter 0, Loss: 4.82164e-03, Loss_u: 1.59074e-02, Loss_f: 7.06164e-05, Alpha:-0.000
# Iter 0, Loss: 4.82164e-03, Loss_u: 1.59072e-02, Loss_f: 7.06997e-05, Alpha:-0.000
# Iter 0, Loss: 4.82162e-03, Loss_u: 1.59062e-02, Loss_f: 7.11003e-05, Alpha:0.000
# Iter 0, Loss: 4.82161e-03, Loss_u: 1.59062e-02, Loss_f: 7.10897e-05, Alpha:0.000
# Iter 0, Loss: 4.82161e-03, Loss_u: 1.59062e-02, Loss_f: 7.10818e-05, Alpha:0.000
# Iter 0, Loss: 4.82160e-03, Loss_u: 1.59062e-02, Loss_f: 7.10403e-05, Alpha:0.000
# Iter 0, Loss: 4.82159e-03, Loss_u: 1.59064e-02, Loss_f: 7.09497e-05, Alpha:0.000
# Iter 0, Loss: 4.82158e-03, Loss_u: 1.59066e-02, Loss_f: 7.08438e-05, Alpha:0.000
# Iter 0, Loss: 4.82155e-03, Loss_u: 1.59076e-02, Loss_f: 7.03751e-05, Alpha:0.000
# Iter 0, Loss: 4.82154e-03, Loss_u: 1.59077e-02, Loss_f: 7.03470e-05, Alpha:0.000
# Iter 0, Loss: 4.82153e-03, Loss_u: 1.59077e-02, Loss_f: 7.03098e-05, Alpha:0.000
# Iter 0, Loss: 4.82151e-03, Loss_u: 1.59080e-02, Loss_f: 7.01707e-05, Alpha:0.000
# Iter 0, Loss: 4.82148e-03, Loss_u: 1.59088e-02, Loss_f: 6.97563e-05, Alpha:0.000
# Iter 0, Loss: 4.82146e-03, Loss_u: 1.59088e-02, Loss_f: 6.97464e-05, Alpha:0.000
# Iter 0, Loss: 4.82144e-03, Loss_u: 1.59087e-02, Loss_f: 6.97532e-05, Alpha:0.000
# Iter 0, Loss: 4.82142e-03, Loss_u: 1.59087e-02, Loss_f: 6.97236e-05, Alpha:0.000
# Iter 0, Loss: 4.82140e-03, Loss_u: 1.59087e-02, Loss_f: 6.97184e-05, Alpha:0.000
# Iter 0, Loss: 4.82137e-03, Loss_u: 1.59084e-02, Loss_f: 6.97731e-05, Alpha:0.000
# Iter 0, Loss: 4.82132e-03, Loss_u: 1.59075e-02, Loss_f: 7.00933e-05, Alpha:0.000
# Iter 0, Loss: 4.82129e-03, Loss_u: 1.59073e-02, Loss_f: 7.01512e-05, Alpha:0.000
# Iter 0, Loss: 4.82123e-03, Loss_u: 1.59062e-02, Loss_f: 7.05183e-05, Alpha:0.000
# Iter 0, Loss: 4.82121e-03, Loss_u: 1.59059e-02, Loss_f: 7.06208e-05, Alpha:0.000
# Iter 0, Loss: 4.82117e-03, Loss_u: 1.59052e-02, Loss_f: 7.08825e-05, Alpha:0.000
# Iter 0, Loss: 4.82109e-03, Loss_u: 1.59043e-02, Loss_f: 7.11461e-05, Alpha:0.000
# Iter 0, Loss: 4.82081e-03, Loss_u: 1.58962e-02, Loss_f: 7.42225e-05, Alpha:0.000
# Iter 0, Loss: 4.82067e-03, Loss_u: 1.58925e-02, Loss_f: 7.55817e-05, Alpha:0.000
# Iter 0, Loss: 4.82040e-03, Loss_u: 1.58755e-02, Loss_f: 8.25037e-05, Alpha:0.000
# Iter 0, Loss: 4.82027e-03, Loss_u: 1.58747e-02, Loss_f: 8.26408e-05, Alpha:0.000
# Iter 0, Loss: 4.82006e-03, Loss_u: 1.58681e-02, Loss_f: 8.51840e-05, Alpha:0.000
# Iter 0, Loss: 4.81991e-03, Loss_u: 1.58703e-02, Loss_f: 8.40293e-05, Alpha:0.000
# Iter 0, Loss: 4.81971e-03, Loss_u: 1.58733e-02, Loss_f: 8.24698e-05, Alpha:0.000
# Iter 0, Loss: 4.81956e-03, Loss_u: 1.58752e-02, Loss_f: 8.14129e-05, Alpha:0.000
# Iter 0, Loss: 4.81933e-03, Loss_u: 1.58778e-02, Loss_f: 7.99772e-05, Alpha:0.001
# Iter 0, Loss: 4.81911e-03, Loss_u: 1.58800e-02, Loss_f: 7.87108e-05, Alpha:0.001
# Iter 0, Loss: 4.81891e-03, Loss_u: 1.58816e-02, Loss_f: 7.77684e-05, Alpha:0.001
# Iter 0, Loss: 4.81826e-03, Loss_u: 1.58871e-02, Loss_f: 7.44566e-05, Alpha:0.001
# Iter 0, Loss: 4.81819e-03, Loss_u: 1.58875e-02, Loss_f: 7.42191e-05, Alpha:0.001
# Iter 0, Loss: 4.81795e-03, Loss_u: 1.58888e-02, Loss_f: 7.32844e-05, Alpha:0.001
# Iter 0, Loss: 4.81788e-03, Loss_u: 1.58889e-02, Loss_f: 7.31589e-05, Alpha:0.001
# Iter 0, Loss: 4.81760e-03, Loss_u: 1.58899e-02, Loss_f: 7.23348e-05, Alpha:0.001
# Iter 0, Loss: 4.81748e-03, Loss_u: 1.58901e-02, Loss_f: 7.20909e-05, Alpha:0.001
# Iter 0, Loss: 4.81737e-03, Loss_u: 1.58894e-02, Loss_f: 7.22023e-05, Alpha:0.001
# Iter 0, Loss: 4.81727e-03, Loss_u: 1.58883e-02, Loss_f: 7.25230e-05, Alpha:0.001
# Iter 0, Loss: 4.81718e-03, Loss_u: 1.58870e-02, Loss_f: 7.29873e-05, Alpha:0.001
# Iter 0, Loss: 4.81709e-03, Loss_u: 1.58849e-02, Loss_f: 7.37601e-05, Alpha:0.001
# Iter 0, Loss: 4.81702e-03, Loss_u: 1.58830e-02, Loss_f: 7.44494e-05, Alpha:0.001
# Iter 0, Loss: 4.81695e-03, Loss_u: 1.58808e-02, Loss_f: 7.52994e-05, Alpha:0.001
# Iter 0, Loss: 4.81690e-03, Loss_u: 1.58791e-02, Loss_f: 7.59703e-05, Alpha:0.001
# Iter 0, Loss: 4.81686e-03, Loss_u: 1.58773e-02, Loss_f: 7.66697e-05, Alpha:0.001
# Iter 0, Loss: 4.81683e-03, Loss_u: 1.58757e-02, Loss_f: 7.72955e-05, Alpha:0.001
# Iter 0, Loss: 4.81680e-03, Loss_u: 1.58742e-02, Loss_f: 7.79103e-05, Alpha:0.001
# Iter 0, Loss: 4.81678e-03, Loss_u: 1.58728e-02, Loss_f: 7.84604e-05, Alpha:0.001
# Iter 0, Loss: 4.81676e-03, Loss_u: 1.58715e-02, Loss_f: 7.89968e-05, Alpha:0.001
# Iter 0, Loss: 4.81674e-03, Loss_u: 1.58704e-02, Loss_f: 7.94738e-05, Alpha:0.001
# Iter 0, Loss: 4.81673e-03, Loss_u: 1.58692e-02, Loss_f: 7.99443e-05, Alpha:0.001
# Iter 0, Loss: 4.81671e-03, Loss_u: 1.58682e-02, Loss_f: 8.03582e-05, Alpha:0.001
# Iter 0, Loss: 4.81670e-03, Loss_u: 1.58672e-02, Loss_f: 8.07783e-05, Alpha:0.001
# Iter 0, Loss: 4.81669e-03, Loss_u: 1.58663e-02, Loss_f: 8.11438e-05, Alpha:0.001
# Iter 0, Loss: 4.81668e-03, Loss_u: 1.58654e-02, Loss_f: 8.15220e-05, Alpha:0.001
# Iter 0, Loss: 4.81667e-03, Loss_u: 1.58646e-02, Loss_f: 8.18550e-05, Alpha:0.001
# Iter 0, Loss: 4.81667e-03, Loss_u: 1.58638e-02, Loss_f: 8.21982e-05, Alpha:0.001
# Iter 0, Loss: 4.81666e-03, Loss_u: 1.58632e-02, Loss_f: 8.24288e-05, Alpha:0.001
# Iter 0, Loss: 4.81665e-03, Loss_u: 1.58625e-02, Loss_f: 8.27121e-05, Alpha:0.001
# Iter 0, Loss: 4.81665e-03, Loss_u: 1.58621e-02, Loss_f: 8.28944e-05, Alpha:0.001
# Iter 0, Loss: 4.81664e-03, Loss_u: 1.58614e-02, Loss_f: 8.31718e-05, Alpha:0.001
# Iter 0, Loss: 4.81664e-03, Loss_u: 1.58609e-02, Loss_f: 8.33990e-05, Alpha:0.001
# Iter 0, Loss: 4.81663e-03, Loss_u: 1.58603e-02, Loss_f: 8.36411e-05, Alpha:0.001
# Iter 0, Loss: 4.81661e-03, Loss_u: 1.58552e-02, Loss_f: 8.57907e-05, Alpha:0.002
# Iter 0, Loss: 4.81661e-03, Loss_u: 1.58551e-02, Loss_f: 8.58414e-05, Alpha:0.002
# Iter 0, Loss: 4.81661e-03, Loss_u: 1.58549e-02, Loss_f: 8.58914e-05, Alpha:0.002
# Iter 0, Loss: 4.81660e-03, Loss_u: 1.58547e-02, Loss_f: 8.59710e-05, Alpha:0.002
# Iter 0, Loss: 4.81659e-03, Loss_u: 1.58545e-02, Loss_f: 8.60385e-05, Alpha:0.002
# Iter 0, Loss: 4.81658e-03, Loss_u: 1.58542e-02, Loss_f: 8.61620e-05, Alpha:0.002
# Iter 0, Loss: 4.81656e-03, Loss_u: 1.58539e-02, Loss_f: 8.62558e-05, Alpha:0.002
# Iter 0, Loss: 4.81647e-03, Loss_u: 1.58525e-02, Loss_f: 8.67423e-05, Alpha:0.001
# Iter 0, Loss: 4.81644e-03, Loss_u: 1.58520e-02, Loss_f: 8.69107e-05, Alpha:0.002
# Iter 0, Loss: 4.81629e-03, Loss_u: 1.58495e-02, Loss_f: 8.77537e-05, Alpha:0.002
# Iter 0, Loss: 4.81618e-03, Loss_u: 1.58488e-02, Loss_f: 8.79053e-05, Alpha:0.002
# Iter 0, Loss: 4.81604e-03, Loss_u: 1.58488e-02, Loss_f: 8.77067e-05, Alpha:0.002
# Iter 0, Loss: 4.81597e-03, Loss_u: 1.58491e-02, Loss_f: 8.74788e-05, Alpha:0.002
# Iter 0, Loss: 4.81590e-03, Loss_u: 1.58497e-02, Loss_f: 8.71346e-05, Alpha:0.002
# Iter 0, Loss: 4.81585e-03, Loss_u: 1.58501e-02, Loss_f: 8.68596e-05, Alpha:0.002
# Iter 0, Loss: 4.81580e-03, Loss_u: 1.58507e-02, Loss_f: 8.65422e-05, Alpha:0.002
# Iter 0, Loss: 4.81575e-03, Loss_u: 1.58512e-02, Loss_f: 8.62670e-05, Alpha:0.002
# Iter 0, Loss: 4.81562e-03, Loss_u: 1.58523e-02, Loss_f: 8.56339e-05, Alpha:0.002
# Iter 0, Loss: 4.81559e-03, Loss_u: 1.58530e-02, Loss_f: 8.52695e-05, Alpha:0.002
# Iter 0, Loss: 4.81556e-03, Loss_u: 1.58537e-02, Loss_f: 8.49332e-05, Alpha:0.002
# Iter 0, Loss: 4.81552e-03, Loss_u: 1.58538e-02, Loss_f: 8.48454e-05, Alpha:0.002
# Iter 0, Loss: 4.81539e-03, Loss_u: 1.58530e-02, Loss_f: 8.49979e-05, Alpha:0.002
# Iter 0, Loss: 4.81535e-03, Loss_u: 1.58541e-02, Loss_f: 8.44618e-05, Alpha:0.002
# Iter 0, Loss: 4.81531e-03, Loss_u: 1.58546e-02, Loss_f: 8.41806e-05, Alpha:0.002
# Iter 0, Loss: 4.81525e-03, Loss_u: 1.58552e-02, Loss_f: 8.38231e-05, Alpha:0.002
# Iter 0, Loss: 4.81519e-03, Loss_u: 1.58557e-02, Loss_f: 8.35697e-05, Alpha:0.002
# Iter 0, Loss: 4.81514e-03, Loss_u: 1.58557e-02, Loss_f: 8.34561e-05, Alpha:0.002
# Iter 0, Loss: 4.81488e-03, Loss_u: 1.58517e-02, Loss_f: 8.48269e-05, Alpha:0.002
# Iter 0, Loss: 4.81484e-03, Loss_u: 1.58525e-02, Loss_f: 8.43904e-05, Alpha:0.002
# Iter 0, Loss: 4.81480e-03, Loss_u: 1.58528e-02, Loss_f: 8.42421e-05, Alpha:0.002
# Iter 0, Loss: 4.81469e-03, Loss_u: 1.58530e-02, Loss_f: 8.39701e-05, Alpha:0.001
# Iter 0, Loss: 4.81466e-03, Loss_u: 1.58534e-02, Loss_f: 8.37716e-05, Alpha:0.001
# Iter 0, Loss: 4.81458e-03, Loss_u: 1.58547e-02, Loss_f: 8.30778e-05, Alpha:0.001
# Iter 0, Loss: 4.81454e-03, Loss_u: 1.58546e-02, Loss_f: 8.30852e-05, Alpha:0.001
# Iter 0, Loss: 4.81448e-03, Loss_u: 1.58549e-02, Loss_f: 8.28646e-05, Alpha:0.001
# Iter 0, Loss: 4.81439e-03, Loss_u: 1.58543e-02, Loss_f: 8.29789e-05, Alpha:0.001
# Iter 0, Loss: 4.81433e-03, Loss_u: 1.58538e-02, Loss_f: 8.31297e-05, Alpha:0.001
# Iter 0, Loss: 4.81429e-03, Loss_u: 1.58534e-02, Loss_f: 8.32252e-05, Alpha:0.001
# Iter 0, Loss: 4.81414e-03, Loss_u: 1.58478e-02, Loss_f: 8.54507e-05, Alpha:0.001
# Iter 0, Loss: 4.81408e-03, Loss_u: 1.58479e-02, Loss_f: 8.53122e-05, Alpha:0.001
# Iter 0, Loss: 4.81402e-03, Loss_u: 1.58480e-02, Loss_f: 8.51567e-05, Alpha:0.001
# Iter 0, Loss: 4.81394e-03, Loss_u: 1.58493e-02, Loss_f: 8.45088e-05, Alpha:0.001
# Iter 0, Loss: 4.81387e-03, Loss_u: 1.58490e-02, Loss_f: 8.45387e-05, Alpha:0.001
# Iter 0, Loss: 4.81378e-03, Loss_u: 1.58495e-02, Loss_f: 8.41604e-05, Alpha:0.001
# Iter 0, Loss: 4.81359e-03, Loss_u: 1.58480e-02, Loss_f: 8.45745e-05, Alpha:0.001
# Iter 0, Loss: 4.81351e-03, Loss_u: 1.58479e-02, Loss_f: 8.44830e-05, Alpha:0.001
# Iter 0, Loss: 4.81341e-03, Loss_u: 1.58492e-02, Loss_f: 8.37968e-05, Alpha:0.001
# Iter 0, Loss: 4.81330e-03, Loss_u: 1.58454e-02, Loss_f: 8.52612e-05, Alpha:0.002
# Iter 0, Loss: 4.81320e-03, Loss_u: 1.58456e-02, Loss_f: 8.50261e-05, Alpha:0.002
# Iter 0, Loss: 4.81313e-03, Loss_u: 1.58448e-02, Loss_f: 8.52570e-05, Alpha:0.002
# Iter 0, Loss: 4.81306e-03, Loss_u: 1.58454e-02, Loss_f: 8.48966e-05, Alpha:0.002
# Iter 0, Loss: 4.81299e-03, Loss_u: 1.58452e-02, Loss_f: 8.49109e-05, Alpha:0.002
# Iter 0, Loss: 4.81280e-03, Loss_u: 1.58355e-02, Loss_f: 8.87738e-05, Alpha:0.002
# Iter 0, Loss: 4.81274e-03, Loss_u: 1.58373e-02, Loss_f: 8.79372e-05, Alpha:0.002
# Iter 0, Loss: 4.81268e-03, Loss_u: 1.58376e-02, Loss_f: 8.77285e-05, Alpha:0.002
# Iter 0, Loss: 4.81261e-03, Loss_u: 1.58389e-02, Loss_f: 8.70597e-05, Alpha:0.002
# Iter 0, Loss: 4.81255e-03, Loss_u: 1.58391e-02, Loss_f: 8.68815e-05, Alpha:0.002
# Iter 0, Loss: 4.81247e-03, Loss_u: 1.58389e-02, Loss_f: 8.68612e-05, Alpha:0.002
# Iter 0, Loss: 4.81239e-03, Loss_u: 1.58402e-02, Loss_f: 8.61961e-05, Alpha:0.002
# Iter 0, Loss: 4.81231e-03, Loss_u: 1.58380e-02, Loss_f: 8.69936e-05, Alpha:0.002
# Iter 0, Loss: 4.81223e-03, Loss_u: 1.58380e-02, Loss_f: 8.68791e-05, Alpha:0.002
# Iter 0, Loss: 4.81216e-03, Loss_u: 1.58373e-02, Loss_f: 8.71018e-05, Alpha:0.002
# Iter 0, Loss: 4.81200e-03, Loss_u: 1.58319e-02, Loss_f: 8.91725e-05, Alpha:0.002
# Iter 0, Loss: 4.81195e-03, Loss_u: 1.58322e-02, Loss_f: 8.89708e-05, Alpha:0.002
# Iter 0, Loss: 4.81190e-03, Loss_u: 1.58319e-02, Loss_f: 8.90381e-05, Alpha:0.002
# Iter 0, Loss: 4.81175e-03, Loss_u: 1.58278e-02, Loss_f: 9.06049e-05, Alpha:0.002
# Iter 0, Loss: 4.81171e-03, Loss_u: 1.58279e-02, Loss_f: 9.05059e-05, Alpha:0.002
# Iter 0, Loss: 4.81169e-03, Loss_u: 1.58284e-02, Loss_f: 9.02607e-05, Alpha:0.002
# Iter 0, Loss: 4.81166e-03, Loss_u: 1.58273e-02, Loss_f: 9.06684e-05, Alpha:0.002
# Iter 0, Loss: 4.81164e-03, Loss_u: 1.58276e-02, Loss_f: 9.04989e-05, Alpha:0.002
# Iter 0, Loss: 4.81161e-03, Loss_u: 1.58273e-02, Loss_f: 9.05810e-05, Alpha:0.002
# Iter 0, Loss: 4.81159e-03, Loss_u: 1.58269e-02, Loss_f: 9.07571e-05, Alpha:0.002
# Iter 0, Loss: 4.81156e-03, Loss_u: 1.58268e-02, Loss_f: 9.07488e-05, Alpha:0.002
# Iter 0, Loss: 4.81155e-03, Loss_u: 1.58267e-02, Loss_f: 9.07696e-05, Alpha:0.002
# Iter 0, Loss: 4.81153e-03, Loss_u: 1.58263e-02, Loss_f: 9.09118e-05, Alpha:0.002
# Iter 0, Loss: 4.81151e-03, Loss_u: 1.58258e-02, Loss_f: 9.11179e-05, Alpha:0.002
# Iter 0, Loss: 4.81149e-03, Loss_u: 1.58257e-02, Loss_f: 9.11142e-05, Alpha:0.002
# Iter 0, Loss: 4.81148e-03, Loss_u: 1.58257e-02, Loss_f: 9.11244e-05, Alpha:0.002
# Iter 0, Loss: 4.81147e-03, Loss_u: 1.58253e-02, Loss_f: 9.12711e-05, Alpha:0.002
# Iter 0, Loss: 4.81145e-03, Loss_u: 1.58248e-02, Loss_f: 9.14338e-05, Alpha:0.002
# Iter 0, Loss: 4.81143e-03, Loss_u: 1.58248e-02, Loss_f: 9.14053e-05, Alpha:0.002
# Iter 0, Loss: 4.81137e-03, Loss_u: 1.58243e-02, Loss_f: 9.15144e-05, Alpha:0.002
# Iter 0, Loss: 4.81135e-03, Loss_u: 1.58239e-02, Loss_f: 9.16688e-05, Alpha:0.002
# Iter 0, Loss: 4.81130e-03, Loss_u: 1.58217e-02, Loss_f: 9.25419e-05, Alpha:0.002
# Iter 0, Loss: 4.81127e-03, Loss_u: 1.58220e-02, Loss_f: 9.23875e-05, Alpha:0.002
# Iter 0, Loss: 4.81124e-03, Loss_u: 1.58223e-02, Loss_f: 9.22169e-05, Alpha:0.002
# Iter 0, Loss: 4.81120e-03, Loss_u: 1.58219e-02, Loss_f: 9.23297e-05, Alpha:0.002
# Iter 0, Loss: 4.81106e-03, Loss_u: 1.58189e-02, Loss_f: 9.34088e-05, Alpha:0.002
# Iter 0, Loss: 4.81102e-03, Loss_u: 1.58197e-02, Loss_f: 9.30313e-05, Alpha:0.002
# Iter 0, Loss: 4.81098e-03, Loss_u: 1.58195e-02, Loss_f: 9.30425e-05, Alpha:0.002
# Iter 0, Loss: 4.81084e-03, Loss_u: 1.58182e-02, Loss_f: 9.33778e-05, Alpha:0.002
# Iter 0, Loss: 4.81080e-03, Loss_u: 1.58192e-02, Loss_f: 9.29188e-05, Alpha:0.002
# Iter 0, Loss: 4.81070e-03, Loss_u: 1.58215e-02, Loss_f: 9.17966e-05, Alpha:0.002
# Iter 0, Loss: 4.81066e-03, Loss_u: 1.58215e-02, Loss_f: 9.17183e-05, Alpha:0.002
# Iter 0, Loss: 4.81061e-03, Loss_u: 1.58215e-02, Loss_f: 9.16485e-05, Alpha:0.002
# Iter 0, Loss: 4.81057e-03, Loss_u: 1.58221e-02, Loss_f: 9.13434e-05, Alpha:0.002
# Iter 0, Loss: 4.81053e-03, Loss_u: 1.58223e-02, Loss_f: 9.11981e-05, Alpha:0.002
# Iter 0, Loss: 4.81042e-03, Loss_u: 1.58229e-02, Loss_f: 9.07835e-05, Alpha:0.002
# Iter 0, Loss: 4.81040e-03, Loss_u: 1.58232e-02, Loss_f: 9.06219e-05, Alpha:0.002
# Iter 0, Loss: 4.81034e-03, Loss_u: 1.58246e-02, Loss_f: 8.99254e-05, Alpha:0.002
# Iter 0, Loss: 4.81033e-03, Loss_u: 1.58248e-02, Loss_f: 8.98271e-05, Alpha:0.002
# Iter 0, Loss: 4.81032e-03, Loss_u: 1.58250e-02, Loss_f: 8.97482e-05, Alpha:0.002
# Iter 0, Loss: 4.81028e-03, Loss_u: 1.58245e-02, Loss_f: 8.99204e-05, Alpha:0.002
# Iter 0, Loss: 4.81024e-03, Loss_u: 1.58244e-02, Loss_f: 8.98692e-05, Alpha:0.002
# Iter 0, Loss: 4.81018e-03, Loss_u: 1.58247e-02, Loss_f: 8.96682e-05, Alpha:0.002
# Iter 0, Loss: 4.81014e-03, Loss_u: 1.58246e-02, Loss_f: 8.96631e-05, Alpha:0.002
# Iter 0, Loss: 4.81009e-03, Loss_u: 1.58247e-02, Loss_f: 8.95397e-05, Alpha:0.002
# Iter 0, Loss: 4.80995e-03, Loss_u: 1.58245e-02, Loss_f: 8.94197e-05, Alpha:0.002
# ...
# Iter 0, Loss: 7.34328e-04, Loss_u: 2.42343e-03, Loss_f: 1.04249e-05, Alpha:0.960
# Iter 0, Loss: 7.34252e-04, Loss_u: 2.42309e-03, Loss_f: 1.04626e-05, Alpha:0.960
# Iter 0, Loss: 7.34190e-04, Loss_u: 2.42291e-03, Loss_f: 1.04551e-05, Alpha:0.960
# Iter 0, Loss: 7.34101e-04, Loss_u: 2.42261e-03, Loss_f: 1.04520e-05, Alpha:0.959
# Iter 0, Loss: 7.34061e-04, Loss_u: 2.42247e-03, Loss_f: 1.04546e-05, Alpha:0.959
# Iter 0, Loss: 7.34036e-04, Loss_u: 2.42238e-03, Loss_f: 1.04587e-05, Alpha:0.959
# Iter 0, Loss: 7.34005e-04, Loss_u: 2.42227e-03, Loss_f: 1.04649e-05, Alpha:0.959
# Iter 0, Loss: 7.33992e-04, Loss_u: 2.42221e-03, Loss_f: 1.04696e-05, Alpha:0.959
# Iter 0, Loss: 7.33970e-04, Loss_u: 2.42212e-03, Loss_f: 1.04764e-05, Alpha:0.959
# Iter 0, Loss: 7.33942e-04, Loss_u: 2.42197e-03, Loss_f: 1.04991e-05, Alpha:0.959
# Iter 0, Loss: 7.33934e-04, Loss_u: 2.42193e-03, Loss_f: 1.05089e-05, Alpha:0.959
# Iter 0, Loss: 7.33891e-04, Loss_u: 2.42164e-03, Loss_f: 1.05715e-05, Alpha:0.959
# Iter 0, Loss: 7.33888e-04, Loss_u: 2.42160e-03, Loss_f: 1.05815e-05, Alpha:0.959
# Iter 0, Loss: 7.33879e-04, Loss_u: 2.42148e-03, Loss_f: 1.06205e-05, Alpha:0.959
# Iter 0, Loss: 7.33877e-04, Loss_u: 2.42146e-03, Loss_f: 1.06263e-05, Alpha:0.959
# Iter 0, Loss: 7.33876e-04, Loss_u: 2.42145e-03, Loss_f: 1.06295e-05, Alpha:0.959
# Iter 0, Loss: 7.33879e-04, Loss_u: 2.42146e-03, Loss_f: 1.06284e-05, Alpha:0.959
# Iter 0, Loss: 7.33876e-04, Loss_u: 2.42145e-03, Loss_f: 1.06295e-05, Alpha:0.959
# Iter 0, Loss: 7.33876e-04, Loss_u: 2.42144e-03, Loss_f: 1.06331e-05, Alpha:0.959
# Iter 0, Loss: 7.33878e-04, Loss_u: 2.42144e-03, Loss_f: 1.06369e-05, Alpha:0.959
# Iter 0, Loss: 7.33876e-04, Loss_u: 2.42144e-03, Loss_f: 1.06330e-05, Alpha:0.959
# Iter 0, Loss: 7.33871e-04, Loss_u: 2.42141e-03, Loss_f: 1.06397e-05, Alpha:0.959
# Iter 0, Loss: 7.33876e-04, Loss_u: 2.42142e-03, Loss_f: 1.06416e-05, Alpha:0.959
# Iter 0, Loss: 7.33874e-04, Loss_u: 2.42142e-03, Loss_f: 1.06380e-05, Alpha:0.959
# Iter 0, Loss: 7.33873e-04, Loss_u: 2.42142e-03, Loss_f: 1.06390e-05, Alpha:0.959
# Iter 0, Loss: 7.33871e-04, Loss_u: 2.42141e-03, Loss_f: 1.06396e-05, Alpha:0.959
# Iter 0, Loss: 7.33872e-04, Loss_u: 2.42142e-03, Loss_f: 1.06387e-05, Alpha:0.959
# Iter 0, Loss: 7.33871e-04, Loss_u: 2.42141e-03, Loss_f: 1.06389e-05, Alpha:0.959
# Iter 0, Loss: 7.33867e-04, Loss_u: 2.42138e-03, Loss_f: 1.06458e-05, Alpha:0.959
# Iter 0, Loss: 7.33859e-04, Loss_u: 2.42130e-03, Loss_f: 1.06675e-05, Alpha:0.959
# Iter 0, Loss: 7.33854e-04, Loss_u: 2.42128e-03, Loss_f: 1.06717e-05, Alpha:0.959
# Iter 0, Loss: 7.33856e-04, Loss_u: 2.42129e-03, Loss_f: 1.06715e-05, Alpha:0.959
# Iter 0, Loss: 7.33857e-04, Loss_u: 2.42130e-03, Loss_f: 1.06690e-05, Alpha:0.959
# Iter 0, Loss: 7.33856e-04, Loss_u: 2.42129e-03, Loss_f: 1.06715e-05, Alpha:0.959
# Iter 0, Loss: 7.33852e-04, Loss_u: 2.42127e-03, Loss_f: 1.06709e-05, Alpha:0.959
# Iter 0, Loss: 7.33855e-04, Loss_u: 2.42128e-03, Loss_f: 1.06724e-05, Alpha:0.959
# Iter 0, Loss: 7.33846e-04, Loss_u: 2.42125e-03, Loss_f: 1.06708e-05, Alpha:0.959
# Iter 0, Loss: 7.33848e-04, Loss_u: 2.42126e-03, Loss_f: 1.06694e-05, Alpha:0.959
# Iter 0, Loss: 7.33845e-04, Loss_u: 2.42125e-03, Loss_f: 1.06710e-05, Alpha:0.959
# Iter 0, Loss: 7.33846e-04, Loss_u: 2.42125e-03, Loss_f: 1.06711e-05, Alpha:0.959
# Iter 0, Loss: 7.33845e-04, Loss_u: 2.42125e-03, Loss_f: 1.06710e-05, Alpha:0.959
# Iter 0, Loss: 7.33845e-04, Loss_u: 2.42125e-03, Loss_f: 1.06710e-05, Alpha:0.959
# Iter 0, Loss: 7.33840e-04, Loss_u: 2.42125e-03, Loss_f: 1.06644e-05, Alpha:0.959
# Iter 0, Loss: 7.33819e-04, Loss_u: 2.42125e-03, Loss_f: 1.06322e-05, Alpha:0.960
# Iter 0, Loss: 7.33818e-04, Loss_u: 2.42126e-03, Loss_f: 1.06287e-05, Alpha:0.960
# Iter 0, Loss: 7.33808e-04, Loss_u: 2.42125e-03, Loss_f: 1.06175e-05, Alpha:0.960
# Iter 0, Loss: 7.33809e-04, Loss_u: 2.42127e-03, Loss_f: 1.06113e-05, Alpha:0.960
# Iter 0, Loss: 7.33809e-04, Loss_u: 2.42126e-03, Loss_f: 1.06165e-05, Alpha:0.960
# Iter 0, Loss: 7.33805e-04, Loss_u: 2.42124e-03, Loss_f: 1.06191e-05, Alpha:0.960
# Iter 0, Loss: 7.33807e-04, Loss_u: 2.42125e-03, Loss_f: 1.06185e-05, Alpha:0.960
# Iter 0, Loss: 7.33807e-04, Loss_u: 2.42124e-03, Loss_f: 1.06198e-05, Alpha:0.960
# Iter 0, Loss: 7.33805e-04, Loss_u: 2.42124e-03, Loss_f: 1.06191e-05, Alpha:0.960
# Iter 0, Loss: 7.33809e-04, Loss_u: 2.42126e-03, Loss_f: 1.06151e-05, Alpha:0.960
# Iter 0, Loss: 7.33809e-04, Loss_u: 2.42125e-03, Loss_f: 1.06194e-05, Alpha:0.960
# Iter 0, Loss: 7.33807e-04, Loss_u: 2.42124e-03, Loss_f: 1.06200e-05, Alpha:0.960
# Iter 0, Loss: 7.33805e-04, Loss_u: 2.42124e-03, Loss_f: 1.06191e-05, Alpha:0.960
# Iter 0, Loss: 7.33805e-04, Loss_u: 2.42124e-03, Loss_f: 1.06191e-05, Alpha:0.960
# Iter 0, Loss: 6.73529e-04, Loss_u: 2.04994e-03, Loss_f: 8.36393e-05, Alpha:0.960
# Iter 0, Loss: 6.51980e-04, Loss_u: 2.03958e-03, Loss_f: 5.72929e-05, Alpha:0.955
# Iter 0, Loss: 6.37389e-04, Loss_u: 2.00562e-03, Loss_f: 5.10047e-05, Alpha:0.956
# Iter 0, Loss: 6.25802e-04, Loss_u: 1.97704e-03, Loss_f: 4.67019e-05, Alpha:0.959
# Iter 0, Loss: 6.17161e-04, Loss_u: 1.95524e-03, Loss_f: 4.36992e-05, Alpha:0.962
# Iter 0, Loss: 6.10222e-04, Loss_u: 1.93733e-03, Loss_f: 4.14598e-05, Alpha:0.963
# Iter 0, Loss: 6.04635e-04, Loss_u: 1.92254e-03, Loss_f: 3.98206e-05, Alpha:0.966
# Iter 0, Loss: 6.00134e-04, Loss_u: 1.91054e-03, Loss_f: 3.85319e-05, Alpha:0.967
# Iter 0, Loss: 5.96455e-04, Loss_u: 1.90071e-03, Loss_f: 3.74880e-05, Alpha:0.969
# Iter 0, Loss: 5.81316e-04, Loss_u: 1.85577e-03, Loss_f: 3.51209e-05, Alpha:0.982
# Iter 0, Loss: 5.81052e-04, Loss_u: 1.85552e-03, Loss_f: 3.48519e-05, Alpha:0.982
# Iter 0, Loss: 5.80275e-04, Loss_u: 1.85469e-03, Loss_f: 3.40983e-05, Alpha:0.982
# Iter 0, Loss: 5.79929e-04, Loss_u: 1.85435e-03, Loss_f: 3.37470e-05, Alpha:0.983
# Iter 0, Loss: 5.79535e-04, Loss_u: 1.85404e-03, Loss_f: 3.33183e-05, Alpha:0.983
# Iter 0, Loss: 5.78277e-04, Loss_u: 1.85208e-03, Loss_f: 3.23620e-05, Alpha:0.984
# Iter 0, Loss: 5.78012e-04, Loss_u: 1.85202e-03, Loss_f: 3.20092e-05, Alpha:0.985
# Iter 0, Loss: 5.77862e-04, Loss_u: 1.85198e-03, Loss_f: 3.18116e-05, Alpha:0.986
# Iter 0, Loss: 5.77333e-04, Loss_u: 1.85147e-03, Loss_f: 3.12724e-05, Alpha:0.987
# Iter 0, Loss: 5.77227e-04, Loss_u: 1.85139e-03, Loss_f: 3.11567e-05, Alpha:0.987
# Iter 0, Loss: 5.77063e-04, Loss_u: 1.85117e-03, Loss_f: 3.10157e-05, Alpha:0.987
# Iter 0, Loss: 5.76949e-04, Loss_u: 1.85131e-03, Loss_f: 3.07931e-05, Alpha:0.987
# Iter 0, Loss: 5.76819e-04, Loss_u: 1.85113e-03, Loss_f: 3.06867e-05, Alpha:0.987
# Iter 0, Loss: 5.76709e-04, Loss_u: 1.85125e-03, Loss_f: 3.04780e-05, Alpha:0.987
# Iter 0, Loss: 5.76621e-04, Loss_u: 1.85125e-03, Loss_f: 3.03498e-05, Alpha:0.986
# Iter 0, Loss: 5.76547e-04, Loss_u: 1.85132e-03, Loss_f: 3.02179e-05, Alpha:0.986
# Iter 0, Loss: 5.76307e-04, Loss_u: 1.85147e-03, Loss_f: 2.98079e-05, Alpha:0.985
# Iter 0, Loss: 5.76291e-04, Loss_u: 1.85150e-03, Loss_f: 2.97713e-05, Alpha:0.985
# Iter 0, Loss: 5.76229e-04, Loss_u: 1.85163e-03, Loss_f: 2.96292e-05, Alpha:0.984
# Iter 0, Loss: 5.76220e-04, Loss_u: 1.85166e-03, Loss_f: 2.96020e-05, Alpha:0.984
# Iter 0, Loss: 5.76178e-04, Loss_u: 1.85179e-03, Loss_f: 2.94861e-05, Alpha:0.984
# Iter 0, Loss: 5.76166e-04, Loss_u: 1.85181e-03, Loss_f: 2.94595e-05, Alpha:0.984
# Iter 0, Loss: 5.76151e-04, Loss_u: 1.85185e-03, Loss_f: 2.94221e-05, Alpha:0.984
# Iter 0, Loss: 5.76130e-04, Loss_u: 1.85191e-03, Loss_f: 2.93681e-05, Alpha:0.983
# Iter 0, Loss: 5.76121e-04, Loss_u: 1.85195e-03, Loss_f: 2.93376e-05, Alpha:0.983
# Iter 0, Loss: 5.76101e-04, Loss_u: 1.85196e-03, Loss_f: 2.93019e-05, Alpha:0.983
# Iter 0, Loss: 5.76035e-04, Loss_u: 1.85209e-03, Loss_f: 2.91543e-05, Alpha:0.983
# Iter 0, Loss: 5.76026e-04, Loss_u: 1.85214e-03, Loss_f: 2.91196e-05, Alpha:0.982
# Iter 0, Loss: 5.75987e-04, Loss_u: 1.85240e-03, Loss_f: 2.89550e-05, Alpha:0.982
# Iter 0, Loss: 5.75979e-04, Loss_u: 1.85238e-03, Loss_f: 2.89488e-05, Alpha:0.982
# Iter 0, Loss: 5.75947e-04, Loss_u: 1.85232e-03, Loss_f: 2.89279e-05, Alpha:0.982
# Iter 0, Loss: 5.75936e-04, Loss_u: 1.85233e-03, Loss_f: 2.89072e-05, Alpha:0.982
# Iter 0, Loss: 5.75932e-04, Loss_u: 1.85234e-03, Loss_f: 2.89005e-05, Alpha:0.982
# Iter 0, Loss: 5.75923e-04, Loss_u: 1.85236e-03, Loss_f: 2.88783e-05, Alpha:0.982
# Iter 0, Loss: 5.75883e-04, Loss_u: 1.85243e-03, Loss_f: 2.87917e-05, Alpha:0.982
# Iter 0, Loss: 5.75871e-04, Loss_u: 1.85237e-03, Loss_f: 2.87985e-05, Alpha:0.982
# Iter 0, Loss: 5.75867e-04, Loss_u: 1.85236e-03, Loss_f: 2.87986e-05, Alpha:0.982
# Iter 0, Loss: 5.75857e-04, Loss_u: 1.85234e-03, Loss_f: 2.87908e-05, Alpha:0.982
# Iter 0, Loss: 5.75816e-04, Loss_u: 1.85226e-03, Loss_f: 2.87705e-05, Alpha:0.982
# Iter 0, Loss: 5.75807e-04, Loss_u: 1.85218e-03, Loss_f: 2.87884e-05, Alpha:0.983
# Iter 0, Loss: 5.75800e-04, Loss_u: 1.85215e-03, Loss_f: 2.87940e-05, Alpha:0.983
# Iter 0, Loss: 5.75797e-04, Loss_u: 1.85213e-03, Loss_f: 2.87986e-05, Alpha:0.983
# Iter 0, Loss: 5.75789e-04, Loss_u: 1.85209e-03, Loss_f: 2.88021e-05, Alpha:0.983
# Iter 0, Loss: 5.75767e-04, Loss_u: 1.85197e-03, Loss_f: 2.88204e-05, Alpha:0.983
# Iter 0, Loss: 5.75763e-04, Loss_u: 1.85196e-03, Loss_f: 2.88216e-05, Alpha:0.983
# Iter 0, Loss: 5.75760e-04, Loss_u: 1.85193e-03, Loss_f: 2.88305e-05, Alpha:0.983
# Iter 0, Loss: 5.75755e-04, Loss_u: 1.85190e-03, Loss_f: 2.88336e-05, Alpha:0.983
# Iter 0, Loss: 5.75756e-04, Loss_u: 1.85190e-03, Loss_f: 2.88359e-05, Alpha:0.983
# Iter 0, Loss: 5.75752e-04, Loss_u: 1.85189e-03, Loss_f: 2.88384e-05, Alpha:0.983
# Iter 0, Loss: 5.75746e-04, Loss_u: 1.85186e-03, Loss_f: 2.88397e-05, Alpha:0.983
# Iter 0, Loss: 5.75742e-04, Loss_u: 1.85185e-03, Loss_f: 2.88404e-05, Alpha:0.983
# Iter 0, Loss: 5.75741e-04, Loss_u: 1.85182e-03, Loss_f: 2.88487e-05, Alpha:0.983
# Iter 0, Loss: 5.75738e-04, Loss_u: 1.85180e-03, Loss_f: 2.88531e-05, Alpha:0.983
# Iter 0, Loss: 5.75728e-04, Loss_u: 1.85172e-03, Loss_f: 2.88723e-05, Alpha:0.983
# Iter 0, Loss: 5.75726e-04, Loss_u: 1.85171e-03, Loss_f: 2.88748e-05, Alpha:0.983
# Iter 0, Loss: 5.75725e-04, Loss_u: 1.85169e-03, Loss_f: 2.88831e-05, Alpha:0.983
# Iter 0, Loss: 5.75723e-04, Loss_u: 1.85168e-03, Loss_f: 2.88852e-05, Alpha:0.983
# Iter 0, Loss: 5.75722e-04, Loss_u: 1.85168e-03, Loss_f: 2.88840e-05, Alpha:0.983
# Iter 0, Loss: 5.75718e-04, Loss_u: 1.85165e-03, Loss_f: 2.88881e-05, Alpha:0.983
# Iter 0, Loss: 5.75719e-04, Loss_u: 1.85166e-03, Loss_f: 2.88894e-05, Alpha:0.983
# Iter 0, Loss: 5.75719e-04, Loss_u: 1.85166e-03, Loss_f: 2.88872e-05, Alpha:0.983
# Iter 0, Loss: 5.75719e-04, Loss_u: 1.85166e-03, Loss_f: 2.88872e-05, Alpha:0.983
# Iter 0, Loss: 5.75719e-04, Loss_u: 1.85166e-03, Loss_f: 2.88872e-05, Alpha:0.983
# Iter 0, Loss: 5.75717e-04, Loss_u: 1.85164e-03, Loss_f: 2.88946e-05, Alpha:0.983
# Iter 0, Loss: 5.75710e-04, Loss_u: 1.85155e-03, Loss_f: 2.89201e-05, Alpha:0.983
# Iter 0, Loss: 5.75706e-04, Loss_u: 1.85153e-03, Loss_f: 2.89251e-05, Alpha:0.983
# Iter 0, Loss: 5.75705e-04, Loss_u: 1.85151e-03, Loss_f: 2.89332e-05, Alpha:0.983
# Iter 0, Loss: 5.75702e-04, Loss_u: 1.85149e-03, Loss_f: 2.89353e-05, Alpha:0.983
# Iter 0, Loss: 5.75702e-04, Loss_u: 1.85148e-03, Loss_f: 2.89385e-05, Alpha:0.983
# Iter 0, Loss: 5.75703e-04, Loss_u: 1.85146e-03, Loss_f: 2.89487e-05, Alpha:0.983
# Iter 0, Loss: 5.75702e-04, Loss_u: 1.85148e-03, Loss_f: 2.89389e-05, Alpha:0.983
# Iter 0, Loss: 5.75704e-04, Loss_u: 1.85149e-03, Loss_f: 2.89380e-05, Alpha:0.983
# Iter 0, Loss: 5.75702e-04, Loss_u: 1.85148e-03, Loss_f: 2.89382e-05, Alpha:0.983
# Iter 0, Loss: 5.75702e-04, Loss_u: 1.85148e-03, Loss_f: 2.89385e-05, Alpha:0.983
# Iter 0, Loss: 6.80448e-04, Loss_u: 2.20353e-03, Loss_f: 2.77002e-05, Alpha:0.983
# Iter 0, Loss: 6.70472e-04, Loss_u: 2.16353e-03, Loss_f: 3.05918e-05, Alpha:0.961
# Iter 0, Loss: 6.67533e-04, Loss_u: 2.15635e-03, Loss_f: 2.94668e-05, Alpha:0.958
# Iter 0, Loss: 6.63517e-04, Loss_u: 2.14867e-03, Loss_f: 2.70252e-05, Alpha:0.954
# Iter 0, Loss: 6.60757e-04, Loss_u: 2.14276e-03, Loss_f: 2.56124e-05, Alpha:0.951
# Iter 0, Loss: 6.58468e-04, Loss_u: 2.13878e-03, Loss_f: 2.40495e-05, Alpha:0.948
# Iter 0, Loss: 6.56799e-04, Loss_u: 2.13510e-03, Loss_f: 2.32388e-05, Alpha:0.945
# Iter 0, Loss: 6.54824e-04, Loss_u: 2.13257e-03, Loss_f: 2.15055e-05, Alpha:0.941
# Iter 0, Loss: 6.53847e-04, Loss_u: 2.13072e-03, Loss_f: 2.08998e-05, Alpha:0.938
# Iter 0, Loss: 6.53160e-04, Loss_u: 2.12962e-03, Loss_f: 2.03931e-05, Alpha:0.936
# Iter 0, Loss: 6.52602e-04, Loss_u: 2.12874e-03, Loss_f: 1.99709e-05, Alpha:0.934
# Iter 0, Loss: 6.50799e-04, Loss_u: 2.12626e-03, Loss_f: 1.84574e-05, Alpha:0.925
# Iter 0, Loss: 6.50670e-04, Loss_u: 2.12620e-03, Loss_f: 1.83019e-05, Alpha:0.924
# Iter 0, Loss: 6.50441e-04, Loss_u: 2.12618e-03, Loss_f: 1.79812e-05, Alpha:0.922
# Iter 0, Loss: 6.50369e-04, Loss_u: 2.12617e-03, Loss_f: 1.78850e-05, Alpha:0.922
# Iter 0, Loss: 6.50112e-04, Loss_u: 2.12632e-03, Loss_f: 1.74530e-05, Alpha:0.918
# Iter 0, Loss: 6.50091e-04, Loss_u: 2.12638e-03, Loss_f: 1.73967e-05, Alpha:0.918
# Iter 0, Loss: 6.50076e-04, Loss_u: 2.12647e-03, Loss_f: 1.73372e-05, Alpha:0.917
# Iter 0, Loss: 6.50056e-04, Loss_u: 2.12652e-03, Loss_f: 1.72854e-05, Alpha:0.917
# Iter 0, Loss: 6.49997e-04, Loss_u: 2.12673e-03, Loss_f: 1.71104e-05, Alpha:0.916
# Iter 0, Loss: 6.49984e-04, Loss_u: 2.12680e-03, Loss_f: 1.70624e-05, Alpha:0.916
# Iter 0, Loss: 6.49940e-04, Loss_u: 2.12711e-03, Loss_f: 1.68676e-05, Alpha:0.914
# Iter 0, Loss: 6.49926e-04, Loss_u: 2.12715e-03, Loss_f: 1.68289e-05, Alpha:0.914
# Iter 0, Loss: 6.49912e-04, Loss_u: 2.12720e-03, Loss_f: 1.67905e-05, Alpha:0.914
# Iter 0, Loss: 6.49888e-04, Loss_u: 2.12725e-03, Loss_f: 1.67329e-05, Alpha:0.914
# Iter 0, Loss: 6.49862e-04, Loss_u: 2.12731e-03, Loss_f: 1.66715e-05, Alpha:0.914
# Iter 0, Loss: 6.49832e-04, Loss_u: 2.12736e-03, Loss_f: 1.66074e-05, Alpha:0.913
# Iter 0, Loss: 6.49727e-04, Loss_u: 2.12751e-03, Loss_f: 1.63911e-05, Alpha:0.913
# Iter 0, Loss: 6.49706e-04, Loss_u: 2.12750e-03, Loss_f: 1.63671e-05, Alpha:0.913
# Iter 0, Loss: 6.49698e-04, Loss_u: 2.12750e-03, Loss_f: 1.63568e-05, Alpha:0.913
# Iter 0, Loss: 6.49674e-04, Loss_u: 2.12746e-03, Loss_f: 1.63371e-05, Alpha:0.913
# Iter 0, Loss: 6.49585e-04, Loss_u: 2.12718e-03, Loss_f: 1.63278e-05, Alpha:0.913
# Iter 0, Loss: 6.49575e-04, Loss_u: 2.12716e-03, Loss_f: 1.63222e-05, Alpha:0.913
# Iter 0, Loss: 6.49560e-04, Loss_u: 2.12710e-03, Loss_f: 1.63270e-05, Alpha:0.913
# Iter 0, Loss: 6.49503e-04, Loss_u: 2.12678e-03, Loss_f: 1.63845e-05, Alpha:0.914
# Iter 0, Loss: 6.49491e-04, Loss_u: 2.12674e-03, Loss_f: 1.63850e-05, Alpha:0.914
# Iter 0, Loss: 6.49484e-04, Loss_u: 2.12671e-03, Loss_f: 1.63873e-05, Alpha:0.915
# Iter 0, Loss: 6.49469e-04, Loss_u: 2.12666e-03, Loss_f: 1.63889e-05, Alpha:0.915
# Iter 0, Loss: 6.49467e-04, Loss_u: 2.12665e-03, Loss_f: 1.63900e-05, Alpha:0.915
# Iter 0, Loss: 6.49459e-04, Loss_u: 2.12662e-03, Loss_f: 1.63885e-05, Alpha:0.915
# Iter 0, Loss: 6.49423e-04, Loss_u: 2.12651e-03, Loss_f: 1.63866e-05, Alpha:0.916
# Iter 0, Loss: 6.49420e-04, Loss_u: 2.12650e-03, Loss_f: 1.63847e-05, Alpha:0.916
# Iter 0, Loss: 6.49405e-04, Loss_u: 2.12642e-03, Loss_f: 1.63961e-05, Alpha:0.916
# Iter 0, Loss: 6.49401e-04, Loss_u: 2.12643e-03, Loss_f: 1.63904e-05, Alpha:0.916
# Iter 0, Loss: 6.49399e-04, Loss_u: 2.12643e-03, Loss_f: 1.63881e-05, Alpha:0.916
# Iter 0, Loss: 6.49397e-04, Loss_u: 2.12643e-03, Loss_f: 1.63818e-05, Alpha:0.916
# Iter 0, Loss: 6.49389e-04, Loss_u: 2.12645e-03, Loss_f: 1.63625e-05, Alpha:0.916
# Iter 0, Loss: 6.49389e-04, Loss_u: 2.12647e-03, Loss_f: 1.63541e-05, Alpha:0.916
# Iter 0, Loss: 6.49389e-04, Loss_u: 2.12647e-03, Loss_f: 1.63540e-05, Alpha:0.916
# Iter 0, Loss: 6.49389e-04, Loss_u: 2.12647e-03, Loss_f: 1.63536e-05, Alpha:0.916
# Iter 0, Loss: 6.49389e-04, Loss_u: 2.12647e-03, Loss_f: 1.63536e-05, Alpha:0.916
# Iter 0, Loss: 6.49387e-04, Loss_u: 2.12649e-03, Loss_f: 1.63444e-05, Alpha:0.916
# Iter 0, Loss: 6.49380e-04, Loss_u: 2.12656e-03, Loss_f: 1.63038e-05, Alpha:0.916
# Iter 0, Loss: 6.49382e-04, Loss_u: 2.12658e-03, Loss_f: 1.62977e-05, Alpha:0.916
# Iter 0, Loss: 6.49382e-04, Loss_u: 2.12656e-03, Loss_f: 1.63054e-05, Alpha:0.916
# Iter 0, Loss: 6.49381e-04, Loss_u: 2.12656e-03, Loss_f: 1.63033e-05, Alpha:0.916
# Iter 0, Loss: 6.49380e-04, Loss_u: 2.12656e-03, Loss_f: 1.63038e-05, Alpha:0.916
# iteration =   10   loss = 0.0034

# %%
from laplace import Laplace
from laplace.utils import ParamNameSubnetMask

subnetwork_mask = ParamNameSubnetMask(model, parameter_names=['alpha','layers.layer_2.weight','layers.layer_2.bias'])
subnetwork_mask.select()
subnetwork_indices = subnetwork_mask.indices

#la = Laplace(model, 'regression', subset_of_weights='subnetwork', hessian_structure='full',subnetwork_indices=subnetwork_indices)

la = Laplace(model, 'regression', subset_of_weights='last_layer', hessian_structure='diag')

la.fit(X_u_train)

# %%
log_prior, log_sigma = torch.ones(1, requires_grad=True), torch.ones(1, requires_grad=True)

hyper_optimizer = torch.optim.Adam([log_prior, log_sigma], lr=1e-1)

for i in range(1000):
    hyper_optimizer.zero_grad()
    neg_marglik = - la.log_marginal_likelihood(log_prior.exp(), log_sigma.exp())
    neg_marglik.backward()
    hyper_optimizer.step()

# %%
torch.nn.utils.parameters_to_vector(la.model.last_layer.parameters())
# Out:
# tensor([ 0.9153, -2.3555, -1.2691,  0.2813, -1.4095,  0.7607,  2.0017, -0.4619,
#         -0.2395,  0.0563,  1.0031, -4.9743, -1.7364], grad_fn=<CatBackward0>)

# %%
la.mean
# Out:
# tensor([ 0.9153, -2.3555, -1.2691,  0.2813, -1.4095,  0.7607,  2.0017, -0.4619,
#         -0.2395,  0.0563,  1.0031, -4.9743, -1.7364])

# %%
la.posterior_precision
# Out:
# tensor([197649.3281,  87803.1172, 207069.8906, 207067.1406, 206832.8438,
#         207070.2031, 206781.8594, 204249.7656, 182902.3125, 205001.2344,
#          53386.6328, 102508.9453, 207071.7812], grad_fn=<AddBackward0>)

# %%
t= np.linspace(0,4,500)

sol = (1/ (2*np.pi))*np.sin(2*np.pi*t)+1

noise_sol_test = sol + np.random.normal(mean,std, len(t))

# %%
f_mu, f_var = la(torch.tensor(t.flatten()[:,None]).float())
f_mu = f_mu.squeeze().detach().cpu().numpy()
f_sigma = f_var.squeeze().sqrt().cpu().numpy()
pred_std = np.sqrt(f_sigma**2 + la.sigma_noise.item()**2)

# %%
u_pred = model(torch.tensor(t.flatten()[:,None] ).float()).detach().cpu().numpy()

error_u = np.linalg.norm(noise_sol_test-u_pred,2)/np.linalg.norm(noise_sol_test,2)
print('Error u: %e' % (error_u))
# Out:
# Error u: 4.524570e+00

# %%
#for name, param in la.model.named_parameters():
#        print(name, param.data)

# %%
plt.plot(t, u_pred, label = "PINN", color = "red")


plt.scatter(t,noise_sol_test,linestyle='dashed', label = "Observations",color= "orange")
plt.annotate(f"Alpha: {model.alpha.item():0.3f}",(1.5,1.3),ha='center')


plt.plot(t, f_mu, "--",label='NN prediction',color="blue")
plt.fill_between(t, f_mu+pred_std,f_mu-pred_std,alpha=0.3, color = "blue")
plt.fill_between(t, f_mu+2*pred_std,f_mu-2*pred_std,alpha=0.2, color = "blue")
plt.fill_between(t, f_mu+3*pred_std,f_mu-3*pred_std,alpha=0.1, color = "blue")


plt.xlabel("T")
plt.ylabel("Y")
plt.legend(frameon=False)

# %%
from LaplacePINN import Laplace
from laplace.utils import ParamNameSubnetMask

#subnetwork_mask = ParamNameSubnetMask(model, parameter_names=['alpha','layers.layer_2.weight','layers.layer_2.bias'])
subnetwork_mask = ParamNameSubnetMask(model, parameter_names=['layers.layer_2.weight','layers.layer_2.bias'])
subnetwork_mask.select()
subnetwork_indices = subnetwork_mask.indices

# %%
from backpack.extensions import DiagGGNExact, DiagGGNMC, KFAC, KFLR, SumGradSquared, BatchGrad
from backpack import backpack, extend, memory_cleanup
from torch.nn.utils import parameters_to_vector, vector_to_parameters


# def diag(self, X, y, **kwargs):
#     context = DiagGGNMC if self.stochastic else DiagGGNExact
#     f = self.model(X)
#     loss = self.lossfunc(f, y)
#     with backpack(context()):
#         loss.backward()
#     dggn = self._get_diag_ggn()

# def _get_diag_ggn(self):
#         if self.stochastic:
#             return torch.cat([p.diag_ggn_mc.data.flatten() for p in self._model.parameters()])
#         else:
#             return torch.cat([p.diag_ggn_exact.data.flatten() for p in self._model.parameters()])

_model = extend(model,use_converter=True)

_loss = extend(torch.nn.MSELoss(reduction ='mean'))


XX,yy = next(iter(X_u_train))

XX, yy = Variable(XX, requires_grad=True), Variable(yy, requires_grad=True)

_model.zero_grad()

_model.eval()

uu = _model(XX)

lloss = _loss(uu, yy) 

with backpack(DiagGGNExact()):
       lloss.backward()

h = torch.cat([p.diag_ggn_exact.data.flatten() for p in _model.parameters()])
print(h)
print(h.shape)

len(parameters_to_vector(_model.parameters()))
