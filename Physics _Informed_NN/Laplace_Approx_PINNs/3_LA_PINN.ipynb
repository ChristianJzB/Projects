# %%
import torch
from torch.autograd import Variable, grad
from torch.utils.data import DataLoader, TensorDataset

from collections import OrderedDict

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from pyDOE import lhs

import os

os.chdir("/home/s2113174/Projects-1")

#np.random.seed(1234)

# CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")

# %% [markdown]
# ## Making the data for an Inverse Problem following the parametric ODE
#
# $$\frac{du}{dt} - \alpha cos(2\pi t)=0$$
#
# with solution
# $$ u(t) = \alpha \frac{sin ( 2 \pi t )}{2 \pi}$$
#
# ## The Problem consist in infering $ \alpha $

# %%
# Deep neural network
class DNN(torch.nn.Module):
    def __init__(self, layers):
        super(DNN, self).__init__()

        # Number of layers
        self.depth = len(layers) - 1
        
        # Activation Function
        self.activation = torch.nn.Tanh
        
        # The following loop organized the layers of the NN         
        layer_list = list()
        for i in range(self.depth - 1): 
            layer_list.append(
                ('layer_%d' % i, torch.nn.Linear(layers[i], layers[i+1])))
            layer_list.append(('activation_%d' % i, self.activation()))
        layer_list.append(
            ('layer_%d' % (self.depth - 1), torch.nn.Linear(layers[-2], layers[-1]))
        )
        layerDict = OrderedDict(layer_list)
        
        # Deploy layers
        self.layers = torch.nn.Sequential(layerDict)

        for param in self.parameters():
            if len(param.shape) > 1:
                torch.nn.init.xavier_normal_(param)

    def forward(self, x):
        out = self.layers(x)
        return out

# %% [markdown]
# ## Parametric PINN for Inverse Problems

# %%
def DE(self,t,pr):
    """ The pytorch autograd version of calculating residual """
    u = self(torch.cat([t, pr], dim=1))
    
    u_t = torch.autograd.grad(
        u, t, 
        grad_outputs=torch.ones_like(u),
        retain_graph=True,
        create_graph=True
    )[0]
    
    f = u_t - pr*torch.cos( 2*torch.pi *t)
    return f

# %%
DNN.DE = DE

# %%
def sample_ic(size):
    return np.zeros(size)

def samples_space(size,maxl):
    t_f_train = lhs(1, size)*maxl
    return t_f_train

def samples_param(min,max,size = 100):
    return min + np.random.rand(size)*max

# %%
def data_pde(size,maxl,minp,maxp):
    t, param = samples_space(size,maxl),samples_param(minp,maxp,size)

    X_u_train = torch.from_numpy(np.concatenate((t.reshape(-1,1),param.reshape(-1,1)),axis=1)).float().to(device)

    X_u_train = TensorDataset(X_u_train,torch.zeros_like(X_u_train[:,0]))
    X_u_train = DataLoader(X_u_train,batch_size=size)

    return X_u_train

def data_ic(size):
    ic = sample_ic(size)

    X_u_train = torch.from_numpy(ic.reshape(-1,1)).float().to(device)

    X_u_train = TensorDataset(X_u_train,torch.zeros_like(X_u_train[:,0]))
    X_u_train = DataLoader(X_u_train,batch_size=size)

    return X_u_train

# %%
def test_set(max_space = 2,obs = 1,param = 1 ,mean = 0,std = 0):

    t= np.linspace(0,max_space,obs)

    sol = (param/ (2*np.pi))*np.sin(2*np.pi*t)

    noise_sol_test = sol + np.random.normal(mean,std, len(t))

    return t,noise_sol_test


def data(max_space = 2,obs = 1,param = 1 ,mean = 0,std = 0.1):

    t= np.linspace(0,max_space,obs)

    sol = (param/ (2*np.pi))*np.sin(2*np.pi*t)

    noise_sol_test = sol + np.random.normal(mean,std, len(t))

    x,y = torch.tensor(t).float().reshape(-1,1),torch.tensor(noise_sol_test).float().reshape(-1,1)
    
    X_u_train = TensorDataset(x,y)

    X_u_train = DataLoader(X_u_train,batch_size=obs)

    return X_u_train

# %%
def train(epochs, pinn,loss,optimizer,size,maxl,minp,maxp):
   
   print("Starting Training")

   #for epoch in range(epochs):
   itr_loss = 0.0   

   for i in range(epochs):
    data_pde_, data_ic_ = data_pde(size,maxl,minp,maxp),data_ic(size)
    
    for (x, y),(ic,yic) in zip(data_pde_, data_ic_):

        ic,t, param = Variable(ic,requires_grad=True),Variable(x[:,0].reshape(-1,1),requires_grad=True),Variable(x[:,1].reshape(-1,1),requires_grad=True)
        
        def loss_func_train():
            
            optimizer.zero_grad()

            ic_pred,f_pred = pinn(torch.cat([ic, param], dim=1)),pinn.DE(t,param)

            loss_u_ic,loss_f = loss(ic_pred,yic),loss(f_pred,y)

            Loss =  loss_f + loss_u_ic

            if i % 10 == 0:
                    print('Iter %d, Loss: %.5e, Loss_ic: %.5e, Loss_f: %.5e' % (i, Loss.item(), loss_u_ic.item(), loss_f.item()))
            
            Loss.backward() 
        
            return Loss

        optimizer.step(loss_func_train) 
        
        oupt = pinn(torch.cat([ic, param], dim=1))  

        loss_val = loss_func_train() 

        itr_loss += loss_val.item()

# %%
# Number of observations
epochs = 100
nobs = 1000
lr = 0.01

min_param , max_param = 0, 10

space = 3

layers = [2] + 2*[50] + [1]

model = DNN(layers)
loss = torch.nn.MSELoss(reduction ='mean')

# %%
optimizer = torch.optim.LBFGS(
    model.parameters(), lr=lr, max_iter=50000, max_eval=None, tolerance_grad=1e-5, tolerance_change=1.0 * np.finfo(float).eps,line_search_fn="strong_wolfe" 
    )

#optimizer = torch.optim.Adam(model.parameters(), lr = lr)

# %%
train(epochs, model,loss,optimizer,nobs,space,min_param , max_param)

# model.load_state_dict(torch.load("Param_model.pt"))
# model.eval()
# Out:
# Starting Training
# Iter 0, Loss: 1.68528e+01, Loss_ic: 3.48747e-02, Loss_f: 1.68179e+01
# Iter 0, Loss: 1.68518e+01, Loss_ic: 3.40377e-02, Loss_f: 1.68177e+01
# Iter 0, Loss: 1.68473e+01, Loss_ic: 3.04033e-02, Loss_f: 1.68169e+01
# Iter 0, Loss: 1.68131e+01, Loss_ic: 5.50606e-03, Loss_f: 1.68076e+01
# Iter 0, Loss: 1.68128e+01, Loss_ic: 5.40317e-03, Loss_f: 1.68074e+01
# Iter 0, Loss: 1.68116e+01, Loss_ic: 4.96085e-03, Loss_f: 1.68067e+01
# Iter 0, Loss: 1.68033e+01, Loss_ic: 2.65359e-03, Loss_f: 1.68007e+01
# Iter 0, Loss: 1.68030e+01, Loss_ic: 2.61572e-03, Loss_f: 1.68004e+01
# Iter 0, Loss: 1.68014e+01, Loss_ic: 2.45597e-03, Loss_f: 1.67990e+01
# Iter 0, Loss: 1.67937e+01, Loss_ic: 2.30239e-03, Loss_f: 1.67914e+01
# Iter 0, Loss: 1.67932e+01, Loss_ic: 2.31175e-03, Loss_f: 1.67909e+01
# Iter 0, Loss: 1.67896e+01, Loss_ic: 2.44429e-03, Loss_f: 1.67872e+01
# Iter 0, Loss: 1.67637e+01, Loss_ic: 9.93354e-03, Loss_f: 1.67538e+01
# Iter 0, Loss: 1.67634e+01, Loss_ic: 9.98285e-03, Loss_f: 1.67534e+01
# Iter 0, Loss: 1.67618e+01, Loss_ic: 1.02081e-02, Loss_f: 1.67516e+01
# Iter 0, Loss: 1.67469e+01, Loss_ic: 1.29920e-02, Loss_f: 1.67340e+01
# Iter 0, Loss: 1.67462e+01, Loss_ic: 1.28978e-02, Loss_f: 1.67333e+01
# Iter 0, Loss: 1.67425e+01, Loss_ic: 1.23815e-02, Loss_f: 1.67301e+01
# Iter 0, Loss: 1.67251e+01, Loss_ic: 9.63924e-03, Loss_f: 1.67155e+01
# Iter 0, Loss: 1.67245e+01, Loss_ic: 9.46984e-03, Loss_f: 1.67150e+01
# Iter 0, Loss: 1.67194e+01, Loss_ic: 7.97642e-03, Loss_f: 1.67114e+01
# Iter 0, Loss: 1.66958e+01, Loss_ic: 6.91866e-04, Loss_f: 1.66951e+01
# Iter 0, Loss: 1.66958e+01, Loss_ic: 6.91776e-04, Loss_f: 1.66951e+01
# Iter 0, Loss: 1.66957e+01, Loss_ic: 6.91374e-04, Loss_f: 1.66950e+01
# Iter 0, Loss: 1.66957e+01, Loss_ic: 6.90888e-04, Loss_f: 1.66950e+01
# Iter 0, Loss: 1.66952e+01, Loss_ic: 6.87427e-04, Loss_f: 1.66945e+01
# Iter 0, Loss: 1.66951e+01, Loss_ic: 6.85624e-04, Loss_f: 1.66944e+01
# Iter 0, Loss: 1.66946e+01, Loss_ic: 6.79004e-04, Loss_f: 1.66940e+01
# Iter 0, Loss: 1.66924e+01, Loss_ic: 6.88675e-04, Loss_f: 1.66918e+01
# Iter 0, Loss: 1.66923e+01, Loss_ic: 6.90366e-04, Loss_f: 1.66916e+01
# Iter 0, Loss: 1.66915e+01, Loss_ic: 7.01380e-04, Loss_f: 1.66908e+01
# Iter 0, Loss: 1.66868e+01, Loss_ic: 9.65979e-04, Loss_f: 1.66858e+01
# /home/s2113174/anaconda3/lib/python3.11/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([1000])) that is different to the input size (torch.Size([1000, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Iter 0, Loss: 1.66866e+01, Loss_ic: 9.73231e-04, Loss_f: 1.66856e+01
# Iter 0, Loss: 1.66862e+01, Loss_ic: 9.90526e-04, Loss_f: 1.66852e+01
# Iter 0, Loss: 1.66839e+01, Loss_ic: 1.12351e-03, Loss_f: 1.66828e+01
# Iter 0, Loss: 1.66837e+01, Loss_ic: 1.12612e-03, Loss_f: 1.66826e+01
# Iter 0, Loss: 1.66827e+01, Loss_ic: 1.13817e-03, Loss_f: 1.66815e+01
# Iter 0, Loss: 1.66777e+01, Loss_ic: 1.19156e-03, Loss_f: 1.66765e+01
# Iter 0, Loss: 1.66773e+01, Loss_ic: 1.16457e-03, Loss_f: 1.66762e+01
# Iter 0, Loss: 1.66759e+01, Loss_ic: 1.04504e-03, Loss_f: 1.66749e+01
# Iter 0, Loss: 1.66689e+01, Loss_ic: 3.67737e-03, Loss_f: 1.66652e+01
# Iter 0, Loss: 1.66688e+01, Loss_ic: 3.62695e-03, Loss_f: 1.66652e+01
# Iter 0, Loss: 1.66683e+01, Loss_ic: 3.40602e-03, Loss_f: 1.66649e+01
# Iter 0, Loss: 1.66661e+01, Loss_ic: 2.36933e-03, Loss_f: 1.66637e+01
# Iter 0, Loss: 1.66660e+01, Loss_ic: 2.34355e-03, Loss_f: 1.66637e+01
# Iter 0, Loss: 1.66656e+01, Loss_ic: 2.23142e-03, Loss_f: 1.66634e+01
# Iter 0, Loss: 1.66626e+01, Loss_ic: 1.39638e-03, Loss_f: 1.66612e+01
# Iter 0, Loss: 1.66625e+01, Loss_ic: 1.38358e-03, Loss_f: 1.66611e+01
# Iter 0, Loss: 1.66625e+01, Loss_ic: 1.36345e-03, Loss_f: 1.66611e+01
# Iter 0, Loss: 1.66621e+01, Loss_ic: 1.23050e-03, Loss_f: 1.66609e+01
# Iter 0, Loss: 1.66621e+01, Loss_ic: 1.22451e-03, Loss_f: 1.66609e+01
# Iter 0, Loss: 1.66620e+01, Loss_ic: 1.21553e-03, Loss_f: 1.66608e+01
# Iter 0, Loss: 1.66617e+01, Loss_ic: 1.15789e-03, Loss_f: 1.66605e+01
# Iter 0, Loss: 1.66616e+01, Loss_ic: 1.14931e-03, Loss_f: 1.66605e+01
# Iter 0, Loss: 1.66615e+01, Loss_ic: 1.11263e-03, Loss_f: 1.66603e+01
# Iter 0, Loss: 1.66609e+01, Loss_ic: 1.00783e-03, Loss_f: 1.66599e+01
# Iter 0, Loss: 1.66609e+01, Loss_ic: 1.00440e-03, Loss_f: 1.66599e+01
# Iter 0, Loss: 1.66606e+01, Loss_ic: 9.76457e-04, Loss_f: 1.66596e+01
# Iter 0, Loss: 1.66594e+01, Loss_ic: 9.03548e-04, Loss_f: 1.66585e+01
# Iter 0, Loss: 1.66594e+01, Loss_ic: 9.02642e-04, Loss_f: 1.66585e+01
# Iter 0, Loss: 1.66594e+01, Loss_ic: 9.01816e-04, Loss_f: 1.66585e+01
# Iter 0, Loss: 1.66592e+01, Loss_ic: 8.96273e-04, Loss_f: 1.66583e+01
# Iter 0, Loss: 1.66587e+01, Loss_ic: 9.00380e-04, Loss_f: 1.66578e+01
# Iter 0, Loss: 1.66587e+01, Loss_ic: 8.99557e-04, Loss_f: 1.66578e+01
# Iter 0, Loss: 1.66586e+01, Loss_ic: 8.95877e-04, Loss_f: 1.66577e+01
# Iter 0, Loss: 1.66579e+01, Loss_ic: 8.75378e-04, Loss_f: 1.66570e+01
# Iter 0, Loss: 1.66578e+01, Loss_ic: 8.74567e-04, Loss_f: 1.66570e+01
# Iter 0, Loss: 1.66576e+01, Loss_ic: 8.71526e-04, Loss_f: 1.66567e+01
# Iter 0, Loss: 1.66566e+01, Loss_ic: 8.70452e-04, Loss_f: 1.66557e+01
# Iter 0, Loss: 1.66565e+01, Loss_ic: 8.64105e-04, Loss_f: 1.66556e+01
# Iter 0, Loss: 1.66561e+01, Loss_ic: 8.34686e-04, Loss_f: 1.66553e+01
# Iter 0, Loss: 1.66533e+01, Loss_ic: 4.66421e-04, Loss_f: 1.66528e+01
# Iter 0, Loss: 1.66532e+01, Loss_ic: 4.64129e-04, Loss_f: 1.66527e+01
# Iter 0, Loss: 1.66531e+01, Loss_ic: 4.60125e-04, Loss_f: 1.66526e+01
# Iter 0, Loss: 1.66524e+01, Loss_ic: 4.44840e-04, Loss_f: 1.66520e+01
# Iter 0, Loss: 1.66523e+01, Loss_ic: 4.36533e-04, Loss_f: 1.66519e+01
# Iter 0, Loss: 1.66519e+01, Loss_ic: 3.99071e-04, Loss_f: 1.66516e+01
# Iter 0, Loss: 1.66505e+01, Loss_ic: 2.43469e-04, Loss_f: 1.66503e+01
# Iter 0, Loss: 1.66505e+01, Loss_ic: 2.40190e-04, Loss_f: 1.66502e+01
# Iter 0, Loss: 1.66502e+01, Loss_ic: 2.25595e-04, Loss_f: 1.66500e+01
# Iter 0, Loss: 1.66493e+01, Loss_ic: 1.71167e-04, Loss_f: 1.66492e+01
# Iter 0, Loss: 1.66493e+01, Loss_ic: 1.66865e-04, Loss_f: 1.66491e+01
# Iter 0, Loss: 1.66491e+01, Loss_ic: 1.54340e-04, Loss_f: 1.66490e+01
# Iter 0, Loss: 1.66482e+01, Loss_ic: 9.65229e-05, Loss_f: 1.66481e+01
# Iter 0, Loss: 1.66481e+01, Loss_ic: 9.33584e-05, Loss_f: 1.66480e+01
# Iter 0, Loss: 1.66474e+01, Loss_ic: 6.82594e-05, Loss_f: 1.66473e+01
# Iter 0, Loss: 1.66453e+01, Loss_ic: 1.53277e-03, Loss_f: 1.66438e+01
# Iter 0, Loss: 1.66452e+01, Loss_ic: 1.49134e-03, Loss_f: 1.66437e+01
# Iter 0, Loss: 1.66450e+01, Loss_ic: 1.31333e-03, Loss_f: 1.66437e+01
# Iter 0, Loss: 1.66440e+01, Loss_ic: 5.77088e-04, Loss_f: 1.66434e+01
# Iter 0, Loss: 1.66439e+01, Loss_ic: 5.68098e-04, Loss_f: 1.66434e+01
# Iter 0, Loss: 1.66437e+01, Loss_ic: 5.03152e-04, Loss_f: 1.66432e+01
# Iter 0, Loss: 1.66425e+01, Loss_ic: 2.75935e-04, Loss_f: 1.66422e+01
# Iter 0, Loss: 1.66424e+01, Loss_ic: 2.71081e-04, Loss_f: 1.66422e+01
# Iter 0, Loss: 1.66423e+01, Loss_ic: 2.63750e-04, Loss_f: 1.66421e+01
# Iter 0, Loss: 1.66418e+01, Loss_ic: 2.34011e-04, Loss_f: 1.66416e+01
# Iter 0, Loss: 1.66394e+01, Loss_ic: 2.87084e-04, Loss_f: 1.66391e+01
# Iter 0, Loss: 1.66394e+01, Loss_ic: 2.88846e-04, Loss_f: 1.66391e+01
# Iter 0, Loss: 1.66393e+01, Loss_ic: 2.92002e-04, Loss_f: 1.66390e+01
# Iter 0, Loss: 1.66388e+01, Loss_ic: 3.15631e-04, Loss_f: 1.66385e+01
# Iter 0, Loss: 1.66387e+01, Loss_ic: 3.12947e-04, Loss_f: 1.66384e+01
# Iter 0, Loss: 1.66384e+01, Loss_ic: 3.01719e-04, Loss_f: 1.66381e+01
# Iter 0, Loss: 1.66369e+01, Loss_ic: 2.58030e-04, Loss_f: 1.66366e+01
# Iter 0, Loss: 1.66368e+01, Loss_ic: 2.59531e-04, Loss_f: 1.66365e+01
# Iter 0, Loss: 1.66364e+01, Loss_ic: 2.65732e-04, Loss_f: 1.66361e+01
# Iter 0, Loss: 1.66344e+01, Loss_ic: 2.78353e-04, Loss_f: 1.66341e+01
# Iter 0, Loss: 1.66342e+01, Loss_ic: 2.61927e-04, Loss_f: 1.66340e+01
# Iter 0, Loss: 1.66331e+01, Loss_ic: 1.62916e-04, Loss_f: 1.66329e+01
# Iter 0, Loss: 1.66329e+01, Loss_ic: 1.58903e-04, Loss_f: 1.66328e+01
# Iter 0, Loss: 1.66324e+01, Loss_ic: 1.40114e-04, Loss_f: 1.66323e+01
# Iter 0, Loss: 1.66288e+01, Loss_ic: 9.89235e-05, Loss_f: 1.66287e+01
# Iter 0, Loss: 1.66287e+01, Loss_ic: 9.74343e-05, Loss_f: 1.66287e+01
# Iter 0, Loss: 1.66287e+01, Loss_ic: 9.50038e-05, Loss_f: 1.66286e+01
# Iter 0, Loss: 1.66282e+01, Loss_ic: 8.42140e-05, Loss_f: 1.66281e+01
# Iter 0, Loss: 1.66264e+01, Loss_ic: 1.47667e-04, Loss_f: 1.66262e+01
# Iter 0, Loss: 1.66263e+01, Loss_ic: 1.49393e-04, Loss_f: 1.66262e+01
# Iter 0, Loss: 1.66262e+01, Loss_ic: 1.54365e-04, Loss_f: 1.66260e+01
# Iter 0, Loss: 1.66257e+01, Loss_ic: 1.81781e-04, Loss_f: 1.66255e+01
# Iter 0, Loss: 1.66220e+01, Loss_ic: 5.18723e-04, Loss_f: 1.66215e+01
# Iter 0, Loss: 1.66219e+01, Loss_ic: 5.18821e-04, Loss_f: 1.66214e+01
# Iter 0, Loss: 1.66216e+01, Loss_ic: 5.16367e-04, Loss_f: 1.66211e+01
# Iter 0, Loss: 1.66201e+01, Loss_ic: 4.37234e-04, Loss_f: 1.66197e+01
# Iter 0, Loss: 1.66200e+01, Loss_ic: 4.38860e-04, Loss_f: 1.66196e+01
# Iter 0, Loss: 1.66196e+01, Loss_ic: 4.40970e-04, Loss_f: 1.66192e+01
# Iter 0, Loss: 1.66179e+01, Loss_ic: 3.38505e-04, Loss_f: 1.66176e+01
# Iter 0, Loss: 1.66178e+01, Loss_ic: 3.21230e-04, Loss_f: 1.66175e+01
# Iter 0, Loss: 1.66174e+01, Loss_ic: 2.58932e-04, Loss_f: 1.66172e+01
# Iter 0, Loss: 1.66173e+01, Loss_ic: 2.52945e-04, Loss_f: 1.66171e+01
# Iter 0, Loss: 1.66172e+01, Loss_ic: 2.40780e-04, Loss_f: 1.66170e+01
# Iter 0, Loss: 1.66168e+01, Loss_ic: 2.11071e-04, Loss_f: 1.66166e+01
# Iter 0, Loss: 1.66167e+01, Loss_ic: 2.06736e-04, Loss_f: 1.66165e+01
# Iter 0, Loss: 1.66164e+01, Loss_ic: 1.83864e-04, Loss_f: 1.66162e+01
# Iter 0, Loss: 1.66150e+01, Loss_ic: 1.66760e-04, Loss_f: 1.66149e+01
# Iter 0, Loss: 1.66150e+01, Loss_ic: 1.67196e-04, Loss_f: 1.66148e+01
# Iter 0, Loss: 1.66149e+01, Loss_ic: 1.70078e-04, Loss_f: 1.66147e+01
# Iter 0, Loss: 1.66147e+01, Loss_ic: 1.80280e-04, Loss_f: 1.66145e+01
# Iter 0, Loss: 1.66146e+01, Loss_ic: 1.77826e-04, Loss_f: 1.66145e+01
# Iter 0, Loss: 1.66145e+01, Loss_ic: 1.72669e-04, Loss_f: 1.66144e+01
# Iter 0, Loss: 1.66140e+01, Loss_ic: 1.55768e-04, Loss_f: 1.66138e+01
# Iter 0, Loss: 1.66139e+01, Loss_ic: 1.56422e-04, Loss_f: 1.66138e+01
# Iter 0, Loss: 1.66138e+01, Loss_ic: 1.59404e-04, Loss_f: 1.66136e+01
# Iter 0, Loss: 1.66129e+01, Loss_ic: 2.37077e-04, Loss_f: 1.66127e+01
# Iter 0, Loss: 1.66129e+01, Loss_ic: 2.36106e-04, Loss_f: 1.66126e+01
# Iter 0, Loss: 1.66126e+01, Loss_ic: 2.34768e-04, Loss_f: 1.66124e+01
# Iter 0, Loss: 1.66115e+01, Loss_ic: 2.98331e-04, Loss_f: 1.66112e+01
# Iter 0, Loss: 1.66115e+01, Loss_ic: 3.04207e-04, Loss_f: 1.66111e+01
# Iter 0, Loss: 1.66112e+01, Loss_ic: 3.32745e-04, Loss_f: 1.66108e+01
# Iter 0, Loss: 1.66097e+01, Loss_ic: 5.55985e-04, Loss_f: 1.66092e+01
# Iter 0, Loss: 1.66096e+01, Loss_ic: 5.69289e-04, Loss_f: 1.66090e+01
# Iter 0, Loss: 1.66089e+01, Loss_ic: 6.36931e-04, Loss_f: 1.66083e+01
# Iter 0, Loss: 1.66045e+01, Loss_ic: 1.65837e-03, Loss_f: 1.66028e+01
# Iter 0, Loss: 1.66043e+01, Loss_ic: 1.70386e-03, Loss_f: 1.66026e+01
# Iter 0, Loss: 1.66033e+01, Loss_ic: 1.92314e-03, Loss_f: 1.66014e+01
# Iter 0, Loss: 1.65970e+01, Loss_ic: 4.78641e-03, Loss_f: 1.65922e+01
# Iter 0, Loss: 1.65964e+01, Loss_ic: 4.98974e-03, Loss_f: 1.65914e+01
# Iter 0, Loss: 1.65940e+01, Loss_ic: 6.04172e-03, Loss_f: 1.65879e+01
# Iter 0, Loss: 1.65852e+01, Loss_ic: 1.77619e-02, Loss_f: 1.65674e+01
# Iter 0, Loss: 1.65848e+01, Loss_ic: 1.80139e-02, Loss_f: 1.65668e+01
# Iter 0, Loss: 1.65832e+01, Loss_ic: 1.91925e-02, Loss_f: 1.65640e+01
# Iter 0, Loss: 1.65746e+01, Loss_ic: 2.67521e-02, Loss_f: 1.65478e+01
# Iter 0, Loss: 1.65151e+01, Loss_ic: 6.43762e-02, Loss_f: 1.64507e+01
# Iter 0, Loss: 2.20086e+01, Loss_ic: 4.41769e+00, Loss_f: 1.75909e+01
# Iter 0, Loss: 1.64963e+01, Loss_ic: 7.02939e-02, Loss_f: 1.64260e+01
# Iter 0, Loss: 1.64907e+01, Loss_ic: 8.85317e-02, Loss_f: 1.64022e+01
# Iter 0, Loss: 1.64890e+01, Loss_ic: 8.89377e-02, Loss_f: 1.64001e+01
# Iter 0, Loss: 1.64814e+01, Loss_ic: 9.09633e-02, Loss_f: 1.63904e+01
# Iter 0, Loss: 1.64223e+01, Loss_ic: 1.46952e-01, Loss_f: 1.62753e+01
# Iter 0, Loss: 1.63976e+01, Loss_ic: 1.51432e-01, Loss_f: 1.62461e+01
# Iter 0, Loss: 1.62111e+01, Loss_ic: 2.62806e-01, Loss_f: 1.59483e+01
# Iter 0, Loss: 1.61973e+01, Loss_ic: 2.67904e-01, Loss_f: 1.59293e+01
# Iter 0, Loss: 1.60896e+01, Loss_ic: 3.25074e-01, Loss_f: 1.57646e+01
# Iter 0, Loss: 1.60721e+01, Loss_ic: 3.24309e-01, Loss_f: 1.57478e+01
# Iter 0, Loss: 1.59983e+01, Loss_ic: 3.26165e-01, Loss_f: 1.56722e+01
# Iter 0, Loss: 1.59791e+01, Loss_ic: 3.34097e-01, Loss_f: 1.56450e+01
# Iter 0, Loss: 1.58312e+01, Loss_ic: 4.11901e-01, Loss_f: 1.54193e+01
# Iter 0, Loss: 1.58032e+01, Loss_ic: 4.18500e-01, Loss_f: 1.53847e+01
# Iter 0, Loss: 1.56117e+01, Loss_ic: 4.97179e-01, Loss_f: 1.51146e+01
# Iter 0, Loss: 1.56054e+01, Loss_ic: 4.96827e-01, Loss_f: 1.51086e+01
# Iter 0, Loss: 1.55533e+01, Loss_ic: 4.95561e-01, Loss_f: 1.50577e+01
# Iter 0, Loss: 1.55464e+01, Loss_ic: 4.96382e-01, Loss_f: 1.50500e+01
# Iter 0, Loss: 1.55167e+01, Loss_ic: 5.00153e-01, Loss_f: 1.50165e+01
# Iter 0, Loss: 1.53642e+01, Loss_ic: 5.53477e-01, Loss_f: 1.48107e+01
# Iter 0, Loss: 1.53599e+01, Loss_ic: 5.51656e-01, Loss_f: 1.48083e+01
# Iter 0, Loss: 1.53239e+01, Loss_ic: 5.36012e-01, Loss_f: 1.47879e+01
# Iter 0, Loss: 1.53180e+01, Loss_ic: 5.33380e-01, Loss_f: 1.47846e+01
# Iter 0, Loss: 1.52915e+01, Loss_ic: 5.21650e-01, Loss_f: 1.47699e+01
# Iter 0, Loss: 1.50513e+01, Loss_ic: 4.05579e-01, Loss_f: 1.46458e+01
# Iter 0, Loss: 1.50390e+01, Loss_ic: 4.00103e-01, Loss_f: 1.46389e+01
# Iter 0, Loss: 1.49344e+01, Loss_ic: 3.54023e-01, Loss_f: 1.45804e+01
# Iter 0, Loss: 1.49157e+01, Loss_ic: 3.47663e-01, Loss_f: 1.45681e+01
# Iter 0, Loss: 1.47580e+01, Loss_ic: 2.94736e-01, Loss_f: 1.44633e+01
# Iter 0, Loss: 1.47374e+01, Loss_ic: 2.87630e-01, Loss_f: 1.44497e+01
# Iter 0, Loss: 1.45629e+01, Loss_ic: 2.29431e-01, Loss_f: 1.43335e+01
# Iter 0, Loss: 1.45436e+01, Loss_ic: 2.24962e-01, Loss_f: 1.43186e+01
# Iter 0, Loss: 1.43821e+01, Loss_ic: 1.89117e-01, Loss_f: 1.41930e+01
# Iter 0, Loss: 1.43670e+01, Loss_ic: 1.84847e-01, Loss_f: 1.41822e+01
# Iter 0, Loss: 1.43015e+01, Loss_ic: 1.66540e-01, Loss_f: 1.41350e+01
# Iter 0, Loss: 1.39272e+01, Loss_ic: 7.01952e-02, Loss_f: 1.38570e+01
# Iter 0, Loss: 1.39237e+01, Loss_ic: 6.95950e-02, Loss_f: 1.38541e+01
# Iter 0, Loss: 1.38946e+01, Loss_ic: 6.54452e-02, Loss_f: 1.38292e+01
# Iter 0, Loss: 1.38898e+01, Loss_ic: 6.51491e-02, Loss_f: 1.38246e+01
# Iter 0, Loss: 1.38684e+01, Loss_ic: 6.38361e-02, Loss_f: 1.38046e+01
# Iter 0, Loss: 1.37652e+01, Loss_ic: 5.76208e-02, Loss_f: 1.37076e+01
# Iter 0, Loss: 1.37524e+01, Loss_ic: 5.64573e-02, Loss_f: 1.36959e+01
# Iter 0, Loss: 1.36458e+01, Loss_ic: 5.17112e-02, Loss_f: 1.35941e+01
# Iter 0, Loss: 1.36300e+01, Loss_ic: 5.02889e-02, Loss_f: 1.35797e+01
# Iter 0, Loss: 1.35447e+01, Loss_ic: 3.99986e-02, Loss_f: 1.35047e+01
# Iter 0, Loss: 1.35415e+01, Loss_ic: 3.95745e-02, Loss_f: 1.35019e+01
# Iter 0, Loss: 1.35152e+01, Loss_ic: 3.59663e-02, Loss_f: 1.34793e+01
# Iter 0, Loss: 1.35126e+01, Loss_ic: 3.55049e-02, Loss_f: 1.34771e+01
# Iter 0, Loss: 1.35011e+01, Loss_ic: 3.34942e-02, Loss_f: 1.34676e+01
# Iter 0, Loss: 1.34105e+01, Loss_ic: 1.79902e-02, Loss_f: 1.33925e+01
# Iter 0, Loss: 1.34089e+01, Loss_ic: 1.78529e-02, Loss_f: 1.33911e+01
# Iter 0, Loss: 1.34021e+01, Loss_ic: 1.72499e-02, Loss_f: 1.33849e+01
# Iter 0, Loss: 1.33484e+01, Loss_ic: 1.20877e-02, Loss_f: 1.33363e+01
# Iter 0, Loss: 1.33475e+01, Loss_ic: 1.19739e-02, Loss_f: 1.33355e+01
# Iter 0, Loss: 1.33433e+01, Loss_ic: 1.14786e-02, Loss_f: 1.33319e+01
# Iter 0, Loss: 1.33075e+01, Loss_ic: 7.74835e-03, Loss_f: 1.32997e+01
# Iter 0, Loss: 1.33065e+01, Loss_ic: 7.68786e-03, Loss_f: 1.32988e+01
# Iter 0, Loss: 1.32979e+01, Loss_ic: 7.18690e-03, Loss_f: 1.32907e+01
# Iter 0, Loss: 1.32614e+01, Loss_ic: 5.68548e-03, Loss_f: 1.32557e+01
# Iter 0, Loss: 1.32598e+01, Loss_ic: 5.62813e-03, Loss_f: 1.32542e+01
# Iter 0, Loss: 1.32528e+01, Loss_ic: 5.39238e-03, Loss_f: 1.32474e+01
# Iter 0, Loss: 1.32015e+01, Loss_ic: 8.17040e-03, Loss_f: 1.31933e+01
# Iter 0, Loss: 1.31997e+01, Loss_ic: 7.94259e-03, Loss_f: 1.31917e+01
# Iter 0, Loss: 1.31919e+01, Loss_ic: 6.98870e-03, Loss_f: 1.31849e+01
# Iter 0, Loss: 1.31371e+01, Loss_ic: 3.78105e-03, Loss_f: 1.31333e+01
# Iter 0, Loss: 1.31364e+01, Loss_ic: 3.73452e-03, Loss_f: 1.31327e+01
# Iter 0, Loss: 1.31311e+01, Loss_ic: 3.40005e-03, Loss_f: 1.31277e+01
# Iter 0, Loss: 1.30962e+01, Loss_ic: 3.82933e-03, Loss_f: 1.30923e+01
# Iter 0, Loss: 1.30955e+01, Loss_ic: 3.78245e-03, Loss_f: 1.30917e+01
# Iter 0, Loss: 1.30900e+01, Loss_ic: 3.38241e-03, Loss_f: 1.30866e+01
# Iter 0, Loss: 1.30664e+01, Loss_ic: 1.88160e-03, Loss_f: 1.30645e+01
# Iter 0, Loss: 1.30650e+01, Loss_ic: 1.83156e-03, Loss_f: 1.30631e+01
# Iter 0, Loss: 1.30585e+01, Loss_ic: 1.62110e-03, Loss_f: 1.30569e+01
# Iter 0, Loss: 1.29981e+01, Loss_ic: 8.11410e-04, Loss_f: 1.29973e+01
# Iter 0, Loss: 1.29945e+01, Loss_ic: 8.18214e-04, Loss_f: 1.29937e+01
# Iter 0, Loss: 1.29636e+01, Loss_ic: 1.02389e-03, Loss_f: 1.29626e+01
# Iter 0, Loss: 1.28139e+01, Loss_ic: 4.51174e-02, Loss_f: 1.27688e+01
# Iter 0, Loss: 1.28113e+01, Loss_ic: 4.44526e-02, Loss_f: 1.27669e+01
# Iter 0, Loss: 1.27890e+01, Loss_ic: 3.89674e-02, Loss_f: 1.27500e+01
# Iter 0, Loss: 1.26843e+01, Loss_ic: 3.92277e-02, Loss_f: 1.26451e+01
# Iter 0, Loss: 1.26820e+01, Loss_ic: 3.92719e-02, Loss_f: 1.26427e+01
# Iter 0, Loss: 1.26623e+01, Loss_ic: 3.97457e-02, Loss_f: 1.26225e+01
# Iter 0, Loss: 1.26585e+01, Loss_ic: 3.97897e-02, Loss_f: 1.26187e+01
# Iter 0, Loss: 1.26420e+01, Loss_ic: 4.00719e-02, Loss_f: 1.26020e+01
# Iter 0, Loss: 1.25247e+01, Loss_ic: 5.14998e-02, Loss_f: 1.24732e+01
# Iter 0, Loss: 1.25221e+01, Loss_ic: 5.12256e-02, Loss_f: 1.24709e+01
# Iter 0, Loss: 1.25106e+01, Loss_ic: 5.00591e-02, Loss_f: 1.24606e+01
# Iter 0, Loss: 1.24242e+01, Loss_ic: 4.79978e-02, Loss_f: 1.23762e+01
# Iter 0, Loss: 1.24220e+01, Loss_ic: 4.78974e-02, Loss_f: 1.23741e+01
# Iter 0, Loss: 1.24123e+01, Loss_ic: 4.75112e-02, Loss_f: 1.23648e+01
# Iter 0, Loss: 1.23396e+01, Loss_ic: 4.89138e-02, Loss_f: 1.22907e+01
# Iter 0, Loss: 1.23376e+01, Loss_ic: 4.90489e-02, Loss_f: 1.22885e+01
# Iter 0, Loss: 1.23203e+01, Loss_ic: 5.03321e-02, Loss_f: 1.22700e+01
# Iter 0, Loss: 1.23175e+01, Loss_ic: 5.03023e-02, Loss_f: 1.22672e+01
# Iter 0, Loss: 1.23049e+01, Loss_ic: 5.01420e-02, Loss_f: 1.22547e+01
# Iter 0, Loss: 1.22091e+01, Loss_ic: 4.52330e-02, Loss_f: 1.21639e+01
# Iter 0, Loss: 1.22068e+01, Loss_ic: 4.51186e-02, Loss_f: 1.21617e+01
# Iter 0, Loss: 1.21969e+01, Loss_ic: 4.46313e-02, Loss_f: 1.21522e+01
# Iter 0, Loss: 1.21248e+01, Loss_ic: 4.40142e-02, Loss_f: 1.20808e+01
# Iter 0, Loss: 1.21232e+01, Loss_ic: 4.35923e-02, Loss_f: 1.20796e+01
# Iter 0, Loss: 1.21097e+01, Loss_ic: 3.98759e-02, Loss_f: 1.20698e+01
# Iter 0, Loss: 1.20364e+01, Loss_ic: 1.66473e-02, Loss_f: 1.20197e+01
# Iter 0, Loss: 1.20352e+01, Loss_ic: 1.65908e-02, Loss_f: 1.20186e+01
# Iter 0, Loss: 1.20300e+01, Loss_ic: 1.63898e-02, Loss_f: 1.20136e+01
# Iter 0, Loss: 1.19949e+01, Loss_ic: 2.06252e-02, Loss_f: 1.19742e+01
# Iter 0, Loss: 1.19943e+01, Loss_ic: 2.06524e-02, Loss_f: 1.19736e+01
# Iter 0, Loss: 1.19918e+01, Loss_ic: 2.07824e-02, Loss_f: 1.19710e+01
# Iter 0, Loss: 1.19673e+01, Loss_ic: 2.29818e-02, Loss_f: 1.19443e+01
# Iter 0, Loss: 1.19650e+01, Loss_ic: 2.32298e-02, Loss_f: 1.19418e+01
# Iter 0, Loss: 1.19449e+01, Loss_ic: 2.57145e-02, Loss_f: 1.19192e+01
# Iter 0, Loss: 1.18351e+01, Loss_ic: 7.35727e-02, Loss_f: 1.17615e+01
# Iter 0, Loss: 1.18320e+01, Loss_ic: 7.35978e-02, Loss_f: 1.17584e+01
# Iter 0, Loss: 1.18069e+01, Loss_ic: 7.45778e-02, Loss_f: 1.17324e+01
# Iter 0, Loss: 1.18048e+01, Loss_ic: 7.44031e-02, Loss_f: 1.17304e+01
# Iter 0, Loss: 1.17857e+01, Loss_ic: 7.28533e-02, Loss_f: 1.17129e+01
# Iter 0, Loss: 1.16685e+01, Loss_ic: 6.63158e-02, Loss_f: 1.16022e+01
# Iter 0, Loss: 1.16672e+01, Loss_ic: 6.59368e-02, Loss_f: 1.16013e+01
# Iter 0, Loss: 1.16616e+01, Loss_ic: 6.42463e-02, Loss_f: 1.15974e+01
# Iter 0, Loss: 1.16209e+01, Loss_ic: 4.77031e-02, Loss_f: 1.15732e+01
# Iter 0, Loss: 1.16199e+01, Loss_ic: 4.73132e-02, Loss_f: 1.15726e+01
# Iter 0, Loss: 1.16158e+01, Loss_ic: 4.55788e-02, Loss_f: 1.15702e+01
# Iter 0, Loss: 1.15950e+01, Loss_ic: 3.67191e-02, Loss_f: 1.15583e+01
# Iter 0, Loss: 1.15930e+01, Loss_ic: 3.59688e-02, Loss_f: 1.15571e+01
# Iter 0, Loss: 1.15846e+01, Loss_ic: 3.27624e-02, Loss_f: 1.15518e+01
# Iter 0, Loss: 1.15228e+01, Loss_ic: 1.85176e-02, Loss_f: 1.15042e+01
# Iter 0, Loss: 1.15211e+01, Loss_ic: 1.83507e-02, Loss_f: 1.15027e+01
# Iter 0, Loss: 1.15078e+01, Loss_ic: 1.68802e-02, Loss_f: 1.14909e+01
# Iter 0, Loss: 1.15068e+01, Loss_ic: 1.68435e-02, Loss_f: 1.14899e+01
# Iter 0, Loss: 1.15021e+01, Loss_ic: 1.66860e-02, Loss_f: 1.14854e+01
# Iter 0, Loss: 1.14632e+01, Loss_ic: 1.57359e-02, Loss_f: 1.14474e+01
# Iter 0, Loss: 1.14624e+01, Loss_ic: 1.56670e-02, Loss_f: 1.14467e+01
# Iter 0, Loss: 1.14589e+01, Loss_ic: 1.53571e-02, Loss_f: 1.14435e+01
# Iter 0, Loss: 1.14422e+01, Loss_ic: 1.36760e-02, Loss_f: 1.14285e+01
# Iter 0, Loss: 1.14410e+01, Loss_ic: 1.35803e-02, Loss_f: 1.14275e+01
# Iter 0, Loss: 1.14362e+01, Loss_ic: 1.31506e-02, Loss_f: 1.14230e+01
# Iter 0, Loss: 1.13974e+01, Loss_ic: 8.83501e-03, Loss_f: 1.13885e+01
# Iter 0, Loss: 1.13965e+01, Loss_ic: 8.76715e-03, Loss_f: 1.13877e+01
# Iter 0, Loss: 1.13889e+01, Loss_ic: 8.18398e-03, Loss_f: 1.13807e+01
# Iter 0, Loss: 1.13454e+01, Loss_ic: 6.83749e-03, Loss_f: 1.13386e+01
# Iter 0, Loss: 1.13448e+01, Loss_ic: 6.83511e-03, Loss_f: 1.13379e+01
# Iter 0, Loss: 1.13388e+01, Loss_ic: 6.82049e-03, Loss_f: 1.13320e+01
# Iter 0, Loss: 1.12910e+01, Loss_ic: 7.42334e-03, Loss_f: 1.12836e+01
# Iter 0, Loss: 1.12892e+01, Loss_ic: 7.39144e-03, Loss_f: 1.12818e+01
# Iter 0, Loss: 1.12734e+01, Loss_ic: 7.13809e-03, Loss_f: 1.12663e+01
# Iter 0, Loss: 1.11725e+01, Loss_ic: 8.43672e-03, Loss_f: 1.11641e+01
# Iter 0, Loss: 1.11703e+01, Loss_ic: 8.46441e-03, Loss_f: 1.11618e+01
# Iter 0, Loss: 1.11606e+01, Loss_ic: 8.61709e-03, Loss_f: 1.11520e+01
# Iter 0, Loss: 1.10899e+01, Loss_ic: 1.47683e-02, Loss_f: 1.10751e+01
# Iter 0, Loss: 1.10879e+01, Loss_ic: 1.49107e-02, Loss_f: 1.10730e+01
# Iter 0, Loss: 1.10713e+01, Loss_ic: 1.63621e-02, Loss_f: 1.10549e+01
# Iter 0, Loss: 1.10041e+01, Loss_ic: 4.02422e-02, Loss_f: 1.09638e+01
# Iter 0, Loss: 1.10028e+01, Loss_ic: 4.04405e-02, Loss_f: 1.09624e+01
# Iter 0, Loss: 1.09920e+01, Loss_ic: 4.22734e-02, Loss_f: 1.09497e+01
# Iter 0, Loss: 1.09174e+01, Loss_ic: 6.58754e-02, Loss_f: 1.08516e+01
# Iter 0, Loss: 1.09125e+01, Loss_ic: 6.53614e-02, Loss_f: 1.08471e+01
# Iter 0, Loss: 1.08720e+01, Loss_ic: 6.21852e-02, Loss_f: 1.08099e+01
# Iter 0, Loss: 1.08674e+01, Loss_ic: 6.22608e-02, Loss_f: 1.08052e+01
# Iter 0, Loss: 1.08281e+01, Loss_ic: 6.35763e-02, Loss_f: 1.07645e+01
# Iter 0, Loss: 1.08212e+01, Loss_ic: 6.39138e-02, Loss_f: 1.07573e+01
# Iter 0, Loss: 1.07635e+01, Loss_ic: 6.77990e-02, Loss_f: 1.06957e+01
# Iter 0, Loss: 1.07557e+01, Loss_ic: 6.81205e-02, Loss_f: 1.06876e+01
# Iter 0, Loss: 1.07219e+01, Loss_ic: 6.99929e-02, Loss_f: 1.06519e+01
# Iter 0, Loss: 1.05826e+01, Loss_ic: 1.10877e-01, Loss_f: 1.04717e+01
# Iter 0, Loss: 1.05796e+01, Loss_ic: 1.10805e-01, Loss_f: 1.04688e+01
# Iter 0, Loss: 1.05667e+01, Loss_ic: 1.10487e-01, Loss_f: 1.04562e+01
# Iter 0, Loss: 1.04937e+01, Loss_ic: 1.08110e-01, Loss_f: 1.03856e+01
# Iter 0, Loss: 1.04915e+01, Loss_ic: 1.07844e-01, Loss_f: 1.03837e+01
# Iter 0, Loss: 1.04729e+01, Loss_ic: 1.05459e-01, Loss_f: 1.03675e+01
# Iter 0, Loss: 1.03653e+01, Loss_ic: 8.33242e-02, Loss_f: 1.02820e+01
# Iter 0, Loss: 1.03627e+01, Loss_ic: 8.30427e-02, Loss_f: 1.02796e+01
# Iter 0, Loss: 1.03400e+01, Loss_ic: 8.06150e-02, Loss_f: 1.02594e+01
# Iter 0, Loss: 1.02221e+01, Loss_ic: 7.16140e-02, Loss_f: 1.01504e+01
# Iter 0, Loss: 1.02192e+01, Loss_ic: 7.18587e-02, Loss_f: 1.01473e+01
# Iter 0, Loss: 1.01948e+01, Loss_ic: 7.40806e-02, Loss_f: 1.01207e+01
# Iter 0, Loss: 1.01894e+01, Loss_ic: 7.39376e-02, Loss_f: 1.01154e+01
# Iter 0, Loss: 1.01436e+01, Loss_ic: 7.34162e-02, Loss_f: 1.00702e+01
# Iter 0, Loss: 1.01362e+01, Loss_ic: 7.38162e-02, Loss_f: 1.00624e+01
# Iter 0, Loss: 1.01044e+01, Loss_ic: 7.56244e-02, Loss_f: 1.00288e+01
# Iter 0, Loss: 9.90741e+00, Loss_ic: 9.96504e-02, Loss_f: 9.80776e+00
# Iter 0, Loss: 9.90357e+00, Loss_ic: 9.94291e-02, Loss_f: 9.80414e+00
# Iter 0, Loss: 9.88683e+00, Loss_ic: 9.85333e-02, Loss_f: 9.78830e+00
# Iter 0, Loss: 9.76899e+00, Loss_ic: 9.94777e-02, Loss_f: 9.66951e+00
# Iter 0, Loss: 9.76510e+00, Loss_ic: 1.00048e-01, Loss_f: 9.66505e+00
# Iter 0, Loss: 9.73224e+00, Loss_ic: 1.05530e-01, Loss_f: 9.62671e+00
# Iter 0, Loss: 9.72519e+00, Loss_ic: 1.06014e-01, Loss_f: 9.61917e+00
# Iter 0, Loss: 9.69436e+00, Loss_ic: 1.08332e-01, Loss_f: 9.58602e+00
# Iter 0, Loss: 9.48624e+00, Loss_ic: 1.47252e-01, Loss_f: 9.33899e+00
# Iter 0, Loss: 9.48026e+00, Loss_ic: 1.46973e-01, Loss_f: 9.33328e+00
# Iter 0, Loss: 9.45529e+00, Loss_ic: 1.45889e-01, Loss_f: 9.30941e+00
# Iter 0, Loss: 9.45097e+00, Loss_ic: 1.45926e-01, Loss_f: 9.30505e+00
# Iter 0, Loss: 9.41480e+00, Loss_ic: 1.46357e-01, Loss_f: 9.26844e+00
# Iter 0, Loss: 9.40640e+00, Loss_ic: 1.46509e-01, Loss_f: 9.25989e+00
# Iter 0, Loss: 9.33668e+00, Loss_ic: 1.48224e-01, Loss_f: 9.18845e+00
# Iter 0, Loss: 9.32856e+00, Loss_ic: 1.48293e-01, Loss_f: 9.18027e+00
# Iter 0, Loss: 9.29290e+00, Loss_ic: 1.48770e-01, Loss_f: 9.14413e+00
# Iter 0, Loss: 9.01339e+00, Loss_ic: 1.73537e-01, Loss_f: 8.83985e+00
# Iter 0, Loss: 9.00867e+00, Loss_ic: 1.74108e-01, Loss_f: 8.83456e+00
# Iter 0, Loss: 8.96953e+00, Loss_ic: 1.79614e-01, Loss_f: 8.78991e+00
# Iter 0, Loss: 8.96264e+00, Loss_ic: 1.80562e-01, Loss_f: 8.78208e+00
# Iter 0, Loss: 8.90334e+00, Loss_ic: 1.89724e-01, Loss_f: 8.71362e+00
# Iter 0, Loss: 8.74160e+00, Loss_ic: 2.64540e-01, Loss_f: 8.47706e+00
# Iter 0, Loss: 8.73670e+00, Loss_ic: 2.64508e-01, Loss_f: 8.47220e+00
# Iter 0, Loss: 8.69459e+00, Loss_ic: 2.64494e-01, Loss_f: 8.43010e+00
# Iter 0, Loss: 8.47287e+00, Loss_ic: 2.92116e-01, Loss_f: 8.18076e+00
# Iter 0, Loss: 8.46588e+00, Loss_ic: 2.91014e-01, Loss_f: 8.17487e+00
# Iter 0, Loss: 8.40529e+00, Loss_ic: 2.81209e-01, Loss_f: 8.12408e+00
# Iter 0, Loss: 8.05732e+00, Loss_ic: 1.95723e-01, Loss_f: 7.86160e+00
# Iter 0, Loss: 8.04325e+00, Loss_ic: 1.94287e-01, Loss_f: 7.84896e+00
# Iter 0, Loss: 7.92898e+00, Loss_ic: 1.81921e-01, Loss_f: 7.74706e+00
# Iter 0, Loss: 7.91790e+00, Loss_ic: 1.80121e-01, Loss_f: 7.73778e+00
# Iter 0, Loss: 7.82378e+00, Loss_ic: 1.64883e-01, Loss_f: 7.65890e+00
# Iter 0, Loss: 7.80666e+00, Loss_ic: 1.62372e-01, Loss_f: 7.64429e+00
# Iter 0, Loss: 7.73320e+00, Loss_ic: 1.51364e-01, Loss_f: 7.58183e+00
# Iter 0, Loss: 7.37021e+00, Loss_ic: 6.69788e-02, Loss_f: 7.30323e+00
# Iter 0, Loss: 7.35663e+00, Loss_ic: 6.56172e-02, Loss_f: 7.29102e+00
# Iter 0, Loss: 7.24882e+00, Loss_ic: 5.47293e-02, Loss_f: 7.19409e+00
# Iter 0, Loss: 7.23847e+00, Loss_ic: 5.42038e-02, Loss_f: 7.18426e+00
# Iter 0, Loss: 7.15437e+00, Loss_ic: 4.98995e-02, Loss_f: 7.10447e+00
# Iter 0, Loss: 7.14262e+00, Loss_ic: 4.89616e-02, Loss_f: 7.09366e+00
# Iter 0, Loss: 7.09210e+00, Loss_ic: 4.50020e-02, Loss_f: 7.04709e+00
# Iter 0, Loss: 6.80823e+00, Loss_ic: 2.79709e-02, Loss_f: 6.78026e+00
# Iter 0, Loss: 6.80243e+00, Loss_ic: 2.77388e-02, Loss_f: 6.77470e+00
# Iter 0, Loss: 6.75518e+00, Loss_ic: 2.58074e-02, Loss_f: 6.72937e+00
# Iter 0, Loss: 6.74939e+00, Loss_ic: 2.52500e-02, Loss_f: 6.72414e+00
# Iter 0, Loss: 6.72422e+00, Loss_ic: 2.29548e-02, Loss_f: 6.70126e+00
# Iter 0, Loss: 6.55196e+00, Loss_ic: 2.38049e-02, Loss_f: 6.52815e+00
# Iter 0, Loss: 6.54777e+00, Loss_ic: 2.35906e-02, Loss_f: 6.52418e+00
# Iter 0, Loss: 6.52967e+00, Loss_ic: 2.27144e-02, Loss_f: 6.50696e+00
# Iter 0, Loss: 6.42189e+00, Loss_ic: 2.25000e-02, Loss_f: 6.39939e+00
# Iter 0, Loss: 6.41995e+00, Loss_ic: 2.24769e-02, Loss_f: 6.39747e+00
# Iter 0, Loss: 6.40304e+00, Loss_ic: 2.23407e-02, Loss_f: 6.38070e+00
# Iter 0, Loss: 6.29415e+00, Loss_ic: 2.82255e-02, Loss_f: 6.26593e+00
# Iter 0, Loss: 6.29119e+00, Loss_ic: 2.83030e-02, Loss_f: 6.26289e+00
# Iter 0, Loss: 6.27831e+00, Loss_ic: 2.86724e-02, Loss_f: 6.24964e+00
# Iter 0, Loss: 6.18712e+00, Loss_ic: 3.50310e-02, Loss_f: 6.15209e+00
# Iter 0, Loss: 6.18463e+00, Loss_ic: 3.49817e-02, Loss_f: 6.14965e+00
# Iter 0, Loss: 6.17365e+00, Loss_ic: 3.47668e-02, Loss_f: 6.13889e+00
# Iter 0, Loss: 6.07952e+00, Loss_ic: 3.31117e-02, Loss_f: 6.04641e+00
# Iter 0, Loss: 6.07630e+00, Loss_ic: 3.30784e-02, Loss_f: 6.04322e+00
# Iter 0, Loss: 6.04808e+00, Loss_ic: 3.28769e-02, Loss_f: 6.01521e+00
# Iter 0, Loss: 5.92707e+00, Loss_ic: 3.41293e-02, Loss_f: 5.89294e+00
# Iter 0, Loss: 5.92078e+00, Loss_ic: 3.39861e-02, Loss_f: 5.88680e+00
# Iter 0, Loss: 5.89309e+00, Loss_ic: 3.33544e-02, Loss_f: 5.85974e+00
# Iter 0, Loss: 5.66200e+00, Loss_ic: 2.90741e-02, Loss_f: 5.63292e+00
# Iter 0, Loss: 5.65620e+00, Loss_ic: 2.90844e-02, Loss_f: 5.62711e+00
# Iter 0, Loss: 5.60742e+00, Loss_ic: 2.94834e-02, Loss_f: 5.57794e+00
# Iter 0, Loss: 5.60207e+00, Loss_ic: 2.93898e-02, Loss_f: 5.57268e+00
# Iter 0, Loss: 5.55636e+00, Loss_ic: 2.87360e-02, Loss_f: 5.52762e+00
# Iter 0, Loss: 5.54924e+00, Loss_ic: 2.85900e-02, Loss_f: 5.52065e+00
# Iter 0, Loss: 5.48874e+00, Loss_ic: 2.75059e-02, Loss_f: 5.46124e+00
# Iter 0, Loss: 5.47994e+00, Loss_ic: 2.74686e-02, Loss_f: 5.45247e+00
# Iter 0, Loss: 5.44166e+00, Loss_ic: 2.74052e-02, Loss_f: 5.41425e+00
# Iter 0, Loss: 5.18543e+00, Loss_ic: 3.65413e-02, Loss_f: 5.14888e+00
# Iter 0, Loss: 5.18257e+00, Loss_ic: 3.65505e-02, Loss_f: 5.14602e+00
# Iter 0, Loss: 5.15831e+00, Loss_ic: 3.68147e-02, Loss_f: 5.12149e+00
# Iter 0, Loss: 5.15421e+00, Loss_ic: 3.69135e-02, Loss_f: 5.11730e+00
# Iter 0, Loss: 5.13615e+00, Loss_ic: 3.73979e-02, Loss_f: 5.09875e+00
# Iter 0, Loss: 4.98174e+00, Loss_ic: 4.71596e-02, Loss_f: 4.93458e+00
# Iter 0, Loss: 4.97815e+00, Loss_ic: 4.74028e-02, Loss_f: 4.93075e+00
# Iter 0, Loss: 4.96238e+00, Loss_ic: 4.85710e-02, Loss_f: 4.91381e+00
# Iter 0, Loss: 4.83160e+00, Loss_ic: 6.95335e-02, Loss_f: 4.76207e+00
# Iter 0, Loss: 4.82811e+00, Loss_ic: 6.95848e-02, Loss_f: 4.75853e+00
# Iter 0, Loss: 4.81281e+00, Loss_ic: 6.98585e-02, Loss_f: 4.74295e+00
# Iter 0, Loss: 4.69332e+00, Loss_ic: 7.79310e-02, Loss_f: 4.61539e+00
# Iter 0, Loss: 4.69043e+00, Loss_ic: 7.79359e-02, Loss_f: 4.61250e+00
# Iter 0, Loss: 4.67771e+00, Loss_ic: 7.79802e-02, Loss_f: 4.59973e+00
# Iter 0, Loss: 4.57206e+00, Loss_ic: 8.09425e-02, Loss_f: 4.49112e+00
# Iter 0, Loss: 4.56919e+00, Loss_ic: 8.06826e-02, Loss_f: 4.48851e+00
# Iter 0, Loss: 4.54418e+00, Loss_ic: 7.84333e-02, Loss_f: 4.46574e+00
# Iter 0, Loss: 4.38410e+00, Loss_ic: 6.67172e-02, Loss_f: 4.31738e+00
# Iter 0, Loss: 4.38043e+00, Loss_ic: 6.61390e-02, Loss_f: 4.31429e+00
# Iter 0, Loss: 4.36436e+00, Loss_ic: 6.36050e-02, Loss_f: 4.30075e+00
# Iter 0, Loss: 4.23706e+00, Loss_ic: 4.35723e-02, Loss_f: 4.19349e+00
# Iter 0, Loss: 4.23292e+00, Loss_ic: 4.30642e-02, Loss_f: 4.18986e+00
# Iter 0, Loss: 4.19722e+00, Loss_ic: 3.87383e-02, Loss_f: 4.15848e+00
# Iter 0, Loss: 4.00929e+00, Loss_ic: 2.10352e-02, Loss_f: 3.98826e+00
# Iter 0, Loss: 4.00677e+00, Loss_ic: 2.09297e-02, Loss_f: 3.98584e+00
# Iter 0, Loss: 3.99568e+00, Loss_ic: 2.04796e-02, Loss_f: 3.97520e+00
# Iter 0, Loss: 3.90170e+00, Loss_ic: 1.82239e-02, Loss_f: 3.88348e+00
# Iter 0, Loss: 3.89749e+00, Loss_ic: 1.81147e-02, Loss_f: 3.87938e+00
# Iter 0, Loss: 3.86170e+00, Loss_ic: 1.73710e-02, Loss_f: 3.84433e+00
# Iter 0, Loss: 3.85606e+00, Loss_ic: 1.73321e-02, Loss_f: 3.83873e+00
# Iter 0, Loss: 3.83162e+00, Loss_ic: 1.72246e-02, Loss_f: 3.81439e+00
# Iter 0, Loss: 3.67092e+00, Loss_ic: 2.32017e-02, Loss_f: 3.64772e+00
# Iter 0, Loss: 3.66821e+00, Loss_ic: 2.33919e-02, Loss_f: 3.64482e+00
# Iter 0, Loss: 3.64639e+00, Loss_ic: 2.53218e-02, Loss_f: 3.62107e+00
# Iter 0, Loss: 3.64476e+00, Loss_ic: 2.54213e-02, Loss_f: 3.61934e+00
# Iter 0, Loss: 3.63757e+00, Loss_ic: 2.58975e-02, Loss_f: 3.61167e+00
# Iter 0, Loss: 3.57810e+00, Loss_ic: 3.41726e-02, Loss_f: 3.54393e+00
# Iter 0, Loss: 3.57705e+00, Loss_ic: 3.42940e-02, Loss_f: 3.54276e+00
# Iter 0, Loss: 3.56798e+00, Loss_ic: 3.54239e-02, Loss_f: 3.53256e+00
# Iter 0, Loss: 3.51614e+00, Loss_ic: 5.04513e-02, Loss_f: 3.46569e+00
# Iter 0, Loss: 3.51531e+00, Loss_ic: 5.05127e-02, Loss_f: 3.46479e+00
# Iter 0, Loss: 3.51158e+00, Loss_ic: 5.07908e-02, Loss_f: 3.46079e+00
# Iter 0, Loss: 3.47555e+00, Loss_ic: 5.40616e-02, Loss_f: 3.42148e+00
# Iter 0, Loss: 3.47330e+00, Loss_ic: 5.40954e-02, Loss_f: 3.41921e+00
# Iter 0, Loss: 3.46340e+00, Loss_ic: 5.42446e-02, Loss_f: 3.40915e+00
# Iter 0, Loss: 3.37614e+00, Loss_ic: 5.55080e-02, Loss_f: 3.32063e+00
# Iter 0, Loss: 3.37411e+00, Loss_ic: 5.54560e-02, Loss_f: 3.31866e+00
# Iter 0, Loss: 3.35662e+00, Loss_ic: 5.49513e-02, Loss_f: 3.30167e+00
# Iter 0, Loss: 3.25654e+00, Loss_ic: 4.62211e-02, Loss_f: 3.21032e+00
# Iter 0, Loss: 3.25428e+00, Loss_ic: 4.60000e-02, Loss_f: 3.20828e+00
# Iter 0, Loss: 3.24481e+00, Loss_ic: 4.49897e-02, Loss_f: 3.19982e+00
# Iter 0, Loss: 3.24322e+00, Loss_ic: 4.48425e-02, Loss_f: 3.19838e+00
# Iter 0, Loss: 3.22941e+00, Loss_ic: 4.34959e-02, Loss_f: 3.18591e+00
# Iter 0, Loss: 3.17293e+00, Loss_ic: 3.61856e-02, Loss_f: 3.13674e+00
# Iter 0, Loss: 3.17103e+00, Loss_ic: 3.59061e-02, Loss_f: 3.13512e+00
# Iter 0, Loss: 3.16265e+00, Loss_ic: 3.46412e-02, Loss_f: 3.12801e+00
# Iter 0, Loss: 3.09237e+00, Loss_ic: 2.13360e-02, Loss_f: 3.07103e+00
# Iter 0, Loss: 3.09012e+00, Loss_ic: 2.11337e-02, Loss_f: 3.06898e+00
# Iter 0, Loss: 3.08032e+00, Loss_ic: 2.02548e-02, Loss_f: 3.06007e+00
# Iter 0, Loss: 3.01276e+00, Loss_ic: 1.44999e-02, Loss_f: 2.99826e+00
# Iter 0, Loss: 3.01177e+00, Loss_ic: 1.44086e-02, Loss_f: 2.99736e+00
# Iter 0, Loss: 3.00739e+00, Loss_ic: 1.40050e-02, Loss_f: 2.99338e+00
# Iter 0, Loss: 2.97251e+00, Loss_ic: 1.09087e-02, Loss_f: 2.96160e+00
# Iter 0, Loss: 2.97159e+00, Loss_ic: 1.09295e-02, Loss_f: 2.96066e+00
# Iter 0, Loss: 2.96367e+00, Loss_ic: 1.11284e-02, Loss_f: 2.95254e+00
# Iter 0, Loss: 2.91904e+00, Loss_ic: 1.39906e-02, Loss_f: 2.90505e+00
# Iter 0, Loss: 2.91846e+00, Loss_ic: 1.39827e-02, Loss_f: 2.90448e+00
# Iter 0, Loss: 2.91589e+00, Loss_ic: 1.39504e-02, Loss_f: 2.90194e+00
# Iter 0, Loss: 2.89190e+00, Loss_ic: 1.39454e-02, Loss_f: 2.87795e+00
# Iter 0, Loss: 2.89084e+00, Loss_ic: 1.39946e-02, Loss_f: 2.87684e+00
# Iter 0, Loss: 2.88175e+00, Loss_ic: 1.44970e-02, Loss_f: 2.86725e+00
# Iter 0, Loss: 2.83340e+00, Loss_ic: 2.52537e-02, Loss_f: 2.80815e+00
# Iter 0, Loss: 2.83296e+00, Loss_ic: 2.52908e-02, Loss_f: 2.80767e+00
# Iter 0, Loss: 2.83101e+00, Loss_ic: 2.54586e-02, Loss_f: 2.80555e+00
# Iter 0, Loss: 2.81317e+00, Loss_ic: 2.73692e-02, Loss_f: 2.78581e+00
# Iter 0, Loss: 2.81216e+00, Loss_ic: 2.73568e-02, Loss_f: 2.78480e+00
# Iter 0, Loss: 2.80332e+00, Loss_ic: 2.72429e-02, Loss_f: 2.77608e+00
# Iter 0, Loss: 2.74687e+00, Loss_ic: 2.66277e-02, Loss_f: 2.72024e+00
# Iter 0, Loss: 2.74541e+00, Loss_ic: 2.67772e-02, Loss_f: 2.71864e+00
# Iter 0, Loss: 2.73300e+00, Loss_ic: 2.82532e-02, Loss_f: 2.70474e+00
# Iter 0, Loss: 2.73076e+00, Loss_ic: 2.83104e-02, Loss_f: 2.70245e+00
# Iter 0, Loss: 2.72092e+00, Loss_ic: 2.85754e-02, Loss_f: 2.69234e+00
# Iter 0, Loss: 2.63849e+00, Loss_ic: 3.22475e-02, Loss_f: 2.60624e+00
# Iter 0, Loss: 2.63701e+00, Loss_ic: 3.22402e-02, Loss_f: 2.60477e+00
# Iter 0, Loss: 2.62417e+00, Loss_ic: 3.22060e-02, Loss_f: 2.59197e+00
# Iter 0, Loss: 2.54236e+00, Loss_ic: 3.48918e-02, Loss_f: 2.50747e+00
# Iter 0, Loss: 2.54158e+00, Loss_ic: 3.48201e-02, Loss_f: 2.50676e+00
# Iter 0, Loss: 2.53478e+00, Loss_ic: 3.41842e-02, Loss_f: 2.50060e+00
# Iter 0, Loss: 2.50590e+00, Loss_ic: 3.13078e-02, Loss_f: 2.47459e+00
# Iter 0, Loss: 2.50430e+00, Loss_ic: 3.12879e-02, Loss_f: 2.47301e+00
# Iter 0, Loss: 2.49049e+00, Loss_ic: 3.11523e-02, Loss_f: 2.45934e+00
# Iter 0, Loss: 2.41305e+00, Loss_ic: 3.44663e-02, Loss_f: 2.37858e+00
# Iter 0, Loss: 2.41224e+00, Loss_ic: 3.43721e-02, Loss_f: 2.37787e+00
# Iter 0, Loss: 2.40865e+00, Loss_ic: 3.39488e-02, Loss_f: 2.37470e+00
# Iter 0, Loss: 2.37710e+00, Loss_ic: 2.94676e-02, Loss_f: 2.34764e+00
# Iter 0, Loss: 2.37594e+00, Loss_ic: 2.94409e-02, Loss_f: 2.34650e+00
# Iter 0, Loss: 2.36594e+00, Loss_ic: 2.92342e-02, Loss_f: 2.33670e+00
# Iter 0, Loss: 2.30666e+00, Loss_ic: 3.01052e-02, Loss_f: 2.27655e+00
# Iter 0, Loss: 2.30608e+00, Loss_ic: 2.99061e-02, Loss_f: 2.27617e+00
# Iter 0, Loss: 2.30116e+00, Loss_ic: 2.81666e-02, Loss_f: 2.27300e+00
# Iter 0, Loss: 2.30036e+00, Loss_ic: 2.81166e-02, Loss_f: 2.27225e+00
# Iter 0, Loss: 2.29346e+00, Loss_ic: 2.76786e-02, Loss_f: 2.26578e+00
# Iter 0, Loss: 2.25554e+00, Loss_ic: 2.44605e-02, Loss_f: 2.23107e+00
# Iter 0, Loss: 2.25528e+00, Loss_ic: 2.44200e-02, Loss_f: 2.23086e+00
# Iter 0, Loss: 2.25415e+00, Loss_ic: 2.42387e-02, Loss_f: 2.22991e+00
# Iter 0, Loss: 2.24825e+00, Loss_ic: 2.32766e-02, Loss_f: 2.22497e+00
# Iter 0, Loss: 2.24713e+00, Loss_ic: 2.31993e-02, Loss_f: 2.22393e+00
# Iter 0, Loss: 2.23749e+00, Loss_ic: 2.25165e-02, Loss_f: 2.21498e+00
# Iter 0, Loss: 2.18204e+00, Loss_ic: 1.71006e-02, Loss_f: 2.16493e+00
# Iter 0, Loss: 2.18154e+00, Loss_ic: 1.71044e-02, Loss_f: 2.16443e+00
# Iter 0, Loss: 2.17934e+00, Loss_ic: 1.71219e-02, Loss_f: 2.16222e+00
# Iter 0, Loss: 2.16854e+00, Loss_ic: 1.72352e-02, Loss_f: 2.15131e+00
# Iter 0, Loss: 2.16758e+00, Loss_ic: 1.72132e-02, Loss_f: 2.15036e+00
# Iter 0, Loss: 2.16331e+00, Loss_ic: 1.71167e-02, Loss_f: 2.14619e+00
# Iter 0, Loss: 2.12639e+00, Loss_ic: 1.63223e-02, Loss_f: 2.11007e+00
# Iter 0, Loss: 2.12552e+00, Loss_ic: 1.63175e-02, Loss_f: 2.10920e+00
# Iter 0, Loss: 2.11792e+00, Loss_ic: 1.62834e-02, Loss_f: 2.10163e+00
# Iter 0, Loss: 2.06908e+00, Loss_ic: 1.65555e-02, Loss_f: 2.05252e+00
# Iter 0, Loss: 2.06859e+00, Loss_ic: 1.65946e-02, Loss_f: 2.05199e+00
# Iter 0, Loss: 2.06436e+00, Loss_ic: 1.69464e-02, Loss_f: 2.04742e+00
# Iter 0, Loss: 2.03802e+00, Loss_ic: 2.04875e-02, Loss_f: 2.01753e+00
# Iter 0, Loss: 2.03757e+00, Loss_ic: 2.04925e-02, Loss_f: 2.01708e+00
# Iter 0, Loss: 2.03366e+00, Loss_ic: 2.05409e-02, Loss_f: 2.01312e+00
# Iter 0, Loss: 2.00608e+00, Loss_ic: 2.13483e-02, Loss_f: 1.98473e+00
# Iter 0, Loss: 2.00556e+00, Loss_ic: 2.13185e-02, Loss_f: 1.98424e+00
# Iter 0, Loss: 2.00099e+00, Loss_ic: 2.10448e-02, Loss_f: 1.97995e+00
# Iter 0, Loss: 1.96981e+00, Loss_ic: 1.81280e-02, Loss_f: 1.95169e+00
# Iter 0, Loss: 1.96919e+00, Loss_ic: 1.81300e-02, Loss_f: 1.95106e+00
# Iter 0, Loss: 1.96646e+00, Loss_ic: 1.81462e-02, Loss_f: 1.94832e+00
# Iter 0, Loss: 1.94346e+00, Loss_ic: 1.90689e-02, Loss_f: 1.92439e+00
# Iter 0, Loss: 1.94266e+00, Loss_ic: 1.89866e-02, Loss_f: 1.92368e+00
# Iter 0, Loss: 1.93916e+00, Loss_ic: 1.86212e-02, Loss_f: 1.92054e+00
# Iter 0, Loss: 1.90924e+00, Loss_ic: 1.51739e-02, Loss_f: 1.89406e+00
# Iter 0, Loss: 1.90842e+00, Loss_ic: 1.51393e-02, Loss_f: 1.89329e+00
# Iter 0, Loss: 1.90138e+00, Loss_ic: 1.48459e-02, Loss_f: 1.88654e+00
# Iter 0, Loss: 1.85789e+00, Loss_ic: 1.37904e-02, Loss_f: 1.84410e+00
# Iter 0, Loss: 1.85735e+00, Loss_ic: 1.37527e-02, Loss_f: 1.84359e+00
# Iter 0, Loss: 1.85495e+00, Loss_ic: 1.35857e-02, Loss_f: 1.84137e+00
# Iter 0, Loss: 1.84316e+00, Loss_ic: 1.27594e-02, Loss_f: 1.83040e+00
# Iter 0, Loss: 1.84214e+00, Loss_ic: 1.27073e-02, Loss_f: 1.82943e+00
# Iter 0, Loss: 1.83765e+00, Loss_ic: 1.24812e-02, Loss_f: 1.82517e+00
# Iter 0, Loss: 1.79898e+00, Loss_ic: 1.11551e-02, Loss_f: 1.78782e+00
# Iter 0, Loss: 1.79809e+00, Loss_ic: 1.11593e-02, Loss_f: 1.78693e+00
# Iter 0, Loss: 1.79416e+00, Loss_ic: 1.11820e-02, Loss_f: 1.78298e+00
# Iter 0, Loss: 1.75919e+00, Loss_ic: 1.18939e-02, Loss_f: 1.74729e+00
# Iter 0, Loss: 1.75808e+00, Loss_ic: 1.19336e-02, Loss_f: 1.74614e+00
# Iter 0, Loss: 1.75316e+00, Loss_ic: 1.21175e-02, Loss_f: 1.74104e+00
# Iter 0, Loss: 1.70825e+00, Loss_ic: 1.47298e-02, Loss_f: 1.69352e+00
# Iter 0, Loss: 1.70663e+00, Loss_ic: 1.47980e-02, Loss_f: 1.69183e+00
# Iter 0, Loss: 1.69275e+00, Loss_ic: 1.55262e-02, Loss_f: 1.67723e+00
# Iter 0, Loss: 1.62464e+00, Loss_ic: 3.59513e-02, Loss_f: 1.58868e+00
# Iter 0, Loss: 1.62363e+00, Loss_ic: 3.58497e-02, Loss_f: 1.58778e+00
# Iter 0, Loss: 1.61496e+00, Loss_ic: 3.49846e-02, Loss_f: 1.57998e+00
# Iter 0, Loss: 1.57018e+00, Loss_ic: 3.14703e-02, Loss_f: 1.53871e+00
# Iter 0, Loss: 1.56952e+00, Loss_ic: 3.14880e-02, Loss_f: 1.53803e+00
# Iter 0, Loss: 1.56659e+00, Loss_ic: 3.15733e-02, Loss_f: 1.53502e+00
# Iter 0, Loss: 1.54213e+00, Loss_ic: 3.31208e-02, Loss_f: 1.50901e+00
# Iter 0, Loss: 1.54124e+00, Loss_ic: 3.32014e-02, Loss_f: 1.50804e+00
# Iter 0, Loss: 1.53736e+00, Loss_ic: 3.35679e-02, Loss_f: 1.50379e+00
# Iter 0, Loss: 1.50858e+00, Loss_ic: 3.79585e-02, Loss_f: 1.47062e+00
# Iter 0, Loss: 1.50805e+00, Loss_ic: 3.80261e-02, Loss_f: 1.47003e+00
# Iter 0, Loss: 1.50353e+00, Loss_ic: 3.86466e-02, Loss_f: 1.46488e+00
# Iter 0, Loss: 1.47531e+00, Loss_ic: 4.59185e-02, Loss_f: 1.42939e+00
# Iter 0, Loss: 1.47486e+00, Loss_ic: 4.59334e-02, Loss_f: 1.42892e+00
# Iter 0, Loss: 1.47092e+00, Loss_ic: 4.60682e-02, Loss_f: 1.42485e+00
# Iter 0, Loss: 1.45483e+00, Loss_ic: 4.67561e-02, Loss_f: 1.40808e+00
# Iter 0, Loss: 1.45403e+00, Loss_ic: 4.67385e-02, Loss_f: 1.40729e+00
# Iter 0, Loss: 1.45049e+00, Loss_ic: 4.66583e-02, Loss_f: 1.40384e+00
# Iter 0, Loss: 1.41881e+00, Loss_ic: 4.57101e-02, Loss_f: 1.37310e+00
# Iter 0, Loss: 1.41774e+00, Loss_ic: 4.56546e-02, Loss_f: 1.37208e+00
# Iter 0, Loss: 1.40849e+00, Loss_ic: 4.51519e-02, Loss_f: 1.36334e+00
# Iter 0, Loss: 1.35079e+00, Loss_ic: 3.98631e-02, Loss_f: 1.31093e+00
# Iter 0, Loss: 1.34969e+00, Loss_ic: 3.97881e-02, Loss_f: 1.30990e+00
# Iter 0, Loss: 1.34485e+00, Loss_ic: 3.94590e-02, Loss_f: 1.30540e+00
# Iter 0, Loss: 1.30796e+00, Loss_ic: 3.67719e-02, Loss_f: 1.27119e+00
# Iter 0, Loss: 1.30694e+00, Loss_ic: 3.67054e-02, Loss_f: 1.27024e+00
# Iter 0, Loss: 1.29819e+00, Loss_ic: 3.61330e-02, Loss_f: 1.26205e+00
# Iter 0, Loss: 1.24850e+00, Loss_ic: 3.32343e-02, Loss_f: 1.21527e+00
# Iter 0, Loss: 1.24663e+00, Loss_ic: 3.30639e-02, Loss_f: 1.21357e+00
# Iter 0, Loss: 1.23887e+00, Loss_ic: 3.23086e-02, Loss_f: 1.20656e+00
# Iter 0, Loss: 1.23775e+00, Loss_ic: 3.22237e-02, Loss_f: 1.20552e+00
# Iter 0, Loss: 1.22808e+00, Loss_ic: 3.15092e-02, Loss_f: 1.19657e+00
# Iter 0, Loss: 1.17822e+00, Loss_ic: 3.01027e-02, Loss_f: 1.14812e+00
# Iter 0, Loss: 1.17784e+00, Loss_ic: 3.01067e-02, Loss_f: 1.14773e+00
# Iter 0, Loss: 1.17614e+00, Loss_ic: 3.01254e-02, Loss_f: 1.14602e+00
# Iter 0, Loss: 1.16041e+00, Loss_ic: 3.03975e-02, Loss_f: 1.13001e+00
# Iter 0, Loss: 1.15969e+00, Loss_ic: 3.04098e-02, Loss_f: 1.12928e+00
# Iter 0, Loss: 1.15358e+00, Loss_ic: 3.05325e-02, Loss_f: 1.12305e+00
# Iter 0, Loss: 1.12350e+00, Loss_ic: 3.30733e-02, Loss_f: 1.09043e+00
# Iter 0, Loss: 1.12316e+00, Loss_ic: 3.30270e-02, Loss_f: 1.09013e+00
# Iter 0, Loss: 1.12164e+00, Loss_ic: 3.28188e-02, Loss_f: 1.08882e+00
# Iter 0, Loss: 1.10858e+00, Loss_ic: 3.06306e-02, Loss_f: 1.07795e+00
# Iter 0, Loss: 1.10817e+00, Loss_ic: 3.05658e-02, Loss_f: 1.07761e+00
# Iter 0, Loss: 1.10457e+00, Loss_ic: 2.99884e-02, Loss_f: 1.07458e+00
# Iter 0, Loss: 1.07889e+00, Loss_ic: 2.48655e-02, Loss_f: 1.05403e+00
# Iter 0, Loss: 1.07846e+00, Loss_ic: 2.47895e-02, Loss_f: 1.05367e+00
# Iter 0, Loss: 1.07468e+00, Loss_ic: 2.41138e-02, Loss_f: 1.05057e+00
# Iter 0, Loss: 1.04997e+00, Loss_ic: 1.82366e-02, Loss_f: 1.03173e+00
# Iter 0, Loss: 1.04932e+00, Loss_ic: 1.81677e-02, Loss_f: 1.03115e+00
# Iter 0, Loss: 1.04642e+00, Loss_ic: 1.78625e-02, Loss_f: 1.02856e+00
# Iter 0, Loss: 1.02117e+00, Loss_ic: 1.50468e-02, Loss_f: 1.00612e+00
# Iter 0, Loss: 1.02021e+00, Loss_ic: 1.49723e-02, Loss_f: 1.00524e+00
# Iter 0, Loss: 1.01598e+00, Loss_ic: 1.46469e-02, Loss_f: 1.00134e+00
# Iter 0, Loss: 9.79873e-01, Loss_ic: 1.22309e-02, Loss_f: 9.67642e-01
# Iter 0, Loss: 9.79128e-01, Loss_ic: 1.22050e-02, Loss_f: 9.66923e-01
# Iter 0, Loss: 9.72691e-01, Loss_ic: 1.19854e-02, Loss_f: 9.60705e-01
# Iter 0, Loss: 9.36454e-01, Loss_ic: 1.12779e-02, Loss_f: 9.25177e-01
# Iter 0, Loss: 9.36134e-01, Loss_ic: 1.12966e-02, Loss_f: 9.24837e-01
# Iter 0, Loss: 9.33348e-01, Loss_ic: 1.14737e-02, Loss_f: 9.21874e-01
# Iter 0, Loss: 9.14806e-01, Loss_ic: 1.39604e-02, Loss_f: 9.00845e-01
# Iter 0, Loss: 9.14331e-01, Loss_ic: 1.39519e-02, Loss_f: 9.00379e-01
# Iter 0, Loss: 9.12245e-01, Loss_ic: 1.39191e-02, Loss_f: 8.98326e-01
# Iter 0, Loss: 9.02218e-01, Loss_ic: 1.38977e-02, Loss_f: 8.88320e-01
# Iter 0, Loss: 9.01623e-01, Loss_ic: 1.39126e-02, Loss_f: 8.87711e-01
# Iter 0, Loss: 8.99006e-01, Loss_ic: 1.39801e-02, Loss_f: 8.85026e-01
# Iter 0, Loss: 8.86337e-01, Loss_ic: 1.43559e-02, Loss_f: 8.71981e-01
# Iter 0, Loss: 8.85587e-01, Loss_ic: 1.43866e-02, Loss_f: 8.71200e-01
# Iter 0, Loss: 8.79142e-01, Loss_ic: 1.47194e-02, Loss_f: 8.64423e-01
# Iter 0, Loss: 8.54304e-01, Loss_ic: 1.74718e-02, Loss_f: 8.36832e-01
# Iter 0, Loss: 8.53645e-01, Loss_ic: 1.74451e-02, Loss_f: 8.36200e-01
# Iter 0, Loss: 8.48018e-01, Loss_ic: 1.71937e-02, Loss_f: 8.30824e-01
# Iter 0, Loss: 8.47094e-01, Loss_ic: 1.72232e-02, Loss_f: 8.29871e-01
# Iter 0, Loss: 8.39147e-01, Loss_ic: 1.74575e-02, Loss_f: 8.21689e-01
# Iter 0, Loss: 8.09089e-01, Loss_ic: 1.79164e-02, Loss_f: 7.91172e-01
# Iter 0, Loss: 8.08537e-01, Loss_ic: 1.79074e-02, Loss_f: 7.90630e-01
# Iter 0, Loss: 8.03749e-01, Loss_ic: 1.78248e-02, Loss_f: 7.85924e-01
# Iter 0, Loss: 7.75369e-01, Loss_ic: 1.83485e-02, Loss_f: 7.57020e-01
# Iter 0, Loss: 7.74816e-01, Loss_ic: 1.82987e-02, Loss_f: 7.56517e-01
# Iter 0, Loss: 7.70129e-01, Loss_ic: 1.79134e-02, Loss_f: 7.52216e-01
# Iter 0, Loss: 7.69452e-01, Loss_ic: 1.78888e-02, Loss_f: 7.51563e-01
# Iter 0, Loss: 7.66471e-01, Loss_ic: 1.77865e-02, Loss_f: 7.48684e-01
# Iter 0, Loss: 7.52139e-01, Loss_ic: 1.74304e-02, Loss_f: 7.34708e-01
# Iter 0, Loss: 7.51382e-01, Loss_ic: 1.73819e-02, Loss_f: 7.34000e-01
# Iter 0, Loss: 7.44879e-01, Loss_ic: 1.70151e-02, Loss_f: 7.27864e-01
# Iter 0, Loss: 7.07892e-01, Loss_ic: 1.93837e-02, Loss_f: 6.88508e-01
# Iter 0, Loss: 7.07517e-01, Loss_ic: 1.93340e-02, Loss_f: 6.88183e-01
# Iter 0, Loss: 7.05896e-01, Loss_ic: 1.91136e-02, Loss_f: 6.86783e-01
# Iter 0, Loss: 6.95845e-01, Loss_ic: 1.72631e-02, Loss_f: 6.78582e-01
# Iter 0, Loss: 6.95625e-01, Loss_ic: 1.72615e-02, Loss_f: 6.78363e-01
# Iter 0, Loss: 6.93727e-01, Loss_ic: 1.72494e-02, Loss_f: 6.76477e-01
# Iter 0, Loss: 6.83428e-01, Loss_ic: 1.73072e-02, Loss_f: 6.66121e-01
# Iter 0, Loss: 6.83172e-01, Loss_ic: 1.72949e-02, Loss_f: 6.65877e-01
# Iter 0, Loss: 6.82044e-01, Loss_ic: 1.72400e-02, Loss_f: 6.64804e-01
# Iter 0, Loss: 6.76600e-01, Loss_ic: 1.69482e-02, Loss_f: 6.59652e-01
# Iter 0, Loss: 6.76259e-01, Loss_ic: 1.69114e-02, Loss_f: 6.59348e-01
# Iter 0, Loss: 6.73316e-01, Loss_ic: 1.65855e-02, Loss_f: 6.56731e-01
# Iter 0, Loss: 6.56520e-01, Loss_ic: 1.38461e-02, Loss_f: 6.42674e-01
# Iter 0, Loss: 6.56398e-01, Loss_ic: 1.38395e-02, Loss_f: 6.42558e-01
# Iter 0, Loss: 6.55855e-01, Loss_ic: 1.38104e-02, Loss_f: 6.42045e-01
# Iter 0, Loss: 6.51270e-01, Loss_ic: 1.35954e-02, Loss_f: 6.37675e-01
# Iter 0, Loss: 6.51105e-01, Loss_ic: 1.36001e-02, Loss_f: 6.37505e-01
# Iter 0, Loss: 6.49663e-01, Loss_ic: 1.36518e-02, Loss_f: 6.36011e-01
# Iter 0, Loss: 6.39601e-01, Loss_ic: 1.51009e-02, Loss_f: 6.24500e-01
# Iter 0, Loss: 6.39359e-01, Loss_ic: 1.51190e-02, Loss_f: 6.24240e-01
# Iter 0, Loss: 6.37231e-01, Loss_ic: 1.52922e-02, Loss_f: 6.21938e-01
# Iter 0, Loss: 6.20554e-01, Loss_ic: 1.80259e-02, Loss_f: 6.02528e-01
# Iter 0, Loss: 6.20037e-01, Loss_ic: 1.80478e-02, Loss_f: 6.01989e-01
# Iter 0, Loss: 6.15552e-01, Loss_ic: 1.82593e-02, Loss_f: 5.97292e-01
# Iter 0, Loss: 5.86884e-01, Loss_ic: 2.19305e-02, Loss_f: 5.64953e-01
# Iter 0, Loss: 5.86507e-01, Loss_ic: 2.18817e-02, Loss_f: 5.64625e-01
# Iter 0, Loss: 5.84848e-01, Loss_ic: 2.16633e-02, Loss_f: 5.63185e-01
# Iter 0, Loss: 5.70832e-01, Loss_ic: 1.94446e-02, Loss_f: 5.51387e-01
# Iter 0, Loss: 5.70421e-01, Loss_ic: 1.93427e-02, Loss_f: 5.51078e-01
# Iter 0, Loss: 5.68621e-01, Loss_ic: 1.88908e-02, Loss_f: 5.49730e-01
# Iter 0, Loss: 5.54325e-01, Loss_ic: 1.46724e-02, Loss_f: 5.39653e-01
# Iter 0, Loss: 5.54087e-01, Loss_ic: 1.45974e-02, Loss_f: 5.39490e-01
# Iter 0, Loss: 5.53043e-01, Loss_ic: 1.42654e-02, Loss_f: 5.38777e-01
# Iter 0, Loss: 5.44492e-01, Loss_ic: 1.12607e-02, Loss_f: 5.33231e-01
# Iter 0, Loss: 5.44306e-01, Loss_ic: 1.12197e-02, Loss_f: 5.33086e-01
# Iter 0, Loss: 5.42690e-01, Loss_ic: 1.08706e-02, Loss_f: 5.31819e-01
# Iter 0, Loss: 5.32316e-01, Loss_ic: 9.29162e-03, Loss_f: 5.23024e-01
# Iter 0, Loss: 5.32158e-01, Loss_ic: 9.27925e-03, Loss_f: 5.22878e-01
# Iter 0, Loss: 5.30767e-01, Loss_ic: 9.17259e-03, Loss_f: 5.21595e-01
# Iter 0, Loss: 5.24647e-01, Loss_ic: 8.77411e-03, Loss_f: 5.15873e-01
# Iter 0, Loss: 5.24196e-01, Loss_ic: 8.76961e-03, Loss_f: 5.15427e-01
# Iter 0, Loss: 5.22205e-01, Loss_ic: 8.75236e-03, Loss_f: 5.13452e-01
# ...
# Iter 70, Loss: 1.86102e-04, Loss_ic: 6.23213e-06, Loss_f: 1.79870e-04
# Iter 70, Loss: 1.86102e-04, Loss_ic: 6.23208e-06, Loss_f: 1.79870e-04
# Iter 70, Loss: 1.86102e-04, Loss_ic: 6.23209e-06, Loss_f: 1.79870e-04
# Iter 70, Loss: 1.86102e-04, Loss_ic: 6.23213e-06, Loss_f: 1.79870e-04
# Iter 70, Loss: 1.86102e-04, Loss_ic: 6.23209e-06, Loss_f: 1.79870e-04
# Iter 70, Loss: 1.86109e-04, Loss_ic: 6.23308e-06, Loss_f: 1.79876e-04
# Iter 70, Loss: 1.86103e-04, Loss_ic: 6.23210e-06, Loss_f: 1.79871e-04
# Iter 70, Loss: 1.86102e-04, Loss_ic: 6.23208e-06, Loss_f: 1.79870e-04
# Iter 70, Loss: 1.86102e-04, Loss_ic: 6.23209e-06, Loss_f: 1.79870e-04
# Iter 70, Loss: 1.86102e-04, Loss_ic: 6.23209e-06, Loss_f: 1.79870e-04
# Iter 80, Loss: 2.22482e-04, Loss_ic: 5.95175e-06, Loss_f: 2.16530e-04
# Iter 80, Loss: 2.22282e-04, Loss_ic: 5.95789e-06, Loss_f: 2.16324e-04
# Iter 80, Loss: 2.21481e-04, Loss_ic: 5.98630e-06, Loss_f: 2.15495e-04
# Iter 80, Loss: 2.17442e-04, Loss_ic: 6.17660e-06, Loss_f: 2.11265e-04
# Iter 80, Loss: 2.17205e-04, Loss_ic: 6.19422e-06, Loss_f: 2.11011e-04
# Iter 80, Loss: 2.16657e-04, Loss_ic: 6.23695e-06, Loss_f: 2.10420e-04
# Iter 80, Loss: 2.13593e-04, Loss_ic: 6.51411e-06, Loss_f: 2.07079e-04
# Iter 80, Loss: 2.13380e-04, Loss_ic: 6.53646e-06, Loss_f: 2.06843e-04
# Iter 80, Loss: 2.12433e-04, Loss_ic: 6.63851e-06, Loss_f: 2.05794e-04
# Iter 80, Loss: 2.09294e-04, Loss_ic: 7.04003e-06, Loss_f: 2.02254e-04
# Iter 80, Loss: 2.09133e-04, Loss_ic: 7.06217e-06, Loss_f: 2.02070e-04
# Iter 80, Loss: 2.08411e-04, Loss_ic: 7.16322e-06, Loss_f: 2.01248e-04
# Iter 80, Loss: 2.06635e-04, Loss_ic: 7.44735e-06, Loss_f: 1.99188e-04
# Iter 80, Loss: 2.06502e-04, Loss_ic: 7.46806e-06, Loss_f: 1.99034e-04
# Iter 80, Loss: 2.06169e-04, Loss_ic: 7.52265e-06, Loss_f: 1.98647e-04
# Iter 80, Loss: 2.04280e-04, Loss_ic: 7.87258e-06, Loss_f: 1.96408e-04
# Iter 80, Loss: 2.04181e-04, Loss_ic: 7.89061e-06, Loss_f: 1.96291e-04
# Iter 80, Loss: 2.03739e-04, Loss_ic: 7.97262e-06, Loss_f: 1.95767e-04
# Iter 80, Loss: 2.02476e-04, Loss_ic: 8.23954e-06, Loss_f: 1.94236e-04
# Iter 80, Loss: 2.02393e-04, Loss_ic: 8.25384e-06, Loss_f: 1.94139e-04
# Iter 80, Loss: 2.02318e-04, Loss_ic: 8.27042e-06, Loss_f: 1.94047e-04
# Iter 80, Loss: 2.01667e-04, Loss_ic: 8.40717e-06, Loss_f: 1.93260e-04
# Iter 80, Loss: 2.01596e-04, Loss_ic: 8.42145e-06, Loss_f: 1.93175e-04
# Iter 80, Loss: 2.01276e-04, Loss_ic: 8.48262e-06, Loss_f: 1.92793e-04
# Iter 80, Loss: 2.00576e-04, Loss_ic: 8.63382e-06, Loss_f: 1.91942e-04
# Iter 80, Loss: 2.00510e-04, Loss_ic: 8.64511e-06, Loss_f: 1.91865e-04
# Iter 80, Loss: 2.00464e-04, Loss_ic: 8.65482e-06, Loss_f: 1.91809e-04
# Iter 80, Loss: 1.99982e-04, Loss_ic: 8.75106e-06, Loss_f: 1.91231e-04
# Iter 80, Loss: 1.98438e-04, Loss_ic: 9.15701e-06, Loss_f: 1.89281e-04
# Iter 80, Loss: 1.98419e-04, Loss_ic: 9.16424e-06, Loss_f: 1.89255e-04
# Iter 80, Loss: 1.98291e-04, Loss_ic: 9.19467e-06, Loss_f: 1.89096e-04
# Iter 80, Loss: 1.98064e-04, Loss_ic: 9.25820e-06, Loss_f: 1.88806e-04
# Iter 80, Loss: 1.98038e-04, Loss_ic: 9.26326e-06, Loss_f: 1.88774e-04
# Iter 80, Loss: 1.98015e-04, Loss_ic: 9.26729e-06, Loss_f: 1.88748e-04
# Iter 80, Loss: 1.97813e-04, Loss_ic: 9.30829e-06, Loss_f: 1.88505e-04
# Iter 80, Loss: 1.96987e-04, Loss_ic: 9.53981e-06, Loss_f: 1.87448e-04
# Iter 80, Loss: 1.96978e-04, Loss_ic: 9.54195e-06, Loss_f: 1.87436e-04
# Iter 80, Loss: 1.96922e-04, Loss_ic: 9.55095e-06, Loss_f: 1.87371e-04
# Iter 80, Loss: 1.96884e-04, Loss_ic: 9.55901e-06, Loss_f: 1.87325e-04
# Iter 80, Loss: 1.96484e-04, Loss_ic: 9.64749e-06, Loss_f: 1.86836e-04
# Iter 80, Loss: 1.96470e-04, Loss_ic: 9.64664e-06, Loss_f: 1.86823e-04
# Iter 80, Loss: 1.96402e-04, Loss_ic: 9.64663e-06, Loss_f: 1.86755e-04
# Iter 80, Loss: 1.96312e-04, Loss_ic: 9.64708e-06, Loss_f: 1.86665e-04
# Iter 80, Loss: 1.95707e-04, Loss_ic: 9.65354e-06, Loss_f: 1.86053e-04
# Iter 80, Loss: 1.95689e-04, Loss_ic: 9.65131e-06, Loss_f: 1.86038e-04
# Iter 80, Loss: 1.95667e-04, Loss_ic: 9.64915e-06, Loss_f: 1.86017e-04
# Iter 80, Loss: 1.95660e-04, Loss_ic: 9.64873e-06, Loss_f: 1.86012e-04
# Iter 80, Loss: 1.95469e-04, Loss_ic: 9.62907e-06, Loss_f: 1.85840e-04
# Iter 80, Loss: 1.95442e-04, Loss_ic: 9.62429e-06, Loss_f: 1.85818e-04
# Iter 80, Loss: 1.95323e-04, Loss_ic: 9.60085e-06, Loss_f: 1.85722e-04
# Iter 80, Loss: 1.94380e-04, Loss_ic: 9.38185e-06, Loss_f: 1.84998e-04
# Iter 80, Loss: 1.94358e-04, Loss_ic: 9.37988e-06, Loss_f: 1.84978e-04
# Iter 80, Loss: 1.94341e-04, Loss_ic: 9.37688e-06, Loss_f: 1.84964e-04
# Iter 80, Loss: 1.94326e-04, Loss_ic: 9.37587e-06, Loss_f: 1.84950e-04
# Iter 80, Loss: 1.94305e-04, Loss_ic: 9.37121e-06, Loss_f: 1.84934e-04
# Iter 80, Loss: 1.94053e-04, Loss_ic: 9.33596e-06, Loss_f: 1.84717e-04
# Iter 80, Loss: 1.94048e-04, Loss_ic: 9.33303e-06, Loss_f: 1.84715e-04
# Iter 80, Loss: 1.94007e-04, Loss_ic: 9.31948e-06, Loss_f: 1.84687e-04
# Iter 80, Loss: 1.93869e-04, Loss_ic: 9.27204e-06, Loss_f: 1.84597e-04
# Iter 80, Loss: 1.93851e-04, Loss_ic: 9.26707e-06, Loss_f: 1.84584e-04
# Iter 80, Loss: 1.93850e-04, Loss_ic: 9.26692e-06, Loss_f: 1.84583e-04
# Iter 80, Loss: 1.93794e-04, Loss_ic: 9.24397e-06, Loss_f: 1.84550e-04
# Iter 80, Loss: 1.93511e-04, Loss_ic: 9.12502e-06, Loss_f: 1.84386e-04
# Iter 80, Loss: 1.93507e-04, Loss_ic: 9.12365e-06, Loss_f: 1.84384e-04
# Iter 80, Loss: 1.93469e-04, Loss_ic: 9.11552e-06, Loss_f: 1.84354e-04
# Iter 80, Loss: 1.93443e-04, Loss_ic: 9.10868e-06, Loss_f: 1.84334e-04
# Iter 80, Loss: 1.93203e-04, Loss_ic: 9.04196e-06, Loss_f: 1.84161e-04
# Iter 80, Loss: 1.93203e-04, Loss_ic: 9.03969e-06, Loss_f: 1.84163e-04
# Iter 80, Loss: 1.93204e-04, Loss_ic: 9.04002e-06, Loss_f: 1.84164e-04
# Iter 80, Loss: 1.93203e-04, Loss_ic: 9.03966e-06, Loss_f: 1.84163e-04
# Iter 80, Loss: 1.93196e-04, Loss_ic: 9.03810e-06, Loss_f: 1.84158e-04
# Iter 80, Loss: 1.93199e-04, Loss_ic: 9.03806e-06, Loss_f: 1.84161e-04
# Iter 80, Loss: 1.93199e-04, Loss_ic: 9.03806e-06, Loss_f: 1.84161e-04
# Iter 80, Loss: 1.93199e-04, Loss_ic: 9.03806e-06, Loss_f: 1.84161e-04
# Iter 80, Loss: 1.93197e-04, Loss_ic: 9.03647e-06, Loss_f: 1.84161e-04
# Iter 80, Loss: 1.93196e-04, Loss_ic: 9.03643e-06, Loss_f: 1.84160e-04
# Iter 80, Loss: 1.93196e-04, Loss_ic: 9.03644e-06, Loss_f: 1.84160e-04
# Iter 80, Loss: 1.93196e-04, Loss_ic: 9.03644e-06, Loss_f: 1.84160e-04
# Iter 80, Loss: 1.93194e-04, Loss_ic: 9.03474e-06, Loss_f: 1.84159e-04
# Iter 80, Loss: 1.93177e-04, Loss_ic: 9.02712e-06, Loss_f: 1.84150e-04
# Iter 80, Loss: 1.93156e-04, Loss_ic: 9.01678e-06, Loss_f: 1.84139e-04
# Iter 80, Loss: 1.93121e-04, Loss_ic: 8.99939e-06, Loss_f: 1.84121e-04
# Iter 80, Loss: 1.93117e-04, Loss_ic: 8.99826e-06, Loss_f: 1.84119e-04
# Iter 80, Loss: 1.93098e-04, Loss_ic: 8.99325e-06, Loss_f: 1.84105e-04
# Iter 80, Loss: 1.93086e-04, Loss_ic: 8.98863e-06, Loss_f: 1.84097e-04
# Iter 80, Loss: 1.92949e-04, Loss_ic: 8.94547e-06, Loss_f: 1.84004e-04
# Iter 80, Loss: 1.92949e-04, Loss_ic: 8.94506e-06, Loss_f: 1.84004e-04
# Iter 80, Loss: 1.92948e-04, Loss_ic: 8.94531e-06, Loss_f: 1.84003e-04
# Iter 80, Loss: 1.92948e-04, Loss_ic: 8.94531e-06, Loss_f: 1.84003e-04
# Iter 80, Loss: 1.92943e-04, Loss_ic: 8.94402e-06, Loss_f: 1.83999e-04
# Iter 80, Loss: 1.92944e-04, Loss_ic: 8.94386e-06, Loss_f: 1.84000e-04
# Iter 80, Loss: 1.92943e-04, Loss_ic: 8.94377e-06, Loss_f: 1.84000e-04
# Iter 80, Loss: 1.92944e-04, Loss_ic: 8.94373e-06, Loss_f: 1.84000e-04
# Iter 80, Loss: 1.92933e-04, Loss_ic: 8.94315e-06, Loss_f: 1.83990e-04
# Iter 80, Loss: 1.92933e-04, Loss_ic: 8.94285e-06, Loss_f: 1.83990e-04
# Iter 80, Loss: 1.92933e-04, Loss_ic: 8.94293e-06, Loss_f: 1.83990e-04
# Iter 80, Loss: 1.92933e-04, Loss_ic: 8.94292e-06, Loss_f: 1.83990e-04
# Iter 80, Loss: 1.92933e-04, Loss_ic: 8.94292e-06, Loss_f: 1.83990e-04
# Iter 80, Loss: 1.92941e-04, Loss_ic: 8.94224e-06, Loss_f: 1.83999e-04
# Iter 80, Loss: 1.92937e-04, Loss_ic: 8.94312e-06, Loss_f: 1.83994e-04
# Iter 80, Loss: 1.92933e-04, Loss_ic: 8.94295e-06, Loss_f: 1.83990e-04
# Iter 80, Loss: 1.92933e-04, Loss_ic: 8.94292e-06, Loss_f: 1.83990e-04
# Iter 80, Loss: 1.92933e-04, Loss_ic: 8.94292e-06, Loss_f: 1.83990e-04
# Iter 90, Loss: 1.78959e-04, Loss_ic: 3.86668e-06, Loss_f: 1.75092e-04
# Iter 90, Loss: 1.78857e-04, Loss_ic: 3.86660e-06, Loss_f: 1.74991e-04
# Iter 90, Loss: 1.78691e-04, Loss_ic: 3.86676e-06, Loss_f: 1.74824e-04
# Iter 90, Loss: 1.77551e-04, Loss_ic: 3.87081e-06, Loss_f: 1.73680e-04
# Iter 90, Loss: 1.77395e-04, Loss_ic: 3.87173e-06, Loss_f: 1.73523e-04
# Iter 90, Loss: 1.77146e-04, Loss_ic: 3.87359e-06, Loss_f: 1.73273e-04
# Iter 90, Loss: 1.75465e-04, Loss_ic: 3.88925e-06, Loss_f: 1.71576e-04
# Iter 90, Loss: 1.75317e-04, Loss_ic: 3.88976e-06, Loss_f: 1.71427e-04
# Iter 90, Loss: 1.74976e-04, Loss_ic: 3.89203e-06, Loss_f: 1.71084e-04
# Iter 90, Loss: 1.71496e-04, Loss_ic: 3.92311e-06, Loss_f: 1.67573e-04
# Iter 90, Loss: 1.71409e-04, Loss_ic: 3.92481e-06, Loss_f: 1.67484e-04
# Iter 90, Loss: 1.71072e-04, Loss_ic: 3.93345e-06, Loss_f: 1.67138e-04
# Iter 90, Loss: 1.69432e-04, Loss_ic: 3.97986e-06, Loss_f: 1.65452e-04
# Iter 90, Loss: 1.69372e-04, Loss_ic: 3.97914e-06, Loss_f: 1.65393e-04
# Iter 90, Loss: 1.69111e-04, Loss_ic: 3.97702e-06, Loss_f: 1.65134e-04
# Iter 90, Loss: 1.67994e-04, Loss_ic: 3.96932e-06, Loss_f: 1.64024e-04
# Iter 90, Loss: 1.67965e-04, Loss_ic: 3.97002e-06, Loss_f: 1.63995e-04
# Iter 90, Loss: 1.67835e-04, Loss_ic: 3.97487e-06, Loss_f: 1.63860e-04
# Iter 90, Loss: 1.67206e-04, Loss_ic: 4.00496e-06, Loss_f: 1.63201e-04
# Iter 90, Loss: 1.67194e-04, Loss_ic: 4.00550e-06, Loss_f: 1.63189e-04
# Iter 90, Loss: 1.67124e-04, Loss_ic: 4.00980e-06, Loss_f: 1.63114e-04
# Iter 90, Loss: 1.66787e-04, Loss_ic: 4.03355e-06, Loss_f: 1.62754e-04
# Iter 90, Loss: 1.66772e-04, Loss_ic: 4.03428e-06, Loss_f: 1.62738e-04
# Iter 90, Loss: 1.66777e-04, Loss_ic: 4.03477e-06, Loss_f: 1.62742e-04
# Iter 90, Loss: 1.66776e-04, Loss_ic: 4.03484e-06, Loss_f: 1.62741e-04
# Iter 90, Loss: 1.66776e-04, Loss_ic: 4.03483e-06, Loss_f: 1.62741e-04
# Iter 90, Loss: 1.66776e-04, Loss_ic: 4.03483e-06, Loss_f: 1.62741e-04
# Iter 90, Loss: 1.66759e-04, Loss_ic: 4.03548e-06, Loss_f: 1.62723e-04
# Iter 90, Loss: 1.66752e-04, Loss_ic: 4.03589e-06, Loss_f: 1.62716e-04
# Iter 90, Loss: 1.66742e-04, Loss_ic: 4.03650e-06, Loss_f: 1.62705e-04
# Iter 90, Loss: 1.66721e-04, Loss_ic: 4.03727e-06, Loss_f: 1.62684e-04
# Iter 90, Loss: 1.66724e-04, Loss_ic: 4.03766e-06, Loss_f: 1.62686e-04
# Iter 90, Loss: 1.66721e-04, Loss_ic: 4.03742e-06, Loss_f: 1.62684e-04
# Iter 90, Loss: 1.66724e-04, Loss_ic: 4.03741e-06, Loss_f: 1.62686e-04
# Iter 90, Loss: 1.66725e-04, Loss_ic: 4.03746e-06, Loss_f: 1.62687e-04
# Iter 90, Loss: 1.66722e-04, Loss_ic: 4.03742e-06, Loss_f: 1.62684e-04
# Iter 90, Loss: 1.66708e-04, Loss_ic: 4.03824e-06, Loss_f: 1.62669e-04
# Iter 90, Loss: 1.66633e-04, Loss_ic: 4.04166e-06, Loss_f: 1.62592e-04
# Iter 90, Loss: 1.66480e-04, Loss_ic: 4.04896e-06, Loss_f: 1.62431e-04
# Iter 90, Loss: 1.66466e-04, Loss_ic: 4.04984e-06, Loss_f: 1.62416e-04
# Iter 90, Loss: 1.66396e-04, Loss_ic: 4.05360e-06, Loss_f: 1.62343e-04
# Iter 90, Loss: 1.66286e-04, Loss_ic: 4.06011e-06, Loss_f: 1.62226e-04
# Iter 90, Loss: 1.66278e-04, Loss_ic: 4.06074e-06, Loss_f: 1.62218e-04
# Iter 90, Loss: 1.66217e-04, Loss_ic: 4.06454e-06, Loss_f: 1.62153e-04
# Iter 90, Loss: 1.66104e-04, Loss_ic: 4.07224e-06, Loss_f: 1.62032e-04
# Iter 90, Loss: 1.66091e-04, Loss_ic: 4.07320e-06, Loss_f: 1.62018e-04
# Iter 90, Loss: 1.66071e-04, Loss_ic: 4.07414e-06, Loss_f: 1.61997e-04
# Iter 90, Loss: 1.66053e-04, Loss_ic: 4.07515e-06, Loss_f: 1.61978e-04
# Iter 90, Loss: 1.66048e-04, Loss_ic: 4.07534e-06, Loss_f: 1.61972e-04
# Iter 90, Loss: 1.65830e-04, Loss_ic: 4.09153e-06, Loss_f: 1.61738e-04
# Iter 90, Loss: 1.65819e-04, Loss_ic: 4.09247e-06, Loss_f: 1.61726e-04
# Iter 90, Loss: 1.65811e-04, Loss_ic: 4.09285e-06, Loss_f: 1.61718e-04
# Iter 90, Loss: 1.65810e-04, Loss_ic: 4.09293e-06, Loss_f: 1.61717e-04
# Iter 90, Loss: 1.65724e-04, Loss_ic: 4.09822e-06, Loss_f: 1.61626e-04
# Iter 90, Loss: 1.65661e-04, Loss_ic: 4.10367e-06, Loss_f: 1.61557e-04
# Iter 90, Loss: 1.65650e-04, Loss_ic: 4.10424e-06, Loss_f: 1.61546e-04
# Iter 90, Loss: 1.65638e-04, Loss_ic: 4.10445e-06, Loss_f: 1.61534e-04
# Iter 90, Loss: 1.65640e-04, Loss_ic: 4.10458e-06, Loss_f: 1.61535e-04
# Iter 90, Loss: 1.65639e-04, Loss_ic: 4.10444e-06, Loss_f: 1.61534e-04
# Iter 90, Loss: 1.65638e-04, Loss_ic: 4.10445e-06, Loss_f: 1.61534e-04
# Iter 90, Loss: 1.65638e-04, Loss_ic: 4.10445e-06, Loss_f: 1.61534e-04
# Iter 90, Loss: 1.65632e-04, Loss_ic: 4.10512e-06, Loss_f: 1.61527e-04
# Iter 90, Loss: 1.65581e-04, Loss_ic: 4.10734e-06, Loss_f: 1.61474e-04
# Iter 90, Loss: 1.65527e-04, Loss_ic: 4.11013e-06, Loss_f: 1.61416e-04
# Iter 90, Loss: 1.65424e-04, Loss_ic: 4.11638e-06, Loss_f: 1.61308e-04
# Iter 90, Loss: 1.65415e-04, Loss_ic: 4.11680e-06, Loss_f: 1.61298e-04
# Iter 90, Loss: 1.65367e-04, Loss_ic: 4.11858e-06, Loss_f: 1.61248e-04
# Iter 90, Loss: 1.65316e-04, Loss_ic: 4.12138e-06, Loss_f: 1.61195e-04
# Iter 90, Loss: 1.64942e-04, Loss_ic: 4.15020e-06, Loss_f: 1.60792e-04
# Iter 90, Loss: 1.64936e-04, Loss_ic: 4.14994e-06, Loss_f: 1.60786e-04
# Iter 90, Loss: 1.64939e-04, Loss_ic: 4.15005e-06, Loss_f: 1.60789e-04
# Iter 90, Loss: 1.64938e-04, Loss_ic: 4.15015e-06, Loss_f: 1.60788e-04
# Iter 90, Loss: 1.64938e-04, Loss_ic: 4.15015e-06, Loss_f: 1.60788e-04
# Iter 90, Loss: 1.64938e-04, Loss_ic: 4.15015e-06, Loss_f: 1.60788e-04
# Iter 90, Loss: 1.64934e-04, Loss_ic: 4.14994e-06, Loss_f: 1.60784e-04
# Iter 90, Loss: 1.64919e-04, Loss_ic: 4.14980e-06, Loss_f: 1.60769e-04
# Iter 90, Loss: 1.64836e-04, Loss_ic: 4.14868e-06, Loss_f: 1.60688e-04
# Iter 90, Loss: 1.64828e-04, Loss_ic: 4.14827e-06, Loss_f: 1.60680e-04
# Iter 90, Loss: 1.64821e-04, Loss_ic: 4.14809e-06, Loss_f: 1.60673e-04
# Iter 90, Loss: 1.64822e-04, Loss_ic: 4.14866e-06, Loss_f: 1.60674e-04
# Iter 90, Loss: 1.64820e-04, Loss_ic: 4.14813e-06, Loss_f: 1.60672e-04
# Iter 90, Loss: 1.64819e-04, Loss_ic: 4.14812e-06, Loss_f: 1.60671e-04
# Iter 90, Loss: 1.64819e-04, Loss_ic: 4.14827e-06, Loss_f: 1.60671e-04
# Iter 90, Loss: 1.64818e-04, Loss_ic: 4.14819e-06, Loss_f: 1.60670e-04
# Iter 90, Loss: 1.64818e-04, Loss_ic: 4.14819e-06, Loss_f: 1.60670e-04
# Iter 90, Loss: 1.64810e-04, Loss_ic: 4.14740e-06, Loss_f: 1.60663e-04
# Iter 90, Loss: 1.64767e-04, Loss_ic: 4.14507e-06, Loss_f: 1.60622e-04
# Iter 90, Loss: 1.64533e-04, Loss_ic: 4.13099e-06, Loss_f: 1.60402e-04
# Iter 90, Loss: 1.64528e-04, Loss_ic: 4.13047e-06, Loss_f: 1.60398e-04
# Iter 90, Loss: 1.64488e-04, Loss_ic: 4.12612e-06, Loss_f: 1.60362e-04
# Iter 90, Loss: 1.64454e-04, Loss_ic: 4.12253e-06, Loss_f: 1.60332e-04
# Iter 90, Loss: 1.64169e-04, Loss_ic: 4.08352e-06, Loss_f: 1.60086e-04
# Iter 90, Loss: 1.64170e-04, Loss_ic: 4.08273e-06, Loss_f: 1.60087e-04
# Iter 90, Loss: 1.64169e-04, Loss_ic: 4.08364e-06, Loss_f: 1.60086e-04
# Iter 90, Loss: 1.64167e-04, Loss_ic: 4.08332e-06, Loss_f: 1.60084e-04
# Iter 90, Loss: 1.64168e-04, Loss_ic: 4.08340e-06, Loss_f: 1.60085e-04
# Iter 90, Loss: 1.64168e-04, Loss_ic: 4.08333e-06, Loss_f: 1.60085e-04
# Iter 90, Loss: 1.64167e-04, Loss_ic: 4.08332e-06, Loss_f: 1.60084e-04
# Iter 90, Loss: 1.64171e-04, Loss_ic: 4.08265e-06, Loss_f: 1.60088e-04
# Iter 90, Loss: 1.64168e-04, Loss_ic: 4.08313e-06, Loss_f: 1.60085e-04
# Iter 90, Loss: 1.64165e-04, Loss_ic: 4.08347e-06, Loss_f: 1.60081e-04
# Iter 90, Loss: 1.64166e-04, Loss_ic: 4.08323e-06, Loss_f: 1.60083e-04
# Iter 90, Loss: 1.64165e-04, Loss_ic: 4.08345e-06, Loss_f: 1.60081e-04
# Iter 90, Loss: 1.64165e-04, Loss_ic: 4.08345e-06, Loss_f: 1.60081e-04
# Iter 90, Loss: 1.64168e-04, Loss_ic: 4.08274e-06, Loss_f: 1.60086e-04
# Iter 90, Loss: 1.64172e-04, Loss_ic: 4.08302e-06, Loss_f: 1.60089e-04
# Iter 90, Loss: 1.64164e-04, Loss_ic: 4.08343e-06, Loss_f: 1.60080e-04
# Iter 90, Loss: 1.64166e-04, Loss_ic: 4.08324e-06, Loss_f: 1.60083e-04
# Iter 90, Loss: 1.64164e-04, Loss_ic: 4.08347e-06, Loss_f: 1.60081e-04
# Iter 90, Loss: 1.64169e-04, Loss_ic: 4.08271e-06, Loss_f: 1.60086e-04
# Iter 90, Loss: 1.64172e-04, Loss_ic: 4.08307e-06, Loss_f: 1.60089e-04
# Iter 90, Loss: 1.64164e-04, Loss_ic: 4.08343e-06, Loss_f: 1.60081e-04
# Iter 90, Loss: 1.64164e-04, Loss_ic: 4.08343e-06, Loss_f: 1.60080e-04
# Iter 90, Loss: 1.64164e-04, Loss_ic: 4.08343e-06, Loss_f: 1.60080e-04
# Iter 90, Loss: 1.64164e-04, Loss_ic: 4.08343e-06, Loss_f: 1.60080e-04

# %%
# a dict to store the activations
forw_activation = {}
def forw_getActivation(name):
  # the hook signature
  def hook(model, input, output):
    forw_activation[name] = output.detach()
  return hook

h1 = model.layers[-2].register_forward_hook(forw_getActivation('layers.activation_1'))

# %%
data_pde_ = data_pde(nobs,space,min_param , max_param)

t,param = next(iter(data_pde_))

t, param = Variable(t[:,0].reshape(-1,1),requires_grad=True),Variable(t[:,1].reshape(-1,1),requires_grad=True)

# %%
f_pred = model.DE(t,param)

h1.remove()

ic_pred = model(torch.cat([torch.zeros_like(param), param], dim=1))

loss_u_ic,loss_f = loss(ic_pred,torch.zeros_like(ic_pred)),loss(f_pred,torch.zeros_like(f_pred))

# %%
df_f_1 = grad(loss_f, f_pred, create_graph=True)[0]

ddf_ff_1 = grad(df_f_1, f_pred, torch.ones_like(df_f_1))[0]

#df_f_2 = grad(loss_u_ic, ic_pred, create_graph=True)[0]

#ddf_ff_2 = grad(df_f_2, ic_pred, torch.ones_like(df_f_2))[0]

# %%
wt,bias = model.layers[-1].weight, model.layers[-1].bias

param_MAP = torch.cat((wt,bias.reshape(1,1)),1) 

nparam = param_MAP.reshape(-1).shape

# %%
df_theta = torch.cat((forw_activation['layers.activation_1'],torch.ones_like(ddf_ff_1)),1)

H = (nobs/2)*torch.sum(df_theta*ddf_ff_1*df_theta,axis=0)

print(H)
# Out:
# tensor([ 980.4095,  997.3158,  999.8784, 1000.0000,  992.0839,  999.9936,
#          999.8754,  999.7734,  994.8450,  999.5013,  965.7816,  139.4676,
#          998.6441,  926.1995,  940.8390,  670.7416,  992.5685,  994.7382,
#          999.7524,  999.8637,  990.9568,  997.9500,  979.2992,  839.9318,
#          999.8949,  913.8722, 1000.0000, 1000.0000,  791.7939,  830.9116,
#          995.7245,  998.4598,  992.3414,  239.3941,  406.5838,  992.5878,
#          885.6454, 1000.0001,  932.6146,  998.4505,  922.6512,  384.6780,
#          999.7444,   15.9614, 1000.0001,  991.2941, 1000.0001,  999.5840,
#          999.7912,  925.0798, 1000.0001])

# %%
def sigma_noise():
    return _sigma_noise

def _H_factor():
    sigma2 = sigma_noise().square()
    return 1 / sigma2 / temperature

def prior_precision_diag(prior_precision,n_params):
    """Obtain the diagonal prior precision \\(p_0\\) constructed from either
    a scalar, layer-wise, or diagonal prior precision.

    Returns
    -------
    prior_precision_diag : torch.Tensor
    """
    if len(prior_precision) == 1:  # scalar
        return prior_precision * torch.ones(n_params, device=device)

    elif len(prior_precision) == n_params:  # diagonal
        return prior_precision

    # elif len(prior_precision) == n_layers:  # per layer
    #     n_params_per_layer = parameters_per_layer(self.model)
    #     return torch.cat([prior * torch.ones(n_params, device=self._device) for prior, n_params
    #                         in zip(self.prior_precision, n_params_per_layer)])

    # else:
    #     raise ValueError('Mismatch of prior and model. Diagonal, scalar, or per-layer prior.')

_sigma_noise=torch.tensor([1])
temperature=torch.tensor([1])
prior_precision=torch.tensor([1])

prior_precision_diag = prior_precision_diag(prior_precision,nparam)

# %%
import matplotlib.pyplot as plt
from matplotlib import cm


param_trained =  samples_param(min_param , max_param,6)
ns, mean, std = 3, 0,0.1

# Plotting
fig = plt.figure(figsize=(25,25))
plt.subplots_adjust(hspace=0.25)

for n,pr in enumerate(param_trained):

    t, noise_sol_test = test_set(ns,500,pr,mean,std)

    data_test = np.hstack((t.flatten()[:,None], np.ones_like(t).flatten()[:,None]*(pr)))


    ######################################################################################

    forw_activation_ = {}
    h1 = model.layers[-2].register_forward_hook(forw_getActivation('layers.activation_1'))

    f  = model(torch.tensor(data_test).float()).detach().cpu().numpy()

    h1.remove()

    phi = forw_activation['layers.activation_1']

    bsize = phi.shape[0]
    output_size = f.shape[-1]

    # calculate Jacobians using the feature vector 'phi'
    identity = torch.eye(output_size, device=device).unsqueeze(0).tile(bsize, 1, 1)
    # Jacobians are batch x output x params
    Js = torch.einsum('kp,kij->kijp', phi, identity).reshape(bsize, output_size, -1)
    Js = torch.cat([Js, identity], dim=2)

    post_presicion = _H_factor() * H + prior_precision_diag


    post_variance = 1 / post_presicion

    functional_var = torch.einsum('ncp,p,nkp->nck', Js, post_variance, Js)

    #######################################################################################
    f_mu = f.reshape(-1)
    f_sigma = functional_var.squeeze().sqrt().cpu().numpy().reshape(-1)

    plt.subplot(8, 2, n + 1)

    plt.scatter(t,noise_sol_test, label = "Observations",color= "blue",alpha = 0.5)
    plt.plot(t, f_mu, "--",label='NN prediction',color="blue")
    plt.fill_between(t, f_mu+f_sigma,f_mu-f_sigma,alpha=0.3, color = "red")

    plt.xlabel("t")
    plt.ylabel("u")
    plt.legend(frameon=False)
