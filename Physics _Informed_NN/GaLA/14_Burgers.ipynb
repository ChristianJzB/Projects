# %%
import os
import re

os.chdir("/home/s2113174/Projects-1")

from Galab import llaplace

import torch
from torch.autograd import Variable, grad

from collections import OrderedDict

import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import griddata

from pyDOE import lhs

np.random.seed(1234)

# CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")

# %% [markdown]
# ## Burgers Equation
#
# $$\frac{\partial u}{\partial t} + u\frac{\partial u}{\partial x} - \frac{0.01}{\pi}\frac{\partial^{2} u}{\partial x^{2}}=0$$
# $$u(x,0) = -sin( \pi x),  u(-1,t)=u(1,t)=0$$

# %% [markdown]
# ## Feed Forward Neural Network

# %%
# Deep neural network
class DNN(torch.nn.Module):
    def __init__(self, layers):
        super(DNN, self).__init__()

        # Number of layers
        self.depth = len(layers) - 1
        
        # Activation Function
        self.activation = torch.nn.Tanh
        
        # The following loop organized the layers of the NN         
        layer_list = list()
        for i in range(self.depth - 1): 
            layer_list.append(
                ('layer_%d' % i, torch.nn.Linear(layers[i], layers[i+1])))
            layer_list.append(('activation_%d' % i, self.activation()))
        layer_list.append(
            ('layer_%d' % (self.depth - 1), torch.nn.Linear(layers[-2], layers[-1]))
        )
        layerDict = OrderedDict(layer_list)
        
        # Deploy layers
        self.layers = torch.nn.Sequential(layerDict)

    def forward(self, x):
        out = self.layers(x)
        return out

# %% [markdown]
# ## Burgers Equation definition for the NN

# %%
def de(self,data_domain):
    """ The pytorch autograd version of calculating residual """
    u = self(data_domain)
    
    du = torch.autograd.grad(
        u, data_domain, 
        grad_outputs=torch.ones_like(u),
        retain_graph=True,
        create_graph=True
    )[0]

    ddu_x = torch.autograd.grad(
        du[:,0],data_domain, 
        grad_outputs=torch.ones_like(du[:,0]),
        retain_graph=True,
        create_graph=True
        )[0]
    
    f = du[:,1].reshape(-1,1) + u.reshape(-1,1)*du[:,0].reshape(-1,1) - data_domain[:,2].reshape(-1,1)*ddu_x[:,0].reshape(-1,1)

    return f

def ini_c(self,data_inic):
    u = self(data_inic)
    return u + torch.sin(torch.pi*data_inic[:,0].reshape(-1,1))

def left_bc(self,data_lbc):
    u = self(data_lbc)
    return u

def right_bc(self,data_rbc):
    u = self(data_rbc)
    return u

# %%
DNN.de = de
DNN.ini_c = ini_c
DNN.left_bc = left_bc
DNN.right_bc = right_bc

# %%
def samples_space(size,maxl):
    t_f_train = lhs(2, size)*maxl
    t_f_train[:,0] = t_f_train[:,0]*(2)-1
    t_f_train[:,1] = t_f_train[:,1]*(0.5)
    return t_f_train

def samples_param(min,max,size = 100):
    return np.random.uniform(min,max,size = size)

# %%
def data_pde(size,maxl,minp,maxp):

    xy, param = samples_space(size,maxl),samples_param(minp,maxp,(size,1)).reshape(-1,1)
    pde_domain = torch.tensor(np.hstack((xy,param.reshape(-1,1)))).float()
    
    x,y, param  = torch.tensor(xy[:,0]).reshape(-1,1),torch.tensor(xy[:,1]).reshape(-1,1),torch.tensor(param).reshape(-1,1)

    ini_c = torch.cat([x,torch.zeros_like(x).float(),param],axis = 1).float()

    left_bc = torch.cat([torch.ones_like(x).float()*(-1),y, param],axis = 1).float()

    right_bc = torch.cat([torch.ones_like(x).float(),y, param],axis = 1).float()

    return pde_domain,ini_c,left_bc,right_bc

# %%
def train_adam(pinn,loss,optimizer,epochs, sample_size = 100, bound_limit = 1,minval_param = 0.2,maxval_param = 2):
     
     print("Starting Adam Training")

     for i in range(epochs):
        pde_domain,ini_c,left_bc,right_bc = data_pde(sample_size,bound_limit,minval_param,maxval_param)
        
        pde_domain,ini_c = Variable(pde_domain,requires_grad=True),Variable(ini_c,requires_grad=True)
        left_bc,right_bc = Variable(left_bc,requires_grad=True),Variable(right_bc,requires_grad=True)
        
        for _ in range(15):
                optimizer.zero_grad()

                pde_pred,ini_c_pred = pinn.de(pde_domain), pinn.ini_c(ini_c)
                left_bc_pred,right_bc_pred = pinn.left_bc(left_bc),pinn.right_bc(right_bc)

                loss_pde,loss_ini = loss(pde_pred,torch.zeros_like(pde_pred)),loss(ini_c_pred,torch.zeros_like(pde_pred))
                loss_lbc,loss_rbc = loss(left_bc_pred,torch.zeros_like(pde_pred)),loss(right_bc_pred,torch.zeros_like(pde_pred))

                Loss =  loss_pde + loss_ini + loss_lbc + loss_rbc

                if epochs % 10 == 0:
                        print('Iter %d, Loss: %.5e, Loss_PDE: %.5e, Loss_ini: %.5e, Loss_lbc: %.5e,Loss_rbc: %.5e' % (i, 
                                                                         Loss.item(),loss_pde.item(),loss_ini.item(), loss_lbc.item(), loss_rbc.item()))
                                
                Loss.backward() 

                optimizer.step() 

                #sheduler.step()

# %%
def train_LBFGS(pinn,loss,optimizer, sample_size = 100, bound_limit = 1,minval_param = 0.2,maxval_param = 2):
    
    print("Starting Training: LBFGS optimizer")

    pde_domain,ini_c,left_bc,right_bc = data_pde(sample_size,bound_limit,minval_param,maxval_param)
    
    pde_domain,ini_c = Variable(pde_domain,requires_grad=True),Variable(ini_c,requires_grad=True)
    left_bc,right_bc = Variable(left_bc,requires_grad=True),Variable(right_bc,requires_grad=True)
    

    def loss_func_train():
        optimizer.zero_grad()
        
        pde_pred,ini_c_pred = pinn.de(pde_domain), pinn.ini_c(ini_c)
        left_bc_pred,right_bc_pred = pinn.left_bc(left_bc),pinn.right_bc(right_bc)

        loss_pde,loss_ini = loss(pde_pred,torch.zeros_like(pde_pred)),loss(ini_c_pred,torch.zeros_like(pde_pred))
        loss_lbc,loss_rbc = loss(left_bc_pred,torch.zeros_like(pde_pred)),loss(right_bc_pred,torch.zeros_like(pde_pred))

        Loss =  loss_pde + loss_ini + loss_lbc + loss_rbc

        print('Loss: %.5e, Loss_PDE: %.5e, Loss_ini: %.5e, Loss_lbc: %.5e,Loss_rbc: %.5e' % ( 
                                                            Loss.item(),loss_pde.item(),loss_ini.item(), loss_lbc.item(), loss_rbc.item()))

        Loss.backward() 

        return Loss

    optimizer.step(loss_func_train)

# %%
# Number of observations
epochs = 1200
nobs = 3000
lr = 0.01

min_param , max_param = 0.0001, 0.05

space = 1

layers = [3] + 4*[30] + [1]

# %%
model = DNN(layers)

model.load_state_dict(torch.load(f"../Projects-1/Physics _Informed_NN/GaLA/Gala_models/BurgEq_4_30.pt"))
model.eval()

# loss = torch.nn.MSELoss(reduction ='mean')

# optimizer = torch.optim.Adam(model.parameters(), lr = lr)

# dta_set = train_adam(model,loss,optimizer,epochs, nobs,space,min_param,max_param)

# optimizer = torch.optim.LBFGS(
#     model.parameters(), lr=lr, max_iter=50000, max_eval=None, tolerance_grad=1e-5, tolerance_change=1.0 * np.finfo(float).eps,line_search_fn="strong_wolfe" 
#     )

# train_LBFGS(model,loss,optimizer, nobs,space,min_param,max_param)
# Out:
# DNN(
#   (layers): Sequential(
#     (layer_0): Linear(in_features=3, out_features=30, bias=True)
#     (activation_0): Tanh()
#     (layer_1): Linear(in_features=30, out_features=30, bias=True)
#     (activation_1): Tanh()
#     (layer_2): Linear(in_features=30, out_features=30, bias=True)
#     (activation_2): Tanh()
#     (layer_3): Linear(in_features=30, out_features=30, bias=True)
#     (activation_3): Tanh()
#     (layer_4): Linear(in_features=30, out_features=1, bias=True)
#   )
# )

# %%
x = np.linspace(-1,1,100)
y = np.linspace(0,1,100)

xx, yy = np.meshgrid(x, y)
xx, yy = torch.tensor(xx).reshape(-1,1).float(),torch.tensor(yy).reshape(-1,1).float()

X_star = torch.cat([xx,yy,torch.ones_like(xx)*(0.001/np.pi)],axis = 1)

znn = model(X_star)

xx,yy = np.meshgrid(x, y)

U_pred = griddata(np.hstack([xx.reshape(-1,1),yy.reshape(-1,1)]), znn.detach().numpy().flatten(), (xx,yy), method='cubic')

print(U_pred.shape)

h = plt.contourf(y.flatten(), x.flatten(), U_pred.T,cmap='rainbow')


plt.axis('scaled')
plt.colorbar()
plt.show()
plt.plot(x,U_pred[10,:])
# Out:
# (100, 100)

# %%
x, y = np.linspace(-1,1,100), np.linspace(0,1,100)

xx,yy = np.meshgrid(x, y)

pde_domain,ini_c,left_bc,right_bc = data_pde(nobs,space,min_param,max_param)

pde = {"PDE":["de","ini_c","left_bc","right_bc"], 
       "data_set":{"de" : Variable(pde_domain,requires_grad=True),
                   "ini_c" : ini_c,
                   "left_bc":left_bc,
                   "right_bc" :right_bc}}

# %%
llp = llaplace(model,sigma_noise=1, prior_precision=1)
llp.fit(pde=pde, hessian_structure = "full")

log_prior, log_sigma = torch.ones(1, requires_grad=True), torch.ones(1, requires_grad=True)
hyper_optimizer = torch.optim.Adam([log_prior, log_sigma], lr=1e-1)
for i in range(1000):
    hyper_optimizer.zero_grad()
    neg_marglik = - llp.log_marginal_likelihood(log_prior.exp(), log_sigma.exp())
    neg_marglik.backward(retain_graph=True)
    hyper_optimizer.step()
    print(log_prior,log_sigma)
# Out:
# tensor([1.1000], requires_grad=True) tensor([0.9000], requires_grad=True)
# tensor([1.2000], requires_grad=True) tensor([0.8000], requires_grad=True)
# tensor([1.2999], requires_grad=True) tensor([0.7000], requires_grad=True)
# tensor([1.3998], requires_grad=True) tensor([0.6001], requires_grad=True)
# tensor([1.4995], requires_grad=True) tensor([0.5001], requires_grad=True)
# tensor([1.5990], requires_grad=True) tensor([0.4002], requires_grad=True)
# tensor([1.6983], requires_grad=True) tensor([0.3003], requires_grad=True)
# tensor([1.7971], requires_grad=True) tensor([0.2006], requires_grad=True)
# tensor([1.8953], requires_grad=True) tensor([0.1009], requires_grad=True)
# tensor([1.9928], requires_grad=True) tensor([0.0013], requires_grad=True)
# tensor([2.0892], requires_grad=True) tensor([-0.0981], requires_grad=True)
# tensor([2.1843], requires_grad=True) tensor([-0.1974], requires_grad=True)
# tensor([2.2776], requires_grad=True) tensor([-0.2963], requires_grad=True)
# tensor([2.3688], requires_grad=True) tensor([-0.3949], requires_grad=True)
# tensor([2.4572], requires_grad=True) tensor([-0.4931], requires_grad=True)
# tensor([2.5421], requires_grad=True) tensor([-0.5906], requires_grad=True)
# tensor([2.6228], requires_grad=True) tensor([-0.6875], requires_grad=True)
# tensor([2.6984], requires_grad=True) tensor([-0.7833], requires_grad=True)
# tensor([2.7679], requires_grad=True) tensor([-0.8780], requires_grad=True)
# tensor([2.8304], requires_grad=True) tensor([-0.9710], requires_grad=True)
# tensor([2.8850], requires_grad=True) tensor([-1.0620], requires_grad=True)
# tensor([2.9310], requires_grad=True) tensor([-1.1504], requires_grad=True)
# tensor([2.9679], requires_grad=True) tensor([-1.2355], requires_grad=True)
# tensor([2.9957], requires_grad=True) tensor([-1.3163], requires_grad=True)
# tensor([3.0146], requires_grad=True) tensor([-1.3918], requires_grad=True)
# tensor([3.0250], requires_grad=True) tensor([-1.4606], requires_grad=True)
# tensor([3.0278], requires_grad=True) tensor([-1.5215], requires_grad=True)
# tensor([3.0239], requires_grad=True) tensor([-1.5730], requires_grad=True)
# tensor([3.0144], requires_grad=True) tensor([-1.6139], requires_grad=True)
# tensor([3.0004], requires_grad=True) tensor([-1.6435], requires_grad=True)
# tensor([2.9832], requires_grad=True) tensor([-1.6614], requires_grad=True)
# tensor([2.9637], requires_grad=True) tensor([-1.6680], requires_grad=True)
# tensor([2.9431], requires_grad=True) tensor([-1.6642], requires_grad=True)
# tensor([2.9223], requires_grad=True) tensor([-1.6512], requires_grad=True)
# tensor([2.9022], requires_grad=True) tensor([-1.6304], requires_grad=True)
# tensor([2.8833], requires_grad=True) tensor([-1.6036], requires_grad=True)
# tensor([2.8662], requires_grad=True) tensor([-1.5723], requires_grad=True)
# tensor([2.8513], requires_grad=True) tensor([-1.5382], requires_grad=True)
# tensor([2.8388], requires_grad=True) tensor([-1.5026], requires_grad=True)
# tensor([2.8288], requires_grad=True) tensor([-1.4669], requires_grad=True)
# tensor([2.8213], requires_grad=True) tensor([-1.4323], requires_grad=True)
# tensor([2.8161], requires_grad=True) tensor([-1.3998], requires_grad=True)
# tensor([2.8130], requires_grad=True) tensor([-1.3700], requires_grad=True)
# tensor([2.8118], requires_grad=True) tensor([-1.3437], requires_grad=True)
# tensor([2.8122], requires_grad=True) tensor([-1.3212], requires_grad=True)
# tensor([2.8138], requires_grad=True) tensor([-1.3029], requires_grad=True)
# tensor([2.8162], requires_grad=True) tensor([-1.2887], requires_grad=True)
# tensor([2.8193], requires_grad=True) tensor([-1.2788], requires_grad=True)
# tensor([2.8227], requires_grad=True) tensor([-1.2730], requires_grad=True)
# tensor([2.8262], requires_grad=True) tensor([-1.2711], requires_grad=True)
# tensor([2.8296], requires_grad=True) tensor([-1.2728], requires_grad=True)
# tensor([2.8327], requires_grad=True) tensor([-1.2777], requires_grad=True)
# tensor([2.8356], requires_grad=True) tensor([-1.2855], requires_grad=True)
# tensor([2.8380], requires_grad=True) tensor([-1.2958], requires_grad=True)
# tensor([2.8401], requires_grad=True) tensor([-1.3080], requires_grad=True)
# tensor([2.8419], requires_grad=True) tensor([-1.3217], requires_grad=True)
# tensor([2.8434], requires_grad=True) tensor([-1.3364], requires_grad=True)
# tensor([2.8448], requires_grad=True) tensor([-1.3516], requires_grad=True)
# tensor([2.8461], requires_grad=True) tensor([-1.3668], requires_grad=True)
# tensor([2.8473], requires_grad=True) tensor([-1.3815], requires_grad=True)
# tensor([2.8486], requires_grad=True) tensor([-1.3953], requires_grad=True)
# tensor([2.8501], requires_grad=True) tensor([-1.4079], requires_grad=True)
# tensor([2.8516], requires_grad=True) tensor([-1.4189], requires_grad=True)
# tensor([2.8534], requires_grad=True) tensor([-1.4280], requires_grad=True)
# tensor([2.8552], requires_grad=True) tensor([-1.4352], requires_grad=True)
# tensor([2.8571], requires_grad=True) tensor([-1.4402], requires_grad=True)
# tensor([2.8591], requires_grad=True) tensor([-1.4431], requires_grad=True)
# tensor([2.8609], requires_grad=True) tensor([-1.4440], requires_grad=True)
# tensor([2.8626], requires_grad=True) tensor([-1.4429], requires_grad=True)
# tensor([2.8641], requires_grad=True) tensor([-1.4402], requires_grad=True)
# tensor([2.8652], requires_grad=True) tensor([-1.4360], requires_grad=True)
# tensor([2.8659], requires_grad=True) tensor([-1.4307], requires_grad=True)
# tensor([2.8662], requires_grad=True) tensor([-1.4246], requires_grad=True)
# tensor([2.8659], requires_grad=True) tensor([-1.4179], requires_grad=True)
# tensor([2.8651], requires_grad=True) tensor([-1.4110], requires_grad=True)
# tensor([2.8638], requires_grad=True) tensor([-1.4041], requires_grad=True)
# tensor([2.8621], requires_grad=True) tensor([-1.3976], requires_grad=True)
# tensor([2.8601], requires_grad=True) tensor([-1.3916], requires_grad=True)
# tensor([2.8578], requires_grad=True) tensor([-1.3864], requires_grad=True)
# tensor([2.8553], requires_grad=True) tensor([-1.3820], requires_grad=True)
# tensor([2.8527], requires_grad=True) tensor([-1.3785], requires_grad=True)
# tensor([2.8503], requires_grad=True) tensor([-1.3761], requires_grad=True)
# tensor([2.8481], requires_grad=True) tensor([-1.3746], requires_grad=True)
# tensor([2.8461], requires_grad=True) tensor([-1.3741], requires_grad=True)
# tensor([2.8445], requires_grad=True) tensor([-1.3745], requires_grad=True)
# tensor([2.8434], requires_grad=True) tensor([-1.3757], requires_grad=True)
# tensor([2.8428], requires_grad=True) tensor([-1.3776], requires_grad=True)
# tensor([2.8427], requires_grad=True) tensor([-1.3800], requires_grad=True)
# tensor([2.8431], requires_grad=True) tensor([-1.3828], requires_grad=True)
# tensor([2.8440], requires_grad=True) tensor([-1.3859], requires_grad=True)
# tensor([2.8453], requires_grad=True) tensor([-1.3891], requires_grad=True)
# tensor([2.8469], requires_grad=True) tensor([-1.3923], requires_grad=True)
# tensor([2.8487], requires_grad=True) tensor([-1.3953], requires_grad=True)
# tensor([2.8506], requires_grad=True) tensor([-1.3981], requires_grad=True)
# tensor([2.8525], requires_grad=True) tensor([-1.4005], requires_grad=True)
# tensor([2.8544], requires_grad=True) tensor([-1.4024], requires_grad=True)
# tensor([2.8560], requires_grad=True) tensor([-1.4039], requires_grad=True)
# tensor([2.8574], requires_grad=True) tensor([-1.4049], requires_grad=True)
# tensor([2.8585], requires_grad=True) tensor([-1.4054], requires_grad=True)
# tensor([2.8593], requires_grad=True) tensor([-1.4054], requires_grad=True)
# tensor([2.8596], requires_grad=True) tensor([-1.4050], requires_grad=True)
# tensor([2.8596], requires_grad=True) tensor([-1.4043], requires_grad=True)
# tensor([2.8592], requires_grad=True) tensor([-1.4032], requires_grad=True)
# tensor([2.8586], requires_grad=True) tensor([-1.4019], requires_grad=True)
# tensor([2.8577], requires_grad=True) tensor([-1.4004], requires_grad=True)
# tensor([2.8566], requires_grad=True) tensor([-1.3989], requires_grad=True)
# tensor([2.8554], requires_grad=True) tensor([-1.3974], requires_grad=True)
# tensor([2.8542], requires_grad=True) tensor([-1.3959], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3946], requires_grad=True)
# tensor([2.8519], requires_grad=True) tensor([-1.3935], requires_grad=True)
# tensor([2.8511], requires_grad=True) tensor([-1.3925], requires_grad=True)
# tensor([2.8504], requires_grad=True) tensor([-1.3918], requires_grad=True)
# tensor([2.8499], requires_grad=True) tensor([-1.3914], requires_grad=True)
# tensor([2.8496], requires_grad=True) tensor([-1.3912], requires_grad=True)
# tensor([2.8496], requires_grad=True) tensor([-1.3913], requires_grad=True)
# tensor([2.8498], requires_grad=True) tensor([-1.3915], requires_grad=True)
# tensor([2.8502], requires_grad=True) tensor([-1.3919], requires_grad=True)
# tensor([2.8507], requires_grad=True) tensor([-1.3925], requires_grad=True)
# tensor([2.8512], requires_grad=True) tensor([-1.3932], requires_grad=True)
# tensor([2.8519], requires_grad=True) tensor([-1.3939], requires_grad=True)
# tensor([2.8526], requires_grad=True) tensor([-1.3946], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3954], requires_grad=True)
# tensor([2.8537], requires_grad=True) tensor([-1.3960], requires_grad=True)
# tensor([2.8542], requires_grad=True) tensor([-1.3966], requires_grad=True)
# tensor([2.8546], requires_grad=True) tensor([-1.3972], requires_grad=True)
# tensor([2.8548], requires_grad=True) tensor([-1.3975], requires_grad=True)
# tensor([2.8549], requires_grad=True) tensor([-1.3978], requires_grad=True)
# tensor([2.8549], requires_grad=True) tensor([-1.3979], requires_grad=True)
# tensor([2.8548], requires_grad=True) tensor([-1.3979], requires_grad=True)
# tensor([2.8546], requires_grad=True) tensor([-1.3978], requires_grad=True)
# tensor([2.8543], requires_grad=True) tensor([-1.3977], requires_grad=True)
# tensor([2.8540], requires_grad=True) tensor([-1.3974], requires_grad=True)
# tensor([2.8537], requires_grad=True) tensor([-1.3971], requires_grad=True)
# tensor([2.8534], requires_grad=True) tensor([-1.3967], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3963], requires_grad=True)
# tensor([2.8529], requires_grad=True) tensor([-1.3960], requires_grad=True)
# tensor([2.8527], requires_grad=True) tensor([-1.3956], requires_grad=True)
# tensor([2.8525], requires_grad=True) tensor([-1.3953], requires_grad=True)
# tensor([2.8525], requires_grad=True) tensor([-1.3951], requires_grad=True)
# tensor([2.8524], requires_grad=True) tensor([-1.3949], requires_grad=True)
# tensor([2.8525], requires_grad=True) tensor([-1.3948], requires_grad=True)
# tensor([2.8525], requires_grad=True) tensor([-1.3947], requires_grad=True)
# tensor([2.8526], requires_grad=True) tensor([-1.3947], requires_grad=True)
# tensor([2.8527], requires_grad=True) tensor([-1.3948], requires_grad=True)
# tensor([2.8529], requires_grad=True) tensor([-1.3949], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3950], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3952], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3954], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3956], requires_grad=True)
# tensor([2.8534], requires_grad=True) tensor([-1.3957], requires_grad=True)
# tensor([2.8534], requires_grad=True) tensor([-1.3959], requires_grad=True)
# tensor([2.8534], requires_grad=True) tensor([-1.3960], requires_grad=True)
# tensor([2.8534], requires_grad=True) tensor([-1.3962], requires_grad=True)
# tensor([2.8534], requires_grad=True) tensor([-1.3962], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3963], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3963], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3963], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3962], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3962], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3961], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3960], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3959], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3957], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3956], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3956], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3955], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3955], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3955], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3955], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3955], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3956], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3956], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3957], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3957], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3959], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3959], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3959], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3959], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3959], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3959], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3959], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3959], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3957], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3957], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3957], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3957], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3957], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3957], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3957], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3957], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3957], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8534], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8534], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8534], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8534], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8534], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8534], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8534], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8534], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8534], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8534], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8534], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8534], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# ...
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8534], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8529], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8529], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8534], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8534], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8534], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8530], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8533], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8532], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)
# tensor([2.8531], requires_grad=True) tensor([-1.3958], requires_grad=True)

# %%
fig, axs = plt.subplots(1, 2, figsize=(15,4), sharey=True,sharex=True)
plt.rcParams.update({'font.size': 10})
zz= 25
pr = (0.001/np.pi)


X_star = torch.cat([torch.tensor(xx).reshape(-1,1),torch.tensor(yy).reshape(-1,1),torch.ones(xx.reshape(-1,1).shape)*pr],axis = 1).float()

f_mu, f_sigma = llp(X_star)

f_mu, f_sigma= f_mu.cpu().numpy(), f_sigma.squeeze().sqrt().cpu().numpy()


z_pred = griddata(np.hstack([xx.reshape(-1,1),yy.reshape(-1,1)]), f_mu.flatten(), (xx,yy), method='cubic')
z_pred_var = griddata(np.hstack([xx.reshape(-1,1),yy.reshape(-1,1)]), f_sigma.flatten(), (xx,yy), method='cubic')


axs[0].set_title(fr"t = 0.25 (In-sample)",color = "black")
axs[0].plot(x,z_pred[zz,:],color = "blue", label = f"NN",linewidth=1)
axs[0].fill_between(x.reshape(-1), z_pred[zz,:]+2*z_pred_var[zz,:],z_pred[zz,:]-2*z_pred_var[zz,:],alpha=0.4, color = "red",label = r"NN Uncertainty ($\sigma^{2})$")
axs[0].set_ylabel(r'u(y,t)')
axs[0].legend(frameon = False, prop={'size': 8},loc='lower left')

axs[1].set_title(fr"t = 0.75 (Out-sample)",color = "black")
axs[1].plot(x,z_pred[zz +50,:],color = "blue",linewidth=1)
axs[1].fill_between(x.reshape(-1), z_pred[zz +50,:]+2*z_pred_var[zz +50,:],z_pred[75,:]-2*z_pred_var[zz +50,:],alpha=0.4, color = "red")
#axs[1].legend(frameon = False, prop={'size': 8},loc='lower left')
